# %% [markdown]
# # OPEN API

# %% [markdown]
# ```
# uv add requests
# uv add python-dotenv
# ```

# %% [markdown]
# # 1. 공공데이터포털 OPEN API

# %% [markdown]
# ## 1) API KEY 불러오기

# %%
# 1. .env 파일에 PUBLIC_DATA_API_KEY = "인증키 입력"을 입력한 후 저장
# 2. .env 파일에 있는 ㅐ용 불러오기

from dotenv import load_dotenv
import os

load_dotenv()
print(os.getenv("PUBLIC_DATA_API_KEY"))
# Out:
# l2k6C80iKDQkUG2ghP%2BaEv0xbbFMYss1vUth7eLqXB8CjwO8ctQFzYIzH31vPaW%2BbeKeXjQ2I1Iil3YT0ne%2BTQ%3D%3D

# %% [markdown]
# ## 2) URL 만들기

# %% [markdown]
# ### 방법 1 인코딩 일반 인증키

# %%
# 3. requests 요청
import requests

base_url = "http://apis.data.go.kr/B552061/frequentzoneLgrViolt/getRestFrequentzoneLgrViolt"
serviceKey = os.getenv("PUBLIC_DATA_API_KEY")
searchYearCd=2017
siDo=11
guGun=680
type="json"
numOfRows=10
pageNo=1

url = f"{base_url}?servicekey={serviceKey}&searchYearCd={searchYearCd}&siDo={siDo}&guGun={guGun}&type={type}&numOfRows={numOfRows}&pageNo={pageNo}"
print(url)
# Out:
# http://apis.data.go.kr/B552061/frequentzoneLgrViolt/getRestFrequentzoneLgrViolt?servicekey=l2k6C80iKDQkUG2ghP%2BaEv0xbbFMYss1vUth7eLqXB8CjwO8ctQFzYIzH31vPaW%2BbeKeXjQ2I1Iil3YT0ne%2BTQ%3D%3D&searchYearCd=2017&siDo=11&guGun=680&type=json&numOfRows=10&pageNo=1

# %% [markdown]
# ### 방법 2 디코딩 일반 인증키

# %%
base_url = "http://apis.data.go.kr/B552061/frequentzoneLgrViolt/getRestFrequentzoneLgrViolt"

params = {
    "serviceKey" : os.getenv("PUBLIC_DATA_API_KEY_DE"),
    "searchYearCd" : 2017,
    "siDo" : 11,
    "guGun" : 680,
    "type" : "json",
    "numOfRows" : 10,
    "pageNo" : 1
}

import requests
response = requests.get(base_url, params=params)
print(response.text)
# Out:
# {"resultCode":"00","resultMsg":"NORMAL_CODE","items":{"item":[{"afos_fid":6423519,"afos_id":"01","bjd_cd":"1168010100","spot_cd":"11680001","sido_sgg_nm":"서울특별시 강남구1","spot_nm":"서울특별시 강남구 역삼동(역삼역 부근)","occrrnc_cnt":9,"caslt_cnt":13,"dth_dnv_cnt":0,"se_dnv_cnt":4,"sl_dnv_cnt":7,"wnd_dnv_cnt":2,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[127.03780003,37.50074789],[127.03778277,37.50060885],[127.03773165,37.50047516],[127.03764864,37.50035195],[127.03753692,37.50024395],[127.03740079,37.50015532],[127.03724548,37.50008946],[127.03707697,37.5000489],[127.03690171,37.50003521],[127.03672646,37.5000489],[127.03655794,37.50008946],[127.03640264,37.50015532],[127.03626651,37.50024395],[127.03615479,37.50035195],[127.03607178,37.50047516],[127.03602066,37.50060885],[127.0360034,37.50074789],[127.03602066,37.50088692],[127.03607178,37.50102061],[127.03615479,37.50114383],[127.03626651,37.50125182],[127.03640264,37.50134045],[127.03655794,37.50140631],[127.03672646,37.50144686],[127.03690171,37.50146056],[127.03707697,37.50144686],[127.03724548,37.50140631],[127.03740079,37.50134045],[127.03753692,37.50125182],[127.03764864,37.50114383],[127.03773165,37.50102061],[127.03778277,37.50088692],[127.03780003,37.50074789]]]}","lo_crd":"127.036901714144","la_crd":"37.500747886806"},{"afos_fid":6423685,"afos_id":"01","bjd_cd":"1168010600","spot_cd":"11680002","sido_sgg_nm":"서울특별시 강남구2","spot_nm":"서울특별시 강남구 대치동(학여울역 부근)","occrrnc_cnt":8,"caslt_cnt":12,"dth_dnv_cnt":0,"se_dnv_cnt":1,"sl_dnv_cnt":11,"wnd_dnv_cnt":0,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[127.0715715,37.49668413],[127.07155424,37.49654508],[127.07150312,37.49641138],[127.07142011,37.49628816],[127.07130839,37.49618016],[127.07117226,37.49609152],[127.07101695,37.49602566],[127.07084844,37.4959851],[127.07067318,37.49597141],[127.07049793,37.4959851],[127.07032941,37.49602566],[127.07017411,37.49609152],[127.07003798,37.49618016],[127.06992626,37.49628816],[127.06984325,37.49641138],[127.06979213,37.49654508],[127.06977487,37.49668413],[127.06979213,37.49682317],[127.06984325,37.49695687],[127.06992626,37.49708009],[127.07003798,37.49718809],[127.07017411,37.49727672],[127.07032941,37.49734258],[127.07049793,37.49738314],[127.07067318,37.49739684],[127.07084844,37.49738314],[127.07101695,37.49734258],[127.07117226,37.49727672],[127.07130839,37.49718809],[127.07142011,37.49708009],[127.07150312,37.49695687],[127.07155424,37.49682317],[127.0715715,37.49668413]]]}","lo_crd":"127.070673183322","la_crd":"37.496684126572"},{"afos_fid":6423402,"afos_id":"01","bjd_cd":"1168010100","spot_cd":"11680003","sido_sgg_nm":"서울특별시 강남구3","spot_nm":"서울특별시 강남구 역삼동(교보타워사거리 부근)","occrrnc_cnt":7,"caslt_cnt":12,"dth_dnv_cnt":0,"se_dnv_cnt":6,"sl_dnv_cnt":6,"wnd_dnv_cnt":0,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[127.02537731,37.5043941],[127.02536005,37.50425507],[127.02530893,37.50412138],[127.02522591,37.50399818],[127.0251142,37.50389019],[127.02497807,37.50380156],[127.02482276,37.5037357],[127.02465425,37.50369515],[127.02447899,37.50368146],[127.02430374,37.50369515],[127.02413522,37.5037357],[127.02397992,37.50380156],[127.02384379,37.50389019],[127.02373207,37.50399818],[127.02364906,37.50412138],[127.02359794,37.50425507],[127.02358068,37.5043941],[127.02359794,37.50453313],[127.02364906,37.50466682],[127.02373207,37.50479002],[127.02384379,37.50489801],[127.02397992,37.50498664],[127.02413522,37.50505249],[127.02430374,37.50509304],[127.02447899,37.50510674],[127.02465425,37.50509304],[127.02482276,37.50505249],[127.02497807,37.50498664],[127.0251142,37.50489801],[127.02522591,37.50479002],[127.02530893,37.50466682],[127.02536005,37.50453313],[127.02537731,37.5043941]]]}","lo_crd":"127.024478992912","la_crd":"37.504394100808"},{"afos_fid":6423999,"afos_id":"01","bjd_cd":"1168010100","spot_cd":"11680004","sido_sgg_nm":"서울특별시 강남구4","spot_nm":"서울특별시 강남구 역삼동(강남역 부근)","occrrnc_cnt":7,"caslt_cnt":12,"dth_dnv_cnt":0,"se_dnv_cnt":4,"sl_dnv_cnt":7,"wnd_dnv_cnt":1,"geom_ ...

# %%
# # params를 쓰면 키값 그대로 호출이 가능하기 때문에 인증키를 디코딩으로 설정해야 한다.

# keyword = "컴퓨터"
# url = f"www.example.com/keyword=컴퓨터" # XXXXX 컴퓨터 인코딩해야한다.

# params = {
#     "keyword": "컴퓨터"
# }

# %% [markdown]
# ## 3) 데이터 파악하기

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
response_text =response.text
print(response_text)
# print(response_text["resultCode"])
# Out:
# {"resultCode":"00","resultMsg":"NORMAL_CODE","items":{"item":[{"afos_fid":6423519,"afos_id":"01","bjd_cd":"1168010100","spot_cd":"11680001","sido_sgg_nm":"서울특별시 강남구1","spot_nm":"서울특별시 강남구 역삼동(역삼역 부근)","occrrnc_cnt":9,"caslt_cnt":13,"dth_dnv_cnt":0,"se_dnv_cnt":4,"sl_dnv_cnt":7,"wnd_dnv_cnt":2,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[127.03780003,37.50074789],[127.03778277,37.50060885],[127.03773165,37.50047516],[127.03764864,37.50035195],[127.03753692,37.50024395],[127.03740079,37.50015532],[127.03724548,37.50008946],[127.03707697,37.5000489],[127.03690171,37.50003521],[127.03672646,37.5000489],[127.03655794,37.50008946],[127.03640264,37.50015532],[127.03626651,37.50024395],[127.03615479,37.50035195],[127.03607178,37.50047516],[127.03602066,37.50060885],[127.0360034,37.50074789],[127.03602066,37.50088692],[127.03607178,37.50102061],[127.03615479,37.50114383],[127.03626651,37.50125182],[127.03640264,37.50134045],[127.03655794,37.50140631],[127.03672646,37.50144686],[127.03690171,37.50146056],[127.03707697,37.50144686],[127.03724548,37.50140631],[127.03740079,37.50134045],[127.03753692,37.50125182],[127.03764864,37.50114383],[127.03773165,37.50102061],[127.03778277,37.50088692],[127.03780003,37.50074789]]]}","lo_crd":"127.036901714144","la_crd":"37.500747886806"},{"afos_fid":6423685,"afos_id":"01","bjd_cd":"1168010600","spot_cd":"11680002","sido_sgg_nm":"서울특별시 강남구2","spot_nm":"서울특별시 강남구 대치동(학여울역 부근)","occrrnc_cnt":8,"caslt_cnt":12,"dth_dnv_cnt":0,"se_dnv_cnt":1,"sl_dnv_cnt":11,"wnd_dnv_cnt":0,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[127.0715715,37.49668413],[127.07155424,37.49654508],[127.07150312,37.49641138],[127.07142011,37.49628816],[127.07130839,37.49618016],[127.07117226,37.49609152],[127.07101695,37.49602566],[127.07084844,37.4959851],[127.07067318,37.49597141],[127.07049793,37.4959851],[127.07032941,37.49602566],[127.07017411,37.49609152],[127.07003798,37.49618016],[127.06992626,37.49628816],[127.06984325,37.49641138],[127.06979213,37.49654508],[127.06977487,37.49668413],[127.06979213,37.49682317],[127.06984325,37.49695687],[127.06992626,37.49708009],[127.07003798,37.49718809],[127.07017411,37.49727672],[127.07032941,37.49734258],[127.07049793,37.49738314],[127.07067318,37.49739684],[127.07084844,37.49738314],[127.07101695,37.49734258],[127.07117226,37.49727672],[127.07130839,37.49718809],[127.07142011,37.49708009],[127.07150312,37.49695687],[127.07155424,37.49682317],[127.0715715,37.49668413]]]}","lo_crd":"127.070673183322","la_crd":"37.496684126572"},{"afos_fid":6423402,"afos_id":"01","bjd_cd":"1168010100","spot_cd":"11680003","sido_sgg_nm":"서울특별시 강남구3","spot_nm":"서울특별시 강남구 역삼동(교보타워사거리 부근)","occrrnc_cnt":7,"caslt_cnt":12,"dth_dnv_cnt":0,"se_dnv_cnt":6,"sl_dnv_cnt":6,"wnd_dnv_cnt":0,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[127.02537731,37.5043941],[127.02536005,37.50425507],[127.02530893,37.50412138],[127.02522591,37.50399818],[127.0251142,37.50389019],[127.02497807,37.50380156],[127.02482276,37.5037357],[127.02465425,37.50369515],[127.02447899,37.50368146],[127.02430374,37.50369515],[127.02413522,37.5037357],[127.02397992,37.50380156],[127.02384379,37.50389019],[127.02373207,37.50399818],[127.02364906,37.50412138],[127.02359794,37.50425507],[127.02358068,37.5043941],[127.02359794,37.50453313],[127.02364906,37.50466682],[127.02373207,37.50479002],[127.02384379,37.50489801],[127.02397992,37.50498664],[127.02413522,37.50505249],[127.02430374,37.50509304],[127.02447899,37.50510674],[127.02465425,37.50509304],[127.02482276,37.50505249],[127.02497807,37.50498664],[127.0251142,37.50489801],[127.02522591,37.50479002],[127.02530893,37.50466682],[127.02536005,37.50453313],[127.02537731,37.5043941]]]}","lo_crd":"127.024478992912","la_crd":"37.504394100808"},{"afos_fid":6423999,"afos_id":"01","bjd_cd":"1168010100","spot_cd":"11680004","sido_sgg_nm":"서울특별시 강남구4","spot_nm":"서울특별시 강남구 역삼동(강남역 부근)","occrrnc_cnt":7,"caslt_cnt":12,"dth_dnv_cnt":0,"se_dnv_cnt":4,"sl_dnv_cnt":7,"wnd_dnv_cnt":1,"geom_ ...

# %%
response_json = response.json()
print(response_json)
print()
print(response_json["resultCode"])
# Out:
# {'resultCode': '00', 'resultMsg': 'NORMAL_CODE', 'items': {'item': [{'afos_fid': 6423519, 'afos_id': '01', 'bjd_cd': '1168010100', 'spot_cd': '11680001', 'sido_sgg_nm': '서울특별시 강남구1', 'spot_nm': '서울특별시 강남구 역삼동(역삼역 부근)', 'occrrnc_cnt': 9, 'caslt_cnt': 13, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 4, 'sl_dnv_cnt': 7, 'wnd_dnv_cnt': 2, 'geom_json': '{"type":"Polygon","coordinates":[[[127.03780003,37.50074789],[127.03778277,37.50060885],[127.03773165,37.50047516],[127.03764864,37.50035195],[127.03753692,37.50024395],[127.03740079,37.50015532],[127.03724548,37.50008946],[127.03707697,37.5000489],[127.03690171,37.50003521],[127.03672646,37.5000489],[127.03655794,37.50008946],[127.03640264,37.50015532],[127.03626651,37.50024395],[127.03615479,37.50035195],[127.03607178,37.50047516],[127.03602066,37.50060885],[127.0360034,37.50074789],[127.03602066,37.50088692],[127.03607178,37.50102061],[127.03615479,37.50114383],[127.03626651,37.50125182],[127.03640264,37.50134045],[127.03655794,37.50140631],[127.03672646,37.50144686],[127.03690171,37.50146056],[127.03707697,37.50144686],[127.03724548,37.50140631],[127.03740079,37.50134045],[127.03753692,37.50125182],[127.03764864,37.50114383],[127.03773165,37.50102061],[127.03778277,37.50088692],[127.03780003,37.50074789]]]}', 'lo_crd': '127.036901714144', 'la_crd': '37.500747886806'}, {'afos_fid': 6423685, 'afos_id': '01', 'bjd_cd': '1168010600', 'spot_cd': '11680002', 'sido_sgg_nm': '서울특별시 강남구2', 'spot_nm': '서울특별시 강남구 대치동(학여울역 부근)', 'occrrnc_cnt': 8, 'caslt_cnt': 12, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 1, 'sl_dnv_cnt': 11, 'wnd_dnv_cnt': 0, 'geom_json': '{"type":"Polygon","coordinates":[[[127.0715715,37.49668413],[127.07155424,37.49654508],[127.07150312,37.49641138],[127.07142011,37.49628816],[127.07130839,37.49618016],[127.07117226,37.49609152],[127.07101695,37.49602566],[127.07084844,37.4959851],[127.07067318,37.49597141],[127.07049793,37.4959851],[127.07032941,37.49602566],[127.07017411,37.49609152],[127.07003798,37.49618016],[127.06992626,37.49628816],[127.06984325,37.49641138],[127.06979213,37.49654508],[127.06977487,37.49668413],[127.06979213,37.49682317],[127.06984325,37.49695687],[127.06992626,37.49708009],[127.07003798,37.49718809],[127.07017411,37.49727672],[127.07032941,37.49734258],[127.07049793,37.49738314],[127.07067318,37.49739684],[127.07084844,37.49738314],[127.07101695,37.49734258],[127.07117226,37.49727672],[127.07130839,37.49718809],[127.07142011,37.49708009],[127.07150312,37.49695687],[127.07155424,37.49682317],[127.0715715,37.49668413]]]}', 'lo_crd': '127.070673183322', 'la_crd': '37.496684126572'}, {'afos_fid': 6423402, 'afos_id': '01', 'bjd_cd': '1168010100', 'spot_cd': '11680003', 'sido_sgg_nm': '서울특별시 강남구3', 'spot_nm': '서울특별시 강남구 역삼동(교보타워사거리 부근)', 'occrrnc_cnt': 7, 'caslt_cnt': 12, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 6, 'sl_dnv_cnt': 6, 'wnd_dnv_cnt': 0, 'geom_json': '{"type":"Polygon","coordinates":[[[127.02537731,37.5043941],[127.02536005,37.50425507],[127.02530893,37.50412138],[127.02522591,37.50399818],[127.0251142,37.50389019],[127.02497807,37.50380156],[127.02482276,37.5037357],[127.02465425,37.50369515],[127.02447899,37.50368146],[127.02430374,37.50369515],[127.02413522,37.5037357],[127.02397992,37.50380156],[127.02384379,37.50389019],[127.02373207,37.50399818],[127.02364906,37.50412138],[127.02359794,37.50425507],[127.02358068,37.5043941],[127.02359794,37.50453313],[127.02364906,37.50466682],[127.02373207,37.50479002],[127.02384379,37.50489801],[127.02397992,37.50498664],[127.02413522,37.50505249],[127.02430374,37.50509304],[127.02447899,37.50510674],[127.02465425,37.50509304],[127.02482276,37.50505249],[127.02497807,37.50498664],[127.0251142,37.50489801],[127.02522591,37.50479002],[127.02530893,37.50466682],[127.02536005,37.50453313],[127.02537731,37.5043941]]]}', 'lo_crd': '127.024478992912', 'la_crd': '37.504394100808'}, {'afos_fid': 6423999, 'afos_id': '01', 'bjd_cd': '1168010100', 'spot_cd': '11680004', 'sido_sgg_nm': '서울특별시 강남구4', 'spot_nm': '서울특별시 강남구 역삼동(강남역 부근)', 'occrrnc_ ...
#
# 00

# %%
# (미션) response_json의 키는 총 몇개 인가요?
# (미션) response_json의 키들은 무슨 의미를 갖고 있나요?
# (미션) items키의 값의 type은 무엇인가요?
# (미션) items키의 item 안에는 어떤 값이 들어있나요?

# %%
test_dict = {"가" : {"A" : 1}, "나" : 1, "다" : 0}
print(test_dict.keys())
print(test_dict["가"]["A"])
# Out:
# dict_keys(['가', '나', '다'])
# 1

# %%
response_json
# Out:
# {'resultCode': '00',
#  'resultMsg': 'NORMAL_CODE',
#  'items': {'item': [{'afos_fid': 6423519,
#     'afos_id': '01',
#     'bjd_cd': '1168010100',
#     'spot_cd': '11680001',
#     'sido_sgg_nm': '서울특별시 강남구1',
#     'spot_nm': '서울특별시 강남구 역삼동(역삼역 부근)',
#     'occrrnc_cnt': 9,
#     'caslt_cnt': 13,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 4,
#     'sl_dnv_cnt': 7,
#     'wnd_dnv_cnt': 2,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.03780003,37.50074789],[127.03778277,37.50060885],[127.03773165,37.50047516],[127.03764864,37.50035195],[127.03753692,37.50024395],[127.03740079,37.50015532],[127.03724548,37.50008946],[127.03707697,37.5000489],[127.03690171,37.50003521],[127.03672646,37.5000489],[127.03655794,37.50008946],[127.03640264,37.50015532],[127.03626651,37.50024395],[127.03615479,37.50035195],[127.03607178,37.50047516],[127.03602066,37.50060885],[127.0360034,37.50074789],[127.03602066,37.50088692],[127.03607178,37.50102061],[127.03615479,37.50114383],[127.03626651,37.50125182],[127.03640264,37.50134045],[127.03655794,37.50140631],[127.03672646,37.50144686],[127.03690171,37.50146056],[127.03707697,37.50144686],[127.03724548,37.50140631],[127.03740079,37.50134045],[127.03753692,37.50125182],[127.03764864,37.50114383],[127.03773165,37.50102061],[127.03778277,37.50088692],[127.03780003,37.50074789]]]}',
#     'lo_crd': '127.036901714144',
#     'la_crd': '37.500747886806'},
#    {'afos_fid': 6423685,
#     'afos_id': '01',
#     'bjd_cd': '1168010600',
#     'spot_cd': '11680002',
#     'sido_sgg_nm': '서울특별시 강남구2',
#     'spot_nm': '서울특별시 강남구 대치동(학여울역 부근)',
#     'occrrnc_cnt': 8,
#     'caslt_cnt': 12,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 1,
#     'sl_dnv_cnt': 11,
#     'wnd_dnv_cnt': 0,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.0715715,37.49668413],[127.07155424,37.49654508],[127.07150312,37.49641138],[127.07142011,37.49628816],[127.07130839,37.49618016],[127.07117226,37.49609152],[127.07101695,37.49602566],[127.07084844,37.4959851],[127.07067318,37.49597141],[127.07049793,37.4959851],[127.07032941,37.49602566],[127.07017411,37.49609152],[127.07003798,37.49618016],[127.06992626,37.49628816],[127.06984325,37.49641138],[127.06979213,37.49654508],[127.06977487,37.49668413],[127.06979213,37.49682317],[127.06984325,37.49695687],[127.06992626,37.49708009],[127.07003798,37.49718809],[127.07017411,37.49727672],[127.07032941,37.49734258],[127.07049793,37.49738314],[127.07067318,37.49739684],[127.07084844,37.49738314],[127.07101695,37.49734258],[127.07117226,37.49727672],[127.07130839,37.49718809],[127.07142011,37.49708009],[127.07150312,37.49695687],[127.07155424,37.49682317],[127.0715715,37.49668413]]]}',
#     'lo_crd': '127.070673183322',
#     'la_crd': '37.496684126572'},
#    {'afos_fid': 6423402,
#     'afos_id': '01',
#     'bjd_cd': '1168010100',
#     'spot_cd': '11680003',
#     'sido_sgg_nm': '서울특별시 강남구3',
#     'spot_nm': '서울특별시 강남구 역삼동(교보타워사거리 부근)',
#     'occrrnc_cnt': 7,
#     'caslt_cnt': 12,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 6,
#     'sl_dnv_cnt': 6,
#     'wnd_dnv_cnt': 0,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.02537731,37.5043941],[127.02536005,37.50425507],[127.02530893,37.50412138],[127.02522591,37.50399818],[127.0251142,37.50389019],[127.02497807,37.50380156],[127.02482276,37.5037357],[127.02465425,37.50369515],[127.02447899,37.50368146],[127.02430374,37.50369515],[127.02413522,37.5037357],[127.02397992,37.50380156],[127.02384379,37.50389019],[127.02373207,37.50399818],[127.02364906,37.50412138],[127.02359794,37.50425507],[127.02358068,37.5043941],[127.02359794,37.50453313],[127.02364906,37.50466682],[127.02373207,37.50479002],[127.02384379,37.50489801],[127.02397992,37.50498664],[127.02413522,37.50505249],[127.02430374,37.50509304],[127.02447899,37.50510674],[127.02465425,37.50509304],[127.02482276,37.50505249],[127.02497807,37.50498664],[127.0251142,37.50489801],[127.02522591,37.50479002],[127.02530893,37.50466682],[127.02536005,37.50453313],[127.02537731,37.5043941]]]}',
#     'lo_crd': '127.024478992912',
#     'la_crd': '37.504394100808'},
#    {'afos_fid': 6423999,
#     'afos_id': '01',
#     'bjd_cd': '1168010100',
#     'spot_cd': '11680004',
#     'sido_sgg_nm': '서울특별시 강남구4',
#     'spot_nm': '서울특별시 강남구 역삼동(강남역 부근)',
#     'occrrnc_cnt': 7,
#     'caslt_cnt': 12,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 4,
#     'sl_dnv_cnt': 7,
#     'wnd_dnv_cnt': 1,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.02814229,37.49798321],[127.02812503,37.49784417],[127.02807391,37.49771047],[127.0279909,37.49758725],[127.02787918,37.49747925],[127.02774306,37.49739062],[127.02758775,37.49732476],[127.02741923,37.4972842],[127.02724398,37.4972705],[127.02706873,37.4972842],[127.02690021,37.49732476],[127.0267449,37.49739062],[127.02660877,37.49747925],[127.02649706,37.49758725],[127.02641404,37.49771047],[127.02636292,37.49784417],[127.02634566,37.49798321],[127.02636292,37.49812225],[127.02641404,37.49825595],[127.02649706,37.49837916],[127.02660877,37.49848716],[127.0267449,37.4985758],[127.02690021,37.49864166],[127.02706873,37.49868221],[127.02724398,37.49869591],[127.02741923,37.49868221],[127.02758775,37.49864166],[127.02774306,37.4985758],[127.02787918,37.49848716],[127.0279909,37.49837916],[127.02807391,37.49825595],[127.02812503,37.49812225],[127.02814229,37.49798321]]]}',
#     'lo_crd': '127.027243979227',
#     'la_crd': '37.497983208959'},
#    {'afos_fid': 6423498,
#     'afos_id': '01',
#     'bjd_cd': '1168010500',
#     'spot_cd': '11680005',
#     'sido_sgg_nm': '서울특별시 강남구5',
#     'spot_nm': '서울특별시 강남구 삼성동(코엑스 부근)',
#     'occrrnc_cnt': 7,
#     'caslt_cnt': 8,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 2,
#     'sl_dnv_cnt': 5,
#     'wnd_dnv_cnt': 1,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.06116079,37.51452879],[127.06114353,37.51438978],[127.06109241,37.51425612],[127.06100939,37.51413293],[127.06089768,37.51402495],[127.06076155,37.51393633],[127.06060624,37.51387049],[127.06043773,37.51382994],[127.06026247,37.51381625],[127.06008722,37.51382994],[127.0599187,37.51387049],[127.0597634,37.51393633],[127.05962727,37.51402495],[127.05951555,37.51413293],[127.05943254,37.51425612],[127.05938142,37.51438978],[127.05936416,37.51452879],[127.05938142,37.5146678],[127.05943254,37.51480147],[127.05951555,37.51492466],[127.05962727,37.51503264],[127.0597634,37.51512125],[127.0599187,37.51518709],[127.06008722,37.51522764],[127.06026247,37.51524133],[127.06043773,37.51522764],[127.06060624,37.51518709],[127.06076155,37.51512125],[127.06089768,37.51503264],[127.06100939,37.51492466],[127.06109241,37.51480147],[127.06114353,37.5146678],[127.06116079,37.51452879]]]}',
#     'lo_crd': '127.060262473036',
#     'la_crd': '37.514528793870'},
#    {'afos_fid': 6423385,
#     'afos_id': '01',
#     'bjd_cd': '1168010500',
#     'spot_cd': '11680006',
#     'sido_sgg_nm': '서울특별시 강남구6',
#     'spot_nm': '서울특별시 강남구 삼성동(강남구청역 부근)',
#     'occrrnc_cnt': 6,
#     'caslt_cnt': 11,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 9,
#     'sl_dnv_cnt': 2,
#     'wnd_dnv_cnt': 0,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.04238299,37.51723357],[127.04236573,37.51709457],[127.04231461,37.5169609],[127.0422316,37.51683772],[127.04211988,37.51672974],[127.04198375,37.51664113],[127.04182845,37.51657529],[127.04165993,37.51653474],[127.04148468,37.51652105],[127.04130942,37.51653474],[127.04114091,37.51657529],[127.0409856,37.51664113],[127.04084947,37.51672974],[127.04073775,37.51683772],[127.04065474,37.5169609],[127.04060362,37.51709457],[127.04058636,37.51723357],[127.04060362,37.51737258],[127.04065474,37.51750624],[127.04073775,37.51762942],[127.04084947,37.51773739],[127.0409856,37.517826],[127.04114091,37.51789185],[127.04130942,37.51793239],[127.04148468,37.51794608],[127.04165993,37.51793239],[127.04182845,37.51789185],[127.04198375,37.517826],[127.04211988,37.51773739],[127.0422316,37.51762942],[127.04231461,37.51750624],[127.04236573,37.51737258],[127.04238299,37.51723357]]]}',
#     'lo_crd': '127.041484676378',
#     'la_crd': '37.517233570574'},
#    {'afos_fid': 6423441,
#     'afos_id': '01',
#     'bjd_cd': '1168010100',
#     'spot_cd': '11680007',
#     'sido_sgg_nm': '서울특별시 강남구7',
#     'spot_nm': '서울특별시 강남구 역삼동(역삼세무서 부근)',
#     'occrrnc_cnt': 6,
#     'caslt_cnt': 7,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 4,
#     'sl_dnv_cnt': 3,
#     'wnd_dnv_cnt': 0,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.04016068,37.49585372],[127.04014342,37.49571468],[127.0400923,37.49558098],[127.04000929,37.49545775],[127.03989757,37.49534975],[127.03976145,37.49526111],[127.03960614,37.49519525],[127.03943762,37.49515469],[127.03926237,37.495141],[127.03908712,37.49515469],[127.0389186,37.49519525],[127.03876329,37.49526111],[127.03862716,37.49534975],[127.03851545,37.49545775],[127.03843243,37.49558098],[127.03838131,37.49571468],[127.03836405,37.49585372],[127.03838131,37.49599277],[127.03843243,37.49612647],[127.03851545,37.49624969],[127.03862716,37.49635769],[127.03876329,37.49644633],[127.0389186,37.49651219],[127.03908712,37.49655275],[127.03926237,37.49656644],[127.03943762,37.49655275],[127.03960614,37.49651219],[127.03976145,37.49644633],[127.03989757,37.49635769],[127.04000929,37.49624969],[127.0400923,37.49612647],[127.04014342,37.49599277],[127.04016068,37.49585372]]]}',
#     'lo_crd': '127.039262367965',
#     'la_crd': '37.495853722272'},
#    {'afos_fid': 6424000,
#     'afos_id': '01',
#     'bjd_cd': '1168011500',
#     'spot_cd': '11680008',
#     'sido_sgg_nm': '서울특별시 강남구8',
#     'spot_nm': '서울특별시 강남구 수서동(수서역 부근)',
#     'occrrnc_cnt': 6,
#     'caslt_cnt': 12,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 3,
#     'sl_dnv_cnt': 9,
#     'wnd_dnv_cnt': 0,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.10280619,37.48749549],[127.10278893,37.48735643],[127.10273781,37.48722271],[127.1026548,37.48709948],[127.10254308,37.48699146],[127.10240695,37.48690282],[127.10225165,37.48683695],[127.10208313,37.48679638],[127.10190788,37.48678269],[127.10173262,37.48679638],[127.10156411,37.48683695],[127.1014088,37.48690282],[127.10127267,37.48699146],[127.10116095,37.48709948],[127.10107794,37.48722271],[127.10102682,37.48735643],[127.10100956,37.48749549],[127.10102682,37.48763455],[127.10107794,37.48776827],[127.10116095,37.4878915],[127.10127267,37.48799952],[127.1014088,37.48808816],[127.10156411,37.48815403],[127.10173262,37.48819459],[127.10190788,37.48820829],[127.10208313,37.48819459],[127.10225165,37.48815403],[127.10240695,37.48808816],[127.10254308,37.48799952],[127.1026548,37.4878915],[127.10273781,37.48776827],[127.10278893,37.48763455],[127.10280619,37.48749549]]]}',
#     'lo_crd': '127.101907876348',
#     'la_crd': '37.487495491525'},
#    {'afos_fid': 6424126,
#     'afos_id': '01',
#     'bjd_cd': '1168010100',
#     'spot_cd': '11680009',
#     'sido_sgg_nm': '서울특별시 강남구9',
#     'spot_nm': '서울특별시 강남구 역삼동(경복아파트 부근)',
#     'occrrnc_cnt': 6,
#     'caslt_cnt': 9,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 2,
#     'sl_dnv_cnt': 7,
#     'wnd_dnv_cnt': 0,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.03962528,37.50871515],[127.03960802,37.50857613],[127.0395569,37.50844245],[127.03947389,37.50831925],[127.03936217,37.50821126],[127.03922604,37.50812264],[127.03907074,37.50805679],[127.03890222,37.50801624],[127.03872697,37.50800255],[127.03855171,37.50801624],[127.0383832,37.50805679],[127.03822789,37.50812264],[127.03809176,37.50821126],[127.03798005,37.50831925],[127.03789703,37.50844245],[127.03784591,37.50857613],[127.03782865,37.50871515],[127.03784591,37.50885417],[127.03789703,37.50898785],[127.03798005,37.50911105],[127.03809176,37.50921903],[127.03822789,37.50930765],[127.0383832,37.5093735],[127.03855171,37.50941405],[127.03872697,37.50942774],[127.03890222,37.50941405],[127.03907074,37.5093735],[127.03922604,37.50930765],[127.03936217,37.50921903],[127.03947389,37.50911105],[127.0395569,37.50898785],[127.03960802,37.50885417],[127.03962528,37.50871515]]]}',
#     'lo_crd': '127.038726967377',
#     'la_crd': '37.508715148087'},
#    {'afos_fid': 6424335,
#     'afos_id': '02',
#     'bjd_cd': '1168011800',
#     'spot_cd': '11680001',
#     'sido_sgg_nm': '서울특별시 강남구1',
#     'spot_nm': '서울특별시 강남구 도곡동(옥신타워 부근)',
#     'occrrnc_cnt': 5,
#     'caslt_cnt': 6,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 3,
#     'sl_dnv_cnt': 3,
#     'wnd_dnv_cnt': 0,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.03687945,37.49028847],[127.03682767,37.48987131],[127.03667431,37.48947017],[127.03642527,37.48910048],[127.03609012,37.48877644],[127.03568174,37.4885105],[127.03521582,37.4883129],[127.03471027,37.48819121],[127.03418451,37.48815012],[127.03365875,37.48819121],[127.0331532,37.4883129],[127.03268728,37.4885105],[127.03227889,37.48877644],[127.03194374,37.48910048],[127.0316947,37.48947017],[127.03154134,37.48987131],[127.03148956,37.49028847],[127.03154134,37.49070564],[127.0316947,37.49110677],[127.03194374,37.49147645],[127.03227889,37.49180048],[127.03268728,37.4920664],[127.0331532,37.492264],[127.03365875,37.49238568],[127.03418451,37.49242677],[127.03471027,37.49238568],[127.03521582,37.492264],[127.03568174,37.4920664],[127.03609012,37.49180048],[127.03642527,37.49147645],[127.03667431,37.49110677],[127.03682767,37.49070564],[127.03687945,37.49028847]]]}',
#     'lo_crd': '127.034184507910',
#     'la_crd': '37.490288473735'}]},
#  'totalCount': 12,
#  'numOfRows': 10,
#  'pageNo': 1}

# %%
response_json.keys()
# resultCode: 결과 코드
# resultMsg: 결과 메세지
# items
# totalCount: 총건수
# numOfRows: 검색 건수
# pageNo: 페이지 번호
# Out:
# dict_keys(['resultCode', 'resultMsg', 'items', 'totalCount', 'numOfRows', 'pageNo'])

# %%
item_value = response_json["items"]["item"] # 리스트
item_value
# Out:
# [{'afos_fid': 6423519,
#   'afos_id': '01',
#   'bjd_cd': '1168010100',
#   'spot_cd': '11680001',
#   'sido_sgg_nm': '서울특별시 강남구1',
#   'spot_nm': '서울특별시 강남구 역삼동(역삼역 부근)',
#   'occrrnc_cnt': 9,
#   'caslt_cnt': 13,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 4,
#   'sl_dnv_cnt': 7,
#   'wnd_dnv_cnt': 2,
#   'geom_json': '{"type":"Polygon","coordinates":[[[127.03780003,37.50074789],[127.03778277,37.50060885],[127.03773165,37.50047516],[127.03764864,37.50035195],[127.03753692,37.50024395],[127.03740079,37.50015532],[127.03724548,37.50008946],[127.03707697,37.5000489],[127.03690171,37.50003521],[127.03672646,37.5000489],[127.03655794,37.50008946],[127.03640264,37.50015532],[127.03626651,37.50024395],[127.03615479,37.50035195],[127.03607178,37.50047516],[127.03602066,37.50060885],[127.0360034,37.50074789],[127.03602066,37.50088692],[127.03607178,37.50102061],[127.03615479,37.50114383],[127.03626651,37.50125182],[127.03640264,37.50134045],[127.03655794,37.50140631],[127.03672646,37.50144686],[127.03690171,37.50146056],[127.03707697,37.50144686],[127.03724548,37.50140631],[127.03740079,37.50134045],[127.03753692,37.50125182],[127.03764864,37.50114383],[127.03773165,37.50102061],[127.03778277,37.50088692],[127.03780003,37.50074789]]]}',
#   'lo_crd': '127.036901714144',
#   'la_crd': '37.500747886806'},
#  {'afos_fid': 6423685,
#   'afos_id': '01',
#   'bjd_cd': '1168010600',
#   'spot_cd': '11680002',
#   'sido_sgg_nm': '서울특별시 강남구2',
#   'spot_nm': '서울특별시 강남구 대치동(학여울역 부근)',
#   'occrrnc_cnt': 8,
#   'caslt_cnt': 12,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 1,
#   'sl_dnv_cnt': 11,
#   'wnd_dnv_cnt': 0,
#   'geom_json': '{"type":"Polygon","coordinates":[[[127.0715715,37.49668413],[127.07155424,37.49654508],[127.07150312,37.49641138],[127.07142011,37.49628816],[127.07130839,37.49618016],[127.07117226,37.49609152],[127.07101695,37.49602566],[127.07084844,37.4959851],[127.07067318,37.49597141],[127.07049793,37.4959851],[127.07032941,37.49602566],[127.07017411,37.49609152],[127.07003798,37.49618016],[127.06992626,37.49628816],[127.06984325,37.49641138],[127.06979213,37.49654508],[127.06977487,37.49668413],[127.06979213,37.49682317],[127.06984325,37.49695687],[127.06992626,37.49708009],[127.07003798,37.49718809],[127.07017411,37.49727672],[127.07032941,37.49734258],[127.07049793,37.49738314],[127.07067318,37.49739684],[127.07084844,37.49738314],[127.07101695,37.49734258],[127.07117226,37.49727672],[127.07130839,37.49718809],[127.07142011,37.49708009],[127.07150312,37.49695687],[127.07155424,37.49682317],[127.0715715,37.49668413]]]}',
#   'lo_crd': '127.070673183322',
#   'la_crd': '37.496684126572'},
#  {'afos_fid': 6423402,
#   'afos_id': '01',
#   'bjd_cd': '1168010100',
#   'spot_cd': '11680003',
#   'sido_sgg_nm': '서울특별시 강남구3',
#   'spot_nm': '서울특별시 강남구 역삼동(교보타워사거리 부근)',
#   'occrrnc_cnt': 7,
#   'caslt_cnt': 12,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 6,
#   'sl_dnv_cnt': 6,
#   'wnd_dnv_cnt': 0,
#   'geom_json': '{"type":"Polygon","coordinates":[[[127.02537731,37.5043941],[127.02536005,37.50425507],[127.02530893,37.50412138],[127.02522591,37.50399818],[127.0251142,37.50389019],[127.02497807,37.50380156],[127.02482276,37.5037357],[127.02465425,37.50369515],[127.02447899,37.50368146],[127.02430374,37.50369515],[127.02413522,37.5037357],[127.02397992,37.50380156],[127.02384379,37.50389019],[127.02373207,37.50399818],[127.02364906,37.50412138],[127.02359794,37.50425507],[127.02358068,37.5043941],[127.02359794,37.50453313],[127.02364906,37.50466682],[127.02373207,37.50479002],[127.02384379,37.50489801],[127.02397992,37.50498664],[127.02413522,37.50505249],[127.02430374,37.50509304],[127.02447899,37.50510674],[127.02465425,37.50509304],[127.02482276,37.50505249],[127.02497807,37.50498664],[127.0251142,37.50489801],[127.02522591,37.50479002],[127.02530893,37.50466682],[127.02536005,37.50453313],[127.02537731,37.5043941]]]}',
#   'lo_crd': '127.024478992912',
#   'la_crd': '37.504394100808'},
#  {'afos_fid': 6423999,
#   'afos_id': '01',
#   'bjd_cd': '1168010100',
#   'spot_cd': '11680004',
#   'sido_sgg_nm': '서울특별시 강남구4',
#   'spot_nm': '서울특별시 강남구 역삼동(강남역 부근)',
#   'occrrnc_cnt': 7,
#   'caslt_cnt': 12,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 4,
#   'sl_dnv_cnt': 7,
#   'wnd_dnv_cnt': 1,
#   'geom_json': '{"type":"Polygon","coordinates":[[[127.02814229,37.49798321],[127.02812503,37.49784417],[127.02807391,37.49771047],[127.0279909,37.49758725],[127.02787918,37.49747925],[127.02774306,37.49739062],[127.02758775,37.49732476],[127.02741923,37.4972842],[127.02724398,37.4972705],[127.02706873,37.4972842],[127.02690021,37.49732476],[127.0267449,37.49739062],[127.02660877,37.49747925],[127.02649706,37.49758725],[127.02641404,37.49771047],[127.02636292,37.49784417],[127.02634566,37.49798321],[127.02636292,37.49812225],[127.02641404,37.49825595],[127.02649706,37.49837916],[127.02660877,37.49848716],[127.0267449,37.4985758],[127.02690021,37.49864166],[127.02706873,37.49868221],[127.02724398,37.49869591],[127.02741923,37.49868221],[127.02758775,37.49864166],[127.02774306,37.4985758],[127.02787918,37.49848716],[127.0279909,37.49837916],[127.02807391,37.49825595],[127.02812503,37.49812225],[127.02814229,37.49798321]]]}',
#   'lo_crd': '127.027243979227',
#   'la_crd': '37.497983208959'},
#  {'afos_fid': 6423498,
#   'afos_id': '01',
#   'bjd_cd': '1168010500',
#   'spot_cd': '11680005',
#   'sido_sgg_nm': '서울특별시 강남구5',
#   'spot_nm': '서울특별시 강남구 삼성동(코엑스 부근)',
#   'occrrnc_cnt': 7,
#   'caslt_cnt': 8,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 2,
#   'sl_dnv_cnt': 5,
#   'wnd_dnv_cnt': 1,
#   'geom_json': '{"type":"Polygon","coordinates":[[[127.06116079,37.51452879],[127.06114353,37.51438978],[127.06109241,37.51425612],[127.06100939,37.51413293],[127.06089768,37.51402495],[127.06076155,37.51393633],[127.06060624,37.51387049],[127.06043773,37.51382994],[127.06026247,37.51381625],[127.06008722,37.51382994],[127.0599187,37.51387049],[127.0597634,37.51393633],[127.05962727,37.51402495],[127.05951555,37.51413293],[127.05943254,37.51425612],[127.05938142,37.51438978],[127.05936416,37.51452879],[127.05938142,37.5146678],[127.05943254,37.51480147],[127.05951555,37.51492466],[127.05962727,37.51503264],[127.0597634,37.51512125],[127.0599187,37.51518709],[127.06008722,37.51522764],[127.06026247,37.51524133],[127.06043773,37.51522764],[127.06060624,37.51518709],[127.06076155,37.51512125],[127.06089768,37.51503264],[127.06100939,37.51492466],[127.06109241,37.51480147],[127.06114353,37.5146678],[127.06116079,37.51452879]]]}',
#   'lo_crd': '127.060262473036',
#   'la_crd': '37.514528793870'},
#  {'afos_fid': 6423385,
#   'afos_id': '01',
#   'bjd_cd': '1168010500',
#   'spot_cd': '11680006',
#   'sido_sgg_nm': '서울특별시 강남구6',
#   'spot_nm': '서울특별시 강남구 삼성동(강남구청역 부근)',
#   'occrrnc_cnt': 6,
#   'caslt_cnt': 11,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 9,
#   'sl_dnv_cnt': 2,
#   'wnd_dnv_cnt': 0,
#   'geom_json': '{"type":"Polygon","coordinates":[[[127.04238299,37.51723357],[127.04236573,37.51709457],[127.04231461,37.5169609],[127.0422316,37.51683772],[127.04211988,37.51672974],[127.04198375,37.51664113],[127.04182845,37.51657529],[127.04165993,37.51653474],[127.04148468,37.51652105],[127.04130942,37.51653474],[127.04114091,37.51657529],[127.0409856,37.51664113],[127.04084947,37.51672974],[127.04073775,37.51683772],[127.04065474,37.5169609],[127.04060362,37.51709457],[127.04058636,37.51723357],[127.04060362,37.51737258],[127.04065474,37.51750624],[127.04073775,37.51762942],[127.04084947,37.51773739],[127.0409856,37.517826],[127.04114091,37.51789185],[127.04130942,37.51793239],[127.04148468,37.51794608],[127.04165993,37.51793239],[127.04182845,37.51789185],[127.04198375,37.517826],[127.04211988,37.51773739],[127.0422316,37.51762942],[127.04231461,37.51750624],[127.04236573,37.51737258],[127.04238299,37.51723357]]]}',
#   'lo_crd': '127.041484676378',
#   'la_crd': '37.517233570574'},
#  {'afos_fid': 6423441,
#   'afos_id': '01',
#   'bjd_cd': '1168010100',
#   'spot_cd': '11680007',
#   'sido_sgg_nm': '서울특별시 강남구7',
#   'spot_nm': '서울특별시 강남구 역삼동(역삼세무서 부근)',
#   'occrrnc_cnt': 6,
#   'caslt_cnt': 7,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 4,
#   'sl_dnv_cnt': 3,
#   'wnd_dnv_cnt': 0,
#   'geom_json': '{"type":"Polygon","coordinates":[[[127.04016068,37.49585372],[127.04014342,37.49571468],[127.0400923,37.49558098],[127.04000929,37.49545775],[127.03989757,37.49534975],[127.03976145,37.49526111],[127.03960614,37.49519525],[127.03943762,37.49515469],[127.03926237,37.495141],[127.03908712,37.49515469],[127.0389186,37.49519525],[127.03876329,37.49526111],[127.03862716,37.49534975],[127.03851545,37.49545775],[127.03843243,37.49558098],[127.03838131,37.49571468],[127.03836405,37.49585372],[127.03838131,37.49599277],[127.03843243,37.49612647],[127.03851545,37.49624969],[127.03862716,37.49635769],[127.03876329,37.49644633],[127.0389186,37.49651219],[127.03908712,37.49655275],[127.03926237,37.49656644],[127.03943762,37.49655275],[127.03960614,37.49651219],[127.03976145,37.49644633],[127.03989757,37.49635769],[127.04000929,37.49624969],[127.0400923,37.49612647],[127.04014342,37.49599277],[127.04016068,37.49585372]]]}',
#   'lo_crd': '127.039262367965',
#   'la_crd': '37.495853722272'},
#  {'afos_fid': 6424000,
#   'afos_id': '01',
#   'bjd_cd': '1168011500',
#   'spot_cd': '11680008',
#   'sido_sgg_nm': '서울특별시 강남구8',
#   'spot_nm': '서울특별시 강남구 수서동(수서역 부근)',
#   'occrrnc_cnt': 6,
#   'caslt_cnt': 12,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 3,
#   'sl_dnv_cnt': 9,
#   'wnd_dnv_cnt': 0,
#   'geom_json': '{"type":"Polygon","coordinates":[[[127.10280619,37.48749549],[127.10278893,37.48735643],[127.10273781,37.48722271],[127.1026548,37.48709948],[127.10254308,37.48699146],[127.10240695,37.48690282],[127.10225165,37.48683695],[127.10208313,37.48679638],[127.10190788,37.48678269],[127.10173262,37.48679638],[127.10156411,37.48683695],[127.1014088,37.48690282],[127.10127267,37.48699146],[127.10116095,37.48709948],[127.10107794,37.48722271],[127.10102682,37.48735643],[127.10100956,37.48749549],[127.10102682,37.48763455],[127.10107794,37.48776827],[127.10116095,37.4878915],[127.10127267,37.48799952],[127.1014088,37.48808816],[127.10156411,37.48815403],[127.10173262,37.48819459],[127.10190788,37.48820829],[127.10208313,37.48819459],[127.10225165,37.48815403],[127.10240695,37.48808816],[127.10254308,37.48799952],[127.1026548,37.4878915],[127.10273781,37.48776827],[127.10278893,37.48763455],[127.10280619,37.48749549]]]}',
#   'lo_crd': '127.101907876348',
#   'la_crd': '37.487495491525'},
#  {'afos_fid': 6424126,
#   'afos_id': '01',
#   'bjd_cd': '1168010100',
#   'spot_cd': '11680009',
#   'sido_sgg_nm': '서울특별시 강남구9',
#   'spot_nm': '서울특별시 강남구 역삼동(경복아파트 부근)',
#   'occrrnc_cnt': 6,
#   'caslt_cnt': 9,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 2,
#   'sl_dnv_cnt': 7,
#   'wnd_dnv_cnt': 0,
#   'geom_json': '{"type":"Polygon","coordinates":[[[127.03962528,37.50871515],[127.03960802,37.50857613],[127.0395569,37.50844245],[127.03947389,37.50831925],[127.03936217,37.50821126],[127.03922604,37.50812264],[127.03907074,37.50805679],[127.03890222,37.50801624],[127.03872697,37.50800255],[127.03855171,37.50801624],[127.0383832,37.50805679],[127.03822789,37.50812264],[127.03809176,37.50821126],[127.03798005,37.50831925],[127.03789703,37.50844245],[127.03784591,37.50857613],[127.03782865,37.50871515],[127.03784591,37.50885417],[127.03789703,37.50898785],[127.03798005,37.50911105],[127.03809176,37.50921903],[127.03822789,37.50930765],[127.0383832,37.5093735],[127.03855171,37.50941405],[127.03872697,37.50942774],[127.03890222,37.50941405],[127.03907074,37.5093735],[127.03922604,37.50930765],[127.03936217,37.50921903],[127.03947389,37.50911105],[127.0395569,37.50898785],[127.03960802,37.50885417],[127.03962528,37.50871515]]]}',
#   'lo_crd': '127.038726967377',
#   'la_crd': '37.508715148087'},
#  {'afos_fid': 6424335,
#   'afos_id': '02',
#   'bjd_cd': '1168011800',
#   'spot_cd': '11680001',
#   'sido_sgg_nm': '서울특별시 강남구1',
#   'spot_nm': '서울특별시 강남구 도곡동(옥신타워 부근)',
#   'occrrnc_cnt': 5,
#   'caslt_cnt': 6,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 3,
#   'sl_dnv_cnt': 3,
#   'wnd_dnv_cnt': 0,
#   'geom_json': '{"type":"Polygon","coordinates":[[[127.03687945,37.49028847],[127.03682767,37.48987131],[127.03667431,37.48947017],[127.03642527,37.48910048],[127.03609012,37.48877644],[127.03568174,37.4885105],[127.03521582,37.4883129],[127.03471027,37.48819121],[127.03418451,37.48815012],[127.03365875,37.48819121],[127.0331532,37.4883129],[127.03268728,37.4885105],[127.03227889,37.48877644],[127.03194374,37.48910048],[127.0316947,37.48947017],[127.03154134,37.48987131],[127.03148956,37.49028847],[127.03154134,37.49070564],[127.0316947,37.49110677],[127.03194374,37.49147645],[127.03227889,37.49180048],[127.03268728,37.4920664],[127.0331532,37.492264],[127.03365875,37.49238568],[127.03418451,37.49242677],[127.03471027,37.49238568],[127.03521582,37.492264],[127.03568174,37.4920664],[127.03609012,37.49180048],[127.03642527,37.49147645],[127.03667431,37.49110677],[127.03682767,37.49070564],[127.03687945,37.49028847]]]}',
#   'lo_crd': '127.034184507910',
#   'la_crd': '37.490288473735'}]

# %%
for item in item_value:
    print(item)
# Out:
# {'afos_fid': 6423519, 'afos_id': '01', 'bjd_cd': '1168010100', 'spot_cd': '11680001', 'sido_sgg_nm': '서울특별시 강남구1', 'spot_nm': '서울특별시 강남구 역삼동(역삼역 부근)', 'occrrnc_cnt': 9, 'caslt_cnt': 13, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 4, 'sl_dnv_cnt': 7, 'wnd_dnv_cnt': 2, 'geom_json': '{"type":"Polygon","coordinates":[[[127.03780003,37.50074789],[127.03778277,37.50060885],[127.03773165,37.50047516],[127.03764864,37.50035195],[127.03753692,37.50024395],[127.03740079,37.50015532],[127.03724548,37.50008946],[127.03707697,37.5000489],[127.03690171,37.50003521],[127.03672646,37.5000489],[127.03655794,37.50008946],[127.03640264,37.50015532],[127.03626651,37.50024395],[127.03615479,37.50035195],[127.03607178,37.50047516],[127.03602066,37.50060885],[127.0360034,37.50074789],[127.03602066,37.50088692],[127.03607178,37.50102061],[127.03615479,37.50114383],[127.03626651,37.50125182],[127.03640264,37.50134045],[127.03655794,37.50140631],[127.03672646,37.50144686],[127.03690171,37.50146056],[127.03707697,37.50144686],[127.03724548,37.50140631],[127.03740079,37.50134045],[127.03753692,37.50125182],[127.03764864,37.50114383],[127.03773165,37.50102061],[127.03778277,37.50088692],[127.03780003,37.50074789]]]}', 'lo_crd': '127.036901714144', 'la_crd': '37.500747886806'}
# {'afos_fid': 6423685, 'afos_id': '01', 'bjd_cd': '1168010600', 'spot_cd': '11680002', 'sido_sgg_nm': '서울특별시 강남구2', 'spot_nm': '서울특별시 강남구 대치동(학여울역 부근)', 'occrrnc_cnt': 8, 'caslt_cnt': 12, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 1, 'sl_dnv_cnt': 11, 'wnd_dnv_cnt': 0, 'geom_json': '{"type":"Polygon","coordinates":[[[127.0715715,37.49668413],[127.07155424,37.49654508],[127.07150312,37.49641138],[127.07142011,37.49628816],[127.07130839,37.49618016],[127.07117226,37.49609152],[127.07101695,37.49602566],[127.07084844,37.4959851],[127.07067318,37.49597141],[127.07049793,37.4959851],[127.07032941,37.49602566],[127.07017411,37.49609152],[127.07003798,37.49618016],[127.06992626,37.49628816],[127.06984325,37.49641138],[127.06979213,37.49654508],[127.06977487,37.49668413],[127.06979213,37.49682317],[127.06984325,37.49695687],[127.06992626,37.49708009],[127.07003798,37.49718809],[127.07017411,37.49727672],[127.07032941,37.49734258],[127.07049793,37.49738314],[127.07067318,37.49739684],[127.07084844,37.49738314],[127.07101695,37.49734258],[127.07117226,37.49727672],[127.07130839,37.49718809],[127.07142011,37.49708009],[127.07150312,37.49695687],[127.07155424,37.49682317],[127.0715715,37.49668413]]]}', 'lo_crd': '127.070673183322', 'la_crd': '37.496684126572'}
# {'afos_fid': 6423402, 'afos_id': '01', 'bjd_cd': '1168010100', 'spot_cd': '11680003', 'sido_sgg_nm': '서울특별시 강남구3', 'spot_nm': '서울특별시 강남구 역삼동(교보타워사거리 부근)', 'occrrnc_cnt': 7, 'caslt_cnt': 12, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 6, 'sl_dnv_cnt': 6, 'wnd_dnv_cnt': 0, 'geom_json': '{"type":"Polygon","coordinates":[[[127.02537731,37.5043941],[127.02536005,37.50425507],[127.02530893,37.50412138],[127.02522591,37.50399818],[127.0251142,37.50389019],[127.02497807,37.50380156],[127.02482276,37.5037357],[127.02465425,37.50369515],[127.02447899,37.50368146],[127.02430374,37.50369515],[127.02413522,37.5037357],[127.02397992,37.50380156],[127.02384379,37.50389019],[127.02373207,37.50399818],[127.02364906,37.50412138],[127.02359794,37.50425507],[127.02358068,37.5043941],[127.02359794,37.50453313],[127.02364906,37.50466682],[127.02373207,37.50479002],[127.02384379,37.50489801],[127.02397992,37.50498664],[127.02413522,37.50505249],[127.02430374,37.50509304],[127.02447899,37.50510674],[127.02465425,37.50509304],[127.02482276,37.50505249],[127.02497807,37.50498664],[127.0251142,37.50489801],[127.02522591,37.50479002],[127.02530893,37.50466682],[127.02536005,37.50453313],[127.02537731,37.5043941]]]}', 'lo_crd': '127.024478992912', 'la_crd': '37.504394100808'}
# {'afos_fid': 6423999, 'afos_id': '01', 'bjd_cd': '1168010100', 'spot_cd': '11680004', 'sido_sgg_nm': '서울특별시 강남구4', 'spot_nm': '서울특별시 강남구 역삼동(강남역 부근)', 'occrrnc_cnt': 7, 'caslt_cnt': 12, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 4, 'sl_dnv_cnt': 7, 'wnd_dnv_cnt': 1, 'geom_json': '{"type":"Polygon","coordinates":[[[127.02814229,37.49798321],[127.02812503,37.49784417],[127.02807391,37.49771047],[127.0279909,37.49758725],[127.02787918,37.49747925],[127.02774306,37.49739062],[127.02758775,37.49732476],[127.02741923,37.4972842],[127.02724398,37.4972705],[127.02706873,37.4972842],[127.02690021,37.49732476],[127.0267449,37.49739062],[127.02660877,37.49747925],[127.02649706,37.49758725],[127.02641404,37.49771047],[127.02636292,37.49784417],[127.02634566,37.49798321],[127.02636292,37.49812225],[127.02641404,37.49825595],[127.02649706,37.49837916],[127.02660877,37.49848716],[127.0267449,37.4985758],[127.02690021,37.49864166],[127.02706873,37.49868221],[127.02724398,37.49869591],[127.02741923,37.49868221],[127.02758775,37.49864166],[127.02774306,37.4985758],[127.02787918,37.49848716],[127.0279909,37.49837916],[127.02807391,37.49825595],[127.02812503,37.49812225],[127.02814229,37.49798321]]]}', 'lo_crd': '127.027243979227', 'la_crd': '37.497983208959'}
# {'afos_fid': 6423498, 'afos_id': '01', 'bjd_cd': '1168010500', 'spot_cd': '11680005', 'sido_sgg_nm': '서울특별시 강남구5', 'spot_nm': '서울특별시 강남구 삼성동(코엑스 부근)', 'occrrnc_cnt': 7, 'caslt_cnt': 8, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 2, 'sl_dnv_cnt': 5, 'wnd_dnv_cnt': 1, 'geom_json': '{"type":"Polygon","coordinates":[[[127.06116079,37.51452879],[127.06114353,37.51438978],[127.06109241,37.51425612],[127.06100939,37.51413293],[127.06089768,37.51402495],[127.06076155,37.51393633],[127.06060624,37.51387049],[127.06043773,37.51382994],[127.06026247,37.51381625],[127.06008722,37.51382994],[127.0599187,37.51387049],[127.0597634,37.51393633],[127.05962727,37.51402495],[127.05951555,37.51413293],[127.05943254,37.51425612],[127.05938142,37.51438978],[127.05936416,37.51452879],[127.05938142,37.5146678],[127.05943254,37.51480147],[127.05951555,37.51492466],[127.05962727,37.51503264],[127.0597634,37.51512125],[127.0599187,37.51518709],[127.06008722,37.51522764],[127.06026247,37.51524133],[127.06043773,37.51522764],[127.06060624,37.51518709],[127.06076155,37.51512125],[127.06089768,37.51503264],[127.06100939,37.51492466],[127.06109241,37.51480147],[127.06114353,37.5146678],[127.06116079,37.51452879]]]}', 'lo_crd': '127.060262473036', 'la_crd': '37.514528793870'}
# {'afos_fid': 6423385, 'afos_id': '01', 'bjd_cd': '1168010500', 'spot_cd': '11680006', 'sido_sgg_nm': '서울특별시 강남구6', 'spot_nm': '서울특별시 강남구 삼성동(강남구청역 부근)', 'occrrnc_cnt': 6, 'caslt_cnt': 11, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 9, 'sl_dnv_cnt': 2, 'wnd_dnv_cnt': 0, 'geom_json': '{"type":"Polygon","coordinates":[[[127.04238299,37.51723357],[127.04236573,37.51709457],[127.04231461,37.5169609],[127.0422316,37.51683772],[127.04211988,37.51672974],[127.04198375,37.51664113],[127.04182845,37.51657529],[127.04165993,37.51653474],[127.04148468,37.51652105],[127.04130942,37.51653474],[127.04114091,37.51657529],[127.0409856,37.51664113],[127.04084947,37.51672974],[127.04073775,37.51683772],[127.04065474,37.5169609],[127.04060362,37.51709457],[127.04058636,37.51723357],[127.04060362,37.51737258],[127.04065474,37.51750624],[127.04073775,37.51762942],[127.04084947,37.51773739],[127.0409856,37.517826],[127.04114091,37.51789185],[127.04130942,37.51793239],[127.04148468,37.51794608],[127.04165993,37.51793239],[127.04182845,37.51789185],[127.04198375,37.517826],[127.04211988,37.51773739],[127.0422316,37.51762942],[127.04231461,37.51750624],[127.04236573,37.51737258],[127.04238299,37.51723357]]]}', 'lo_crd': '127.041484676378', 'la_crd': '37.517233570574'}
# {'afos_fid': 6423441, 'afos_id': '01', 'bjd_cd': '1168010100', 'spot_cd': '11680007', 'sido_sgg_nm': '서울특별시 강남구7', 'spot_nm': '서울특별시 강남구 역삼동(역삼세무서 부근)', 'occrrnc_cnt': 6, 'caslt_cnt': 7, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 4, 'sl_dnv_cnt': 3, 'wnd_dnv_cnt': 0, 'geom_json': '{"type":"Polygon","coordinates":[[[127.04016068,37.49585372],[127.04014342,37.49571468],[127.0400923,37.49558098],[127.04000929,37.49545775],[127.03989757,37.49534975],[127.03976145,37.49526111],[127.03960614,37.49519525],[127.03943762,37.49515469],[127.03926237,37.495141],[127.03908712,37.49515469],[127.0389186,37.49519525],[127.03876329,37.49526111],[127.03862716,37.49534975],[127.03851545,37.49545775],[127.03843243,37.49558098],[127.03838131,37.49571468],[127.03836405,37.49585372],[127.03838131,37.49599277],[127.03843243,37.49612647],[127.03851545,37.49624969],[127.03862716,37.49635769],[127.03876329,37.49644633],[127.0389186,37.49651219],[127.03908712,37.49655275],[127.03926237,37.49656644],[127.03943762,37.49655275],[127.03960614,37.49651219],[127.03976145,37.49644633],[127.03989757,37.49635769],[127.04000929,37.49624969],[127.0400923,37.49612647],[127.04014342,37.49599277],[127.04016068,37.49585372]]]}', 'lo_crd': '127.039262367965', 'la_crd': '37.495853722272'}
# {'afos_fid': 6424000, 'afos_id': '01', 'bjd_cd': '1168011500', 'spot_cd': '11680008', 'sido_sgg_nm': '서울특별시 강남구8', 'spot_nm': '서울특별시 강남구 수서동(수서역 부근)', 'occrrnc_cnt': 6, 'caslt_cnt': 12, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 3, 'sl_dnv_cnt': 9, 'wnd_dnv_cnt': 0, 'geom_json': '{"type":"Polygon","coordinates":[[[127.10280619,37.48749549],[127.10278893,37.48735643],[127.10273781,37.48722271],[127.1026548,37.48709948],[127.10254308,37.48699146],[127.10240695,37.48690282],[127.10225165,37.48683695],[127.10208313,37.48679638],[127.10190788,37.48678269],[127.10173262,37.48679638],[127.10156411,37.48683695],[127.1014088,37.48690282],[127.10127267,37.48699146],[127.10116095,37.48709948],[127.10107794,37.48722271],[127.10102682,37.48735643],[127.10100956,37.48749549],[127.10102682,37.48763455],[127.10107794,37.48776827],[127.10116095,37.4878915],[127.10127267,37.48799952],[127.1014088,37.48808816],[127.10156411,37.48815403],[127.10173262,37.48819459],[127.10190788,37.48820829],[127.10208313,37.48819459],[127.10225165,37.48815403],[127.10240695,37.48808816],[127.10254308,37.48799952],[127.1026548,37.4878915],[127.10273781,37.48776827],[127.10278893,37.48763455],[127.10280619,37.48749549]]]}', 'lo_crd': '127.101907876348', 'la_crd': '37.487495491525'}
# {'afos_fid': 6424126, 'afos_id': '01', 'bjd_cd': '1168010100', 'spot_cd': '11680009', 'sido_sgg_nm': '서울특별시 강남구9', 'spot_nm': '서울특별시 강남구 역삼동(경복아파트 부근)', 'occrrnc_cnt': 6, 'caslt_cnt': 9, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 2, 'sl_dnv_cnt': 7, 'wnd_dnv_cnt': 0, 'geom_json': '{"type":"Polygon","coordinates":[[[127.03962528,37.50871515],[127.03960802,37.50857613],[127.0395569,37.50844245],[127.03947389,37.50831925],[127.03936217,37.50821126],[127.03922604,37.50812264],[127.03907074,37.50805679],[127.03890222,37.50801624],[127.03872697,37.50800255],[127.03855171,37.50801624],[127.0383832,37.50805679],[127.03822789,37.50812264],[127.03809176,37.50821126],[127.03798005,37.50831925],[127.03789703,37.50844245],[127.03784591,37.50857613],[127.03782865,37.50871515],[127.03784591,37.50885417],[127.03789703,37.50898785],[127.03798005,37.50911105],[127.03809176,37.50921903],[127.03822789,37.50930765],[127.0383832,37.5093735],[127.03855171,37.50941405],[127.03872697,37.50942774],[127.03890222,37.50941405],[127.03907074,37.5093735],[127.03922604,37.50930765],[127.03936217,37.50921903],[127.03947389,37.50911105],[127.0395569,37.50898785],[127.03960802,37.50885417],[127.03962528,37.50871515]]]}', 'lo_crd': '127.038726967377', 'la_crd': '37.508715148087'}
# {'afos_fid': 6424335, 'afos_id': '02', 'bjd_cd': '1168011800', 'spot_cd': '11680001', 'sido_sgg_nm': '서울특별시 강남구1', 'spot_nm': '서울특별시 강남구 도곡동(옥신타워 부근)', 'occrrnc_cnt': 5, 'caslt_cnt': 6, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 3, 'sl_dnv_cnt': 3, 'wnd_dnv_cnt': 0, 'geom_json': '{"type":"Polygon","coordinates":[[[127.03687945,37.49028847],[127.03682767,37.48987131],[127.03667431,37.48947017],[127.03642527,37.48910048],[127.03609012,37.48877644],[127.03568174,37.4885105],[127.03521582,37.4883129],[127.03471027,37.48819121],[127.03418451,37.48815012],[127.03365875,37.48819121],[127.0331532,37.4883129],[127.03268728,37.4885105],[127.03227889,37.48877644],[127.03194374,37.48910048],[127.0316947,37.48947017],[127.03154134,37.48987131],[127.03148956,37.49028847],[127.03154134,37.49070564],[127.0316947,37.49110677],[127.03194374,37.49147645],[127.03227889,37.49180048],[127.03268728,37.4920664],[127.0331532,37.492264],[127.03365875,37.49238568],[127.03418451,37.49242677],[127.03471027,37.49238568],[127.03521582,37.492264],[127.03568174,37.4920664],[127.03609012,37.49180048],[127.03642527,37.49147645],[127.03667431,37.49110677],[127.03682767,37.49070564],[127.03687945,37.49028847]]]}', 'lo_crd': '127.034184507910', 'la_crd': '37.490288473735'}

# %% [markdown]
# ## 4) 데이터프레임 만들기

# %%
import pandas as pd

data = pd.DataFrame(response_json["items"]["item"])
data
# Out:
#    afos_fid afos_id      bjd_cd   spot_cd sido_sgg_nm  \
# 0   6423519      01  1168010100  11680001  서울특별시 강남구1
# 1   6423685      01  1168010600  11680002  서울특별시 강남구2
# 2   6423402      01  1168010100  11680003  서울특별시 강남구3
# 3   6423999      01  1168010100  11680004  서울특별시 강남구4
# 4   6423498      01  1168010500  11680005  서울특별시 강남구5
# 5   6423385      01  1168010500  11680006  서울특별시 강남구6
# 6   6423441      01  1168010100  11680007  서울특별시 강남구7
# 7   6424000      01  1168011500  11680008  서울특별시 강남구8
# 8   6424126      01  1168010100  11680009  서울특별시 강남구9
# 9   6424335      02  1168011800  11680001  서울특별시 강남구1
#
#                      spot_nm  occrrnc_cnt  caslt_cnt  dth_dnv_cnt  se_dnv_cnt  \
# 0      서울특별시 강남구 역삼동(역삼역 부근)            9         13            0           4
# 1     서울특별시 강남구 대치동(학여울역 부근)            8         12            0           1
# 2  서울특별시 강남구 역삼동(교보타워사거리 부근)            7         12            0           6
# 3      서울특별시 강남구 역삼동(강남역 부근)            7         12            0           4
# 4      서울특별시 강남구 삼성동(코엑스 부근)            7          8            0           2
# 5    서울특별시 강남구 삼성동(강남구청역 부근)            6         11            0           9
# 6    서울특별시 강남구 역삼동(역삼세무서 부근)            6          7            0           4
# 7      서울특별시 강남구 수서동(수서역 부근)            6         12            0           3
# 8    서울특별시 강남구 역삼동(경복아파트 부근)            6          9            0           2
# 9     서울특별시 강남구 도곡동(옥신타워 부근)            5          6            0           3
#
#    sl_dnv_cnt  wnd_dnv_cnt                                          geom_json  \
# 0           7            2  {"type":"Polygon","coordinates":[[[127.0378000...
# 1          11            0  {"type":"Polygon","coordinates":[[[127.0715715...
# 2           6            0  {"type":"Polygon","coordinates":[[[127.0253773...
# 3           7            1  {"type":"Polygon","coordinates":[[[127.0281422...
# 4           5            1  {"type":"Polygon","coordinates":[[[127.0611607...
# 5           2            0  {"type":"Polygon","coordinates":[[[127.0423829...
# 6           3            0  {"type":"Polygon","coordinates":[[[127.0401606...
# 7           9            0  {"type":"Polygon","coordinates":[[[127.1028061...
# 8           7            0  {"type":"Polygon","coordinates":[[[127.0396252...
# 9           3            0  {"type":"Polygon","coordinates":[[[127.0368794...
#
#              lo_crd           la_crd
# 0  127.036901714144  37.500747886806
# 1  127.070673183322  37.496684126572
# 2  127.024478992912  37.504394100808
# 3  127.027243979227  37.497983208959
# 4  127.060262473036  37.514528793870
# 5  127.041484676378  37.517233570574
# 6  127.039262367965  37.495853722272
# 7  127.101907876348  37.487495491525
# 8  127.038726967377  37.508715148087
# 9  127.034184507910  37.490288473735

# %% [markdown]
# ## 5) 데이터 저장하기

# %%
data.to_csv("data/한국도로교통공단_법규위반별 교통사고 다발지역 정보.csv")

# %% [markdown]
# # 2. 서울 열린 광장 포털 OPENAPI

# %% [markdown]
# ## 1) API KEY 불러오기

# %%
# 1. .env 파일에 PUBLIC_DATA_API_KEY = "인증키 입력"을 입력한 후 저장
# 2. .env 파일에 있는 ㅐ용 불러오기

from dotenv import load_dotenv
import os

load_dotenv()
print(os.getenv("PUBLIC_BIKE_API_KEY"))
# Out:
# 73707758476e61723739706d414246

# %% [markdown]
# ## 2) URL 만들기

# %%
# 샘플 URL : "http://openapi.seoul.go.kr:8088/(인증키)/json/tbCycleStationInfo/1/5/"
base_url = "http://openapi.seoul.go.kr:8088"

# 요청 파라미터
key = os.getenv("PUBLIC_BIKE_API_KEY")
type_n = "json"
service = "tbCycleStationInfo"
start_index = 1
end_index = 1000

# url 만들기
url = f"{base_url}/{key}/{type_n}/{service}/{start_index}/{end_index}"
print(url)
# Out:
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/1/1000

# %%
import requests
response = requests.get(url)
print(response.text)
# Out:
# {"stationInfo":{"list_total_count":"3171","RESULT":{"CODE":"INFO-000","MESSAGE":"정상 처리되었습니다."},"row":[{"STA_LOC":"마포구","RENT_ID":"ST-10","RENT_NO":"00108","RENT_NM":"서교동 사거리","RENT_ID_NM":"108. 서교동 사거리","HOLD_NUM":"12","STA_ADD1":"서울특별시 마포구 양화로 93","STA_ADD2":"427","STA_LAT":"37.55274582","STA_LONG":"126.91861725","START_INDEX":0,"END_INDEX":0,"RNUM":"1"},{"STA_LOC":"광진구","RENT_ID":"ST-100","RENT_NO":"00503","RENT_NM":"더샵스타시티 C동 앞","RENT_ID_NM":"503. 더샵스타시티 C동 앞","HOLD_NUM":"15","STA_ADD1":"서울특별시 광진구 아차산로 262","STA_ADD2":"더샵스타시티 C동 앞","STA_LAT":"37.53666687","STA_LONG":"127.07359314","START_INDEX":0,"END_INDEX":0,"RNUM":"2"},{"STA_LOC":"양천구","RENT_ID":"ST-1000","RENT_NO":"00729","RENT_NM":"서부식자재마트 건너편","RENT_ID_NM":"729. 서부식자재마트 건너편","HOLD_NUM":"10","STA_ADD1":"서울특별시 양천구 신정동 236 ","STA_ADD2":"서부식자재마트 건너편","STA_LAT":"37.51037979","STA_LONG":"126.86679840","START_INDEX":0,"END_INDEX":0,"RNUM":"3"},{"STA_LOC":"양천구","RENT_ID":"ST-1002","RENT_NO":"00731","RENT_NM":"서울시 도로환경관리센터","RENT_ID_NM":"731. 서울시 도로환경관리센터","HOLD_NUM":"10","STA_ADD1":"서울특별시 양천구 목동동로 316-6","STA_ADD2":"서울시 도로환경관리센터","STA_LAT":"37.52989960","STA_LONG":"126.87654114","START_INDEX":0,"END_INDEX":0,"RNUM":"4"},{"STA_LOC":"양천구","RENT_ID":"ST-1003","RENT_NO":"00732","RENT_NM":"신월중학교","RENT_ID_NM":"732. 신월중학교","HOLD_NUM":"10","STA_ADD1":"서울특별시 양천구 화곡로 59","STA_ADD2":"신월동 이마트","STA_LAT":"37.53955078","STA_LONG":"126.82830048","START_INDEX":0,"END_INDEX":0,"RNUM":"5"},{"STA_LOC":"양천구","RENT_ID":"ST-1004","RENT_NO":"00733","RENT_NM":"신정이펜하우스314동","RENT_ID_NM":"733. 신정이펜하우스314동","HOLD_NUM":"10","STA_ADD1":"서울특별시 양천구 신정이펜1로50 ","STA_ADD2":"신정이펜하우스314동","STA_LAT":"37.51409912","STA_LONG":"126.83100128","START_INDEX":0,"END_INDEX":0,"RNUM":"6"},{"STA_LOC":"양천구","RENT_ID":"ST-1005","RENT_NO":"00734","RENT_NM":"신트리공원 입구","RENT_ID_NM":"734. 신트리공원 입구","HOLD_NUM":"10","STA_ADD1":"서울특별시 양천구 신정동 310-8 ","STA_ADD2":"신트리공원 입구","STA_LAT":"37.51395035","STA_LONG":"126.85605621","START_INDEX":0,"END_INDEX":0,"RNUM":"7"},{"STA_LOC":"양천구","RENT_ID":"ST-1006","RENT_NO":"00735","RENT_NM":"영도초등학교","RENT_ID_NM":"735. 영도초등학교","HOLD_NUM":"10","STA_ADD1":"서울특별시 양천구 목동중앙로 70 서울영도초등학교","STA_ADD2":"","STA_LAT":"37.53637695","STA_LONG":"126.87151337","START_INDEX":0,"END_INDEX":0,"RNUM":"8"},{"STA_LOC":"양천구","RENT_ID":"ST-1007","RENT_NO":"00736","RENT_NM":"오솔길공원","RENT_ID_NM":"736. 오솔길공원","HOLD_NUM":"10","STA_ADD1":"서울특별시 양천구 남부순환로70길11-9","STA_ADD2":"오솔길공원","STA_LAT":"37.52219009","STA_LONG":"126.83670044","START_INDEX":0,"END_INDEX":0,"RNUM":"9"},{"STA_LOC":"양천구","RENT_ID":"ST-1008","RENT_NO":"00737","RENT_NM":"장수공원","RENT_ID_NM":"737. 장수공원","HOLD_NUM":"20","STA_ADD1":"서울특별시 양천구 신정동 1235","STA_ADD2":"","STA_LAT":"37.52231216","STA_LONG":"126.84904480","START_INDEX":0,"END_INDEX":0,"RNUM":"10"},{"STA_LOC":"광진구","RENT_ID":"ST-101","RENT_NO":"00504","RENT_NM":"신자초교입구교차로","RENT_ID_NM":"504. 신자초교입구교차로","HOLD_NUM":"9","STA_ADD1":"서울특별시 광진구 뚝섬로 596","STA_ADD2":"신자초교입구교차로","STA_LAT":"37.53297043","STA_LONG":"127.07593536","START_INDEX":0,"END_INDEX":0,"RNUM":"11"},{"STA_LOC":"양천구","RENT_ID":"ST-1010","RENT_NO":"00739","RENT_NM":"신월사거리","RENT_ID_NM":"739. 신월사거리","HOLD_NUM":"13","STA_ADD1":"서울특별시 양천구 남부순환로 334","STA_ADD2":"","STA_LAT":"37.53699493","STA_LONG":"126.82728577","START_INDEX":0,"END_INDEX":0,"RNUM":"12"},{"STA_LOC":"양천구","RENT_ID":"ST-1011","RENT_NO":"00740","RENT_NM":"으뜸공원","RENT_ID_NM":"740. 으뜸공원","HOLD_NUM":"8","STA_ADD1":"서울특별시 양천구 가로공원로 133","STA_ADD2":"으뜸공원","STA_LAT":"37.53636932","STA_LONG":"126.83171082","START_INDEX":0,"END_INDEX":0,"RNUM":"13"},{"STA_LOC":"양천구","RENT_ID":"ST-1012","RENT_NO":"00741","RENT_NM":"화곡로 입구 교차로","RENT_ID_NM":"741. 화곡로 입구 교차로","HOLD_NUM":"10","STA_ADD1":"서울특별시 양천구 신월동 258","STA_ADD2":"화곡로 입구 교차로","STA_LAT":"37.53952026","STA_LONG":"126.82540131","START_INDEX":0,"END_INDEX":0,"RNUM":"14"},{"STA_LOC":"양천구","RENT_ID":"ST-1013","RENT_NO":"00742","RENT_NM":"등촌역 5번 출구 뒤","RENT_ID_NM":"742. 등촌역 5번 출구 뒤","HOLD_NUM":"10","STA_ADD1":"서울특별시 양천구 등촌로 236","STA_ADD2":"등촌역 5번 ...

# %%
response_json = response.json()
response_json
# Out:
# {'stationInfo': {'list_total_count': '3171',
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#   'row': [{'STA_LOC': '마포구',
#     'RENT_ID': 'ST-10',
#     'RENT_NO': '00108',
#     'RENT_NM': '서교동 사거리',
#     'RENT_ID_NM': '108. 서교동 사거리',
#     'HOLD_NUM': '12',
#     'STA_ADD1': '서울특별시 마포구 양화로 93',
#     'STA_ADD2': '427',
#     'STA_LAT': '37.55274582',
#     'STA_LONG': '126.91861725',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '1'},
#    {'STA_LOC': '광진구',
#     'RENT_ID': 'ST-100',
#     'RENT_NO': '00503',
#     'RENT_NM': '더샵스타시티 C동 앞',
#     'RENT_ID_NM': '503. 더샵스타시티 C동 앞',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 광진구 아차산로 262',
#     'STA_ADD2': '더샵스타시티 C동 앞',
#     'STA_LAT': '37.53666687',
#     'STA_LONG': '127.07359314',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '2'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1000',
#     'RENT_NO': '00729',
#     'RENT_NM': '서부식자재마트 건너편',
#     'RENT_ID_NM': '729. 서부식자재마트 건너편',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 신정동 236 ',
#     'STA_ADD2': '서부식자재마트 건너편',
#     'STA_LAT': '37.51037979',
#     'STA_LONG': '126.86679840',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '3'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1002',
#     'RENT_NO': '00731',
#     'RENT_NM': '서울시 도로환경관리센터',
#     'RENT_ID_NM': '731. 서울시 도로환경관리센터',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 목동동로 316-6',
#     'STA_ADD2': '서울시 도로환경관리센터',
#     'STA_LAT': '37.52989960',
#     'STA_LONG': '126.87654114',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '4'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1003',
#     'RENT_NO': '00732',
#     'RENT_NM': '신월중학교',
#     'RENT_ID_NM': '732. 신월중학교',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 화곡로 59',
#     'STA_ADD2': '신월동 이마트',
#     'STA_LAT': '37.53955078',
#     'STA_LONG': '126.82830048',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '5'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1004',
#     'RENT_NO': '00733',
#     'RENT_NM': '신정이펜하우스314동',
#     'RENT_ID_NM': '733. 신정이펜하우스314동',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 신정이펜1로50 ',
#     'STA_ADD2': '신정이펜하우스314동',
#     'STA_LAT': '37.51409912',
#     'STA_LONG': '126.83100128',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '6'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1005',
#     'RENT_NO': '00734',
#     'RENT_NM': '신트리공원 입구',
#     'RENT_ID_NM': '734. 신트리공원 입구',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 신정동 310-8 ',
#     'STA_ADD2': '신트리공원 입구',
#     'STA_LAT': '37.51395035',
#     'STA_LONG': '126.85605621',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '7'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1006',
#     'RENT_NO': '00735',
#     'RENT_NM': '영도초등학교',
#     'RENT_ID_NM': '735. 영도초등학교',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 목동중앙로 70 서울영도초등학교',
#     'STA_ADD2': '',
#     'STA_LAT': '37.53637695',
#     'STA_LONG': '126.87151337',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '8'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1007',
#     'RENT_NO': '00736',
#     'RENT_NM': '오솔길공원',
#     'RENT_ID_NM': '736. 오솔길공원',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 남부순환로70길11-9',
#     'STA_ADD2': '오솔길공원',
#     'STA_LAT': '37.52219009',
#     'STA_LONG': '126.83670044',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '9'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1008',
#     'RENT_NO': '00737',
#     'RENT_NM': '장수공원',
#     'RENT_ID_NM': '737. 장수공원',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 양천구 신정동 1235',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52231216',
#     'STA_LONG': '126.84904480',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '10'},
#    {'STA_LOC': '광진구',
#     'RENT_ID': 'ST-101',
#     'RENT_NO': '00504',
#     'RENT_NM': '신자초교입구교차로',
#     'RENT_ID_NM': '504. 신자초교입구교차로',
#     'HOLD_NUM': '9',
#     'STA_ADD1': '서울특별시 광진구 뚝섬로 596',
#     'STA_ADD2': '신자초교입구교차로',
#     'STA_LAT': '37.53297043',
#     'STA_LONG': '127.07593536',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '11'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1010',
#     'RENT_NO': '00739',
#     'RENT_NM': '신월사거리',
#     'RENT_ID_NM': '739. 신월사거리',
#     'HOLD_NUM': '13',
#     'STA_ADD1': '서울특별시 양천구 남부순환로 334',
#     'STA_ADD2': '',
#     'STA_LAT': '37.53699493',
#     'STA_LONG': '126.82728577',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '12'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1011',
#     'RENT_NO': '00740',
#     'RENT_NM': '으뜸공원',
#     'RENT_ID_NM': '740. 으뜸공원',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 양천구 가로공원로 133',
#     'STA_ADD2': '으뜸공원',
#     'STA_LAT': '37.53636932',
#     'STA_LONG': '126.83171082',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '13'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1012',
#     'RENT_NO': '00741',
#     'RENT_NM': '화곡로 입구 교차로',
#     'RENT_ID_NM': '741. 화곡로 입구 교차로',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 신월동 258',
#     'STA_ADD2': '화곡로 입구 교차로',
#     'STA_LAT': '37.53952026',
#     'STA_LONG': '126.82540131',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '14'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1013',
#     'RENT_NO': '00742',
#     'RENT_NM': '등촌역 5번 출구 뒤',
#     'RENT_ID_NM': '742. 등촌역 5번 출구 뒤',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 등촌로 236',
#     'STA_ADD2': '등촌역 5번 출구 뒤',
#     'STA_LAT': '37.55073166',
#     'STA_LONG': '126.86457825',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '15'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1014',
#     'RENT_NO': '00743',
#     'RENT_NM': '현대6차아파트 101동 옆',
#     'RENT_ID_NM': '743. 현대6차아파트 101동 옆',
#     'HOLD_NUM': '22',
#     'STA_ADD1': '서울특별시 양천구 신정동 735-5',
#     'STA_ADD2': '현대6차아파트 101동 옆',
#     'STA_LAT': '37.50889969',
#     'STA_LONG': '126.84268188',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '16'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1015',
#     'RENT_NO': '00744',
#     'RENT_NM': '신목동역 2번 출구',
#     'RENT_ID_NM': '744. 신목동역 2번 출구',
#     'HOLD_NUM': '40',
#     'STA_ADD1': '서울특별시 양천구 목동중앙로 212 앞',
#     'STA_ADD2': '신목동역 2번 출구',
#     'STA_LAT': '37.54384232',
#     'STA_LONG': '126.88254547',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '17'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1016',
#     'RENT_NO': '00745',
#     'RENT_NM': '강서초등학교',
#     'RENT_ID_NM': '745. 강서초등학교',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 오목로 31 부근',
#     'STA_ADD2': '강서초등학교',
#     'STA_LAT': '37.52228165',
#     'STA_LONG': '126.83969879',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '18'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1017',
#     'RENT_NO': '00746',
#     'RENT_NM': '목동2단지 상가',
#     'RENT_ID_NM': '746. 목동2단지 상가',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 목동 902-5 ',
#     'STA_ADD2': '목동2단지 상가',
#     'STA_LAT': '37.53650284',
#     'STA_LONG': '126.87774658',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '19'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1018',
#     'RENT_NO': '00747',
#     'RENT_NM': '목동3단지 상가',
#     'RENT_ID_NM': '747. 목동3단지 상가',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 목동 903-6',
#     'STA_ADD2': '목동3단지 상가',
#     'STA_LAT': '37.53458023',
#     'STA_LONG': '126.87564850',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '20'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1019',
#     'RENT_NO': '00748',
#     'RENT_NM': '목동운동장',
#     'RENT_ID_NM': '748. 목동운동장',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 양천구 안양천로 939',
#     'STA_ADD2': '목동운동장',
#     'STA_LAT': '37.53025055',
#     'STA_LONG': '126.87930298',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '21'},
#    {'STA_LOC': '광진구',
#     'RENT_ID': 'ST-102',
#     'RENT_NO': '00505',
#     'RENT_NM': '자양사거리 광진아크로텔 앞',
#     'RENT_ID_NM': '505. 자양사거리 광진아크로텔 앞',
#     'HOLD_NUM': '11',
#     'STA_ADD1': '서울특별시 광진구 아차산로 355',
#     'STA_ADD2': '타워더모스트 광진아크로텔',
#     'STA_LAT': '37.53701019',
#     'STA_LONG': '127.08224487',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '22'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1020',
#     'RENT_NO': '00934',
#     'RENT_NM': '신사동 성당',
#     'RENT_ID_NM': '934. 신사동 성당',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 은평구 신사동 41-3',
#     'STA_ADD2': '신사동 성당',
#     'STA_LAT': '37.59714127',
#     'STA_LONG': '126.90959930',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '23'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1021',
#     'RENT_NO': '00935',
#     'RENT_NM': '역촌역 1번 출구',
#     'RENT_ID_NM': '935. 역촌역 1번 출구',
#     'HOLD_NUM': '7',
#     'STA_ADD1': '서울특별시 은평구 역촌동 17-55',
#     'STA_ADD2': '역촌역 1번 출구',
#     'STA_LAT': '37.60520172',
#     'STA_LONG': '126.92211151',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '24'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1023',
#     'RENT_NO': '00937',
#     'RENT_NM': '상림마을 롯데캐슬2단지 옆',
#     'RENT_ID_NM': '937. 상림마을 롯데캐슬2단지 옆',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 은평구 진관동 30-23',
#     'STA_ADD2': '상림마을 롯데캐슬2단지 옆',
#     'STA_LAT': '37.64585114',
#     'STA_LONG': '126.92379761',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '25'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1024',
#     'RENT_NO': '00938',
#     'RENT_NM': '금암 문화공원',
#     'RENT_ID_NM': '938. 금암 문화공원',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 은평구 진관동 44-28 ',
#     'STA_ADD2': '금암 문화공원',
#     'STA_LAT': '37.64468384',
#     'STA_LONG': '126.91845703',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '26'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1025',
#     'RENT_NO': '00939',
#     'RENT_NM': '은평구청 교차로',
#     'RENT_ID_NM': '939. 은평구청 교차로',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 은평구 응암동 82-31',
#     'STA_ADD2': '은평구청 교차로',
#     'STA_LAT': '37.60169983',
#     'STA_LONG': '126.92742157',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '27'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1027',
#     'RENT_NO': '00941',
#     'RENT_NM': '은평뉴타운 도서관',
#     'RENT_ID_NM': '941. 은평뉴타운 도서관',
#     'HOLD_NUM': '13',
#     'STA_ADD1': '서울특별시 은평구 진관동 141-27',
#     'STA_ADD2': '은평뉴타운 도서관',
#     'STA_LAT': '37.63722229',
#     'STA_LONG': '126.93330383',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '28'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1028',
#     'RENT_NO': '00942',
#     'RENT_NM': '상림마을 생태공원',
#     'RENT_ID_NM': '942. 상림마을 생태공원',
#     'HOLD_NUM': '9',
#     'STA_ADD1': '서울특별시 은평구 진관동 16-4',
#     'STA_ADD2': '상림마을 생태공원',
#     'STA_LAT': '37.64408112',
#     'STA_LONG': '126.92928314',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '29'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1029',
#     'RENT_NO': '00943',
#     'RENT_NM': '은평구청 보건소',
#     'RENT_ID_NM': '943. 은평구청 보건소',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 은평구 녹번동 84',
#     'STA_ADD2': '은평구청 보건소',
#     'STA_LAT': '37.60240173',
#     'STA_LONG': '126.92864990',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '30'},
#    {'STA_LOC': '성동구',
#     'RENT_ID': 'ST-103',
#     'RENT_NO': '00506',
#     'RENT_NM': '금호 어울림 아파트 앞',
#     'RENT_ID_NM': '506. 금호 어울림 아파트 앞',
#     'HOLD_NUM': '7',
#     'STA_ADD1': '서울특별시 성동구 광나루로 249',
#     'STA_ADD2': '송정금호어울림 아파트 앞',
#     'STA_LAT': '37.54906082',
#     'STA_LONG': '127.05779266',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '31'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1031',
#     'RENT_NO': '00945',
#     'RENT_NM': '기자촌 사거리 A',
#     'RENT_ID_NM': '945. 기자촌 사거리 A',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 은평구 진관동 149-17',
#     'STA_ADD2': '기자촌 사거리',
#     'STA_LAT': '37.63414001',
#     'STA_LONG': '126.93234253',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '32'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1032',
#     'RENT_NO': '00946',
#     'RENT_NM': '독바위역',
#     'RENT_ID_NM': '946. 독바위역 ',
#     'HOLD_NUM': '16',
#     'STA_ADD1': '서울특별시 은평구 불광로 129',
#     'STA_ADD2': '독바위역 ',
#     'STA_LAT': '37.61843872',
#     'STA_LONG': '126.93288422',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '33'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1033',
#     'RENT_NO': '00947',
#     'RENT_NM': '연신내 선일하이츠빌 정류소',
#     'RENT_ID_NM': '947. 연신내 선일하이츠빌 정류소',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 은평구 불광동 484-165',
#     'STA_ADD2': '연신내 선일하이츠빌 정류소',
#     'STA_LAT': '37.62266922',
#     'STA_LONG': '126.91999054',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '34'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1034',
#     'RENT_NO': '00948',
#     'RENT_NM': '디지털미디어 시티역 4번출구(DMC역)',
#     'RENT_ID_NM': '948. 디지털미디어 시티역 4번출구(DMC역)',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 은평구 증산동 239',
#     'STA_ADD2': '디지털미디어 시티역 4번출구',
#     'STA_LAT': '37.57720184',
#     'STA_LONG': '126.90235138',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '35'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1035',
#     'RENT_NO': '00949',
#     'RENT_NM': '연신내역 1번 출구',
#     'RENT_ID_NM': '949. 연신내역 1번 출구 ',
#     'HOLD_NUM': '6',
#     'STA_ADD1': '서울특별시 은평구 불광동 487-2',
#     'STA_ADD2': '연신내역 1번 출구 ',
#     'STA_LAT': '37.61978149',
#     'STA_LONG': '126.92080688',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '36'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1036',
#     'RENT_NO': '00950',
#     'RENT_NM': '구산역 2번 출구 예일여고 버스정류장',
#     'RENT_ID_NM': '950. 구산역 2번 출구 예일여고 버스정류장',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 은평구 연서로 124',
#     'STA_ADD2': '',
#     'STA_LAT': '37.60980225',
#     'STA_LONG': '126.91679382',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '37'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1037',
#     'RENT_NO': '00951',
#     'RENT_NM': '연신내역 6번출구옆',
#     'RENT_ID_NM': '951. 연신내역 6번출구옆',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 은평구 갈현동 389-15 ',
#     'STA_ADD2': '연신내역 6번출구옆',
#     'STA_LAT': '37.61930466',
#     'STA_LONG': '126.92059326',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '38'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1038',
#     'RENT_NO': '00952',
#     'RENT_NM': '서울연신중학교',
#     'RENT_ID_NM': '952. 서울연신중학교',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 은평구 불광동 400-4번지',
#     'STA_ADD2': '서울연신중학교',
#     'STA_LAT': '37.62265015',
#     'STA_LONG': '126.92524719',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '39'},
#    {'STA_LOC': '은평구',
#     'RENT_ID': 'ST-1039',
#     'RENT_NO': '00953',
#     'RENT_NM': '서울연신초등학교',
#     'RENT_ID_NM': '953. 서울연신초등학교',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 은평구 불광동 73-1번지 ',
#     'STA_ADD2': '서울연신초등학교',
#     'STA_LAT': '37.62577820',
#     'STA_LONG': '126.92881775',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '40'},
#    {'STA_LOC': '성동구',
#     'RENT_ID': 'ST-104',
#     'RENT_NO': '00507',
#     'RENT_NM': '성수아이에스비즈타워 앞',
#     'RENT_ID_NM': '507. 성수아이에스비즈타워 앞',
#     'HOLD_NUM': '7',
#     'STA_ADD1': '서울특별시 성동구 성수이로 147',
#     'STA_ADD2': '아이에스비즈타워 앞',
#     'STA_LAT': '37.54820251',
#     'STA_LONG': '127.05711365',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '41'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1040',
#     'RENT_NO': '01023',
#     'RENT_NM': '한국종합기술사옥 앞',
#     'RENT_ID_NM': '1023. 한국종합기술사옥 앞',
#     'HOLD_NUM': '22',
#     'STA_ADD1': '서울특별시 강동구 상일로6길 21 한국종합기술사옥',
#     'STA_ADD2': '',
#     'STA_LAT': '37.54998398',
#     'STA_LONG': '127.17470551',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '42'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1041',
#     'RENT_NO': '01024',
#     'RENT_NM': '강동구청 앞',
#     'RENT_ID_NM': '1024.  강동구청 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강동구 성내로 28 강동빌딩',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52929688',
#     'STA_LONG': '127.12315369',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '43'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1042',
#     'RENT_NO': '01025',
#     'RENT_NM': '상일초등학교',
#     'RENT_ID_NM': '1025. 상일초등학교',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강동구 상일동 440-3',
#     'STA_ADD2': '상일초등학교',
#     'STA_LAT': '37.54684067',
#     'STA_LONG': '127.17251587',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '44'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1043',
#     'RENT_NO': '01026',
#     'RENT_NM': '대명초교 입구 교차로',
#     'RENT_ID_NM': '1026. 대명초교 입구 교차로',
#     'HOLD_NUM': '14',
#     'STA_ADD1': '서울특별시 강동구 명일동 59',
#     'STA_ADD2': '',
#     'STA_LAT': '37.54653549',
#     'STA_LONG': '127.15583801',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '45'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1044',
#     'RENT_NO': '01027',
#     'RENT_NM': '프라자 아파트 앞',
#     'RENT_ID_NM': '1027. 프라자 아파트 앞',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 강동구 천호대로 1240 프라자아파트',
#     'STA_ADD2': '',
#     'STA_LAT': '37.53596115',
#     'STA_LONG': '127.14781952',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '46'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1045',
#     'RENT_NO': '01028',
#     'RENT_NM': '포레스 주상복합 빌딩',
#     'RENT_ID_NM': '1028. 포레스 주상복합 빌딩',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강동구 천호옛길 41 포레스아파트',
#     'STA_ADD2': '',
#     'STA_LAT': '37.53310776',
#     'STA_LONG': '127.12277222',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '47'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1046',
#     'RENT_NO': '01029',
#     'RENT_NM': '성내어울터',
#     'RENT_ID_NM': '1029. 성내어울터',
#     'HOLD_NUM': '7',
#     'STA_ADD1': '서울특별시 강동구 성내동 43-2',
#     'STA_ADD2': '',
#     'STA_LAT': '37.53655624',
#     'STA_LONG': '127.12553406',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '48'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1047',
#     'RENT_NO': '01030',
#     'RENT_NM': '미호 플랜트 앞',
#     'RENT_ID_NM': '1030. 미호 플랜트 앞',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 강동구 강동대로 143-22',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52703094',
#     'STA_LONG': '127.12206268',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '49'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1048',
#     'RENT_NO': '01031',
#     'RENT_NM': '올림픽로 836(아리수로)',
#     'RENT_ID_NM': '1031. 올림픽로 836(아리수로)',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 강동구 암사동 440',
#     'STA_ADD2': '',
#     'STA_LAT': '37.55604172',
#     'STA_LONG': '127.13093567',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '50'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1049',
#     'RENT_NO': '01032',
#     'RENT_NM': '선사고등학교',
#     'RENT_ID_NM': '1032. 선사고등학교',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 강동구 암사동 524',
#     'STA_ADD2': '',
#     'STA_LAT': '37.55672836',
#     'STA_LONG': '127.13626099',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '51'},
#    {'STA_LOC': '성동구',
#     'RENT_ID': 'ST-105',
#     'RENT_NO': '00508',
#     'RENT_NM': '성수아카데미타워 앞',
#     'RENT_ID_NM': '508. 성수아카데미타워 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 성동구 성수이로 118 성수아카데미타워',
#     'STA_ADD2': '',
#     'STA_LAT': '37.54516983',
#     'STA_LONG': '127.05757141',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '52'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1050',
#     'RENT_NO': '01033',
#     'RENT_NM': '고덕동 아남아파트',
#     'RENT_ID_NM': '1033. 고덕동 아남아파트',
#     'HOLD_NUM': '17',
#     'STA_ADD1': '서울특별시 강동구 고덕동 469',
#     'STA_ADD2': '',
#     'STA_LAT': '37.55793381',
#     'STA_LONG': '127.14476776',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '53'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1051',
#     'RENT_NO': '01034',
#     'RENT_NM': '고덕동 래미안 힐스테이트',
#     'RENT_ID_NM': '1034. 고덕동 래미안 힐스테이트',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 강동구 고덕동 585-4',
#     'STA_ADD2': '',
#     'STA_LAT': '37.56187820',
#     'STA_LONG': '127.15078735',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '54'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1052',
#     'RENT_NO': '01035',
#     'RENT_NM': '고덕역 4번출구',
#     'RENT_ID_NM': '1035. 고덕역 4번출구',
#     'HOLD_NUM': '25',
#     'STA_ADD1': '서울특별시 강동구 명일동 46-6',
#     'STA_ADD2': '',
#     'STA_LAT': '37.55509567',
#     'STA_LONG': '127.15528107',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '55'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1053',
#     'RENT_NO': '01036',
#     'RENT_NM': '고덕동 주양쇼핑',
#     'RENT_ID_NM': '1036. 고덕동 주양쇼핑',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강동구 명일동 48-25',
#     'STA_ADD2': '',
#     'STA_LAT': '37.55199051',
#     'STA_LONG': '127.15331268',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '56'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1054',
#     'RENT_NO': '01037',
#     'RENT_NM': '강일리버파크 6단지',
#     'RENT_ID_NM': '1037. 강일리버파크 6단지',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강동구 강일동 684-2',
#     'STA_ADD2': '',
#     'STA_LAT': '37.56256485',
#     'STA_LONG': '127.17761230',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '57'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1055',
#     'RENT_NO': '01038',
#     'RENT_NM': '강일 다솜 어린이 공원',
#     'RENT_ID_NM': '1038. 강일 다솜 어린이 공원',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강동구 강일동 667-4',
#     'STA_ADD2': '',
#     'STA_LAT': '37.56863785',
#     'STA_LONG': '127.17480469',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '58'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1056',
#     'RENT_NO': '01039',
#     'RENT_NM': '고덕초등학교',
#     'RENT_ID_NM': '1039. 고덕초등학교',
#     'HOLD_NUM': '7',
#     'STA_ADD1': '서울특별시 강동구 고덕로83길 55',
#     'STA_ADD2': '',
#     'STA_LAT': '37.56129837',
#     'STA_LONG': '127.16784668',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '59'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1057',
#     'RENT_NO': '01040',
#     'RENT_NM': '강일동 에너지 마루',
#     'RENT_ID_NM': '1040. 강일동 에너지 마루',
#     'STA_ADD1': '서울특별시 강동구 고덕동 375',
#     'STA_ADD2': '강일동 에너지 마루',
#     'STA_LAT': '37.56719971',
#     'STA_LONG': '127.16345978',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '60'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1058',
#     'RENT_NO': '01041',
#     'RENT_NM': '묘곡초등학교',
#     'RENT_ID_NM': '1041. 묘곡초등학교',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강동구 동남로79길 46 서울묘곡초등학교',
#     'STA_ADD2': '',
#     'STA_LAT': '37.55916214',
#     'STA_LONG': '127.15332031',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '61'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1059',
#     'RENT_NO': '01042',
#     'RENT_NM': '강일리버파크 2~5단지',
#     'RENT_ID_NM': '1042. 강일리버파크 2~5단지',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강동구 아리수로97길 68 강일리버파크2단지아파트',
#     'STA_ADD2': '',
#     'STA_LAT': '37.56854630',
#     'STA_LONG': '127.17700958',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '62'},
#    {'STA_LOC': '성동구',
#     'RENT_ID': 'ST-106',
#     'RENT_NO': '00509',
#     'RENT_NM': '이마트 버스정류소 옆',
#     'RENT_ID_NM': '509. 이마트 버스정류소 옆',
#     'HOLD_NUM': '25',
#     'STA_ADD1': '서울특별시 성동구 뚝섬로 379',
#     'STA_ADD2': '이마트 버스정류소 옆',
#     'STA_LAT': '37.53965378',
#     'STA_LONG': '127.05258942',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '63'},
#    {'STA_LOC': '강동구',
#     'RENT_ID': 'ST-1061',
#     'RENT_NO': '01044',
#     'RENT_NM': '굽은다리역',
#     'RENT_ID_NM': '1044. 굽은다리역',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 강동구 천호동 42-1',
#     'STA_ADD2': '',
#     'STA_LAT': '37.54540634',
#     'STA_LONG': '127.14267731',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '64'},
#    {'STA_LOC': '강서구',
#     'RENT_ID': 'ST-1062',
#     'RENT_NO': '01150',
#     'RENT_NM': '송정역 1번출구',
#     'RENT_ID_NM': '1150. 송정역 1번출구',
#     'HOLD_NUM': '7',
#     'STA_ADD1': '서울특별시 강서구 공항대로 33 송정역(5호선)',
#     'STA_ADD2': '',
#     'STA_LAT': '37.56153107',
#     'STA_LONG': '126.81069946',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '65'},
#    {'STA_LOC': '강서구',
#     'RENT_ID': 'ST-1063',
#     'RENT_NO': '01151',
#     'RENT_NM': '마곡역1번출구',
#     'RENT_ID_NM': '1151. 마곡역1번출구',
#     'HOLD_NUM': '30',
#     'STA_ADD1': '서울특별시 강서구 공항대로 163 마곡역(5호선)',
#     'STA_ADD2': '',
#     'STA_LAT': '37.56020737',
#     'STA_LONG': '126.82414246',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '66'},
#    {'STA_LOC': '강서구',
#     'RENT_ID': 'ST-1064',
#     'RENT_NO': '01152',
#     'RENT_NM': '마곡역교차로',
#     'RENT_ID_NM': '1152. 마곡역교차로',
#     'HOLD_NUM': '36',
#     'STA_ADD1': '서울특별시 강서구 마곡동 728-168',
#     'STA_ADD2': '마곡역7번출구',
#     'STA_LAT': '37.55831146',
#     'STA_LONG': '126.82652283',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '67'},
#    {'STA_LOC': '강서구',
#     'RENT_ID': 'ST-1065',
#     'RENT_NO': '01153',
#     'RENT_NM': '발산역 1번, 9번 인근 대여소',
#     'RENT_ID_NM': '1153. 발산역 1번, 9번 인근 대여소',
#     'HOLD_NUM': '32',
#     'STA_ADD1': '서울특별시 강서구 마곡동 797-5',
#     'STA_ADD2': '',
#     'STA_LAT': '37.55894852',
#     'STA_LONG': '126.83717346',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '68'},
#    {'STA_LOC': '강서구',
#     'RENT_ID': 'ST-1067',
#     'RENT_NO': '01155',
#     'RENT_NM': '기쁜우리복지관',
#     'RENT_ID_NM': '1155. 기쁜우리복지관',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강서구 가양동 1458-15 ',
#     'STA_ADD2': '기쁜우리복지관',
#     'STA_LAT': '37.56925964',
#     'STA_LONG': '126.84841919',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '69'},
#    {'STA_LOC': '강서구',
#     'RENT_ID': 'ST-1069',
#     'RENT_NO': '01157',
#     'RENT_NM': '강서구청',
#     'RENT_ID_NM': '1157. 강서구청',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 강서구 화곡로 302',
#     'STA_ADD2': '강서구청',
#     'STA_LAT': '37.55065918',
#     'STA_LONG': '126.84976959',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '70'},
#    {'STA_LOC': '성동구',
#     'RENT_ID': 'ST-107',
#     'RENT_NO': '00510',
#     'RENT_NM': '뚝도아리수정수센터 버스정류소 옆',
#     'RENT_ID_NM': '510. 뚝도아리수정수센터 버스정류소 옆',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 성동구 왕십리로11길 9',
#     'STA_ADD2': '서울숲남문 버스정류소 옆',
#     'STA_LAT': '37.54122162',
#     'STA_LONG': '127.04380035',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '71'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1070',
#     'RENT_NO': '01251',
#     'RENT_NM': '석촌역 2번출구',
#     'RENT_ID_NM': '1251. 석촌역 2번출구',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 송파구 송파동 68 ',
#     'STA_ADD2': '석촌역 2번출구',
#     'STA_LAT': '37.50593185',
#     'STA_LONG': '127.10774994',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '72'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1072',
#     'RENT_NO': '01253',
#     'RENT_NM': '오금역 3번 출구 뒤',
#     'RENT_ID_NM': '1253. 오금역 3번 출구 뒤',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 송파구 가락동 10-15 ',
#     'STA_ADD2': '오금역 3번 출구 뒤',
#     'STA_LAT': '37.50165176',
#     'STA_LONG': '127.12818146',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '73'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1075',
#     'RENT_NO': '01256',
#     'RENT_NM': '문정현대아파트 교차로',
#     'RENT_ID_NM': '1256. 문정현대아파트 교차로',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 송파구 문정동 3-2 ',
#     'STA_ADD2': '문정현대아파트 교차로',
#     'STA_LAT': '37.49113083',
#     'STA_LONG': '127.12580872',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '74'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1076',
#     'RENT_NO': '01257',
#     'RENT_NM': '가락시장역 사거리',
#     'RENT_ID_NM': '1257. 가락시장역 사거리',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 송파구 가락동 214-15 ',
#     'STA_ADD2': '가락시장역 롯데마트앞',
#     'STA_LAT': '37.49209976',
#     'STA_LONG': '127.11775208',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '75'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1077',
#     'RENT_NO': '01258',
#     'RENT_NM': '가락미륭아파트 앞',
#     'RENT_ID_NM': '1258. 가락미륭아파트 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 송파구 가락동 195-4',
#     'STA_ADD2': '가락미륭아파트 앞',
#     'STA_LAT': '37.49319839',
#     'STA_LONG': '127.12899780',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '76'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1078',
#     'RENT_NO': '01259',
#     'RENT_NM': '방이역 1번출구',
#     'RENT_ID_NM': '1259. 방이역 1번출구',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 송파구 오금동 17-20',
#     'STA_ADD2': '방이역 1번출구',
#     'STA_LAT': '37.50898361',
#     'STA_LONG': '127.12659454',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '77'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1079',
#     'RENT_NO': '01260',
#     'RENT_NM': '방이동 한양3차아파트 옆',
#     'RENT_ID_NM': '1260. 방이동 한양3차아파트 옆',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 송파구 방이동 225-1',
#     'STA_ADD2': '방이동 한양3차아파트 옆',
#     'STA_LAT': '37.50630188',
#     'STA_LONG': '127.12139893',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '78'},
#    {'STA_LOC': '성동구',
#     'RENT_ID': 'ST-108',
#     'RENT_NO': '00511',
#     'RENT_NM': '서울숲역 5번 출구 옆',
#     'RENT_ID_NM': '511. 서울숲역 5번 출구 옆',
#     'HOLD_NUM': '16',
#     'STA_ADD1': '서울특별시 성동구 왕십리로 지하77',
#     'STA_ADD2': '서울숲역 4번 출구 옆',
#     'STA_LAT': '37.54458237',
#     'STA_LONG': '127.04460907',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '79'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1080',
#     'RENT_NO': '01261',
#     'RENT_NM': '석촌역 1번출구 앞',
#     'RENT_ID_NM': '1261. 석촌역 1번출구 앞',
#     'STA_ADD1': '서울특별시 송파구 송파동 69 ',
#     'STA_ADD2': '석촌역 1번출구 앞',
#     'STA_LAT': '37.50582886',
#     'STA_LONG': '127.10705566',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '80'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1081',
#     'RENT_NO': '01262',
#     'RENT_NM': '송파여성문화회관 앞',
#     'RENT_ID_NM': '1262. 송파여성문화회관 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 송파구 송파동 2-3 ',
#     'STA_ADD2': '송파여성문화회관 앞',
#     'STA_LAT': '37.50580215',
#     'STA_LONG': '127.10971832',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '81'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1082',
#     'RENT_NO': '01263',
#     'RENT_NM': '장지공영차고지',
#     'RENT_ID_NM': '1263. 장지공영차고지',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 송파구 장지동 861-6',
#     'STA_ADD2': '장지공영차고지',
#     'STA_LAT': '37.48054123',
#     'STA_LONG': '127.13701630',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '82'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1083',
#     'RENT_NO': '01264',
#     'RENT_NM': '천호역 10번 출구 앞',
#     'RENT_ID_NM': '1264. 천호역 10번 출구 앞',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 송파구 풍납동 490-16',
#     'STA_ADD2': '천호역 10번 출구 앞',
#     'STA_LAT': '37.53858185',
#     'STA_LONG': '127.12280273',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '83'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1084',
#     'RENT_NO': '01265',
#     'RENT_NM': '문정동 근린공원',
#     'RENT_ID_NM': '1265. 문정동 근린공원',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 송파구 문정동 38-3',
#     'STA_ADD2': '문정동 근린공원',
#     'STA_LAT': '37.48598862',
#     'STA_LONG': '127.12476349',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '84'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1085',
#     'RENT_NO': '01266',
#     'RENT_NM': '문정동 글샘 공원',
#     'RENT_ID_NM': '1266. 문정동 글샘 공원',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 송파구 문정동 627',
#     'STA_ADD2': '장지동 글샘 공원',
#     'STA_LAT': '37.47880936',
#     'STA_LONG': '127.12000275',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '85'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1086',
#     'RENT_NO': '01267',
#     'RENT_NM': '올림픽공원 남2문 앞',
#     'RENT_ID_NM': '1267. 올림픽공원 남2문 앞',
#     'HOLD_NUM': '14',
#     'STA_ADD1': '서울특별시 송파구 올림픽로 424',
#     'STA_ADD2': '올림픽공원 남2문 앞',
#     'STA_LAT': '37.51424026',
#     'STA_LONG': '127.12306976',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '86'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1087',
#     'RENT_NO': '01268',
#     'RENT_NM': '몽촌토성역 1번출구 옆',
#     'RENT_ID_NM': '1268. 몽촌토성역 1번출구 옆',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 송파구 방이동 88-21 ',
#     'STA_ADD2': '몽촌토성역 1번출구 옆',
#     'STA_LAT': '37.51728821',
#     'STA_LONG': '127.11419678',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '87'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1088',
#     'RENT_NO': '01269',
#     'RENT_NM': '리센츠아파트',
#     'RENT_ID_NM': '1269. 리센츠아파트 ',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 송파구 올림픽로 135',
#     'STA_ADD2': '리센츠아파트 ',
#     'STA_LAT': '37.51194382',
#     'STA_LONG': '127.09121704',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '88'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1089',
#     'RENT_NO': '01271',
#     'RENT_NM': '송파도서관',
#     'RENT_ID_NM': '1271. 송파도서관',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 송파구 동남로 263',
#     'STA_ADD2': '송파도서관',
#     'STA_LAT': '37.49998474',
#     'STA_LONG': '127.13539124',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '89'},
#    {'STA_LOC': '성동구',
#     'RENT_ID': 'ST-109',
#     'RENT_NO': '00512',
#     'RENT_NM': '뚝섬역 1번 출구 옆',
#     'RENT_ID_NM': '512. 뚝섬역 1번 출구 옆',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 성동구 아차산로 18',
#     'STA_ADD2': '뚝섬역 1번 출구 옆',
#     'STA_LAT': '37.54856110',
#     'STA_LONG': '127.04500580',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '90'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1090',
#     'RENT_NO': '01272',
#     'RENT_NM': '송파 글마루도서관',
#     'RENT_ID_NM': '1272. 송파 글마루도서관',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 송파구 충민로 120',
#     'STA_ADD2': '송파 글마루도서관',
#     'STA_LAT': '0.00000000',
#     'STA_LONG': '0.00000000',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '91'},
#    {'STA_LOC': '송파구',
#     'RENT_ID': 'ST-1092',
#     'RENT_NO': '01274',
#     'RENT_NM': '영파여고 앞',
#     'RENT_ID_NM': '1274. 영파여고 앞',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 송파구 올림픽로 565',
#     'STA_ADD2': '영파여고 앞',
#     'STA_LAT': '37.53284836',
#     'STA_LONG': '127.12104797',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '92'},
#    {'STA_LOC': '중랑구',
#     'RENT_ID': 'ST-1093',
#     'RENT_NO': '01442',
#     'RENT_NM': '중랑구청 중화동 별관 앞',
#     'RENT_ID_NM': '1442. 중랑구청 중화동 별관 앞',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 중랑구 중화동 50-8',
#     'STA_ADD2': '(구)신한은행 중랑교지점',
#     'STA_LAT': '37.59859085',
#     'STA_LONG': '127.07981873',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '93'},
#    {'STA_LOC': '중랑구',
#     'RENT_ID': 'ST-1094',
#     'RENT_NO': '01443',
#     'RENT_NM': '구립망우청소년독서실',
#     'RENT_ID_NM': '1443. 구립망우청소년독서실',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 중랑구 망우동 534-23 ',
#     'STA_ADD2': '구립망우청소년독서실',
#     'STA_LAT': '37.59552002',
#     'STA_LONG': '127.09877777',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '94'},
#    {'STA_LOC': '중랑구',
#     'RENT_ID': 'ST-1095',
#     'RENT_NO': '01444',
#     'RENT_NM': '면목4치안센터',
#     'RENT_ID_NM': '1444. 면목4치안센터',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 중랑구 면목동 646-4',
#     'STA_ADD2': '면목4치안센터',
#     'STA_LAT': '37.57402802',
#     'STA_LONG': '127.08054352',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '95'},
#    {'STA_LOC': '중랑구',
#     'RENT_ID': 'ST-1096',
#     'RENT_NO': '01445',
#     'RENT_NM': '용마지구대 A',
#     'RENT_ID_NM': '1445. 용마지구대 A',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 중랑구 면목동 197-5',
#     'STA_ADD2': '용마지구대',
#     'STA_LAT': '37.57994080',
#     'STA_LONG': '127.07939911',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '96'},
#    {'STA_LOC': '중랑구',
#     'RENT_ID': 'ST-1097',
#     'RENT_NO': '01446',
#     'RENT_NM': '중랑전화국 교차로',
#     'RENT_ID_NM': '1446. 중랑전화국 교차로',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 중랑구 면목동 282-8',
#     'STA_ADD2': '중랑전화국 교차로',
#     'STA_LAT': '37.59130096',
#     'STA_LONG': '127.08032990',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '97'},
#    {'STA_LOC': '중랑구',
#     'RENT_ID': 'ST-1098',
#     'RENT_NO': '01447',
#     'RENT_NM': '면목역 3번출구',
#     'RENT_ID_NM': '1447. 면목역 3번출구',
#     'HOLD_NUM': '17',
#     'STA_ADD1': '서울특별시 중랑구 면목동 120-2',
#     'STA_ADD2': '면목역 3번출구',
#     'STA_LAT': '37.58890152',
#     'STA_LONG': '127.08728027',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '98'},
#    {'STA_LOC': '중랑구',
#     'RENT_ID': 'ST-1099',
#     'RENT_NO': '01448',
#     'RENT_NM': '코스트코 상봉점',
#     'RENT_ID_NM': '1448. 코스트코 상봉점',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 중랑구 상봉동 160-3',
#     'STA_ADD2': '코스트코 상봉점',
#     'STA_LAT': '37.59732056',
#     'STA_LONG': '127.08979797',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '99'},
#    {'STA_LOC': '마포구',
#     'RENT_ID': 'ST-11',
#     'RENT_NO': '00109',
#     'RENT_NM': '제일빌딩 앞',
#     'RENT_ID_NM': '109. 제일빌딩 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 마포구 어울마당로 26',
#     'STA_ADD2': '12-2',
#     'STA_LAT': '37.54769135',
#     'STA_LONG': '126.91998291',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '100'},
#    {'STA_LOC': '마포구',
#     'RENT_ID': 'ST-110',
#     'RENT_NO': '00400',
#     'RENT_NM': '상암한화오벨리스크 1차 앞',
#     'RENT_ID_NM': '400. 상암한화오벨리스크 1차 앞',
#     'HOLD_NUM': '14',
#     'STA_ADD1': '서울특별시 마포구 구룡길 19',
#     'STA_ADD2': '상암한화오벨리스크 1차 앞',
#     'STA_LAT': '37.58752441',
#     'STA_LONG': '126.88300323',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '101'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1100',
#     'RENT_NO': '01526',
#     'RENT_NM': '강북종합시장 앞',
#     'RENT_ID_NM': '1526. 강북종합시장 앞',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 강북구 수유동 140',
#     'STA_ADD2': '수유동 채선당앞',
#     'STA_LAT': '37.64173889',
#     'STA_LONG': '127.02462769',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '102'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1101',
#     'RENT_NO': '01527',
#     'RENT_NM': '미아역 1번 출구 뒤',
#     'RENT_ID_NM': '1527. 미아역 1번 출구 뒤',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강북구 미아동 194-1',
#     'STA_ADD2': '미아역 1번 출구 뒤',
#     'STA_LAT': '37.62733459',
#     'STA_LONG': '127.02605438',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '103'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1102',
#     'RENT_NO': '01528',
#     'RENT_NM': '삼각산동 주민센터',
#     'RENT_ID_NM': '1528. 삼각산동 주민센터',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강북구 미아동 813-8',
#     'STA_ADD2': '삼각산동 주민센터',
#     'STA_LAT': '37.61503601',
#     'STA_LONG': '127.02069855',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '104'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1103',
#     'RENT_NO': '01529',
#     'RENT_NM': '미아동 한국전력공사',
#     'RENT_ID_NM': '1529. 미아동 한국전력공사',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 강북구 미아동 194-1',
#     'STA_ADD2': '미아동 한국전력공사',
#     'STA_LAT': '37.63018036',
#     'STA_LONG': '127.02490997',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '105'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1104',
#     'RENT_NO': '01530',
#     'RENT_NM': '광산사거리',
#     'RENT_ID_NM': '1530. 광산사거리',
#     'HOLD_NUM': '13',
#     'STA_ADD1': '서울특별시 강북구 노해로 87 ',
#     'STA_ADD2': '광산사거리',
#     'STA_LAT': '37.64355087',
#     'STA_LONG': '127.02234650',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '106'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1105',
#     'RENT_NO': '01531',
#     'RENT_NM': '미아사거리 1번 출구',
#     'RENT_ID_NM': '1531. 미아사거리 1번 출구',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강북구 미아동 66-1',
#     'STA_ADD2': '미아사거리 1번 출구',
#     'STA_LAT': '37.61395645',
#     'STA_LONG': '127.03025055',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '107'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1106',
#     'RENT_NO': '01532',
#     'RENT_NM': '번3동 주민센터 교차로',
#     'RENT_ID_NM': '1532. 번3동 주민센터 교차로',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강북구 번동 2-2',
#     'STA_ADD2': '번3동 주민센터 교차로',
#     'STA_LAT': '37.62635422',
#     'STA_LONG': '127.04744720',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '108'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1107',
#     'RENT_NO': '01533',
#     'RENT_NM': '번동 주공3, 4단지 교차로',
#     'RENT_ID_NM': '1533. 번동 주공3, 4단지 교차로',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강북구 번동 254',
#     'STA_ADD2': '번동 주공3, 4단지 교차로',
#     'STA_LAT': '37.62991714',
#     'STA_LONG': '127.04091644',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '109'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1108',
#     'RENT_NO': '01534',
#     'RENT_NM': '북서울 꿈의 숲 동문',
#     'RENT_ID_NM': '1534. 북서울 꿈의 숲 동문',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 강북구 번동 105',
#     'STA_ADD2': '북서울 꿈의 숲 동문',
#     'STA_LAT': '37.61963654',
#     'STA_LONG': '127.04453278',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '110'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1109',
#     'RENT_NO': '01535',
#     'RENT_NM': '효성인텔리안 앞',
#     'RENT_ID_NM': '1535. 효성인텔리안 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 강북구  수유동 230-7',
#     'STA_ADD2': '효성인텔리안 앞',
#     'STA_LAT': '37.63629150',
#     'STA_LONG': '127.02337646',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '111'},
#    {'STA_LOC': '성동구',
#     'RENT_ID': 'ST-111',
#     'RENT_NO': '00513',
#     'RENT_NM': '뚝섬역 5번 출구 정류소 옆',
#     'RENT_ID_NM': '513. 뚝섬역 5번 출구 정류소 옆',
#     'HOLD_NUM': '13',
#     'STA_ADD1': '서울특별시 성동구 아차산로 18',
#     'STA_ADD2': '뚝섬역 5번 출구 정류소 옆',
#     'STA_LAT': '37.54630661',
#     'STA_LONG': '127.04980469',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '112'},
#    {'STA_LOC': '강북구',
#     'RENT_ID': 'ST-1110',
#     'RENT_NO': '01536',
#     'RENT_NM': '번동 두산위브 101동 옆',
#     'RENT_ID_NM': '1536. 번동 두산위브 101동 옆',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 강북구 번동 386-17',
#     'STA_ADD2': '번동 두산위브 101동 옆',
#     'STA_LAT': '37.63626099',
#     'STA_LONG': '127.03217316',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '113'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1111',
#     'RENT_NO': '01643',
#     'RENT_NM': '태릉입구역 8번출구',
#     'RENT_ID_NM': '1643. 태릉입구역 8번출구',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 노원구 공릉동 687-6',
#     'STA_ADD2': '태릉입구역 8번출구',
#     'STA_LAT': '37.61736679',
#     'STA_LONG': '127.07521057',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '114'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1114',
#     'RENT_NO': '01646',
#     'RENT_NM': '삼육대 입구',
#     'RENT_ID_NM': '1646. 삼육대 입구',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 노원구 공릉동 26-43',
#     'STA_ADD2': '삼육대 입구',
#     'STA_LAT': '37.63848877',
#     'STA_LONG': '127.10790253',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '115'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1118',
#     'RENT_NO': '01650',
#     'RENT_NM': '중계근린공원내',
#     'RENT_ID_NM': '1650. 중계근린공원내',
#     'HOLD_NUM': '25',
#     'STA_ADD1': '서울특별시 노원구 중계동 506-3',
#     'STA_ADD2': '중계근린공원내',
#     'STA_LAT': '37.63957977',
#     'STA_LONG': '127.06510162',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '116'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1119',
#     'RENT_NO': '01651',
#     'RENT_NM': '상계동 우방유쉘아파트 앞',
#     'RENT_ID_NM': '1651. 상계동 우방유쉘아파트 앞',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 노원구 상계동 1118-9',
#     'STA_ADD2': '맥도날드 상계점 앞',
#     'STA_LAT': '37.67237473',
#     'STA_LONG': '127.05599213',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '117'},
#    {'STA_LOC': '성동구',
#     'RENT_ID': 'ST-112',
#     'RENT_NO': '00514',
#     'RENT_NM': '성수사거리 버스정류장 앞',
#     'RENT_ID_NM': '514. 성수사거리 버스정류장 앞',
#     'HOLD_NUM': '12',
#     'STA_ADD1': '서울특별시 성동구 아차산로 171',
#     'STA_ADD2': '성수사거리 버스정류장 앞',
#     'STA_LAT': '37.54257965',
#     'STA_LONG': '127.06330872',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '118'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1120',
#     'RENT_NO': '01652',
#     'RENT_NM': '파르코 앞',
#     'RENT_ID_NM': '1652. 파르코 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 노원구 상계동 1263',
#     'STA_ADD2': '파르코 앞',
#     'STA_LAT': '37.68000031',
#     'STA_LONG': '127.05558014',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '119'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1121',
#     'RENT_NO': '01653',
#     'RENT_NM': '노원역1번출구',
#     'RENT_ID_NM': '1653. 노원역1번출구',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 노원구 상계동 335-4',
#     'STA_ADD2': '노원역1번출구',
#     'STA_LAT': '37.65620041',
#     'STA_LONG': '127.06362152',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '120'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1122',
#     'RENT_NO': '01654',
#     'RENT_NM': '당고개입구 오거리',
#     'RENT_ID_NM': '1654. 당고개입구 오거리',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 노원구 상계동 172-2',
#     'STA_ADD2': '보훈회관 대여소',
#     'STA_LAT': '37.66379166',
#     'STA_LONG': '127.07544708',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '121'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1123',
#     'RENT_NO': '01655',
#     'RENT_NM': '공릉1단지아파트',
#     'RENT_ID_NM': '1655. 공릉1단지아파트',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 중랑구 동일로 1127',
#     'STA_ADD2': '공릉1단지아파트',
#     'STA_LAT': '37.63111115',
#     'STA_LONG': '127.07015991',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '122'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1124',
#     'RENT_NO': '01656',
#     'RENT_NM': '중앙하이츠 아파트 입구',
#     'RENT_ID_NM': '1656. 중앙하이츠 아파트 입구',
#     'HOLD_NUM': '12',
#     'STA_ADD1': '서울특별시 노원구 노원로 434 상계2차중앙하이츠아파트',
#     'STA_ADD2': '',
#     'STA_LAT': '37.65501785',
#     'STA_LONG': '127.06750488',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '123'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1125',
#     'RENT_NO': '01657',
#     'RENT_NM': '노원구청',
#     'RENT_ID_NM': '1657. 노원구청 ',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 노원구 노해로 437 ',
#     'STA_ADD2': '노원구청 ',
#     'STA_LAT': '37.65404892',
#     'STA_LONG': '127.05732727',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '124'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1127',
#     'RENT_NO': '01659',
#     'RENT_NM': '중계동 을지중학교',
#     'RENT_ID_NM': '1659. 중계동 을지중학교',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 노원구 중계동 370',
#     'STA_ADD2': '중계동 을지중학교',
#     'STA_LAT': '37.65032959',
#     'STA_LONG': '127.07160187',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '125'},
#    {'STA_LOC': '노원구',
#     'RENT_ID': 'ST-1128',
#     'RENT_NO': '01660',
#     'RENT_NM': '서울시립과학관',
#     'RENT_ID_NM': '1660. 서울시립과학관',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 노원구 하계동 266',
#     'STA_ADD2': '서울시립과학관',
#     'STA_LAT': '37.64207077',
#     'STA_LONG': '127.07662201',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '126'},
#    {'STA_LOC': '도봉구',
#     'RENT_ID': 'ST-1129',
#     'RENT_NO': '01713',
#     'RENT_NM': '쌍문동 이안아파트 앞',
#     'RENT_ID_NM': '1713. 쌍문동 이안아파트 앞',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 도봉구 쌍문동 315-488',
#     'STA_ADD2': '',
#     'STA_LAT': '37.65165329',
#     'STA_LONG': '127.02848816',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '127'},
#    {'STA_LOC': '광진구',
#     'RENT_ID': 'ST-113',
#     'RENT_NO': '00515',
#     'RENT_NM': '광양중학교 앞',
#     'RENT_ID_NM': '515. 광양중학교 앞',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 광진구 자양로3길 7',
#     'STA_ADD2': '광양중학교 앞',
#     'STA_LAT': '37.53023529',
#     'STA_LONG': '127.08683014',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '128'},
#    {'STA_LOC': '도봉구',
#     'RENT_ID': 'ST-1130',
#     'RENT_NO': '01714',
#     'RENT_NM': '도봉문화정보도서관 삼거리',
#     'RENT_ID_NM': '1714. 도봉문화정보도서관 삼거리',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 도봉구 덕릉로 315',
#     'STA_ADD2': '도봉문화정보도서관 삼거리',
#     'STA_LAT': '37.64463043',
#     'STA_LONG': '127.04460907',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '129'},
#    {'STA_LOC': '도봉구',
#     'RENT_ID': 'ST-1131',
#     'RENT_NO': '01715',
#     'RENT_NM': '서울특별시교육청도봉도서관',
#     'RENT_ID_NM': '1715. 서울특별시교육청도봉도서관',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 도봉구 삼양로556',
#     'STA_ADD2': '서울특별시교육청도봉도서관',
#     'STA_LAT': '37.65317917',
#     'STA_LONG': '127.01278687',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '130'},
#    {'STA_LOC': '도봉구',
#     'RENT_ID': 'ST-1132',
#     'RENT_NO': '01716',
#     'RENT_NM': '창동역 1번출구 건너편',
#     'RENT_ID_NM': '1716. 창동역 1번출구 건너편',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 도봉구 마들로11길 20',
#     'STA_ADD2': '하나로마트 창동점',
#     'STA_LAT': '37.65420151',
#     'STA_LONG': '127.05072784',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '131'},
#    {'STA_LOC': '도봉구',
#     'RENT_ID': 'ST-1133',
#     'RENT_NO': '01717',
#     'RENT_NM': '시립창동운동장 입구',
#     'RENT_ID_NM': '1717. 시립창동운동장 입구',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 도봉구 창동 1-24',
#     'STA_ADD2': '시립창동운동장 입구',
#     'STA_LAT': '37.65570831',
#     'STA_LONG': '127.05010223',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '132'},
#    {'STA_LOC': '도봉구',
#     'RENT_ID': 'ST-1135',
#     'RENT_NO': '01719',
#     'RENT_NM': '신도봉사거리 버스정류장',
#     'RENT_ID_NM': '1719. 신도봉사거리 버스정류장',
#     'HOLD_NUM': '6',
#     'STA_ADD1': '서울특별시 도봉구 도봉로 771',
#     'STA_ADD2': '신도봉사거리 버스정류장',
#     'STA_LAT': '37.67328262',
#     'STA_LONG': '127.04399109',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '133'},
#    {'STA_LOC': '도봉구',
#     'RENT_ID': 'ST-1136',
#     'RENT_NO': '01720',
#     'RENT_NM': '도봉구청 옆(중랑천변)',
#     'RENT_ID_NM': '1720. 도봉구청 옆(중랑천변)',
#     'HOLD_NUM': '27',
#     'STA_ADD1': '서울특별시 도봉구 마들로 656',
#     'STA_ADD2': '도봉구청 옆(중랑천변)',
#     'STA_LAT': '37.66867065',
#     'STA_LONG': '127.04798126',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '134'},
#    {'STA_LOC': '도봉구',
#     'RENT_ID': 'ST-1137',
#     'RENT_NO': '01721',
#     'RENT_NM': '창동역 2번출구',
#     'RENT_ID_NM': '1721. 창동역 2번출구 ',
#     'HOLD_NUM': '12',
#     'STA_ADD1': '서울특별시 노원구 창동 74-2 ',
#     'STA_ADD2': '창동역 2번출구 ',
#     'STA_LAT': '37.65301514',
#     'STA_LONG': '127.04699707',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '135'},
#    {'STA_LOC': '광진구',
#     'RENT_ID': 'ST-114',
#     'RENT_NO': '00516',
#     'RENT_NM': '광진메디칼 앞',
#     'RENT_ID_NM': '516. 광진메디칼 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 광진구 광나루로 355',
#     'STA_ADD2': '광진메디컬앞',
#     'STA_LAT': '37.54840469',
#     'STA_LONG': '127.06936646',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '136'},
#    {'STA_LOC': '금천구',
#     'RENT_ID': 'ST-1140',
#     'RENT_NO': '01839',
#     'RENT_NM': '수출의 다리 아래',
#     'RENT_ID_NM': '1839. 수출의 다리 아래',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 금천구 가산동 60-35',
#     'STA_ADD2': '',
#     'STA_LAT': '37.47743607',
#     'STA_LONG': '126.88615417',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '137'},
#    {'STA_LOC': '금천구',
#     'RENT_ID': 'ST-1141',
#     'RENT_NO': '01840',
#     'RENT_NM': '솔브레인이엔지 뒤편',
#     'RENT_ID_NM': '1840. 솔브레인이엔지 뒤편',
#     'HOLD_NUM': '20',
# ...
#     'END_INDEX': 0,
#     'RNUM': '954'},
#    {'STA_LOC': '중구',
#     'RENT_ID': 'ST-196',
#     'RENT_NO': '00381',
#     'RENT_NM': '장충체육관',
#     'RENT_ID_NM': '381. 장충체육관',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 중구 장충동2가 200-99',
#     'STA_ADD2': '장충체육관',
#     'STA_LAT': '37.55853271',
#     'STA_LONG': '127.00698853',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '955'},
#    {'STA_LOC': '구로구',
#     'RENT_ID': 'ST-1960',
#     'RENT_NO': '02820',
#     'RENT_NM': '신세기아파트 앞',
#     'RENT_ID_NM': '2820.신세기아파트 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 구로구 개봉로19길 87 로얄파크',
#     'STA_ADD2': '',
#     'STA_LAT': '37.49396515',
#     'STA_LONG': '126.85304260',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '956'},
#    {'STA_LOC': '구로구',
#     'RENT_ID': 'ST-1961',
#     'RENT_NO': '02821',
#     'RENT_NM': '청구아파트 앞',
#     'RENT_ID_NM': '2821.청구아파트 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 구로구 중앙로6길 5-15 청구아파트',
#     'STA_ADD2': '',
#     'STA_LAT': '37.50119019',
#     'STA_LONG': '126.86353302',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '957'},
#    {'STA_LOC': '구로구',
#     'RENT_ID': 'ST-1962',
#     'RENT_NO': '02822',
#     'RENT_NM': '제니스스포츠 앞',
#     'RENT_ID_NM': '2822.제니스스포츠 앞',
#     'HOLD_NUM': '14',
#     'STA_ADD1': '서울특별시 구로구 고척동 60-42',
#     'STA_ADD2': '',
#     'STA_LAT': '37.50452042',
#     'STA_LONG': '126.87055206',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '958'},
#    {'STA_LOC': '구로구',
#     'RENT_ID': 'ST-1963',
#     'RENT_NO': '02823',
#     'RENT_NM': '중앙유통단지 앞',
#     'RENT_ID_NM': '2823.중앙유통단지 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 구로구 구로동 635-32',
#     'STA_ADD2': '',
#     'STA_LAT': '37.49981308',
#     'STA_LONG': '126.87431335',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '959'},
#    {'STA_LOC': '구로구',
#     'RENT_ID': 'ST-1964',
#     'RENT_NO': '02824',
#     'RENT_NM': '미래사랑어린이공원 앞',
#     'RENT_ID_NM': '2824.미래사랑어린이공원 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 구로구 경인로 673-1 가로판매대',
#     'STA_ADD2': '',
#     'STA_LAT': '37.51006317',
#     'STA_LONG': '126.88956451',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '960'},
#    {'STA_LOC': '구로구',
#     'RENT_ID': 'ST-1965',
#     'RENT_NO': '02825',
#     'RENT_NM': '초롱타운 앞',
#     'RENT_ID_NM': '2825.초롱타운 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 구로구 구로동 467-62',
#     'STA_ADD2': '',
#     'STA_LAT': '37.49545288',
#     'STA_LONG': '126.88039398',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '961'},
#    {'STA_LOC': '구로구',
#     'RENT_ID': 'ST-1966',
#     'RENT_NO': '02826',
#     'RENT_NM': '가마산지하보도 옆',
#     'RENT_ID_NM': '2826.가마산지하보도 옆',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 구로구 가마산로 141',
#     'STA_ADD2': '',
#     'STA_LAT': '37.48864746',
#     'STA_LONG': '126.88047028',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '962'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1967',
#     'RENT_NO': '00295',
#     'RENT_NM': '영등포공원 분수대 앞',
#     'RENT_ID_NM': '295.영등포공원 분수대 앞',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 신길로 275 영등포문화원',
#     'STA_ADD2': '',
#     'STA_LAT': '37.51481247',
#     'STA_LONG': '126.91170502',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '963'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1968',
#     'RENT_NO': '00296',
#     'RENT_NM': 'KT플라자 영등포점',
#     'RENT_ID_NM': '296.KT플라자 영등포점',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 영등포구 영등포동8가 29-1',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52630234',
#     'STA_LONG': '126.90538025',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '964'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1969',
#     'RENT_NO': '00297',
#     'RENT_NM': '국회3문',
#     'RENT_ID_NM': '297.국회3문',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 여의도동 8-1',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52863693',
#     'STA_LONG': '126.91267395',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '965'},
#    {'STA_LOC': '중구',
#     'RENT_ID': 'ST-197',
#     'RENT_NO': '00382',
#     'RENT_NM': '약수역 10번출구 앞',
#     'RENT_ID_NM': '382. 약수역 10번출구 앞',
#     'HOLD_NUM': '7',
#     'STA_ADD1': '서울특별시 중구 신당동 357-1',
#     'STA_ADD2': '약수역 10번출구 앞',
#     'STA_LAT': '37.55519867',
#     'STA_LONG': '127.01004791',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '966'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1970',
#     'RENT_NO': '00298',
#     'RENT_NM': 'KBS 연구동 건너편',
#     'RENT_ID_NM': '298.KBS 연구동 건너편',
#     'HOLD_NUM': '25',
#     'STA_ADD1': '서울특별시 영등포구 여의도동 1-1',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52750778',
#     'STA_LONG': '126.91429901',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '967'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1971',
#     'RENT_NO': '00299',
#     'RENT_NM': '여의도 순복음교회',
#     'RENT_ID_NM': '299.여의도 순복음교회',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 여의서로 60-2 가로판매대22',
#     'STA_ADD2': '',
#     'STA_LAT': '37.53179169',
#     'STA_LONG': '126.92245483',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '968'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1972',
#     'RENT_NO': '03201',
#     'RENT_NM': '당산skv1센터',
#     'RENT_ID_NM': '3201.당산skv1센터',
#     'HOLD_NUM': '9',
#     'STA_ADD1': '서울특별시 영등포구 당산동4가 80-2',
#     'STA_ADD2': '',
#     'STA_LAT': '37.53073502',
#     'STA_LONG': '126.89916992',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '969'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1973',
#     'RENT_NO': '03202',
#     'RENT_NM': '당산롯데캐슬프레스티지',
#     'RENT_ID_NM': '3202.당산롯데캐슬프레스티지',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 영등포구 당산동4가 10-21',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52869034',
#     'STA_LONG': '126.90386200',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '970'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1974',
#     'RENT_NO': '03203',
#     'RENT_NM': '도림동배드민턴체육관',
#     'RENT_ID_NM': '3203.도림동배드민턴체육관',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 도신로15길 5 영등포 다목적 배드민턴 체육관',
#     'STA_ADD2': '',
#     'STA_LAT': '37.50611496',
#     'STA_LONG': '126.89859009',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '971'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1975',
#     'RENT_NO': '03204',
#     'RENT_NM': '도림고가도로 밑',
#     'RENT_ID_NM': '3204.도림고가도로 밑',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 도림동 187-87',
#     'STA_ADD2': '',
#     'STA_LAT': '37.51124191',
#     'STA_LONG': '126.89818573',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '972'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1976',
#     'RENT_NO': '03205',
#     'RENT_NM': '문래현대2차',
#     'RENT_ID_NM': '3205.문래현대2차',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 문래로4길 6 현대아파트',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52021790',
#     'STA_LONG': '126.88216400',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '973'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1977',
#     'RENT_NO': '03206',
#     'RENT_NM': '문래동 주민센터',
#     'RENT_ID_NM': '3206.문래동 주민센터',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 영등포구 문래동3가 55-13',
#     'STA_ADD2': '',
#     'STA_LAT': '37.51707077',
#     'STA_LONG': '126.89908600',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '974'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1978',
#     'RENT_NO': '03207',
#     'RENT_NM': '양남사거리1',
#     'RENT_ID_NM': '3207.양남사거리1',
#     'HOLD_NUM': '12',
#     'STA_ADD1': '서울특별시 영등포구 선유로 87',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52182770',
#     'STA_LONG': '126.88972473',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '975'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1979',
#     'RENT_NO': '03208',
#     'RENT_NM': '양평역 2번출구',
#     'RENT_ID_NM': '3208.양평역 2번출구',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 영등포구 양평동2가 33-80',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52555466',
#     'STA_LONG': '126.88587189',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '976'},
#    {'STA_LOC': '중구',
#     'RENT_ID': 'ST-198',
#     'RENT_NO': '00383',
#     'RENT_NM': '신당역 12번 출구 뒤',
#     'RENT_ID_NM': '383. 신당역 12번 출구 뒤',
#     'HOLD_NUM': '27',
#     'STA_ADD1': '서울특별시 중구 다산로 258 리마크빌 동대문',
#     'STA_ADD2': '',
#     'STA_LAT': '37.56591797',
#     'STA_LONG': '127.01642609',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '977'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1980',
#     'RENT_NO': '03209',
#     'RENT_NM': '롯데칠성음료신협양평분점(근린공원)',
#     'RENT_ID_NM': '3209.롯데칠성음료신협양평분점(근린공원)',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 양평동 1-1',
#     'STA_ADD2': '',
#     'STA_LAT': '37.54185104',
#     'STA_LONG': '126.89380646',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '978'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1981',
#     'RENT_NO': '03210',
#     'RENT_NM': '신길 꿈에그린아파트',
#     'RENT_ID_NM': '3210.신길 꿈에그린아파트',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 영등포구 신길로 119 신길뉴타운 한화 꿈에그린',
#     'STA_ADD2': '',
#     'STA_LAT': '37.50313568',
#     'STA_LONG': '126.91007996',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '979'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1982',
#     'RENT_NO': '03211',
#     'RENT_NM': '신길 래미안 프레비뉴',
#     'RENT_ID_NM': '3211.신길 래미안 프레비뉴',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 영등포구 가마산로 442 래미안프레비뉴',
#     'STA_ADD2': '',
#     'STA_LAT': '37.50438309',
#     'STA_LONG': '126.90808868',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '980'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1983',
#     'RENT_NO': '03212',
#     'RENT_NM': '신풍역 6번출구',
#     'RENT_ID_NM': '3212.신풍역 6번출구',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 신풍로 77 래미안에스티움',
#     'STA_ADD2': '',
#     'STA_LAT': '37.50025558',
#     'STA_LONG': '126.91215515',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '981'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1984',
#     'RENT_NO': '03213',
#     'RENT_NM': '썬프라자 웨딩홀뷔페',
#     'RENT_ID_NM': '3213.썬프라자 웨딩홀뷔페',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 신길로 39-3 가로판매대84',
#     'STA_ADD2': '',
#     'STA_LAT': '37.49636459',
#     'STA_LONG': '126.90824890',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '982'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1985',
#     'RENT_NO': '03214',
#     'RENT_NM': '영등포 푸르지오 아파트 A',
#     'RENT_ID_NM': '3214.영등포 푸르지오 아파트 A',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 도신로29길 28 영등포푸르지오',
#     'STA_ADD2': '',
#     'STA_LAT': '37.51202393',
#     'STA_LONG': '126.90105438',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '983'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1986',
#     'RENT_NO': '03215',
#     'RENT_NM': '강변삼성래미안',
#     'RENT_ID_NM': '3215.강변삼성래미안',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 영등포구 당산동 121-317',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52974319',
#     'STA_LONG': '126.90782928',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '984'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1987',
#     'RENT_NO': '03216',
#     'RENT_NM': '국회의사당',
#     'RENT_ID_NM': '3216.국회의사당',
#     'HOLD_NUM': '13',
#     'STA_ADD1': '서울특별시 영등포구 의사당대로 1 국회',
#     'STA_ADD2': '',
#     'STA_LAT': '37.53266525',
#     'STA_LONG': '126.91376495',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '985'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1988',
#     'RENT_NO': '03217',
#     'RENT_NM': '우리은행 여의도한화금융센터',
#     'RENT_ID_NM': '3217.우리은행 여의도한화금융센터',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 63로 40 라이프오피스텔',
#     'STA_ADD2': '',
#     'STA_LAT': '37.51987457',
#     'STA_LONG': '126.93881989',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '986'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1989',
#     'RENT_NO': '03218',
#     'RENT_NM': '여의도 미원빌딩',
#     'RENT_ID_NM': '3218.여의도 미원빌딩',
#     'HOLD_NUM': '25',
#     'STA_ADD1': '서울특별시 영등포구 여의도동 4-2',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52166367',
#     'STA_LONG': '126.93087769',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '987'},
#    {'STA_LOC': '중구',
#     'RENT_ID': 'ST-199',
#     'RENT_NO': '00384',
#     'RENT_NM': '중림동삼거리',
#     'RENT_ID_NM': '384. 중림동삼거리',
#     'HOLD_NUM': '5',
#     'STA_ADD1': '서울특별시 중구 청파로 456',
#     'STA_ADD2': '종로학원본원 앞',
#     'STA_LAT': '37.55978012',
#     'STA_LONG': '126.96850586',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '988'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1990',
#     'RENT_NO': '03219',
#     'RENT_NM': '영등포역 1번출구',
#     'RENT_ID_NM': '3219.영등포역 1번출구',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 영등포동 618-9',
#     'STA_ADD2': '',
#     'STA_LAT': '37.51484680',
#     'STA_LONG': '126.90773010',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '989'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1991',
#     'RENT_NO': '03220',
#     'RENT_NM': '래미안에스티움 앞 (신풍로)',
#     'RENT_ID_NM': '3220.래미안에스티움 앞 (신풍로)',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 영등포구 신길동 3859',
#     'STA_ADD2': '',
#     'STA_LAT': '37.50013733',
#     'STA_LONG': '126.91397858',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '990'},
#    {'STA_LOC': '영등포구',
#     'RENT_ID': 'ST-1992',
#     'RENT_NO': '03221',
#     'RENT_NM': '서울특별시 남부교육지원청',
#     'RENT_ID_NM': '3221.서울특별시 남부교육지원청',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 영등포구 문래로 121 서울특별시 남부교육지원청',
#     'STA_ADD2': '',
#     'STA_LAT': '37.51933289',
#     'STA_LONG': '126.89530182',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '991'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1993',
#     'RENT_NO': '00767',
#     'RENT_NM': '신정숲속마을아파트',
#     'RENT_ID_NM': '767.신정숲속마을아파트',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 신정로 110 신정숲속마을',
#     'STA_ADD2': '',
#     'STA_LAT': '37.50574493',
#     'STA_LONG': '126.83631134',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '992'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1994',
#     'RENT_NO': '00768',
#     'RENT_NM': '목동5단지아파트 501동',
#     'RENT_ID_NM': '768.목동5단지아파트 501동',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 양천구 목동동로 350 목동신시가지아파트5단지',
#     'STA_ADD2': '',
#     'STA_LAT': '37.53566742',
#     'STA_LONG': '126.88158417',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '993'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1995',
#     'RENT_NO': '00769',
#     'RENT_NM': 'CBS방송국 앞',
#     'RENT_ID_NM': '769.CBS방송국 앞',
#     'HOLD_NUM': '20',
#     'STA_ADD1': '서울특별시 양천구 목동서로 159-3 가로판매대2',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52785492',
#     'STA_LONG': '126.87467194',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '994'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1996',
#     'RENT_NO': '00770',
#     'RENT_NM': '목동역5번출구',
#     'RENT_ID_NM': '770.목동역5번출구',
#     'HOLD_NUM': '12',
#     'STA_ADD1': '서울특별시 양천구 목동 927-10',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52571487',
#     'STA_LONG': '126.86486816',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '995'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1997',
#     'RENT_NO': '00771',
#     'RENT_NM': '목동아파트 703동 앞',
#     'RENT_ID_NM': '771.목동아파트 703동 앞',
#     'HOLD_NUM': '8',
#     'STA_ADD1': '서울특별시 양천구 목동로 212 목동신시가지아파트7단지',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52820587',
#     'STA_LONG': '126.87016296',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '996'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1998',
#     'RENT_NO': '00772',
#     'RENT_NM': '대원칸타빌1차아파트',
#     'RENT_ID_NM': '772.대원칸타빌1차아파트',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 양천구 목동 812',
#     'STA_ADD2': '',
#     'STA_LAT': '37.52825928',
#     'STA_LONG': '126.86426544',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '997'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1999',
#     'RENT_NO': '00773',
#     'RENT_NM': '염창역 3, 4번 출구 사이',
#     'RENT_ID_NM': '773.염창역 3, 4번 출구 사이',
#     'HOLD_NUM': '10',
#     'STA_ADD1': '서울특별시 양천구 공항대로 630 어바니엘',
#     'STA_ADD2': '',
#     'STA_LAT': '37.54670715',
#     'STA_LONG': '126.87457275',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '998'},
#    {'STA_LOC': '마포구',
#     'RENT_ID': 'ST-20',
#     'RENT_NO': '00114',
#     'RENT_NM': '홍대입구역 8번출구 앞',
#     'RENT_ID_NM': '114. 홍대입구역 8번출구 앞',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 마포구 양화로18길 3',
#     'STA_ADD2': '192-5',
#     'STA_LAT': '37.55706024',
#     'STA_LONG': '126.92442322',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '999'},
#    {'STA_LOC': '마포구',
#     'RENT_ID': 'ST-200',
#     'RENT_NO': '00142',
#     'RENT_NM': '아현역 4번출구 앞',
#     'RENT_ID_NM': '142. 아현역 4번출구 앞',
#     'HOLD_NUM': '11',
#     'STA_ADD1': '서울특별시 마포구 아현동 329-15',
#     'STA_ADD2': '아현역 4번출구 앞',
#     'STA_LAT': '37.55720139',
#     'STA_LONG': '126.95566559',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '1000'}]}}

# %% [markdown]
# ## 3) 데이터 파악하기

# %%
response_json.keys()
# Out:
# dict_keys(['stationInfo'])

# %%
response_json["stationInfo"]
# Out:
# {'list_total_count': '3171',
#  'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#  'row': [{'STA_LOC': '마포구',
#    'RENT_ID': 'ST-10',
#    'RENT_NO': '00108',
#    'RENT_NM': '서교동 사거리',
#    'RENT_ID_NM': '108. 서교동 사거리',
#    'HOLD_NUM': '12',
#    'STA_ADD1': '서울특별시 마포구 양화로 93',
#    'STA_ADD2': '427',
#    'STA_LAT': '37.55274582',
#    'STA_LONG': '126.91861725',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '1'},
#   {'STA_LOC': '광진구',
#    'RENT_ID': 'ST-100',
#    'RENT_NO': '00503',
#    'RENT_NM': '더샵스타시티 C동 앞',
#    'RENT_ID_NM': '503. 더샵스타시티 C동 앞',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 광진구 아차산로 262',
#    'STA_ADD2': '더샵스타시티 C동 앞',
#    'STA_LAT': '37.53666687',
#    'STA_LONG': '127.07359314',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '2'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1000',
#    'RENT_NO': '00729',
#    'RENT_NM': '서부식자재마트 건너편',
#    'RENT_ID_NM': '729. 서부식자재마트 건너편',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 신정동 236 ',
#    'STA_ADD2': '서부식자재마트 건너편',
#    'STA_LAT': '37.51037979',
#    'STA_LONG': '126.86679840',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '3'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1002',
#    'RENT_NO': '00731',
#    'RENT_NM': '서울시 도로환경관리센터',
#    'RENT_ID_NM': '731. 서울시 도로환경관리센터',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 목동동로 316-6',
#    'STA_ADD2': '서울시 도로환경관리센터',
#    'STA_LAT': '37.52989960',
#    'STA_LONG': '126.87654114',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '4'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1003',
#    'RENT_NO': '00732',
#    'RENT_NM': '신월중학교',
#    'RENT_ID_NM': '732. 신월중학교',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 화곡로 59',
#    'STA_ADD2': '신월동 이마트',
#    'STA_LAT': '37.53955078',
#    'STA_LONG': '126.82830048',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '5'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1004',
#    'RENT_NO': '00733',
#    'RENT_NM': '신정이펜하우스314동',
#    'RENT_ID_NM': '733. 신정이펜하우스314동',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 신정이펜1로50 ',
#    'STA_ADD2': '신정이펜하우스314동',
#    'STA_LAT': '37.51409912',
#    'STA_LONG': '126.83100128',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '6'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1005',
#    'RENT_NO': '00734',
#    'RENT_NM': '신트리공원 입구',
#    'RENT_ID_NM': '734. 신트리공원 입구',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 신정동 310-8 ',
#    'STA_ADD2': '신트리공원 입구',
#    'STA_LAT': '37.51395035',
#    'STA_LONG': '126.85605621',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '7'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1006',
#    'RENT_NO': '00735',
#    'RENT_NM': '영도초등학교',
#    'RENT_ID_NM': '735. 영도초등학교',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 목동중앙로 70 서울영도초등학교',
#    'STA_ADD2': '',
#    'STA_LAT': '37.53637695',
#    'STA_LONG': '126.87151337',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '8'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1007',
#    'RENT_NO': '00736',
#    'RENT_NM': '오솔길공원',
#    'RENT_ID_NM': '736. 오솔길공원',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 남부순환로70길11-9',
#    'STA_ADD2': '오솔길공원',
#    'STA_LAT': '37.52219009',
#    'STA_LONG': '126.83670044',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '9'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1008',
#    'RENT_NO': '00737',
#    'RENT_NM': '장수공원',
#    'RENT_ID_NM': '737. 장수공원',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 양천구 신정동 1235',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52231216',
#    'STA_LONG': '126.84904480',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '10'},
#   {'STA_LOC': '광진구',
#    'RENT_ID': 'ST-101',
#    'RENT_NO': '00504',
#    'RENT_NM': '신자초교입구교차로',
#    'RENT_ID_NM': '504. 신자초교입구교차로',
#    'HOLD_NUM': '9',
#    'STA_ADD1': '서울특별시 광진구 뚝섬로 596',
#    'STA_ADD2': '신자초교입구교차로',
#    'STA_LAT': '37.53297043',
#    'STA_LONG': '127.07593536',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '11'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1010',
#    'RENT_NO': '00739',
#    'RENT_NM': '신월사거리',
#    'RENT_ID_NM': '739. 신월사거리',
#    'HOLD_NUM': '13',
#    'STA_ADD1': '서울특별시 양천구 남부순환로 334',
#    'STA_ADD2': '',
#    'STA_LAT': '37.53699493',
#    'STA_LONG': '126.82728577',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '12'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1011',
#    'RENT_NO': '00740',
#    'RENT_NM': '으뜸공원',
#    'RENT_ID_NM': '740. 으뜸공원',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 양천구 가로공원로 133',
#    'STA_ADD2': '으뜸공원',
#    'STA_LAT': '37.53636932',
#    'STA_LONG': '126.83171082',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '13'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1012',
#    'RENT_NO': '00741',
#    'RENT_NM': '화곡로 입구 교차로',
#    'RENT_ID_NM': '741. 화곡로 입구 교차로',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 신월동 258',
#    'STA_ADD2': '화곡로 입구 교차로',
#    'STA_LAT': '37.53952026',
#    'STA_LONG': '126.82540131',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '14'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1013',
#    'RENT_NO': '00742',
#    'RENT_NM': '등촌역 5번 출구 뒤',
#    'RENT_ID_NM': '742. 등촌역 5번 출구 뒤',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 등촌로 236',
#    'STA_ADD2': '등촌역 5번 출구 뒤',
#    'STA_LAT': '37.55073166',
#    'STA_LONG': '126.86457825',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '15'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1014',
#    'RENT_NO': '00743',
#    'RENT_NM': '현대6차아파트 101동 옆',
#    'RENT_ID_NM': '743. 현대6차아파트 101동 옆',
#    'HOLD_NUM': '22',
#    'STA_ADD1': '서울특별시 양천구 신정동 735-5',
#    'STA_ADD2': '현대6차아파트 101동 옆',
#    'STA_LAT': '37.50889969',
#    'STA_LONG': '126.84268188',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '16'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1015',
#    'RENT_NO': '00744',
#    'RENT_NM': '신목동역 2번 출구',
#    'RENT_ID_NM': '744. 신목동역 2번 출구',
#    'HOLD_NUM': '40',
#    'STA_ADD1': '서울특별시 양천구 목동중앙로 212 앞',
#    'STA_ADD2': '신목동역 2번 출구',
#    'STA_LAT': '37.54384232',
#    'STA_LONG': '126.88254547',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '17'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1016',
#    'RENT_NO': '00745',
#    'RENT_NM': '강서초등학교',
#    'RENT_ID_NM': '745. 강서초등학교',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 오목로 31 부근',
#    'STA_ADD2': '강서초등학교',
#    'STA_LAT': '37.52228165',
#    'STA_LONG': '126.83969879',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '18'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1017',
#    'RENT_NO': '00746',
#    'RENT_NM': '목동2단지 상가',
#    'RENT_ID_NM': '746. 목동2단지 상가',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 목동 902-5 ',
#    'STA_ADD2': '목동2단지 상가',
#    'STA_LAT': '37.53650284',
#    'STA_LONG': '126.87774658',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '19'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1018',
#    'RENT_NO': '00747',
#    'RENT_NM': '목동3단지 상가',
#    'RENT_ID_NM': '747. 목동3단지 상가',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 목동 903-6',
#    'STA_ADD2': '목동3단지 상가',
#    'STA_LAT': '37.53458023',
#    'STA_LONG': '126.87564850',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '20'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1019',
#    'RENT_NO': '00748',
#    'RENT_NM': '목동운동장',
#    'RENT_ID_NM': '748. 목동운동장',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 양천구 안양천로 939',
#    'STA_ADD2': '목동운동장',
#    'STA_LAT': '37.53025055',
#    'STA_LONG': '126.87930298',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '21'},
#   {'STA_LOC': '광진구',
#    'RENT_ID': 'ST-102',
#    'RENT_NO': '00505',
#    'RENT_NM': '자양사거리 광진아크로텔 앞',
#    'RENT_ID_NM': '505. 자양사거리 광진아크로텔 앞',
#    'HOLD_NUM': '11',
#    'STA_ADD1': '서울특별시 광진구 아차산로 355',
#    'STA_ADD2': '타워더모스트 광진아크로텔',
#    'STA_LAT': '37.53701019',
#    'STA_LONG': '127.08224487',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '22'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1020',
#    'RENT_NO': '00934',
#    'RENT_NM': '신사동 성당',
#    'RENT_ID_NM': '934. 신사동 성당',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 은평구 신사동 41-3',
#    'STA_ADD2': '신사동 성당',
#    'STA_LAT': '37.59714127',
#    'STA_LONG': '126.90959930',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '23'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1021',
#    'RENT_NO': '00935',
#    'RENT_NM': '역촌역 1번 출구',
#    'RENT_ID_NM': '935. 역촌역 1번 출구',
#    'HOLD_NUM': '7',
#    'STA_ADD1': '서울특별시 은평구 역촌동 17-55',
#    'STA_ADD2': '역촌역 1번 출구',
#    'STA_LAT': '37.60520172',
#    'STA_LONG': '126.92211151',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '24'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1023',
#    'RENT_NO': '00937',
#    'RENT_NM': '상림마을 롯데캐슬2단지 옆',
#    'RENT_ID_NM': '937. 상림마을 롯데캐슬2단지 옆',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 은평구 진관동 30-23',
#    'STA_ADD2': '상림마을 롯데캐슬2단지 옆',
#    'STA_LAT': '37.64585114',
#    'STA_LONG': '126.92379761',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '25'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1024',
#    'RENT_NO': '00938',
#    'RENT_NM': '금암 문화공원',
#    'RENT_ID_NM': '938. 금암 문화공원',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 은평구 진관동 44-28 ',
#    'STA_ADD2': '금암 문화공원',
#    'STA_LAT': '37.64468384',
#    'STA_LONG': '126.91845703',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '26'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1025',
#    'RENT_NO': '00939',
#    'RENT_NM': '은평구청 교차로',
#    'RENT_ID_NM': '939. 은평구청 교차로',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 은평구 응암동 82-31',
#    'STA_ADD2': '은평구청 교차로',
#    'STA_LAT': '37.60169983',
#    'STA_LONG': '126.92742157',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '27'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1027',
#    'RENT_NO': '00941',
#    'RENT_NM': '은평뉴타운 도서관',
#    'RENT_ID_NM': '941. 은평뉴타운 도서관',
#    'HOLD_NUM': '13',
#    'STA_ADD1': '서울특별시 은평구 진관동 141-27',
#    'STA_ADD2': '은평뉴타운 도서관',
#    'STA_LAT': '37.63722229',
#    'STA_LONG': '126.93330383',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '28'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1028',
#    'RENT_NO': '00942',
#    'RENT_NM': '상림마을 생태공원',
#    'RENT_ID_NM': '942. 상림마을 생태공원',
#    'HOLD_NUM': '9',
#    'STA_ADD1': '서울특별시 은평구 진관동 16-4',
#    'STA_ADD2': '상림마을 생태공원',
#    'STA_LAT': '37.64408112',
#    'STA_LONG': '126.92928314',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '29'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1029',
#    'RENT_NO': '00943',
#    'RENT_NM': '은평구청 보건소',
#    'RENT_ID_NM': '943. 은평구청 보건소',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 은평구 녹번동 84',
#    'STA_ADD2': '은평구청 보건소',
#    'STA_LAT': '37.60240173',
#    'STA_LONG': '126.92864990',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '30'},
#   {'STA_LOC': '성동구',
#    'RENT_ID': 'ST-103',
#    'RENT_NO': '00506',
#    'RENT_NM': '금호 어울림 아파트 앞',
#    'RENT_ID_NM': '506. 금호 어울림 아파트 앞',
#    'HOLD_NUM': '7',
#    'STA_ADD1': '서울특별시 성동구 광나루로 249',
#    'STA_ADD2': '송정금호어울림 아파트 앞',
#    'STA_LAT': '37.54906082',
#    'STA_LONG': '127.05779266',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '31'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1031',
#    'RENT_NO': '00945',
#    'RENT_NM': '기자촌 사거리 A',
#    'RENT_ID_NM': '945. 기자촌 사거리 A',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 은평구 진관동 149-17',
#    'STA_ADD2': '기자촌 사거리',
#    'STA_LAT': '37.63414001',
#    'STA_LONG': '126.93234253',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '32'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1032',
#    'RENT_NO': '00946',
#    'RENT_NM': '독바위역',
#    'RENT_ID_NM': '946. 독바위역 ',
#    'HOLD_NUM': '16',
#    'STA_ADD1': '서울특별시 은평구 불광로 129',
#    'STA_ADD2': '독바위역 ',
#    'STA_LAT': '37.61843872',
#    'STA_LONG': '126.93288422',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '33'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1033',
#    'RENT_NO': '00947',
#    'RENT_NM': '연신내 선일하이츠빌 정류소',
#    'RENT_ID_NM': '947. 연신내 선일하이츠빌 정류소',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 은평구 불광동 484-165',
#    'STA_ADD2': '연신내 선일하이츠빌 정류소',
#    'STA_LAT': '37.62266922',
#    'STA_LONG': '126.91999054',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '34'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1034',
#    'RENT_NO': '00948',
#    'RENT_NM': '디지털미디어 시티역 4번출구(DMC역)',
#    'RENT_ID_NM': '948. 디지털미디어 시티역 4번출구(DMC역)',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 은평구 증산동 239',
#    'STA_ADD2': '디지털미디어 시티역 4번출구',
#    'STA_LAT': '37.57720184',
#    'STA_LONG': '126.90235138',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '35'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1035',
#    'RENT_NO': '00949',
#    'RENT_NM': '연신내역 1번 출구',
#    'RENT_ID_NM': '949. 연신내역 1번 출구 ',
#    'HOLD_NUM': '6',
#    'STA_ADD1': '서울특별시 은평구 불광동 487-2',
#    'STA_ADD2': '연신내역 1번 출구 ',
#    'STA_LAT': '37.61978149',
#    'STA_LONG': '126.92080688',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '36'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1036',
#    'RENT_NO': '00950',
#    'RENT_NM': '구산역 2번 출구 예일여고 버스정류장',
#    'RENT_ID_NM': '950. 구산역 2번 출구 예일여고 버스정류장',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 은평구 연서로 124',
#    'STA_ADD2': '',
#    'STA_LAT': '37.60980225',
#    'STA_LONG': '126.91679382',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '37'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1037',
#    'RENT_NO': '00951',
#    'RENT_NM': '연신내역 6번출구옆',
#    'RENT_ID_NM': '951. 연신내역 6번출구옆',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 은평구 갈현동 389-15 ',
#    'STA_ADD2': '연신내역 6번출구옆',
#    'STA_LAT': '37.61930466',
#    'STA_LONG': '126.92059326',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '38'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1038',
#    'RENT_NO': '00952',
#    'RENT_NM': '서울연신중학교',
#    'RENT_ID_NM': '952. 서울연신중학교',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 은평구 불광동 400-4번지',
#    'STA_ADD2': '서울연신중학교',
#    'STA_LAT': '37.62265015',
#    'STA_LONG': '126.92524719',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '39'},
#   {'STA_LOC': '은평구',
#    'RENT_ID': 'ST-1039',
#    'RENT_NO': '00953',
#    'RENT_NM': '서울연신초등학교',
#    'RENT_ID_NM': '953. 서울연신초등학교',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 은평구 불광동 73-1번지 ',
#    'STA_ADD2': '서울연신초등학교',
#    'STA_LAT': '37.62577820',
#    'STA_LONG': '126.92881775',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '40'},
#   {'STA_LOC': '성동구',
#    'RENT_ID': 'ST-104',
#    'RENT_NO': '00507',
#    'RENT_NM': '성수아이에스비즈타워 앞',
#    'RENT_ID_NM': '507. 성수아이에스비즈타워 앞',
#    'HOLD_NUM': '7',
#    'STA_ADD1': '서울특별시 성동구 성수이로 147',
#    'STA_ADD2': '아이에스비즈타워 앞',
#    'STA_LAT': '37.54820251',
#    'STA_LONG': '127.05711365',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '41'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1040',
#    'RENT_NO': '01023',
#    'RENT_NM': '한국종합기술사옥 앞',
#    'RENT_ID_NM': '1023. 한국종합기술사옥 앞',
#    'HOLD_NUM': '22',
#    'STA_ADD1': '서울특별시 강동구 상일로6길 21 한국종합기술사옥',
#    'STA_ADD2': '',
#    'STA_LAT': '37.54998398',
#    'STA_LONG': '127.17470551',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '42'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1041',
#    'RENT_NO': '01024',
#    'RENT_NM': '강동구청 앞',
#    'RENT_ID_NM': '1024.  강동구청 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강동구 성내로 28 강동빌딩',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52929688',
#    'STA_LONG': '127.12315369',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '43'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1042',
#    'RENT_NO': '01025',
#    'RENT_NM': '상일초등학교',
#    'RENT_ID_NM': '1025. 상일초등학교',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강동구 상일동 440-3',
#    'STA_ADD2': '상일초등학교',
#    'STA_LAT': '37.54684067',
#    'STA_LONG': '127.17251587',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '44'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1043',
#    'RENT_NO': '01026',
#    'RENT_NM': '대명초교 입구 교차로',
#    'RENT_ID_NM': '1026. 대명초교 입구 교차로',
#    'HOLD_NUM': '14',
#    'STA_ADD1': '서울특별시 강동구 명일동 59',
#    'STA_ADD2': '',
#    'STA_LAT': '37.54653549',
#    'STA_LONG': '127.15583801',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '45'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1044',
#    'RENT_NO': '01027',
#    'RENT_NM': '프라자 아파트 앞',
#    'RENT_ID_NM': '1027. 프라자 아파트 앞',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 강동구 천호대로 1240 프라자아파트',
#    'STA_ADD2': '',
#    'STA_LAT': '37.53596115',
#    'STA_LONG': '127.14781952',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '46'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1045',
#    'RENT_NO': '01028',
#    'RENT_NM': '포레스 주상복합 빌딩',
#    'RENT_ID_NM': '1028. 포레스 주상복합 빌딩',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강동구 천호옛길 41 포레스아파트',
#    'STA_ADD2': '',
#    'STA_LAT': '37.53310776',
#    'STA_LONG': '127.12277222',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '47'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1046',
#    'RENT_NO': '01029',
#    'RENT_NM': '성내어울터',
#    'RENT_ID_NM': '1029. 성내어울터',
#    'HOLD_NUM': '7',
#    'STA_ADD1': '서울특별시 강동구 성내동 43-2',
#    'STA_ADD2': '',
#    'STA_LAT': '37.53655624',
#    'STA_LONG': '127.12553406',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '48'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1047',
#    'RENT_NO': '01030',
#    'RENT_NM': '미호 플랜트 앞',
#    'RENT_ID_NM': '1030. 미호 플랜트 앞',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 강동구 강동대로 143-22',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52703094',
#    'STA_LONG': '127.12206268',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '49'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1048',
#    'RENT_NO': '01031',
#    'RENT_NM': '올림픽로 836(아리수로)',
#    'RENT_ID_NM': '1031. 올림픽로 836(아리수로)',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 강동구 암사동 440',
#    'STA_ADD2': '',
#    'STA_LAT': '37.55604172',
#    'STA_LONG': '127.13093567',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '50'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1049',
#    'RENT_NO': '01032',
#    'RENT_NM': '선사고등학교',
#    'RENT_ID_NM': '1032. 선사고등학교',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 강동구 암사동 524',
#    'STA_ADD2': '',
#    'STA_LAT': '37.55672836',
#    'STA_LONG': '127.13626099',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '51'},
#   {'STA_LOC': '성동구',
#    'RENT_ID': 'ST-105',
#    'RENT_NO': '00508',
#    'RENT_NM': '성수아카데미타워 앞',
#    'RENT_ID_NM': '508. 성수아카데미타워 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 성동구 성수이로 118 성수아카데미타워',
#    'STA_ADD2': '',
#    'STA_LAT': '37.54516983',
#    'STA_LONG': '127.05757141',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '52'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1050',
#    'RENT_NO': '01033',
#    'RENT_NM': '고덕동 아남아파트',
#    'RENT_ID_NM': '1033. 고덕동 아남아파트',
#    'HOLD_NUM': '17',
#    'STA_ADD1': '서울특별시 강동구 고덕동 469',
#    'STA_ADD2': '',
#    'STA_LAT': '37.55793381',
#    'STA_LONG': '127.14476776',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '53'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1051',
#    'RENT_NO': '01034',
#    'RENT_NM': '고덕동 래미안 힐스테이트',
#    'RENT_ID_NM': '1034. 고덕동 래미안 힐스테이트',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 강동구 고덕동 585-4',
#    'STA_ADD2': '',
#    'STA_LAT': '37.56187820',
#    'STA_LONG': '127.15078735',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '54'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1052',
#    'RENT_NO': '01035',
#    'RENT_NM': '고덕역 4번출구',
#    'RENT_ID_NM': '1035. 고덕역 4번출구',
#    'HOLD_NUM': '25',
#    'STA_ADD1': '서울특별시 강동구 명일동 46-6',
#    'STA_ADD2': '',
#    'STA_LAT': '37.55509567',
#    'STA_LONG': '127.15528107',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '55'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1053',
#    'RENT_NO': '01036',
#    'RENT_NM': '고덕동 주양쇼핑',
#    'RENT_ID_NM': '1036. 고덕동 주양쇼핑',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강동구 명일동 48-25',
#    'STA_ADD2': '',
#    'STA_LAT': '37.55199051',
#    'STA_LONG': '127.15331268',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '56'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1054',
#    'RENT_NO': '01037',
#    'RENT_NM': '강일리버파크 6단지',
#    'RENT_ID_NM': '1037. 강일리버파크 6단지',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강동구 강일동 684-2',
#    'STA_ADD2': '',
#    'STA_LAT': '37.56256485',
#    'STA_LONG': '127.17761230',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '57'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1055',
#    'RENT_NO': '01038',
#    'RENT_NM': '강일 다솜 어린이 공원',
#    'RENT_ID_NM': '1038. 강일 다솜 어린이 공원',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강동구 강일동 667-4',
#    'STA_ADD2': '',
#    'STA_LAT': '37.56863785',
#    'STA_LONG': '127.17480469',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '58'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1056',
#    'RENT_NO': '01039',
#    'RENT_NM': '고덕초등학교',
#    'RENT_ID_NM': '1039. 고덕초등학교',
#    'HOLD_NUM': '7',
#    'STA_ADD1': '서울특별시 강동구 고덕로83길 55',
#    'STA_ADD2': '',
#    'STA_LAT': '37.56129837',
#    'STA_LONG': '127.16784668',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '59'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1057',
#    'RENT_NO': '01040',
#    'RENT_NM': '강일동 에너지 마루',
#    'RENT_ID_NM': '1040. 강일동 에너지 마루',
#    'STA_ADD1': '서울특별시 강동구 고덕동 375',
#    'STA_ADD2': '강일동 에너지 마루',
#    'STA_LAT': '37.56719971',
#    'STA_LONG': '127.16345978',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '60'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1058',
#    'RENT_NO': '01041',
#    'RENT_NM': '묘곡초등학교',
#    'RENT_ID_NM': '1041. 묘곡초등학교',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강동구 동남로79길 46 서울묘곡초등학교',
#    'STA_ADD2': '',
#    'STA_LAT': '37.55916214',
#    'STA_LONG': '127.15332031',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '61'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1059',
#    'RENT_NO': '01042',
#    'RENT_NM': '강일리버파크 2~5단지',
#    'RENT_ID_NM': '1042. 강일리버파크 2~5단지',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강동구 아리수로97길 68 강일리버파크2단지아파트',
#    'STA_ADD2': '',
#    'STA_LAT': '37.56854630',
#    'STA_LONG': '127.17700958',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '62'},
#   {'STA_LOC': '성동구',
#    'RENT_ID': 'ST-106',
#    'RENT_NO': '00509',
#    'RENT_NM': '이마트 버스정류소 옆',
#    'RENT_ID_NM': '509. 이마트 버스정류소 옆',
#    'HOLD_NUM': '25',
#    'STA_ADD1': '서울특별시 성동구 뚝섬로 379',
#    'STA_ADD2': '이마트 버스정류소 옆',
#    'STA_LAT': '37.53965378',
#    'STA_LONG': '127.05258942',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '63'},
#   {'STA_LOC': '강동구',
#    'RENT_ID': 'ST-1061',
#    'RENT_NO': '01044',
#    'RENT_NM': '굽은다리역',
#    'RENT_ID_NM': '1044. 굽은다리역',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 강동구 천호동 42-1',
#    'STA_ADD2': '',
#    'STA_LAT': '37.54540634',
#    'STA_LONG': '127.14267731',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '64'},
#   {'STA_LOC': '강서구',
#    'RENT_ID': 'ST-1062',
#    'RENT_NO': '01150',
#    'RENT_NM': '송정역 1번출구',
#    'RENT_ID_NM': '1150. 송정역 1번출구',
#    'HOLD_NUM': '7',
#    'STA_ADD1': '서울특별시 강서구 공항대로 33 송정역(5호선)',
#    'STA_ADD2': '',
#    'STA_LAT': '37.56153107',
#    'STA_LONG': '126.81069946',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '65'},
#   {'STA_LOC': '강서구',
#    'RENT_ID': 'ST-1063',
#    'RENT_NO': '01151',
#    'RENT_NM': '마곡역1번출구',
#    'RENT_ID_NM': '1151. 마곡역1번출구',
#    'HOLD_NUM': '30',
#    'STA_ADD1': '서울특별시 강서구 공항대로 163 마곡역(5호선)',
#    'STA_ADD2': '',
#    'STA_LAT': '37.56020737',
#    'STA_LONG': '126.82414246',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '66'},
#   {'STA_LOC': '강서구',
#    'RENT_ID': 'ST-1064',
#    'RENT_NO': '01152',
#    'RENT_NM': '마곡역교차로',
#    'RENT_ID_NM': '1152. 마곡역교차로',
#    'HOLD_NUM': '36',
#    'STA_ADD1': '서울특별시 강서구 마곡동 728-168',
#    'STA_ADD2': '마곡역7번출구',
#    'STA_LAT': '37.55831146',
#    'STA_LONG': '126.82652283',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '67'},
#   {'STA_LOC': '강서구',
#    'RENT_ID': 'ST-1065',
#    'RENT_NO': '01153',
#    'RENT_NM': '발산역 1번, 9번 인근 대여소',
#    'RENT_ID_NM': '1153. 발산역 1번, 9번 인근 대여소',
#    'HOLD_NUM': '32',
#    'STA_ADD1': '서울특별시 강서구 마곡동 797-5',
#    'STA_ADD2': '',
#    'STA_LAT': '37.55894852',
#    'STA_LONG': '126.83717346',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '68'},
#   {'STA_LOC': '강서구',
#    'RENT_ID': 'ST-1067',
#    'RENT_NO': '01155',
#    'RENT_NM': '기쁜우리복지관',
#    'RENT_ID_NM': '1155. 기쁜우리복지관',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강서구 가양동 1458-15 ',
#    'STA_ADD2': '기쁜우리복지관',
#    'STA_LAT': '37.56925964',
#    'STA_LONG': '126.84841919',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '69'},
#   {'STA_LOC': '강서구',
#    'RENT_ID': 'ST-1069',
#    'RENT_NO': '01157',
#    'RENT_NM': '강서구청',
#    'RENT_ID_NM': '1157. 강서구청',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 강서구 화곡로 302',
#    'STA_ADD2': '강서구청',
#    'STA_LAT': '37.55065918',
#    'STA_LONG': '126.84976959',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '70'},
#   {'STA_LOC': '성동구',
#    'RENT_ID': 'ST-107',
#    'RENT_NO': '00510',
#    'RENT_NM': '뚝도아리수정수센터 버스정류소 옆',
#    'RENT_ID_NM': '510. 뚝도아리수정수센터 버스정류소 옆',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 성동구 왕십리로11길 9',
#    'STA_ADD2': '서울숲남문 버스정류소 옆',
#    'STA_LAT': '37.54122162',
#    'STA_LONG': '127.04380035',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '71'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1070',
#    'RENT_NO': '01251',
#    'RENT_NM': '석촌역 2번출구',
#    'RENT_ID_NM': '1251. 석촌역 2번출구',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 송파구 송파동 68 ',
#    'STA_ADD2': '석촌역 2번출구',
#    'STA_LAT': '37.50593185',
#    'STA_LONG': '127.10774994',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '72'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1072',
#    'RENT_NO': '01253',
#    'RENT_NM': '오금역 3번 출구 뒤',
#    'RENT_ID_NM': '1253. 오금역 3번 출구 뒤',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 송파구 가락동 10-15 ',
#    'STA_ADD2': '오금역 3번 출구 뒤',
#    'STA_LAT': '37.50165176',
#    'STA_LONG': '127.12818146',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '73'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1075',
#    'RENT_NO': '01256',
#    'RENT_NM': '문정현대아파트 교차로',
#    'RENT_ID_NM': '1256. 문정현대아파트 교차로',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 송파구 문정동 3-2 ',
#    'STA_ADD2': '문정현대아파트 교차로',
#    'STA_LAT': '37.49113083',
#    'STA_LONG': '127.12580872',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '74'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1076',
#    'RENT_NO': '01257',
#    'RENT_NM': '가락시장역 사거리',
#    'RENT_ID_NM': '1257. 가락시장역 사거리',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 송파구 가락동 214-15 ',
#    'STA_ADD2': '가락시장역 롯데마트앞',
#    'STA_LAT': '37.49209976',
#    'STA_LONG': '127.11775208',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '75'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1077',
#    'RENT_NO': '01258',
#    'RENT_NM': '가락미륭아파트 앞',
#    'RENT_ID_NM': '1258. 가락미륭아파트 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 송파구 가락동 195-4',
#    'STA_ADD2': '가락미륭아파트 앞',
#    'STA_LAT': '37.49319839',
#    'STA_LONG': '127.12899780',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '76'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1078',
#    'RENT_NO': '01259',
#    'RENT_NM': '방이역 1번출구',
#    'RENT_ID_NM': '1259. 방이역 1번출구',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 송파구 오금동 17-20',
#    'STA_ADD2': '방이역 1번출구',
#    'STA_LAT': '37.50898361',
#    'STA_LONG': '127.12659454',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '77'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1079',
#    'RENT_NO': '01260',
#    'RENT_NM': '방이동 한양3차아파트 옆',
#    'RENT_ID_NM': '1260. 방이동 한양3차아파트 옆',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 송파구 방이동 225-1',
#    'STA_ADD2': '방이동 한양3차아파트 옆',
#    'STA_LAT': '37.50630188',
#    'STA_LONG': '127.12139893',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '78'},
#   {'STA_LOC': '성동구',
#    'RENT_ID': 'ST-108',
#    'RENT_NO': '00511',
#    'RENT_NM': '서울숲역 5번 출구 옆',
#    'RENT_ID_NM': '511. 서울숲역 5번 출구 옆',
#    'HOLD_NUM': '16',
#    'STA_ADD1': '서울특별시 성동구 왕십리로 지하77',
#    'STA_ADD2': '서울숲역 4번 출구 옆',
#    'STA_LAT': '37.54458237',
#    'STA_LONG': '127.04460907',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '79'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1080',
#    'RENT_NO': '01261',
#    'RENT_NM': '석촌역 1번출구 앞',
#    'RENT_ID_NM': '1261. 석촌역 1번출구 앞',
#    'STA_ADD1': '서울특별시 송파구 송파동 69 ',
#    'STA_ADD2': '석촌역 1번출구 앞',
#    'STA_LAT': '37.50582886',
#    'STA_LONG': '127.10705566',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '80'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1081',
#    'RENT_NO': '01262',
#    'RENT_NM': '송파여성문화회관 앞',
#    'RENT_ID_NM': '1262. 송파여성문화회관 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 송파구 송파동 2-3 ',
#    'STA_ADD2': '송파여성문화회관 앞',
#    'STA_LAT': '37.50580215',
#    'STA_LONG': '127.10971832',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '81'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1082',
#    'RENT_NO': '01263',
#    'RENT_NM': '장지공영차고지',
#    'RENT_ID_NM': '1263. 장지공영차고지',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 송파구 장지동 861-6',
#    'STA_ADD2': '장지공영차고지',
#    'STA_LAT': '37.48054123',
#    'STA_LONG': '127.13701630',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '82'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1083',
#    'RENT_NO': '01264',
#    'RENT_NM': '천호역 10번 출구 앞',
#    'RENT_ID_NM': '1264. 천호역 10번 출구 앞',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 송파구 풍납동 490-16',
#    'STA_ADD2': '천호역 10번 출구 앞',
#    'STA_LAT': '37.53858185',
#    'STA_LONG': '127.12280273',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '83'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1084',
#    'RENT_NO': '01265',
#    'RENT_NM': '문정동 근린공원',
#    'RENT_ID_NM': '1265. 문정동 근린공원',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 송파구 문정동 38-3',
#    'STA_ADD2': '문정동 근린공원',
#    'STA_LAT': '37.48598862',
#    'STA_LONG': '127.12476349',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '84'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1085',
#    'RENT_NO': '01266',
#    'RENT_NM': '문정동 글샘 공원',
#    'RENT_ID_NM': '1266. 문정동 글샘 공원',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 송파구 문정동 627',
#    'STA_ADD2': '장지동 글샘 공원',
#    'STA_LAT': '37.47880936',
#    'STA_LONG': '127.12000275',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '85'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1086',
#    'RENT_NO': '01267',
#    'RENT_NM': '올림픽공원 남2문 앞',
#    'RENT_ID_NM': '1267. 올림픽공원 남2문 앞',
#    'HOLD_NUM': '14',
#    'STA_ADD1': '서울특별시 송파구 올림픽로 424',
#    'STA_ADD2': '올림픽공원 남2문 앞',
#    'STA_LAT': '37.51424026',
#    'STA_LONG': '127.12306976',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '86'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1087',
#    'RENT_NO': '01268',
#    'RENT_NM': '몽촌토성역 1번출구 옆',
#    'RENT_ID_NM': '1268. 몽촌토성역 1번출구 옆',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 송파구 방이동 88-21 ',
#    'STA_ADD2': '몽촌토성역 1번출구 옆',
#    'STA_LAT': '37.51728821',
#    'STA_LONG': '127.11419678',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '87'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1088',
#    'RENT_NO': '01269',
#    'RENT_NM': '리센츠아파트',
#    'RENT_ID_NM': '1269. 리센츠아파트 ',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 송파구 올림픽로 135',
#    'STA_ADD2': '리센츠아파트 ',
#    'STA_LAT': '37.51194382',
#    'STA_LONG': '127.09121704',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '88'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1089',
#    'RENT_NO': '01271',
#    'RENT_NM': '송파도서관',
#    'RENT_ID_NM': '1271. 송파도서관',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 송파구 동남로 263',
#    'STA_ADD2': '송파도서관',
#    'STA_LAT': '37.49998474',
#    'STA_LONG': '127.13539124',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '89'},
#   {'STA_LOC': '성동구',
#    'RENT_ID': 'ST-109',
#    'RENT_NO': '00512',
#    'RENT_NM': '뚝섬역 1번 출구 옆',
#    'RENT_ID_NM': '512. 뚝섬역 1번 출구 옆',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 성동구 아차산로 18',
#    'STA_ADD2': '뚝섬역 1번 출구 옆',
#    'STA_LAT': '37.54856110',
#    'STA_LONG': '127.04500580',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '90'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1090',
#    'RENT_NO': '01272',
#    'RENT_NM': '송파 글마루도서관',
#    'RENT_ID_NM': '1272. 송파 글마루도서관',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 송파구 충민로 120',
#    'STA_ADD2': '송파 글마루도서관',
#    'STA_LAT': '0.00000000',
#    'STA_LONG': '0.00000000',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '91'},
#   {'STA_LOC': '송파구',
#    'RENT_ID': 'ST-1092',
#    'RENT_NO': '01274',
#    'RENT_NM': '영파여고 앞',
#    'RENT_ID_NM': '1274. 영파여고 앞',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 송파구 올림픽로 565',
#    'STA_ADD2': '영파여고 앞',
#    'STA_LAT': '37.53284836',
#    'STA_LONG': '127.12104797',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '92'},
#   {'STA_LOC': '중랑구',
#    'RENT_ID': 'ST-1093',
#    'RENT_NO': '01442',
#    'RENT_NM': '중랑구청 중화동 별관 앞',
#    'RENT_ID_NM': '1442. 중랑구청 중화동 별관 앞',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 중랑구 중화동 50-8',
#    'STA_ADD2': '(구)신한은행 중랑교지점',
#    'STA_LAT': '37.59859085',
#    'STA_LONG': '127.07981873',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '93'},
#   {'STA_LOC': '중랑구',
#    'RENT_ID': 'ST-1094',
#    'RENT_NO': '01443',
#    'RENT_NM': '구립망우청소년독서실',
#    'RENT_ID_NM': '1443. 구립망우청소년독서실',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 중랑구 망우동 534-23 ',
#    'STA_ADD2': '구립망우청소년독서실',
#    'STA_LAT': '37.59552002',
#    'STA_LONG': '127.09877777',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '94'},
#   {'STA_LOC': '중랑구',
#    'RENT_ID': 'ST-1095',
#    'RENT_NO': '01444',
#    'RENT_NM': '면목4치안센터',
#    'RENT_ID_NM': '1444. 면목4치안센터',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 중랑구 면목동 646-4',
#    'STA_ADD2': '면목4치안센터',
#    'STA_LAT': '37.57402802',
#    'STA_LONG': '127.08054352',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '95'},
#   {'STA_LOC': '중랑구',
#    'RENT_ID': 'ST-1096',
#    'RENT_NO': '01445',
#    'RENT_NM': '용마지구대 A',
#    'RENT_ID_NM': '1445. 용마지구대 A',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 중랑구 면목동 197-5',
#    'STA_ADD2': '용마지구대',
#    'STA_LAT': '37.57994080',
#    'STA_LONG': '127.07939911',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '96'},
#   {'STA_LOC': '중랑구',
#    'RENT_ID': 'ST-1097',
#    'RENT_NO': '01446',
#    'RENT_NM': '중랑전화국 교차로',
#    'RENT_ID_NM': '1446. 중랑전화국 교차로',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 중랑구 면목동 282-8',
#    'STA_ADD2': '중랑전화국 교차로',
#    'STA_LAT': '37.59130096',
#    'STA_LONG': '127.08032990',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '97'},
#   {'STA_LOC': '중랑구',
#    'RENT_ID': 'ST-1098',
#    'RENT_NO': '01447',
#    'RENT_NM': '면목역 3번출구',
#    'RENT_ID_NM': '1447. 면목역 3번출구',
#    'HOLD_NUM': '17',
#    'STA_ADD1': '서울특별시 중랑구 면목동 120-2',
#    'STA_ADD2': '면목역 3번출구',
#    'STA_LAT': '37.58890152',
#    'STA_LONG': '127.08728027',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '98'},
#   {'STA_LOC': '중랑구',
#    'RENT_ID': 'ST-1099',
#    'RENT_NO': '01448',
#    'RENT_NM': '코스트코 상봉점',
#    'RENT_ID_NM': '1448. 코스트코 상봉점',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 중랑구 상봉동 160-3',
#    'STA_ADD2': '코스트코 상봉점',
#    'STA_LAT': '37.59732056',
#    'STA_LONG': '127.08979797',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '99'},
#   {'STA_LOC': '마포구',
#    'RENT_ID': 'ST-11',
#    'RENT_NO': '00109',
#    'RENT_NM': '제일빌딩 앞',
#    'RENT_ID_NM': '109. 제일빌딩 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 마포구 어울마당로 26',
#    'STA_ADD2': '12-2',
#    'STA_LAT': '37.54769135',
#    'STA_LONG': '126.91998291',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '100'},
#   {'STA_LOC': '마포구',
#    'RENT_ID': 'ST-110',
#    'RENT_NO': '00400',
#    'RENT_NM': '상암한화오벨리스크 1차 앞',
#    'RENT_ID_NM': '400. 상암한화오벨리스크 1차 앞',
#    'HOLD_NUM': '14',
#    'STA_ADD1': '서울특별시 마포구 구룡길 19',
#    'STA_ADD2': '상암한화오벨리스크 1차 앞',
#    'STA_LAT': '37.58752441',
#    'STA_LONG': '126.88300323',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '101'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1100',
#    'RENT_NO': '01526',
#    'RENT_NM': '강북종합시장 앞',
#    'RENT_ID_NM': '1526. 강북종합시장 앞',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 강북구 수유동 140',
#    'STA_ADD2': '수유동 채선당앞',
#    'STA_LAT': '37.64173889',
#    'STA_LONG': '127.02462769',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '102'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1101',
#    'RENT_NO': '01527',
#    'RENT_NM': '미아역 1번 출구 뒤',
#    'RENT_ID_NM': '1527. 미아역 1번 출구 뒤',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강북구 미아동 194-1',
#    'STA_ADD2': '미아역 1번 출구 뒤',
#    'STA_LAT': '37.62733459',
#    'STA_LONG': '127.02605438',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '103'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1102',
#    'RENT_NO': '01528',
#    'RENT_NM': '삼각산동 주민센터',
#    'RENT_ID_NM': '1528. 삼각산동 주민센터',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강북구 미아동 813-8',
#    'STA_ADD2': '삼각산동 주민센터',
#    'STA_LAT': '37.61503601',
#    'STA_LONG': '127.02069855',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '104'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1103',
#    'RENT_NO': '01529',
#    'RENT_NM': '미아동 한국전력공사',
#    'RENT_ID_NM': '1529. 미아동 한국전력공사',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 강북구 미아동 194-1',
#    'STA_ADD2': '미아동 한국전력공사',
#    'STA_LAT': '37.63018036',
#    'STA_LONG': '127.02490997',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '105'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1104',
#    'RENT_NO': '01530',
#    'RENT_NM': '광산사거리',
#    'RENT_ID_NM': '1530. 광산사거리',
#    'HOLD_NUM': '13',
#    'STA_ADD1': '서울특별시 강북구 노해로 87 ',
#    'STA_ADD2': '광산사거리',
#    'STA_LAT': '37.64355087',
#    'STA_LONG': '127.02234650',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '106'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1105',
#    'RENT_NO': '01531',
#    'RENT_NM': '미아사거리 1번 출구',
#    'RENT_ID_NM': '1531. 미아사거리 1번 출구',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강북구 미아동 66-1',
#    'STA_ADD2': '미아사거리 1번 출구',
#    'STA_LAT': '37.61395645',
#    'STA_LONG': '127.03025055',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '107'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1106',
#    'RENT_NO': '01532',
#    'RENT_NM': '번3동 주민센터 교차로',
#    'RENT_ID_NM': '1532. 번3동 주민센터 교차로',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강북구 번동 2-2',
#    'STA_ADD2': '번3동 주민센터 교차로',
#    'STA_LAT': '37.62635422',
#    'STA_LONG': '127.04744720',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '108'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1107',
#    'RENT_NO': '01533',
#    'RENT_NM': '번동 주공3, 4단지 교차로',
#    'RENT_ID_NM': '1533. 번동 주공3, 4단지 교차로',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강북구 번동 254',
#    'STA_ADD2': '번동 주공3, 4단지 교차로',
#    'STA_LAT': '37.62991714',
#    'STA_LONG': '127.04091644',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '109'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1108',
#    'RENT_NO': '01534',
#    'RENT_NM': '북서울 꿈의 숲 동문',
#    'RENT_ID_NM': '1534. 북서울 꿈의 숲 동문',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 강북구 번동 105',
#    'STA_ADD2': '북서울 꿈의 숲 동문',
#    'STA_LAT': '37.61963654',
#    'STA_LONG': '127.04453278',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '110'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1109',
#    'RENT_NO': '01535',
#    'RENT_NM': '효성인텔리안 앞',
#    'RENT_ID_NM': '1535. 효성인텔리안 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 강북구  수유동 230-7',
#    'STA_ADD2': '효성인텔리안 앞',
#    'STA_LAT': '37.63629150',
#    'STA_LONG': '127.02337646',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '111'},
#   {'STA_LOC': '성동구',
#    'RENT_ID': 'ST-111',
#    'RENT_NO': '00513',
#    'RENT_NM': '뚝섬역 5번 출구 정류소 옆',
#    'RENT_ID_NM': '513. 뚝섬역 5번 출구 정류소 옆',
#    'HOLD_NUM': '13',
#    'STA_ADD1': '서울특별시 성동구 아차산로 18',
#    'STA_ADD2': '뚝섬역 5번 출구 정류소 옆',
#    'STA_LAT': '37.54630661',
#    'STA_LONG': '127.04980469',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '112'},
#   {'STA_LOC': '강북구',
#    'RENT_ID': 'ST-1110',
#    'RENT_NO': '01536',
#    'RENT_NM': '번동 두산위브 101동 옆',
#    'RENT_ID_NM': '1536. 번동 두산위브 101동 옆',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 강북구 번동 386-17',
#    'STA_ADD2': '번동 두산위브 101동 옆',
#    'STA_LAT': '37.63626099',
#    'STA_LONG': '127.03217316',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '113'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1111',
#    'RENT_NO': '01643',
#    'RENT_NM': '태릉입구역 8번출구',
#    'RENT_ID_NM': '1643. 태릉입구역 8번출구',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 노원구 공릉동 687-6',
#    'STA_ADD2': '태릉입구역 8번출구',
#    'STA_LAT': '37.61736679',
#    'STA_LONG': '127.07521057',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '114'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1114',
#    'RENT_NO': '01646',
#    'RENT_NM': '삼육대 입구',
#    'RENT_ID_NM': '1646. 삼육대 입구',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 노원구 공릉동 26-43',
#    'STA_ADD2': '삼육대 입구',
#    'STA_LAT': '37.63848877',
#    'STA_LONG': '127.10790253',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '115'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1118',
#    'RENT_NO': '01650',
#    'RENT_NM': '중계근린공원내',
#    'RENT_ID_NM': '1650. 중계근린공원내',
#    'HOLD_NUM': '25',
#    'STA_ADD1': '서울특별시 노원구 중계동 506-3',
#    'STA_ADD2': '중계근린공원내',
#    'STA_LAT': '37.63957977',
#    'STA_LONG': '127.06510162',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '116'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1119',
#    'RENT_NO': '01651',
#    'RENT_NM': '상계동 우방유쉘아파트 앞',
#    'RENT_ID_NM': '1651. 상계동 우방유쉘아파트 앞',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 노원구 상계동 1118-9',
#    'STA_ADD2': '맥도날드 상계점 앞',
#    'STA_LAT': '37.67237473',
#    'STA_LONG': '127.05599213',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '117'},
#   {'STA_LOC': '성동구',
#    'RENT_ID': 'ST-112',
#    'RENT_NO': '00514',
#    'RENT_NM': '성수사거리 버스정류장 앞',
#    'RENT_ID_NM': '514. 성수사거리 버스정류장 앞',
#    'HOLD_NUM': '12',
#    'STA_ADD1': '서울특별시 성동구 아차산로 171',
#    'STA_ADD2': '성수사거리 버스정류장 앞',
#    'STA_LAT': '37.54257965',
#    'STA_LONG': '127.06330872',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '118'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1120',
#    'RENT_NO': '01652',
#    'RENT_NM': '파르코 앞',
#    'RENT_ID_NM': '1652. 파르코 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 노원구 상계동 1263',
#    'STA_ADD2': '파르코 앞',
#    'STA_LAT': '37.68000031',
#    'STA_LONG': '127.05558014',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '119'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1121',
#    'RENT_NO': '01653',
#    'RENT_NM': '노원역1번출구',
#    'RENT_ID_NM': '1653. 노원역1번출구',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 노원구 상계동 335-4',
#    'STA_ADD2': '노원역1번출구',
#    'STA_LAT': '37.65620041',
#    'STA_LONG': '127.06362152',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '120'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1122',
#    'RENT_NO': '01654',
#    'RENT_NM': '당고개입구 오거리',
#    'RENT_ID_NM': '1654. 당고개입구 오거리',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 노원구 상계동 172-2',
#    'STA_ADD2': '보훈회관 대여소',
#    'STA_LAT': '37.66379166',
#    'STA_LONG': '127.07544708',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '121'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1123',
#    'RENT_NO': '01655',
#    'RENT_NM': '공릉1단지아파트',
#    'RENT_ID_NM': '1655. 공릉1단지아파트',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 중랑구 동일로 1127',
#    'STA_ADD2': '공릉1단지아파트',
#    'STA_LAT': '37.63111115',
#    'STA_LONG': '127.07015991',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '122'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1124',
#    'RENT_NO': '01656',
#    'RENT_NM': '중앙하이츠 아파트 입구',
#    'RENT_ID_NM': '1656. 중앙하이츠 아파트 입구',
#    'HOLD_NUM': '12',
#    'STA_ADD1': '서울특별시 노원구 노원로 434 상계2차중앙하이츠아파트',
#    'STA_ADD2': '',
#    'STA_LAT': '37.65501785',
#    'STA_LONG': '127.06750488',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '123'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1125',
#    'RENT_NO': '01657',
#    'RENT_NM': '노원구청',
#    'RENT_ID_NM': '1657. 노원구청 ',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 노원구 노해로 437 ',
#    'STA_ADD2': '노원구청 ',
#    'STA_LAT': '37.65404892',
#    'STA_LONG': '127.05732727',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '124'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1127',
#    'RENT_NO': '01659',
#    'RENT_NM': '중계동 을지중학교',
#    'RENT_ID_NM': '1659. 중계동 을지중학교',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 노원구 중계동 370',
#    'STA_ADD2': '중계동 을지중학교',
#    'STA_LAT': '37.65032959',
#    'STA_LONG': '127.07160187',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '125'},
#   {'STA_LOC': '노원구',
#    'RENT_ID': 'ST-1128',
#    'RENT_NO': '01660',
#    'RENT_NM': '서울시립과학관',
#    'RENT_ID_NM': '1660. 서울시립과학관',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 노원구 하계동 266',
#    'STA_ADD2': '서울시립과학관',
#    'STA_LAT': '37.64207077',
#    'STA_LONG': '127.07662201',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '126'},
#   {'STA_LOC': '도봉구',
#    'RENT_ID': 'ST-1129',
#    'RENT_NO': '01713',
#    'RENT_NM': '쌍문동 이안아파트 앞',
#    'RENT_ID_NM': '1713. 쌍문동 이안아파트 앞',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 도봉구 쌍문동 315-488',
#    'STA_ADD2': '',
#    'STA_LAT': '37.65165329',
#    'STA_LONG': '127.02848816',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '127'},
#   {'STA_LOC': '광진구',
#    'RENT_ID': 'ST-113',
#    'RENT_NO': '00515',
#    'RENT_NM': '광양중학교 앞',
#    'RENT_ID_NM': '515. 광양중학교 앞',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 광진구 자양로3길 7',
#    'STA_ADD2': '광양중학교 앞',
#    'STA_LAT': '37.53023529',
#    'STA_LONG': '127.08683014',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '128'},
#   {'STA_LOC': '도봉구',
#    'RENT_ID': 'ST-1130',
#    'RENT_NO': '01714',
#    'RENT_NM': '도봉문화정보도서관 삼거리',
#    'RENT_ID_NM': '1714. 도봉문화정보도서관 삼거리',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 도봉구 덕릉로 315',
#    'STA_ADD2': '도봉문화정보도서관 삼거리',
#    'STA_LAT': '37.64463043',
#    'STA_LONG': '127.04460907',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '129'},
#   {'STA_LOC': '도봉구',
#    'RENT_ID': 'ST-1131',
#    'RENT_NO': '01715',
#    'RENT_NM': '서울특별시교육청도봉도서관',
#    'RENT_ID_NM': '1715. 서울특별시교육청도봉도서관',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 도봉구 삼양로556',
#    'STA_ADD2': '서울특별시교육청도봉도서관',
#    'STA_LAT': '37.65317917',
#    'STA_LONG': '127.01278687',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '130'},
#   {'STA_LOC': '도봉구',
#    'RENT_ID': 'ST-1132',
#    'RENT_NO': '01716',
#    'RENT_NM': '창동역 1번출구 건너편',
#    'RENT_ID_NM': '1716. 창동역 1번출구 건너편',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 도봉구 마들로11길 20',
#    'STA_ADD2': '하나로마트 창동점',
#    'STA_LAT': '37.65420151',
#    'STA_LONG': '127.05072784',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '131'},
#   {'STA_LOC': '도봉구',
#    'RENT_ID': 'ST-1133',
#    'RENT_NO': '01717',
#    'RENT_NM': '시립창동운동장 입구',
#    'RENT_ID_NM': '1717. 시립창동운동장 입구',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 도봉구 창동 1-24',
#    'STA_ADD2': '시립창동운동장 입구',
#    'STA_LAT': '37.65570831',
#    'STA_LONG': '127.05010223',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '132'},
#   {'STA_LOC': '도봉구',
#    'RENT_ID': 'ST-1135',
#    'RENT_NO': '01719',
#    'RENT_NM': '신도봉사거리 버스정류장',
#    'RENT_ID_NM': '1719. 신도봉사거리 버스정류장',
#    'HOLD_NUM': '6',
#    'STA_ADD1': '서울특별시 도봉구 도봉로 771',
#    'STA_ADD2': '신도봉사거리 버스정류장',
#    'STA_LAT': '37.67328262',
#    'STA_LONG': '127.04399109',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '133'},
#   {'STA_LOC': '도봉구',
#    'RENT_ID': 'ST-1136',
#    'RENT_NO': '01720',
#    'RENT_NM': '도봉구청 옆(중랑천변)',
#    'RENT_ID_NM': '1720. 도봉구청 옆(중랑천변)',
#    'HOLD_NUM': '27',
#    'STA_ADD1': '서울특별시 도봉구 마들로 656',
#    'STA_ADD2': '도봉구청 옆(중랑천변)',
#    'STA_LAT': '37.66867065',
#    'STA_LONG': '127.04798126',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '134'},
#   {'STA_LOC': '도봉구',
#    'RENT_ID': 'ST-1137',
#    'RENT_NO': '01721',
#    'RENT_NM': '창동역 2번출구',
#    'RENT_ID_NM': '1721. 창동역 2번출구 ',
#    'HOLD_NUM': '12',
#    'STA_ADD1': '서울특별시 노원구 창동 74-2 ',
#    'STA_ADD2': '창동역 2번출구 ',
#    'STA_LAT': '37.65301514',
#    'STA_LONG': '127.04699707',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '135'},
#   {'STA_LOC': '광진구',
#    'RENT_ID': 'ST-114',
#    'RENT_NO': '00516',
#    'RENT_NM': '광진메디칼 앞',
#    'RENT_ID_NM': '516. 광진메디칼 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 광진구 광나루로 355',
#    'STA_ADD2': '광진메디컬앞',
#    'STA_LAT': '37.54840469',
#    'STA_LONG': '127.06936646',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '136'},
#   {'STA_LOC': '금천구',
#    'RENT_ID': 'ST-1140',
#    'RENT_NO': '01839',
#    'RENT_NM': '수출의 다리 아래',
#    'RENT_ID_NM': '1839. 수출의 다리 아래',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 금천구 가산동 60-35',
#    'STA_ADD2': '',
#    'STA_LAT': '37.47743607',
#    'STA_LONG': '126.88615417',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '137'},
#   {'STA_LOC': '금천구',
#    'RENT_ID': 'ST-1141',
#    'RENT_NO': '01840',
#    'RENT_NM': '솔브레인이엔지 뒤편',
#    'RENT_ID_NM': '1840. 솔브레인이엔지 뒤편',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 금천구 가산로9길 80',
#    'STA_ADD2': '',
#    'STA_LAT': '37.47555161',
#    'STA_LONG': '126.88845825',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '138'},
#   {'STA_LOC': '금천구',
#    'RENT_ID': 'ST-1142',
#    'RENT_NO': '01841',
#    'RENT_NM': '가산동 주민센터',
#    'RENT_ID_NM': '1841. 가산동 주민센터',
#    'HOLD_NUM': '12',
#    'STA_ADD1': '서울특별시 금천구 가산동 144-3',
#    'STA_ADD2': '가산동 주민센터',
#    'STA_LAT': '37.47695160',
#    'STA_LONG': '126.89186859',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '139'},
#   {'STA_LOC': '금천구',
#    'RENT_ID': 'ST-1143',
#    'RENT_NO': '01842',
#    'RENT_NM': '한울중학교',
#    'RENT_ID_NM': '1842. 한울중학교',
#    'HOLD_NUM': '12',
#    'STA_ADD1': '서울특별시 금천구 시흥동 1000-3',
#    'STA_ADD2': '한울중학교',
#    'STA_LAT': '37.46257401',
#    'STA_LONG': '126.90686035',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '140'},
#   {'STA_LOC': '금천구',
#    'RENT_ID': 'ST-1144',
#    'RENT_NO': '01843',
#    'RENT_NM': '독산고등학교',
#    'RENT_ID_NM': '1843. 독산고등학교',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 금천구 독산동 906-42',
#    'STA_ADD2': '독산고등학교',
#    'STA_LAT': '37.47709656',
#    'STA_LONG': '126.91113281',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '141'},
#   {'STA_LOC': '금천구',
#    'RENT_ID': 'ST-1146',
#    'RENT_NO': '01845',
#    'RENT_NM': '롯데캐슬골드파크1차 서문',
#    'RENT_ID_NM': '1845. 롯데캐슬골드파크1차 서문',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 금천구 벚꽃로40 ',
#    'STA_ADD2': '롯데캐슬골드파크1차 서문',
#    'STA_LAT': '37.46028900',
#    'STA_LONG': '126.89218903',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '142'},
#   {'STA_LOC': '금천구',
#    'RENT_ID': 'ST-1147',
#    'RENT_NO': '01846',
#    'RENT_NM': '롯데캐슬골드파크1차 동문',
#    'RENT_ID_NM': '1846. 롯데캐슬골드파크1차 동문',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 금천구 독산동 441-19 ',
#    'STA_ADD2': '롯데캐슬골드파크1차 동문',
#    'STA_LAT': '37.46017075',
#    'STA_LONG': '126.89604187',
# ...
#    'RENT_NO': '02818',
#    'RENT_NM': '천왕이펜하우스3단지 앞',
#    'RENT_ID_NM': '2818.천왕이펜하우스3단지 앞',
#    'HOLD_NUM': '14',
#    'STA_ADD1': '서울특별시 구로구 천왕로 56 천왕 이펜하우스 3단지',
#    'STA_ADD2': '',
#    'STA_LAT': '37.48223877',
#    'STA_LONG': '126.83853149',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '953'},
#   {'STA_LOC': '구로구',
#    'RENT_ID': 'ST-1959',
#    'RENT_NO': '02819',
#    'RENT_NM': '하늘숲초등학교 앞',
#    'RENT_ID_NM': '2819.하늘숲초등학교 앞',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 구로구 오리로 1100 천왕연지타워',
#    'STA_ADD2': '',
#    'STA_LAT': '37.48366547',
#    'STA_LONG': '126.84161377',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '954'},
#   {'STA_LOC': '중구',
#    'RENT_ID': 'ST-196',
#    'RENT_NO': '00381',
#    'RENT_NM': '장충체육관',
#    'RENT_ID_NM': '381. 장충체육관',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 중구 장충동2가 200-99',
#    'STA_ADD2': '장충체육관',
#    'STA_LAT': '37.55853271',
#    'STA_LONG': '127.00698853',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '955'},
#   {'STA_LOC': '구로구',
#    'RENT_ID': 'ST-1960',
#    'RENT_NO': '02820',
#    'RENT_NM': '신세기아파트 앞',
#    'RENT_ID_NM': '2820.신세기아파트 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 구로구 개봉로19길 87 로얄파크',
#    'STA_ADD2': '',
#    'STA_LAT': '37.49396515',
#    'STA_LONG': '126.85304260',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '956'},
#   {'STA_LOC': '구로구',
#    'RENT_ID': 'ST-1961',
#    'RENT_NO': '02821',
#    'RENT_NM': '청구아파트 앞',
#    'RENT_ID_NM': '2821.청구아파트 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 구로구 중앙로6길 5-15 청구아파트',
#    'STA_ADD2': '',
#    'STA_LAT': '37.50119019',
#    'STA_LONG': '126.86353302',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '957'},
#   {'STA_LOC': '구로구',
#    'RENT_ID': 'ST-1962',
#    'RENT_NO': '02822',
#    'RENT_NM': '제니스스포츠 앞',
#    'RENT_ID_NM': '2822.제니스스포츠 앞',
#    'HOLD_NUM': '14',
#    'STA_ADD1': '서울특별시 구로구 고척동 60-42',
#    'STA_ADD2': '',
#    'STA_LAT': '37.50452042',
#    'STA_LONG': '126.87055206',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '958'},
#   {'STA_LOC': '구로구',
#    'RENT_ID': 'ST-1963',
#    'RENT_NO': '02823',
#    'RENT_NM': '중앙유통단지 앞',
#    'RENT_ID_NM': '2823.중앙유통단지 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 구로구 구로동 635-32',
#    'STA_ADD2': '',
#    'STA_LAT': '37.49981308',
#    'STA_LONG': '126.87431335',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '959'},
#   {'STA_LOC': '구로구',
#    'RENT_ID': 'ST-1964',
#    'RENT_NO': '02824',
#    'RENT_NM': '미래사랑어린이공원 앞',
#    'RENT_ID_NM': '2824.미래사랑어린이공원 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 구로구 경인로 673-1 가로판매대',
#    'STA_ADD2': '',
#    'STA_LAT': '37.51006317',
#    'STA_LONG': '126.88956451',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '960'},
#   {'STA_LOC': '구로구',
#    'RENT_ID': 'ST-1965',
#    'RENT_NO': '02825',
#    'RENT_NM': '초롱타운 앞',
#    'RENT_ID_NM': '2825.초롱타운 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 구로구 구로동 467-62',
#    'STA_ADD2': '',
#    'STA_LAT': '37.49545288',
#    'STA_LONG': '126.88039398',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '961'},
#   {'STA_LOC': '구로구',
#    'RENT_ID': 'ST-1966',
#    'RENT_NO': '02826',
#    'RENT_NM': '가마산지하보도 옆',
#    'RENT_ID_NM': '2826.가마산지하보도 옆',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 구로구 가마산로 141',
#    'STA_ADD2': '',
#    'STA_LAT': '37.48864746',
#    'STA_LONG': '126.88047028',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '962'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1967',
#    'RENT_NO': '00295',
#    'RENT_NM': '영등포공원 분수대 앞',
#    'RENT_ID_NM': '295.영등포공원 분수대 앞',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 신길로 275 영등포문화원',
#    'STA_ADD2': '',
#    'STA_LAT': '37.51481247',
#    'STA_LONG': '126.91170502',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '963'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1968',
#    'RENT_NO': '00296',
#    'RENT_NM': 'KT플라자 영등포점',
#    'RENT_ID_NM': '296.KT플라자 영등포점',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 영등포구 영등포동8가 29-1',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52630234',
#    'STA_LONG': '126.90538025',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '964'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1969',
#    'RENT_NO': '00297',
#    'RENT_NM': '국회3문',
#    'RENT_ID_NM': '297.국회3문',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 여의도동 8-1',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52863693',
#    'STA_LONG': '126.91267395',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '965'},
#   {'STA_LOC': '중구',
#    'RENT_ID': 'ST-197',
#    'RENT_NO': '00382',
#    'RENT_NM': '약수역 10번출구 앞',
#    'RENT_ID_NM': '382. 약수역 10번출구 앞',
#    'HOLD_NUM': '7',
#    'STA_ADD1': '서울특별시 중구 신당동 357-1',
#    'STA_ADD2': '약수역 10번출구 앞',
#    'STA_LAT': '37.55519867',
#    'STA_LONG': '127.01004791',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '966'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1970',
#    'RENT_NO': '00298',
#    'RENT_NM': 'KBS 연구동 건너편',
#    'RENT_ID_NM': '298.KBS 연구동 건너편',
#    'HOLD_NUM': '25',
#    'STA_ADD1': '서울특별시 영등포구 여의도동 1-1',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52750778',
#    'STA_LONG': '126.91429901',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '967'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1971',
#    'RENT_NO': '00299',
#    'RENT_NM': '여의도 순복음교회',
#    'RENT_ID_NM': '299.여의도 순복음교회',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 여의서로 60-2 가로판매대22',
#    'STA_ADD2': '',
#    'STA_LAT': '37.53179169',
#    'STA_LONG': '126.92245483',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '968'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1972',
#    'RENT_NO': '03201',
#    'RENT_NM': '당산skv1센터',
#    'RENT_ID_NM': '3201.당산skv1센터',
#    'HOLD_NUM': '9',
#    'STA_ADD1': '서울특별시 영등포구 당산동4가 80-2',
#    'STA_ADD2': '',
#    'STA_LAT': '37.53073502',
#    'STA_LONG': '126.89916992',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '969'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1973',
#    'RENT_NO': '03202',
#    'RENT_NM': '당산롯데캐슬프레스티지',
#    'RENT_ID_NM': '3202.당산롯데캐슬프레스티지',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 영등포구 당산동4가 10-21',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52869034',
#    'STA_LONG': '126.90386200',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '970'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1974',
#    'RENT_NO': '03203',
#    'RENT_NM': '도림동배드민턴체육관',
#    'RENT_ID_NM': '3203.도림동배드민턴체육관',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 도신로15길 5 영등포 다목적 배드민턴 체육관',
#    'STA_ADD2': '',
#    'STA_LAT': '37.50611496',
#    'STA_LONG': '126.89859009',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '971'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1975',
#    'RENT_NO': '03204',
#    'RENT_NM': '도림고가도로 밑',
#    'RENT_ID_NM': '3204.도림고가도로 밑',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 도림동 187-87',
#    'STA_ADD2': '',
#    'STA_LAT': '37.51124191',
#    'STA_LONG': '126.89818573',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '972'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1976',
#    'RENT_NO': '03205',
#    'RENT_NM': '문래현대2차',
#    'RENT_ID_NM': '3205.문래현대2차',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 문래로4길 6 현대아파트',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52021790',
#    'STA_LONG': '126.88216400',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '973'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1977',
#    'RENT_NO': '03206',
#    'RENT_NM': '문래동 주민센터',
#    'RENT_ID_NM': '3206.문래동 주민센터',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 영등포구 문래동3가 55-13',
#    'STA_ADD2': '',
#    'STA_LAT': '37.51707077',
#    'STA_LONG': '126.89908600',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '974'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1978',
#    'RENT_NO': '03207',
#    'RENT_NM': '양남사거리1',
#    'RENT_ID_NM': '3207.양남사거리1',
#    'HOLD_NUM': '12',
#    'STA_ADD1': '서울특별시 영등포구 선유로 87',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52182770',
#    'STA_LONG': '126.88972473',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '975'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1979',
#    'RENT_NO': '03208',
#    'RENT_NM': '양평역 2번출구',
#    'RENT_ID_NM': '3208.양평역 2번출구',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 영등포구 양평동2가 33-80',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52555466',
#    'STA_LONG': '126.88587189',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '976'},
#   {'STA_LOC': '중구',
#    'RENT_ID': 'ST-198',
#    'RENT_NO': '00383',
#    'RENT_NM': '신당역 12번 출구 뒤',
#    'RENT_ID_NM': '383. 신당역 12번 출구 뒤',
#    'HOLD_NUM': '27',
#    'STA_ADD1': '서울특별시 중구 다산로 258 리마크빌 동대문',
#    'STA_ADD2': '',
#    'STA_LAT': '37.56591797',
#    'STA_LONG': '127.01642609',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '977'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1980',
#    'RENT_NO': '03209',
#    'RENT_NM': '롯데칠성음료신협양평분점(근린공원)',
#    'RENT_ID_NM': '3209.롯데칠성음료신협양평분점(근린공원)',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 양평동 1-1',
#    'STA_ADD2': '',
#    'STA_LAT': '37.54185104',
#    'STA_LONG': '126.89380646',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '978'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1981',
#    'RENT_NO': '03210',
#    'RENT_NM': '신길 꿈에그린아파트',
#    'RENT_ID_NM': '3210.신길 꿈에그린아파트',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 영등포구 신길로 119 신길뉴타운 한화 꿈에그린',
#    'STA_ADD2': '',
#    'STA_LAT': '37.50313568',
#    'STA_LONG': '126.91007996',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '979'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1982',
#    'RENT_NO': '03211',
#    'RENT_NM': '신길 래미안 프레비뉴',
#    'RENT_ID_NM': '3211.신길 래미안 프레비뉴',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 영등포구 가마산로 442 래미안프레비뉴',
#    'STA_ADD2': '',
#    'STA_LAT': '37.50438309',
#    'STA_LONG': '126.90808868',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '980'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1983',
#    'RENT_NO': '03212',
#    'RENT_NM': '신풍역 6번출구',
#    'RENT_ID_NM': '3212.신풍역 6번출구',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 신풍로 77 래미안에스티움',
#    'STA_ADD2': '',
#    'STA_LAT': '37.50025558',
#    'STA_LONG': '126.91215515',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '981'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1984',
#    'RENT_NO': '03213',
#    'RENT_NM': '썬프라자 웨딩홀뷔페',
#    'RENT_ID_NM': '3213.썬프라자 웨딩홀뷔페',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 신길로 39-3 가로판매대84',
#    'STA_ADD2': '',
#    'STA_LAT': '37.49636459',
#    'STA_LONG': '126.90824890',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '982'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1985',
#    'RENT_NO': '03214',
#    'RENT_NM': '영등포 푸르지오 아파트 A',
#    'RENT_ID_NM': '3214.영등포 푸르지오 아파트 A',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 도신로29길 28 영등포푸르지오',
#    'STA_ADD2': '',
#    'STA_LAT': '37.51202393',
#    'STA_LONG': '126.90105438',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '983'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1986',
#    'RENT_NO': '03215',
#    'RENT_NM': '강변삼성래미안',
#    'RENT_ID_NM': '3215.강변삼성래미안',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 영등포구 당산동 121-317',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52974319',
#    'STA_LONG': '126.90782928',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '984'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1987',
#    'RENT_NO': '03216',
#    'RENT_NM': '국회의사당',
#    'RENT_ID_NM': '3216.국회의사당',
#    'HOLD_NUM': '13',
#    'STA_ADD1': '서울특별시 영등포구 의사당대로 1 국회',
#    'STA_ADD2': '',
#    'STA_LAT': '37.53266525',
#    'STA_LONG': '126.91376495',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '985'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1988',
#    'RENT_NO': '03217',
#    'RENT_NM': '우리은행 여의도한화금융센터',
#    'RENT_ID_NM': '3217.우리은행 여의도한화금융센터',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 63로 40 라이프오피스텔',
#    'STA_ADD2': '',
#    'STA_LAT': '37.51987457',
#    'STA_LONG': '126.93881989',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '986'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1989',
#    'RENT_NO': '03218',
#    'RENT_NM': '여의도 미원빌딩',
#    'RENT_ID_NM': '3218.여의도 미원빌딩',
#    'HOLD_NUM': '25',
#    'STA_ADD1': '서울특별시 영등포구 여의도동 4-2',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52166367',
#    'STA_LONG': '126.93087769',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '987'},
#   {'STA_LOC': '중구',
#    'RENT_ID': 'ST-199',
#    'RENT_NO': '00384',
#    'RENT_NM': '중림동삼거리',
#    'RENT_ID_NM': '384. 중림동삼거리',
#    'HOLD_NUM': '5',
#    'STA_ADD1': '서울특별시 중구 청파로 456',
#    'STA_ADD2': '종로학원본원 앞',
#    'STA_LAT': '37.55978012',
#    'STA_LONG': '126.96850586',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '988'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1990',
#    'RENT_NO': '03219',
#    'RENT_NM': '영등포역 1번출구',
#    'RENT_ID_NM': '3219.영등포역 1번출구',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 영등포동 618-9',
#    'STA_ADD2': '',
#    'STA_LAT': '37.51484680',
#    'STA_LONG': '126.90773010',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '989'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1991',
#    'RENT_NO': '03220',
#    'RENT_NM': '래미안에스티움 앞 (신풍로)',
#    'RENT_ID_NM': '3220.래미안에스티움 앞 (신풍로)',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 영등포구 신길동 3859',
#    'STA_ADD2': '',
#    'STA_LAT': '37.50013733',
#    'STA_LONG': '126.91397858',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '990'},
#   {'STA_LOC': '영등포구',
#    'RENT_ID': 'ST-1992',
#    'RENT_NO': '03221',
#    'RENT_NM': '서울특별시 남부교육지원청',
#    'RENT_ID_NM': '3221.서울특별시 남부교육지원청',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 영등포구 문래로 121 서울특별시 남부교육지원청',
#    'STA_ADD2': '',
#    'STA_LAT': '37.51933289',
#    'STA_LONG': '126.89530182',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '991'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1993',
#    'RENT_NO': '00767',
#    'RENT_NM': '신정숲속마을아파트',
#    'RENT_ID_NM': '767.신정숲속마을아파트',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 신정로 110 신정숲속마을',
#    'STA_ADD2': '',
#    'STA_LAT': '37.50574493',
#    'STA_LONG': '126.83631134',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '992'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1994',
#    'RENT_NO': '00768',
#    'RENT_NM': '목동5단지아파트 501동',
#    'RENT_ID_NM': '768.목동5단지아파트 501동',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 양천구 목동동로 350 목동신시가지아파트5단지',
#    'STA_ADD2': '',
#    'STA_LAT': '37.53566742',
#    'STA_LONG': '126.88158417',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '993'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1995',
#    'RENT_NO': '00769',
#    'RENT_NM': 'CBS방송국 앞',
#    'RENT_ID_NM': '769.CBS방송국 앞',
#    'HOLD_NUM': '20',
#    'STA_ADD1': '서울특별시 양천구 목동서로 159-3 가로판매대2',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52785492',
#    'STA_LONG': '126.87467194',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '994'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1996',
#    'RENT_NO': '00770',
#    'RENT_NM': '목동역5번출구',
#    'RENT_ID_NM': '770.목동역5번출구',
#    'HOLD_NUM': '12',
#    'STA_ADD1': '서울특별시 양천구 목동 927-10',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52571487',
#    'STA_LONG': '126.86486816',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '995'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1997',
#    'RENT_NO': '00771',
#    'RENT_NM': '목동아파트 703동 앞',
#    'RENT_ID_NM': '771.목동아파트 703동 앞',
#    'HOLD_NUM': '8',
#    'STA_ADD1': '서울특별시 양천구 목동로 212 목동신시가지아파트7단지',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52820587',
#    'STA_LONG': '126.87016296',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '996'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1998',
#    'RENT_NO': '00772',
#    'RENT_NM': '대원칸타빌1차아파트',
#    'RENT_ID_NM': '772.대원칸타빌1차아파트',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 양천구 목동 812',
#    'STA_ADD2': '',
#    'STA_LAT': '37.52825928',
#    'STA_LONG': '126.86426544',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '997'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1999',
#    'RENT_NO': '00773',
#    'RENT_NM': '염창역 3, 4번 출구 사이',
#    'RENT_ID_NM': '773.염창역 3, 4번 출구 사이',
#    'HOLD_NUM': '10',
#    'STA_ADD1': '서울특별시 양천구 공항대로 630 어바니엘',
#    'STA_ADD2': '',
#    'STA_LAT': '37.54670715',
#    'STA_LONG': '126.87457275',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '998'},
#   {'STA_LOC': '마포구',
#    'RENT_ID': 'ST-20',
#    'RENT_NO': '00114',
#    'RENT_NM': '홍대입구역 8번출구 앞',
#    'RENT_ID_NM': '114. 홍대입구역 8번출구 앞',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 마포구 양화로18길 3',
#    'STA_ADD2': '192-5',
#    'STA_LAT': '37.55706024',
#    'STA_LONG': '126.92442322',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '999'},
#   {'STA_LOC': '마포구',
#    'RENT_ID': 'ST-200',
#    'RENT_NO': '00142',
#    'RENT_NM': '아현역 4번출구 앞',
#    'RENT_ID_NM': '142. 아현역 4번출구 앞',
#    'HOLD_NUM': '11',
#    'STA_ADD1': '서울특별시 마포구 아현동 329-15',
#    'STA_ADD2': '아현역 4번출구 앞',
#    'STA_LAT': '37.55720139',
#    'STA_LONG': '126.95566559',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '1000'}]}

# %%
response_json["stationInfo"].keys()
# Out:
# dict_keys(['list_total_count', 'RESULT', 'row'])

# %%
response_json["stationInfo"]["row"]
# Out:
# [{'STA_LOC': '마포구',
#   'RENT_ID': 'ST-10',
#   'RENT_NO': '00108',
#   'RENT_NM': '서교동 사거리',
#   'RENT_ID_NM': '108. 서교동 사거리',
#   'HOLD_NUM': '12',
#   'STA_ADD1': '서울특별시 마포구 양화로 93',
#   'STA_ADD2': '427',
#   'STA_LAT': '37.55274582',
#   'STA_LONG': '126.91861725',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '1'},
#  {'STA_LOC': '광진구',
#   'RENT_ID': 'ST-100',
#   'RENT_NO': '00503',
#   'RENT_NM': '더샵스타시티 C동 앞',
#   'RENT_ID_NM': '503. 더샵스타시티 C동 앞',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 광진구 아차산로 262',
#   'STA_ADD2': '더샵스타시티 C동 앞',
#   'STA_LAT': '37.53666687',
#   'STA_LONG': '127.07359314',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '2'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1000',
#   'RENT_NO': '00729',
#   'RENT_NM': '서부식자재마트 건너편',
#   'RENT_ID_NM': '729. 서부식자재마트 건너편',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 신정동 236 ',
#   'STA_ADD2': '서부식자재마트 건너편',
#   'STA_LAT': '37.51037979',
#   'STA_LONG': '126.86679840',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '3'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1002',
#   'RENT_NO': '00731',
#   'RENT_NM': '서울시 도로환경관리센터',
#   'RENT_ID_NM': '731. 서울시 도로환경관리센터',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 목동동로 316-6',
#   'STA_ADD2': '서울시 도로환경관리센터',
#   'STA_LAT': '37.52989960',
#   'STA_LONG': '126.87654114',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '4'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1003',
#   'RENT_NO': '00732',
#   'RENT_NM': '신월중학교',
#   'RENT_ID_NM': '732. 신월중학교',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 화곡로 59',
#   'STA_ADD2': '신월동 이마트',
#   'STA_LAT': '37.53955078',
#   'STA_LONG': '126.82830048',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '5'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1004',
#   'RENT_NO': '00733',
#   'RENT_NM': '신정이펜하우스314동',
#   'RENT_ID_NM': '733. 신정이펜하우스314동',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 신정이펜1로50 ',
#   'STA_ADD2': '신정이펜하우스314동',
#   'STA_LAT': '37.51409912',
#   'STA_LONG': '126.83100128',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '6'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1005',
#   'RENT_NO': '00734',
#   'RENT_NM': '신트리공원 입구',
#   'RENT_ID_NM': '734. 신트리공원 입구',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 신정동 310-8 ',
#   'STA_ADD2': '신트리공원 입구',
#   'STA_LAT': '37.51395035',
#   'STA_LONG': '126.85605621',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '7'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1006',
#   'RENT_NO': '00735',
#   'RENT_NM': '영도초등학교',
#   'RENT_ID_NM': '735. 영도초등학교',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 목동중앙로 70 서울영도초등학교',
#   'STA_ADD2': '',
#   'STA_LAT': '37.53637695',
#   'STA_LONG': '126.87151337',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '8'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1007',
#   'RENT_NO': '00736',
#   'RENT_NM': '오솔길공원',
#   'RENT_ID_NM': '736. 오솔길공원',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 남부순환로70길11-9',
#   'STA_ADD2': '오솔길공원',
#   'STA_LAT': '37.52219009',
#   'STA_LONG': '126.83670044',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '9'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1008',
#   'RENT_NO': '00737',
#   'RENT_NM': '장수공원',
#   'RENT_ID_NM': '737. 장수공원',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 양천구 신정동 1235',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52231216',
#   'STA_LONG': '126.84904480',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '10'},
#  {'STA_LOC': '광진구',
#   'RENT_ID': 'ST-101',
#   'RENT_NO': '00504',
#   'RENT_NM': '신자초교입구교차로',
#   'RENT_ID_NM': '504. 신자초교입구교차로',
#   'HOLD_NUM': '9',
#   'STA_ADD1': '서울특별시 광진구 뚝섬로 596',
#   'STA_ADD2': '신자초교입구교차로',
#   'STA_LAT': '37.53297043',
#   'STA_LONG': '127.07593536',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '11'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1010',
#   'RENT_NO': '00739',
#   'RENT_NM': '신월사거리',
#   'RENT_ID_NM': '739. 신월사거리',
#   'HOLD_NUM': '13',
#   'STA_ADD1': '서울특별시 양천구 남부순환로 334',
#   'STA_ADD2': '',
#   'STA_LAT': '37.53699493',
#   'STA_LONG': '126.82728577',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '12'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1011',
#   'RENT_NO': '00740',
#   'RENT_NM': '으뜸공원',
#   'RENT_ID_NM': '740. 으뜸공원',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 양천구 가로공원로 133',
#   'STA_ADD2': '으뜸공원',
#   'STA_LAT': '37.53636932',
#   'STA_LONG': '126.83171082',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '13'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1012',
#   'RENT_NO': '00741',
#   'RENT_NM': '화곡로 입구 교차로',
#   'RENT_ID_NM': '741. 화곡로 입구 교차로',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 신월동 258',
#   'STA_ADD2': '화곡로 입구 교차로',
#   'STA_LAT': '37.53952026',
#   'STA_LONG': '126.82540131',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '14'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1013',
#   'RENT_NO': '00742',
#   'RENT_NM': '등촌역 5번 출구 뒤',
#   'RENT_ID_NM': '742. 등촌역 5번 출구 뒤',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 등촌로 236',
#   'STA_ADD2': '등촌역 5번 출구 뒤',
#   'STA_LAT': '37.55073166',
#   'STA_LONG': '126.86457825',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '15'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1014',
#   'RENT_NO': '00743',
#   'RENT_NM': '현대6차아파트 101동 옆',
#   'RENT_ID_NM': '743. 현대6차아파트 101동 옆',
#   'HOLD_NUM': '22',
#   'STA_ADD1': '서울특별시 양천구 신정동 735-5',
#   'STA_ADD2': '현대6차아파트 101동 옆',
#   'STA_LAT': '37.50889969',
#   'STA_LONG': '126.84268188',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '16'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1015',
#   'RENT_NO': '00744',
#   'RENT_NM': '신목동역 2번 출구',
#   'RENT_ID_NM': '744. 신목동역 2번 출구',
#   'HOLD_NUM': '40',
#   'STA_ADD1': '서울특별시 양천구 목동중앙로 212 앞',
#   'STA_ADD2': '신목동역 2번 출구',
#   'STA_LAT': '37.54384232',
#   'STA_LONG': '126.88254547',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '17'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1016',
#   'RENT_NO': '00745',
#   'RENT_NM': '강서초등학교',
#   'RENT_ID_NM': '745. 강서초등학교',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 오목로 31 부근',
#   'STA_ADD2': '강서초등학교',
#   'STA_LAT': '37.52228165',
#   'STA_LONG': '126.83969879',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '18'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1017',
#   'RENT_NO': '00746',
#   'RENT_NM': '목동2단지 상가',
#   'RENT_ID_NM': '746. 목동2단지 상가',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 목동 902-5 ',
#   'STA_ADD2': '목동2단지 상가',
#   'STA_LAT': '37.53650284',
#   'STA_LONG': '126.87774658',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '19'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1018',
#   'RENT_NO': '00747',
#   'RENT_NM': '목동3단지 상가',
#   'RENT_ID_NM': '747. 목동3단지 상가',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 목동 903-6',
#   'STA_ADD2': '목동3단지 상가',
#   'STA_LAT': '37.53458023',
#   'STA_LONG': '126.87564850',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '20'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1019',
#   'RENT_NO': '00748',
#   'RENT_NM': '목동운동장',
#   'RENT_ID_NM': '748. 목동운동장',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 양천구 안양천로 939',
#   'STA_ADD2': '목동운동장',
#   'STA_LAT': '37.53025055',
#   'STA_LONG': '126.87930298',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '21'},
#  {'STA_LOC': '광진구',
#   'RENT_ID': 'ST-102',
#   'RENT_NO': '00505',
#   'RENT_NM': '자양사거리 광진아크로텔 앞',
#   'RENT_ID_NM': '505. 자양사거리 광진아크로텔 앞',
#   'HOLD_NUM': '11',
#   'STA_ADD1': '서울특별시 광진구 아차산로 355',
#   'STA_ADD2': '타워더모스트 광진아크로텔',
#   'STA_LAT': '37.53701019',
#   'STA_LONG': '127.08224487',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '22'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1020',
#   'RENT_NO': '00934',
#   'RENT_NM': '신사동 성당',
#   'RENT_ID_NM': '934. 신사동 성당',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 은평구 신사동 41-3',
#   'STA_ADD2': '신사동 성당',
#   'STA_LAT': '37.59714127',
#   'STA_LONG': '126.90959930',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '23'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1021',
#   'RENT_NO': '00935',
#   'RENT_NM': '역촌역 1번 출구',
#   'RENT_ID_NM': '935. 역촌역 1번 출구',
#   'HOLD_NUM': '7',
#   'STA_ADD1': '서울특별시 은평구 역촌동 17-55',
#   'STA_ADD2': '역촌역 1번 출구',
#   'STA_LAT': '37.60520172',
#   'STA_LONG': '126.92211151',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '24'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1023',
#   'RENT_NO': '00937',
#   'RENT_NM': '상림마을 롯데캐슬2단지 옆',
#   'RENT_ID_NM': '937. 상림마을 롯데캐슬2단지 옆',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 은평구 진관동 30-23',
#   'STA_ADD2': '상림마을 롯데캐슬2단지 옆',
#   'STA_LAT': '37.64585114',
#   'STA_LONG': '126.92379761',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '25'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1024',
#   'RENT_NO': '00938',
#   'RENT_NM': '금암 문화공원',
#   'RENT_ID_NM': '938. 금암 문화공원',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 은평구 진관동 44-28 ',
#   'STA_ADD2': '금암 문화공원',
#   'STA_LAT': '37.64468384',
#   'STA_LONG': '126.91845703',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '26'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1025',
#   'RENT_NO': '00939',
#   'RENT_NM': '은평구청 교차로',
#   'RENT_ID_NM': '939. 은평구청 교차로',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 은평구 응암동 82-31',
#   'STA_ADD2': '은평구청 교차로',
#   'STA_LAT': '37.60169983',
#   'STA_LONG': '126.92742157',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '27'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1027',
#   'RENT_NO': '00941',
#   'RENT_NM': '은평뉴타운 도서관',
#   'RENT_ID_NM': '941. 은평뉴타운 도서관',
#   'HOLD_NUM': '13',
#   'STA_ADD1': '서울특별시 은평구 진관동 141-27',
#   'STA_ADD2': '은평뉴타운 도서관',
#   'STA_LAT': '37.63722229',
#   'STA_LONG': '126.93330383',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '28'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1028',
#   'RENT_NO': '00942',
#   'RENT_NM': '상림마을 생태공원',
#   'RENT_ID_NM': '942. 상림마을 생태공원',
#   'HOLD_NUM': '9',
#   'STA_ADD1': '서울특별시 은평구 진관동 16-4',
#   'STA_ADD2': '상림마을 생태공원',
#   'STA_LAT': '37.64408112',
#   'STA_LONG': '126.92928314',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '29'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1029',
#   'RENT_NO': '00943',
#   'RENT_NM': '은평구청 보건소',
#   'RENT_ID_NM': '943. 은평구청 보건소',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 은평구 녹번동 84',
#   'STA_ADD2': '은평구청 보건소',
#   'STA_LAT': '37.60240173',
#   'STA_LONG': '126.92864990',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '30'},
#  {'STA_LOC': '성동구',
#   'RENT_ID': 'ST-103',
#   'RENT_NO': '00506',
#   'RENT_NM': '금호 어울림 아파트 앞',
#   'RENT_ID_NM': '506. 금호 어울림 아파트 앞',
#   'HOLD_NUM': '7',
#   'STA_ADD1': '서울특별시 성동구 광나루로 249',
#   'STA_ADD2': '송정금호어울림 아파트 앞',
#   'STA_LAT': '37.54906082',
#   'STA_LONG': '127.05779266',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '31'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1031',
#   'RENT_NO': '00945',
#   'RENT_NM': '기자촌 사거리 A',
#   'RENT_ID_NM': '945. 기자촌 사거리 A',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 은평구 진관동 149-17',
#   'STA_ADD2': '기자촌 사거리',
#   'STA_LAT': '37.63414001',
#   'STA_LONG': '126.93234253',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '32'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1032',
#   'RENT_NO': '00946',
#   'RENT_NM': '독바위역',
#   'RENT_ID_NM': '946. 독바위역 ',
#   'HOLD_NUM': '16',
#   'STA_ADD1': '서울특별시 은평구 불광로 129',
#   'STA_ADD2': '독바위역 ',
#   'STA_LAT': '37.61843872',
#   'STA_LONG': '126.93288422',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '33'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1033',
#   'RENT_NO': '00947',
#   'RENT_NM': '연신내 선일하이츠빌 정류소',
#   'RENT_ID_NM': '947. 연신내 선일하이츠빌 정류소',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 은평구 불광동 484-165',
#   'STA_ADD2': '연신내 선일하이츠빌 정류소',
#   'STA_LAT': '37.62266922',
#   'STA_LONG': '126.91999054',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '34'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1034',
#   'RENT_NO': '00948',
#   'RENT_NM': '디지털미디어 시티역 4번출구(DMC역)',
#   'RENT_ID_NM': '948. 디지털미디어 시티역 4번출구(DMC역)',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 은평구 증산동 239',
#   'STA_ADD2': '디지털미디어 시티역 4번출구',
#   'STA_LAT': '37.57720184',
#   'STA_LONG': '126.90235138',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '35'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1035',
#   'RENT_NO': '00949',
#   'RENT_NM': '연신내역 1번 출구',
#   'RENT_ID_NM': '949. 연신내역 1번 출구 ',
#   'HOLD_NUM': '6',
#   'STA_ADD1': '서울특별시 은평구 불광동 487-2',
#   'STA_ADD2': '연신내역 1번 출구 ',
#   'STA_LAT': '37.61978149',
#   'STA_LONG': '126.92080688',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '36'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1036',
#   'RENT_NO': '00950',
#   'RENT_NM': '구산역 2번 출구 예일여고 버스정류장',
#   'RENT_ID_NM': '950. 구산역 2번 출구 예일여고 버스정류장',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 은평구 연서로 124',
#   'STA_ADD2': '',
#   'STA_LAT': '37.60980225',
#   'STA_LONG': '126.91679382',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '37'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1037',
#   'RENT_NO': '00951',
#   'RENT_NM': '연신내역 6번출구옆',
#   'RENT_ID_NM': '951. 연신내역 6번출구옆',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 은평구 갈현동 389-15 ',
#   'STA_ADD2': '연신내역 6번출구옆',
#   'STA_LAT': '37.61930466',
#   'STA_LONG': '126.92059326',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '38'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1038',
#   'RENT_NO': '00952',
#   'RENT_NM': '서울연신중학교',
#   'RENT_ID_NM': '952. 서울연신중학교',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 은평구 불광동 400-4번지',
#   'STA_ADD2': '서울연신중학교',
#   'STA_LAT': '37.62265015',
#   'STA_LONG': '126.92524719',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '39'},
#  {'STA_LOC': '은평구',
#   'RENT_ID': 'ST-1039',
#   'RENT_NO': '00953',
#   'RENT_NM': '서울연신초등학교',
#   'RENT_ID_NM': '953. 서울연신초등학교',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 은평구 불광동 73-1번지 ',
#   'STA_ADD2': '서울연신초등학교',
#   'STA_LAT': '37.62577820',
#   'STA_LONG': '126.92881775',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '40'},
#  {'STA_LOC': '성동구',
#   'RENT_ID': 'ST-104',
#   'RENT_NO': '00507',
#   'RENT_NM': '성수아이에스비즈타워 앞',
#   'RENT_ID_NM': '507. 성수아이에스비즈타워 앞',
#   'HOLD_NUM': '7',
#   'STA_ADD1': '서울특별시 성동구 성수이로 147',
#   'STA_ADD2': '아이에스비즈타워 앞',
#   'STA_LAT': '37.54820251',
#   'STA_LONG': '127.05711365',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '41'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1040',
#   'RENT_NO': '01023',
#   'RENT_NM': '한국종합기술사옥 앞',
#   'RENT_ID_NM': '1023. 한국종합기술사옥 앞',
#   'HOLD_NUM': '22',
#   'STA_ADD1': '서울특별시 강동구 상일로6길 21 한국종합기술사옥',
#   'STA_ADD2': '',
#   'STA_LAT': '37.54998398',
#   'STA_LONG': '127.17470551',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '42'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1041',
#   'RENT_NO': '01024',
#   'RENT_NM': '강동구청 앞',
#   'RENT_ID_NM': '1024.  강동구청 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강동구 성내로 28 강동빌딩',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52929688',
#   'STA_LONG': '127.12315369',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '43'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1042',
#   'RENT_NO': '01025',
#   'RENT_NM': '상일초등학교',
#   'RENT_ID_NM': '1025. 상일초등학교',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강동구 상일동 440-3',
#   'STA_ADD2': '상일초등학교',
#   'STA_LAT': '37.54684067',
#   'STA_LONG': '127.17251587',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '44'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1043',
#   'RENT_NO': '01026',
#   'RENT_NM': '대명초교 입구 교차로',
#   'RENT_ID_NM': '1026. 대명초교 입구 교차로',
#   'HOLD_NUM': '14',
#   'STA_ADD1': '서울특별시 강동구 명일동 59',
#   'STA_ADD2': '',
#   'STA_LAT': '37.54653549',
#   'STA_LONG': '127.15583801',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '45'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1044',
#   'RENT_NO': '01027',
#   'RENT_NM': '프라자 아파트 앞',
#   'RENT_ID_NM': '1027. 프라자 아파트 앞',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 강동구 천호대로 1240 프라자아파트',
#   'STA_ADD2': '',
#   'STA_LAT': '37.53596115',
#   'STA_LONG': '127.14781952',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '46'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1045',
#   'RENT_NO': '01028',
#   'RENT_NM': '포레스 주상복합 빌딩',
#   'RENT_ID_NM': '1028. 포레스 주상복합 빌딩',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강동구 천호옛길 41 포레스아파트',
#   'STA_ADD2': '',
#   'STA_LAT': '37.53310776',
#   'STA_LONG': '127.12277222',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '47'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1046',
#   'RENT_NO': '01029',
#   'RENT_NM': '성내어울터',
#   'RENT_ID_NM': '1029. 성내어울터',
#   'HOLD_NUM': '7',
#   'STA_ADD1': '서울특별시 강동구 성내동 43-2',
#   'STA_ADD2': '',
#   'STA_LAT': '37.53655624',
#   'STA_LONG': '127.12553406',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '48'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1047',
#   'RENT_NO': '01030',
#   'RENT_NM': '미호 플랜트 앞',
#   'RENT_ID_NM': '1030. 미호 플랜트 앞',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 강동구 강동대로 143-22',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52703094',
#   'STA_LONG': '127.12206268',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '49'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1048',
#   'RENT_NO': '01031',
#   'RENT_NM': '올림픽로 836(아리수로)',
#   'RENT_ID_NM': '1031. 올림픽로 836(아리수로)',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 강동구 암사동 440',
#   'STA_ADD2': '',
#   'STA_LAT': '37.55604172',
#   'STA_LONG': '127.13093567',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '50'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1049',
#   'RENT_NO': '01032',
#   'RENT_NM': '선사고등학교',
#   'RENT_ID_NM': '1032. 선사고등학교',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 강동구 암사동 524',
#   'STA_ADD2': '',
#   'STA_LAT': '37.55672836',
#   'STA_LONG': '127.13626099',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '51'},
#  {'STA_LOC': '성동구',
#   'RENT_ID': 'ST-105',
#   'RENT_NO': '00508',
#   'RENT_NM': '성수아카데미타워 앞',
#   'RENT_ID_NM': '508. 성수아카데미타워 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 성동구 성수이로 118 성수아카데미타워',
#   'STA_ADD2': '',
#   'STA_LAT': '37.54516983',
#   'STA_LONG': '127.05757141',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '52'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1050',
#   'RENT_NO': '01033',
#   'RENT_NM': '고덕동 아남아파트',
#   'RENT_ID_NM': '1033. 고덕동 아남아파트',
#   'HOLD_NUM': '17',
#   'STA_ADD1': '서울특별시 강동구 고덕동 469',
#   'STA_ADD2': '',
#   'STA_LAT': '37.55793381',
#   'STA_LONG': '127.14476776',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '53'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1051',
#   'RENT_NO': '01034',
#   'RENT_NM': '고덕동 래미안 힐스테이트',
#   'RENT_ID_NM': '1034. 고덕동 래미안 힐스테이트',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 강동구 고덕동 585-4',
#   'STA_ADD2': '',
#   'STA_LAT': '37.56187820',
#   'STA_LONG': '127.15078735',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '54'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1052',
#   'RENT_NO': '01035',
#   'RENT_NM': '고덕역 4번출구',
#   'RENT_ID_NM': '1035. 고덕역 4번출구',
#   'HOLD_NUM': '25',
#   'STA_ADD1': '서울특별시 강동구 명일동 46-6',
#   'STA_ADD2': '',
#   'STA_LAT': '37.55509567',
#   'STA_LONG': '127.15528107',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '55'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1053',
#   'RENT_NO': '01036',
#   'RENT_NM': '고덕동 주양쇼핑',
#   'RENT_ID_NM': '1036. 고덕동 주양쇼핑',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강동구 명일동 48-25',
#   'STA_ADD2': '',
#   'STA_LAT': '37.55199051',
#   'STA_LONG': '127.15331268',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '56'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1054',
#   'RENT_NO': '01037',
#   'RENT_NM': '강일리버파크 6단지',
#   'RENT_ID_NM': '1037. 강일리버파크 6단지',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강동구 강일동 684-2',
#   'STA_ADD2': '',
#   'STA_LAT': '37.56256485',
#   'STA_LONG': '127.17761230',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '57'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1055',
#   'RENT_NO': '01038',
#   'RENT_NM': '강일 다솜 어린이 공원',
#   'RENT_ID_NM': '1038. 강일 다솜 어린이 공원',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강동구 강일동 667-4',
#   'STA_ADD2': '',
#   'STA_LAT': '37.56863785',
#   'STA_LONG': '127.17480469',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '58'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1056',
#   'RENT_NO': '01039',
#   'RENT_NM': '고덕초등학교',
#   'RENT_ID_NM': '1039. 고덕초등학교',
#   'HOLD_NUM': '7',
#   'STA_ADD1': '서울특별시 강동구 고덕로83길 55',
#   'STA_ADD2': '',
#   'STA_LAT': '37.56129837',
#   'STA_LONG': '127.16784668',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '59'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1057',
#   'RENT_NO': '01040',
#   'RENT_NM': '강일동 에너지 마루',
#   'RENT_ID_NM': '1040. 강일동 에너지 마루',
#   'STA_ADD1': '서울특별시 강동구 고덕동 375',
#   'STA_ADD2': '강일동 에너지 마루',
#   'STA_LAT': '37.56719971',
#   'STA_LONG': '127.16345978',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '60'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1058',
#   'RENT_NO': '01041',
#   'RENT_NM': '묘곡초등학교',
#   'RENT_ID_NM': '1041. 묘곡초등학교',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강동구 동남로79길 46 서울묘곡초등학교',
#   'STA_ADD2': '',
#   'STA_LAT': '37.55916214',
#   'STA_LONG': '127.15332031',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '61'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1059',
#   'RENT_NO': '01042',
#   'RENT_NM': '강일리버파크 2~5단지',
#   'RENT_ID_NM': '1042. 강일리버파크 2~5단지',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강동구 아리수로97길 68 강일리버파크2단지아파트',
#   'STA_ADD2': '',
#   'STA_LAT': '37.56854630',
#   'STA_LONG': '127.17700958',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '62'},
#  {'STA_LOC': '성동구',
#   'RENT_ID': 'ST-106',
#   'RENT_NO': '00509',
#   'RENT_NM': '이마트 버스정류소 옆',
#   'RENT_ID_NM': '509. 이마트 버스정류소 옆',
#   'HOLD_NUM': '25',
#   'STA_ADD1': '서울특별시 성동구 뚝섬로 379',
#   'STA_ADD2': '이마트 버스정류소 옆',
#   'STA_LAT': '37.53965378',
#   'STA_LONG': '127.05258942',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '63'},
#  {'STA_LOC': '강동구',
#   'RENT_ID': 'ST-1061',
#   'RENT_NO': '01044',
#   'RENT_NM': '굽은다리역',
#   'RENT_ID_NM': '1044. 굽은다리역',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 강동구 천호동 42-1',
#   'STA_ADD2': '',
#   'STA_LAT': '37.54540634',
#   'STA_LONG': '127.14267731',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '64'},
#  {'STA_LOC': '강서구',
#   'RENT_ID': 'ST-1062',
#   'RENT_NO': '01150',
#   'RENT_NM': '송정역 1번출구',
#   'RENT_ID_NM': '1150. 송정역 1번출구',
#   'HOLD_NUM': '7',
#   'STA_ADD1': '서울특별시 강서구 공항대로 33 송정역(5호선)',
#   'STA_ADD2': '',
#   'STA_LAT': '37.56153107',
#   'STA_LONG': '126.81069946',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '65'},
#  {'STA_LOC': '강서구',
#   'RENT_ID': 'ST-1063',
#   'RENT_NO': '01151',
#   'RENT_NM': '마곡역1번출구',
#   'RENT_ID_NM': '1151. 마곡역1번출구',
#   'HOLD_NUM': '30',
#   'STA_ADD1': '서울특별시 강서구 공항대로 163 마곡역(5호선)',
#   'STA_ADD2': '',
#   'STA_LAT': '37.56020737',
#   'STA_LONG': '126.82414246',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '66'},
#  {'STA_LOC': '강서구',
#   'RENT_ID': 'ST-1064',
#   'RENT_NO': '01152',
#   'RENT_NM': '마곡역교차로',
#   'RENT_ID_NM': '1152. 마곡역교차로',
#   'HOLD_NUM': '36',
#   'STA_ADD1': '서울특별시 강서구 마곡동 728-168',
#   'STA_ADD2': '마곡역7번출구',
#   'STA_LAT': '37.55831146',
#   'STA_LONG': '126.82652283',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '67'},
#  {'STA_LOC': '강서구',
#   'RENT_ID': 'ST-1065',
#   'RENT_NO': '01153',
#   'RENT_NM': '발산역 1번, 9번 인근 대여소',
#   'RENT_ID_NM': '1153. 발산역 1번, 9번 인근 대여소',
#   'HOLD_NUM': '32',
#   'STA_ADD1': '서울특별시 강서구 마곡동 797-5',
#   'STA_ADD2': '',
#   'STA_LAT': '37.55894852',
#   'STA_LONG': '126.83717346',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '68'},
#  {'STA_LOC': '강서구',
#   'RENT_ID': 'ST-1067',
#   'RENT_NO': '01155',
#   'RENT_NM': '기쁜우리복지관',
#   'RENT_ID_NM': '1155. 기쁜우리복지관',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강서구 가양동 1458-15 ',
#   'STA_ADD2': '기쁜우리복지관',
#   'STA_LAT': '37.56925964',
#   'STA_LONG': '126.84841919',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '69'},
#  {'STA_LOC': '강서구',
#   'RENT_ID': 'ST-1069',
#   'RENT_NO': '01157',
#   'RENT_NM': '강서구청',
#   'RENT_ID_NM': '1157. 강서구청',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 강서구 화곡로 302',
#   'STA_ADD2': '강서구청',
#   'STA_LAT': '37.55065918',
#   'STA_LONG': '126.84976959',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '70'},
#  {'STA_LOC': '성동구',
#   'RENT_ID': 'ST-107',
#   'RENT_NO': '00510',
#   'RENT_NM': '뚝도아리수정수센터 버스정류소 옆',
#   'RENT_ID_NM': '510. 뚝도아리수정수센터 버스정류소 옆',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 성동구 왕십리로11길 9',
#   'STA_ADD2': '서울숲남문 버스정류소 옆',
#   'STA_LAT': '37.54122162',
#   'STA_LONG': '127.04380035',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '71'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1070',
#   'RENT_NO': '01251',
#   'RENT_NM': '석촌역 2번출구',
#   'RENT_ID_NM': '1251. 석촌역 2번출구',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 송파구 송파동 68 ',
#   'STA_ADD2': '석촌역 2번출구',
#   'STA_LAT': '37.50593185',
#   'STA_LONG': '127.10774994',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '72'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1072',
#   'RENT_NO': '01253',
#   'RENT_NM': '오금역 3번 출구 뒤',
#   'RENT_ID_NM': '1253. 오금역 3번 출구 뒤',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 송파구 가락동 10-15 ',
#   'STA_ADD2': '오금역 3번 출구 뒤',
#   'STA_LAT': '37.50165176',
#   'STA_LONG': '127.12818146',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '73'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1075',
#   'RENT_NO': '01256',
#   'RENT_NM': '문정현대아파트 교차로',
#   'RENT_ID_NM': '1256. 문정현대아파트 교차로',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 송파구 문정동 3-2 ',
#   'STA_ADD2': '문정현대아파트 교차로',
#   'STA_LAT': '37.49113083',
#   'STA_LONG': '127.12580872',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '74'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1076',
#   'RENT_NO': '01257',
#   'RENT_NM': '가락시장역 사거리',
#   'RENT_ID_NM': '1257. 가락시장역 사거리',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 송파구 가락동 214-15 ',
#   'STA_ADD2': '가락시장역 롯데마트앞',
#   'STA_LAT': '37.49209976',
#   'STA_LONG': '127.11775208',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '75'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1077',
#   'RENT_NO': '01258',
#   'RENT_NM': '가락미륭아파트 앞',
#   'RENT_ID_NM': '1258. 가락미륭아파트 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 송파구 가락동 195-4',
#   'STA_ADD2': '가락미륭아파트 앞',
#   'STA_LAT': '37.49319839',
#   'STA_LONG': '127.12899780',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '76'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1078',
#   'RENT_NO': '01259',
#   'RENT_NM': '방이역 1번출구',
#   'RENT_ID_NM': '1259. 방이역 1번출구',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 송파구 오금동 17-20',
#   'STA_ADD2': '방이역 1번출구',
#   'STA_LAT': '37.50898361',
#   'STA_LONG': '127.12659454',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '77'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1079',
#   'RENT_NO': '01260',
#   'RENT_NM': '방이동 한양3차아파트 옆',
#   'RENT_ID_NM': '1260. 방이동 한양3차아파트 옆',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 송파구 방이동 225-1',
#   'STA_ADD2': '방이동 한양3차아파트 옆',
#   'STA_LAT': '37.50630188',
#   'STA_LONG': '127.12139893',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '78'},
#  {'STA_LOC': '성동구',
#   'RENT_ID': 'ST-108',
#   'RENT_NO': '00511',
#   'RENT_NM': '서울숲역 5번 출구 옆',
#   'RENT_ID_NM': '511. 서울숲역 5번 출구 옆',
#   'HOLD_NUM': '16',
#   'STA_ADD1': '서울특별시 성동구 왕십리로 지하77',
#   'STA_ADD2': '서울숲역 4번 출구 옆',
#   'STA_LAT': '37.54458237',
#   'STA_LONG': '127.04460907',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '79'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1080',
#   'RENT_NO': '01261',
#   'RENT_NM': '석촌역 1번출구 앞',
#   'RENT_ID_NM': '1261. 석촌역 1번출구 앞',
#   'STA_ADD1': '서울특별시 송파구 송파동 69 ',
#   'STA_ADD2': '석촌역 1번출구 앞',
#   'STA_LAT': '37.50582886',
#   'STA_LONG': '127.10705566',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '80'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1081',
#   'RENT_NO': '01262',
#   'RENT_NM': '송파여성문화회관 앞',
#   'RENT_ID_NM': '1262. 송파여성문화회관 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 송파구 송파동 2-3 ',
#   'STA_ADD2': '송파여성문화회관 앞',
#   'STA_LAT': '37.50580215',
#   'STA_LONG': '127.10971832',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '81'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1082',
#   'RENT_NO': '01263',
#   'RENT_NM': '장지공영차고지',
#   'RENT_ID_NM': '1263. 장지공영차고지',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 송파구 장지동 861-6',
#   'STA_ADD2': '장지공영차고지',
#   'STA_LAT': '37.48054123',
#   'STA_LONG': '127.13701630',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '82'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1083',
#   'RENT_NO': '01264',
#   'RENT_NM': '천호역 10번 출구 앞',
#   'RENT_ID_NM': '1264. 천호역 10번 출구 앞',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 송파구 풍납동 490-16',
#   'STA_ADD2': '천호역 10번 출구 앞',
#   'STA_LAT': '37.53858185',
#   'STA_LONG': '127.12280273',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '83'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1084',
#   'RENT_NO': '01265',
#   'RENT_NM': '문정동 근린공원',
#   'RENT_ID_NM': '1265. 문정동 근린공원',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 송파구 문정동 38-3',
#   'STA_ADD2': '문정동 근린공원',
#   'STA_LAT': '37.48598862',
#   'STA_LONG': '127.12476349',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '84'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1085',
#   'RENT_NO': '01266',
#   'RENT_NM': '문정동 글샘 공원',
#   'RENT_ID_NM': '1266. 문정동 글샘 공원',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 송파구 문정동 627',
#   'STA_ADD2': '장지동 글샘 공원',
#   'STA_LAT': '37.47880936',
#   'STA_LONG': '127.12000275',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '85'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1086',
#   'RENT_NO': '01267',
#   'RENT_NM': '올림픽공원 남2문 앞',
#   'RENT_ID_NM': '1267. 올림픽공원 남2문 앞',
#   'HOLD_NUM': '14',
#   'STA_ADD1': '서울특별시 송파구 올림픽로 424',
#   'STA_ADD2': '올림픽공원 남2문 앞',
#   'STA_LAT': '37.51424026',
#   'STA_LONG': '127.12306976',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '86'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1087',
#   'RENT_NO': '01268',
#   'RENT_NM': '몽촌토성역 1번출구 옆',
#   'RENT_ID_NM': '1268. 몽촌토성역 1번출구 옆',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 송파구 방이동 88-21 ',
#   'STA_ADD2': '몽촌토성역 1번출구 옆',
#   'STA_LAT': '37.51728821',
#   'STA_LONG': '127.11419678',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '87'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1088',
#   'RENT_NO': '01269',
#   'RENT_NM': '리센츠아파트',
#   'RENT_ID_NM': '1269. 리센츠아파트 ',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 송파구 올림픽로 135',
#   'STA_ADD2': '리센츠아파트 ',
#   'STA_LAT': '37.51194382',
#   'STA_LONG': '127.09121704',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '88'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1089',
#   'RENT_NO': '01271',
#   'RENT_NM': '송파도서관',
#   'RENT_ID_NM': '1271. 송파도서관',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 송파구 동남로 263',
#   'STA_ADD2': '송파도서관',
#   'STA_LAT': '37.49998474',
#   'STA_LONG': '127.13539124',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '89'},
#  {'STA_LOC': '성동구',
#   'RENT_ID': 'ST-109',
#   'RENT_NO': '00512',
#   'RENT_NM': '뚝섬역 1번 출구 옆',
#   'RENT_ID_NM': '512. 뚝섬역 1번 출구 옆',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 성동구 아차산로 18',
#   'STA_ADD2': '뚝섬역 1번 출구 옆',
#   'STA_LAT': '37.54856110',
#   'STA_LONG': '127.04500580',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '90'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1090',
#   'RENT_NO': '01272',
#   'RENT_NM': '송파 글마루도서관',
#   'RENT_ID_NM': '1272. 송파 글마루도서관',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 송파구 충민로 120',
#   'STA_ADD2': '송파 글마루도서관',
#   'STA_LAT': '0.00000000',
#   'STA_LONG': '0.00000000',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '91'},
#  {'STA_LOC': '송파구',
#   'RENT_ID': 'ST-1092',
#   'RENT_NO': '01274',
#   'RENT_NM': '영파여고 앞',
#   'RENT_ID_NM': '1274. 영파여고 앞',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 송파구 올림픽로 565',
#   'STA_ADD2': '영파여고 앞',
#   'STA_LAT': '37.53284836',
#   'STA_LONG': '127.12104797',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '92'},
#  {'STA_LOC': '중랑구',
#   'RENT_ID': 'ST-1093',
#   'RENT_NO': '01442',
#   'RENT_NM': '중랑구청 중화동 별관 앞',
#   'RENT_ID_NM': '1442. 중랑구청 중화동 별관 앞',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 중랑구 중화동 50-8',
#   'STA_ADD2': '(구)신한은행 중랑교지점',
#   'STA_LAT': '37.59859085',
#   'STA_LONG': '127.07981873',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '93'},
#  {'STA_LOC': '중랑구',
#   'RENT_ID': 'ST-1094',
#   'RENT_NO': '01443',
#   'RENT_NM': '구립망우청소년독서실',
#   'RENT_ID_NM': '1443. 구립망우청소년독서실',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 중랑구 망우동 534-23 ',
#   'STA_ADD2': '구립망우청소년독서실',
#   'STA_LAT': '37.59552002',
#   'STA_LONG': '127.09877777',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '94'},
#  {'STA_LOC': '중랑구',
#   'RENT_ID': 'ST-1095',
#   'RENT_NO': '01444',
#   'RENT_NM': '면목4치안센터',
#   'RENT_ID_NM': '1444. 면목4치안센터',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 중랑구 면목동 646-4',
#   'STA_ADD2': '면목4치안센터',
#   'STA_LAT': '37.57402802',
#   'STA_LONG': '127.08054352',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '95'},
#  {'STA_LOC': '중랑구',
#   'RENT_ID': 'ST-1096',
#   'RENT_NO': '01445',
#   'RENT_NM': '용마지구대 A',
#   'RENT_ID_NM': '1445. 용마지구대 A',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 중랑구 면목동 197-5',
#   'STA_ADD2': '용마지구대',
#   'STA_LAT': '37.57994080',
#   'STA_LONG': '127.07939911',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '96'},
#  {'STA_LOC': '중랑구',
#   'RENT_ID': 'ST-1097',
#   'RENT_NO': '01446',
#   'RENT_NM': '중랑전화국 교차로',
#   'RENT_ID_NM': '1446. 중랑전화국 교차로',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 중랑구 면목동 282-8',
#   'STA_ADD2': '중랑전화국 교차로',
#   'STA_LAT': '37.59130096',
#   'STA_LONG': '127.08032990',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '97'},
#  {'STA_LOC': '중랑구',
#   'RENT_ID': 'ST-1098',
#   'RENT_NO': '01447',
#   'RENT_NM': '면목역 3번출구',
#   'RENT_ID_NM': '1447. 면목역 3번출구',
#   'HOLD_NUM': '17',
#   'STA_ADD1': '서울특별시 중랑구 면목동 120-2',
#   'STA_ADD2': '면목역 3번출구',
#   'STA_LAT': '37.58890152',
#   'STA_LONG': '127.08728027',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '98'},
#  {'STA_LOC': '중랑구',
#   'RENT_ID': 'ST-1099',
#   'RENT_NO': '01448',
#   'RENT_NM': '코스트코 상봉점',
#   'RENT_ID_NM': '1448. 코스트코 상봉점',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 중랑구 상봉동 160-3',
#   'STA_ADD2': '코스트코 상봉점',
#   'STA_LAT': '37.59732056',
#   'STA_LONG': '127.08979797',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '99'},
#  {'STA_LOC': '마포구',
#   'RENT_ID': 'ST-11',
#   'RENT_NO': '00109',
#   'RENT_NM': '제일빌딩 앞',
#   'RENT_ID_NM': '109. 제일빌딩 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 마포구 어울마당로 26',
#   'STA_ADD2': '12-2',
#   'STA_LAT': '37.54769135',
#   'STA_LONG': '126.91998291',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '100'},
#  {'STA_LOC': '마포구',
#   'RENT_ID': 'ST-110',
#   'RENT_NO': '00400',
#   'RENT_NM': '상암한화오벨리스크 1차 앞',
#   'RENT_ID_NM': '400. 상암한화오벨리스크 1차 앞',
#   'HOLD_NUM': '14',
#   'STA_ADD1': '서울특별시 마포구 구룡길 19',
#   'STA_ADD2': '상암한화오벨리스크 1차 앞',
#   'STA_LAT': '37.58752441',
#   'STA_LONG': '126.88300323',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '101'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1100',
#   'RENT_NO': '01526',
#   'RENT_NM': '강북종합시장 앞',
#   'RENT_ID_NM': '1526. 강북종합시장 앞',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 강북구 수유동 140',
#   'STA_ADD2': '수유동 채선당앞',
#   'STA_LAT': '37.64173889',
#   'STA_LONG': '127.02462769',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '102'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1101',
#   'RENT_NO': '01527',
#   'RENT_NM': '미아역 1번 출구 뒤',
#   'RENT_ID_NM': '1527. 미아역 1번 출구 뒤',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강북구 미아동 194-1',
#   'STA_ADD2': '미아역 1번 출구 뒤',
#   'STA_LAT': '37.62733459',
#   'STA_LONG': '127.02605438',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '103'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1102',
#   'RENT_NO': '01528',
#   'RENT_NM': '삼각산동 주민센터',
#   'RENT_ID_NM': '1528. 삼각산동 주민센터',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강북구 미아동 813-8',
#   'STA_ADD2': '삼각산동 주민센터',
#   'STA_LAT': '37.61503601',
#   'STA_LONG': '127.02069855',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '104'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1103',
#   'RENT_NO': '01529',
#   'RENT_NM': '미아동 한국전력공사',
#   'RENT_ID_NM': '1529. 미아동 한국전력공사',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 강북구 미아동 194-1',
#   'STA_ADD2': '미아동 한국전력공사',
#   'STA_LAT': '37.63018036',
#   'STA_LONG': '127.02490997',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '105'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1104',
#   'RENT_NO': '01530',
#   'RENT_NM': '광산사거리',
#   'RENT_ID_NM': '1530. 광산사거리',
#   'HOLD_NUM': '13',
#   'STA_ADD1': '서울특별시 강북구 노해로 87 ',
#   'STA_ADD2': '광산사거리',
#   'STA_LAT': '37.64355087',
#   'STA_LONG': '127.02234650',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '106'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1105',
#   'RENT_NO': '01531',
#   'RENT_NM': '미아사거리 1번 출구',
#   'RENT_ID_NM': '1531. 미아사거리 1번 출구',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강북구 미아동 66-1',
#   'STA_ADD2': '미아사거리 1번 출구',
#   'STA_LAT': '37.61395645',
#   'STA_LONG': '127.03025055',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '107'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1106',
#   'RENT_NO': '01532',
#   'RENT_NM': '번3동 주민센터 교차로',
#   'RENT_ID_NM': '1532. 번3동 주민센터 교차로',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강북구 번동 2-2',
#   'STA_ADD2': '번3동 주민센터 교차로',
#   'STA_LAT': '37.62635422',
#   'STA_LONG': '127.04744720',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '108'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1107',
#   'RENT_NO': '01533',
#   'RENT_NM': '번동 주공3, 4단지 교차로',
#   'RENT_ID_NM': '1533. 번동 주공3, 4단지 교차로',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강북구 번동 254',
#   'STA_ADD2': '번동 주공3, 4단지 교차로',
#   'STA_LAT': '37.62991714',
#   'STA_LONG': '127.04091644',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '109'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1108',
#   'RENT_NO': '01534',
#   'RENT_NM': '북서울 꿈의 숲 동문',
#   'RENT_ID_NM': '1534. 북서울 꿈의 숲 동문',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 강북구 번동 105',
#   'STA_ADD2': '북서울 꿈의 숲 동문',
#   'STA_LAT': '37.61963654',
#   'STA_LONG': '127.04453278',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '110'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1109',
#   'RENT_NO': '01535',
#   'RENT_NM': '효성인텔리안 앞',
#   'RENT_ID_NM': '1535. 효성인텔리안 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 강북구  수유동 230-7',
#   'STA_ADD2': '효성인텔리안 앞',
#   'STA_LAT': '37.63629150',
#   'STA_LONG': '127.02337646',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '111'},
#  {'STA_LOC': '성동구',
#   'RENT_ID': 'ST-111',
#   'RENT_NO': '00513',
#   'RENT_NM': '뚝섬역 5번 출구 정류소 옆',
#   'RENT_ID_NM': '513. 뚝섬역 5번 출구 정류소 옆',
#   'HOLD_NUM': '13',
#   'STA_ADD1': '서울특별시 성동구 아차산로 18',
#   'STA_ADD2': '뚝섬역 5번 출구 정류소 옆',
#   'STA_LAT': '37.54630661',
#   'STA_LONG': '127.04980469',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '112'},
#  {'STA_LOC': '강북구',
#   'RENT_ID': 'ST-1110',
#   'RENT_NO': '01536',
#   'RENT_NM': '번동 두산위브 101동 옆',
#   'RENT_ID_NM': '1536. 번동 두산위브 101동 옆',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 강북구 번동 386-17',
#   'STA_ADD2': '번동 두산위브 101동 옆',
#   'STA_LAT': '37.63626099',
#   'STA_LONG': '127.03217316',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '113'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1111',
#   'RENT_NO': '01643',
#   'RENT_NM': '태릉입구역 8번출구',
#   'RENT_ID_NM': '1643. 태릉입구역 8번출구',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 노원구 공릉동 687-6',
#   'STA_ADD2': '태릉입구역 8번출구',
#   'STA_LAT': '37.61736679',
#   'STA_LONG': '127.07521057',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '114'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1114',
#   'RENT_NO': '01646',
#   'RENT_NM': '삼육대 입구',
#   'RENT_ID_NM': '1646. 삼육대 입구',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 노원구 공릉동 26-43',
#   'STA_ADD2': '삼육대 입구',
#   'STA_LAT': '37.63848877',
#   'STA_LONG': '127.10790253',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '115'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1118',
#   'RENT_NO': '01650',
#   'RENT_NM': '중계근린공원내',
#   'RENT_ID_NM': '1650. 중계근린공원내',
#   'HOLD_NUM': '25',
#   'STA_ADD1': '서울특별시 노원구 중계동 506-3',
#   'STA_ADD2': '중계근린공원내',
#   'STA_LAT': '37.63957977',
#   'STA_LONG': '127.06510162',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '116'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1119',
#   'RENT_NO': '01651',
#   'RENT_NM': '상계동 우방유쉘아파트 앞',
#   'RENT_ID_NM': '1651. 상계동 우방유쉘아파트 앞',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 노원구 상계동 1118-9',
#   'STA_ADD2': '맥도날드 상계점 앞',
#   'STA_LAT': '37.67237473',
#   'STA_LONG': '127.05599213',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '117'},
#  {'STA_LOC': '성동구',
#   'RENT_ID': 'ST-112',
#   'RENT_NO': '00514',
#   'RENT_NM': '성수사거리 버스정류장 앞',
#   'RENT_ID_NM': '514. 성수사거리 버스정류장 앞',
#   'HOLD_NUM': '12',
#   'STA_ADD1': '서울특별시 성동구 아차산로 171',
#   'STA_ADD2': '성수사거리 버스정류장 앞',
#   'STA_LAT': '37.54257965',
#   'STA_LONG': '127.06330872',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '118'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1120',
#   'RENT_NO': '01652',
#   'RENT_NM': '파르코 앞',
#   'RENT_ID_NM': '1652. 파르코 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 노원구 상계동 1263',
#   'STA_ADD2': '파르코 앞',
#   'STA_LAT': '37.68000031',
#   'STA_LONG': '127.05558014',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '119'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1121',
#   'RENT_NO': '01653',
#   'RENT_NM': '노원역1번출구',
#   'RENT_ID_NM': '1653. 노원역1번출구',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 노원구 상계동 335-4',
#   'STA_ADD2': '노원역1번출구',
#   'STA_LAT': '37.65620041',
#   'STA_LONG': '127.06362152',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '120'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1122',
#   'RENT_NO': '01654',
#   'RENT_NM': '당고개입구 오거리',
#   'RENT_ID_NM': '1654. 당고개입구 오거리',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 노원구 상계동 172-2',
#   'STA_ADD2': '보훈회관 대여소',
#   'STA_LAT': '37.66379166',
#   'STA_LONG': '127.07544708',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '121'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1123',
#   'RENT_NO': '01655',
#   'RENT_NM': '공릉1단지아파트',
#   'RENT_ID_NM': '1655. 공릉1단지아파트',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 중랑구 동일로 1127',
#   'STA_ADD2': '공릉1단지아파트',
#   'STA_LAT': '37.63111115',
#   'STA_LONG': '127.07015991',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '122'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1124',
#   'RENT_NO': '01656',
#   'RENT_NM': '중앙하이츠 아파트 입구',
#   'RENT_ID_NM': '1656. 중앙하이츠 아파트 입구',
#   'HOLD_NUM': '12',
#   'STA_ADD1': '서울특별시 노원구 노원로 434 상계2차중앙하이츠아파트',
#   'STA_ADD2': '',
#   'STA_LAT': '37.65501785',
#   'STA_LONG': '127.06750488',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '123'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1125',
#   'RENT_NO': '01657',
#   'RENT_NM': '노원구청',
#   'RENT_ID_NM': '1657. 노원구청 ',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 노원구 노해로 437 ',
#   'STA_ADD2': '노원구청 ',
#   'STA_LAT': '37.65404892',
#   'STA_LONG': '127.05732727',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '124'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1127',
#   'RENT_NO': '01659',
#   'RENT_NM': '중계동 을지중학교',
#   'RENT_ID_NM': '1659. 중계동 을지중학교',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 노원구 중계동 370',
#   'STA_ADD2': '중계동 을지중학교',
#   'STA_LAT': '37.65032959',
#   'STA_LONG': '127.07160187',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '125'},
#  {'STA_LOC': '노원구',
#   'RENT_ID': 'ST-1128',
#   'RENT_NO': '01660',
#   'RENT_NM': '서울시립과학관',
#   'RENT_ID_NM': '1660. 서울시립과학관',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 노원구 하계동 266',
#   'STA_ADD2': '서울시립과학관',
#   'STA_LAT': '37.64207077',
#   'STA_LONG': '127.07662201',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '126'},
#  {'STA_LOC': '도봉구',
#   'RENT_ID': 'ST-1129',
#   'RENT_NO': '01713',
#   'RENT_NM': '쌍문동 이안아파트 앞',
#   'RENT_ID_NM': '1713. 쌍문동 이안아파트 앞',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 도봉구 쌍문동 315-488',
#   'STA_ADD2': '',
#   'STA_LAT': '37.65165329',
#   'STA_LONG': '127.02848816',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '127'},
#  {'STA_LOC': '광진구',
#   'RENT_ID': 'ST-113',
#   'RENT_NO': '00515',
#   'RENT_NM': '광양중학교 앞',
#   'RENT_ID_NM': '515. 광양중학교 앞',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 광진구 자양로3길 7',
#   'STA_ADD2': '광양중학교 앞',
#   'STA_LAT': '37.53023529',
#   'STA_LONG': '127.08683014',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '128'},
#  {'STA_LOC': '도봉구',
#   'RENT_ID': 'ST-1130',
#   'RENT_NO': '01714',
#   'RENT_NM': '도봉문화정보도서관 삼거리',
#   'RENT_ID_NM': '1714. 도봉문화정보도서관 삼거리',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 도봉구 덕릉로 315',
#   'STA_ADD2': '도봉문화정보도서관 삼거리',
#   'STA_LAT': '37.64463043',
#   'STA_LONG': '127.04460907',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '129'},
#  {'STA_LOC': '도봉구',
#   'RENT_ID': 'ST-1131',
#   'RENT_NO': '01715',
#   'RENT_NM': '서울특별시교육청도봉도서관',
#   'RENT_ID_NM': '1715. 서울특별시교육청도봉도서관',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 도봉구 삼양로556',
#   'STA_ADD2': '서울특별시교육청도봉도서관',
#   'STA_LAT': '37.65317917',
#   'STA_LONG': '127.01278687',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '130'},
#  {'STA_LOC': '도봉구',
#   'RENT_ID': 'ST-1132',
#   'RENT_NO': '01716',
#   'RENT_NM': '창동역 1번출구 건너편',
#   'RENT_ID_NM': '1716. 창동역 1번출구 건너편',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 도봉구 마들로11길 20',
#   'STA_ADD2': '하나로마트 창동점',
#   'STA_LAT': '37.65420151',
#   'STA_LONG': '127.05072784',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '131'},
#  {'STA_LOC': '도봉구',
#   'RENT_ID': 'ST-1133',
#   'RENT_NO': '01717',
#   'RENT_NM': '시립창동운동장 입구',
#   'RENT_ID_NM': '1717. 시립창동운동장 입구',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 도봉구 창동 1-24',
#   'STA_ADD2': '시립창동운동장 입구',
#   'STA_LAT': '37.65570831',
#   'STA_LONG': '127.05010223',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '132'},
#  {'STA_LOC': '도봉구',
#   'RENT_ID': 'ST-1135',
#   'RENT_NO': '01719',
#   'RENT_NM': '신도봉사거리 버스정류장',
#   'RENT_ID_NM': '1719. 신도봉사거리 버스정류장',
#   'HOLD_NUM': '6',
#   'STA_ADD1': '서울특별시 도봉구 도봉로 771',
#   'STA_ADD2': '신도봉사거리 버스정류장',
#   'STA_LAT': '37.67328262',
#   'STA_LONG': '127.04399109',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '133'},
#  {'STA_LOC': '도봉구',
#   'RENT_ID': 'ST-1136',
#   'RENT_NO': '01720',
#   'RENT_NM': '도봉구청 옆(중랑천변)',
#   'RENT_ID_NM': '1720. 도봉구청 옆(중랑천변)',
#   'HOLD_NUM': '27',
#   'STA_ADD1': '서울특별시 도봉구 마들로 656',
#   'STA_ADD2': '도봉구청 옆(중랑천변)',
#   'STA_LAT': '37.66867065',
#   'STA_LONG': '127.04798126',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '134'},
#  {'STA_LOC': '도봉구',
#   'RENT_ID': 'ST-1137',
#   'RENT_NO': '01721',
#   'RENT_NM': '창동역 2번출구',
#   'RENT_ID_NM': '1721. 창동역 2번출구 ',
#   'HOLD_NUM': '12',
#   'STA_ADD1': '서울특별시 노원구 창동 74-2 ',
#   'STA_ADD2': '창동역 2번출구 ',
#   'STA_LAT': '37.65301514',
#   'STA_LONG': '127.04699707',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '135'},
#  {'STA_LOC': '광진구',
#   'RENT_ID': 'ST-114',
#   'RENT_NO': '00516',
#   'RENT_NM': '광진메디칼 앞',
#   'RENT_ID_NM': '516. 광진메디칼 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 광진구 광나루로 355',
#   'STA_ADD2': '광진메디컬앞',
#   'STA_LAT': '37.54840469',
#   'STA_LONG': '127.06936646',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '136'},
#  {'STA_LOC': '금천구',
#   'RENT_ID': 'ST-1140',
#   'RENT_NO': '01839',
#   'RENT_NM': '수출의 다리 아래',
#   'RENT_ID_NM': '1839. 수출의 다리 아래',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 금천구 가산동 60-35',
#   'STA_ADD2': '',
#   'STA_LAT': '37.47743607',
#   'STA_LONG': '126.88615417',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '137'},
#  {'STA_LOC': '금천구',
#   'RENT_ID': 'ST-1141',
#   'RENT_NO': '01840',
#   'RENT_NM': '솔브레인이엔지 뒤편',
#   'RENT_ID_NM': '1840. 솔브레인이엔지 뒤편',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 금천구 가산로9길 80',
#   'STA_ADD2': '',
#   'STA_LAT': '37.47555161',
#   'STA_LONG': '126.88845825',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '138'},
#  {'STA_LOC': '금천구',
#   'RENT_ID': 'ST-1142',
#   'RENT_NO': '01841',
#   'RENT_NM': '가산동 주민센터',
#   'RENT_ID_NM': '1841. 가산동 주민센터',
#   'HOLD_NUM': '12',
#   'STA_ADD1': '서울특별시 금천구 가산동 144-3',
#   'STA_ADD2': '가산동 주민센터',
#   'STA_LAT': '37.47695160',
#   'STA_LONG': '126.89186859',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '139'},
#  {'STA_LOC': '금천구',
#   'RENT_ID': 'ST-1143',
#   'RENT_NO': '01842',
#   'RENT_NM': '한울중학교',
#   'RENT_ID_NM': '1842. 한울중학교',
#   'HOLD_NUM': '12',
#   'STA_ADD1': '서울특별시 금천구 시흥동 1000-3',
#   'STA_ADD2': '한울중학교',
#   'STA_LAT': '37.46257401',
#   'STA_LONG': '126.90686035',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '140'},
#  {'STA_LOC': '금천구',
#   'RENT_ID': 'ST-1144',
#   'RENT_NO': '01843',
#   'RENT_NM': '독산고등학교',
#   'RENT_ID_NM': '1843. 독산고등학교',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 금천구 독산동 906-42',
#   'STA_ADD2': '독산고등학교',
#   'STA_LAT': '37.47709656',
#   'STA_LONG': '126.91113281',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '141'},
#  {'STA_LOC': '금천구',
#   'RENT_ID': 'ST-1146',
#   'RENT_NO': '01845',
#   'RENT_NM': '롯데캐슬골드파크1차 서문',
#   'RENT_ID_NM': '1845. 롯데캐슬골드파크1차 서문',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 금천구 벚꽃로40 ',
#   'STA_ADD2': '롯데캐슬골드파크1차 서문',
#   'STA_LAT': '37.46028900',
#   'STA_LONG': '126.89218903',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '142'},
#  {'STA_LOC': '금천구',
#   'RENT_ID': 'ST-1147',
#   'RENT_NO': '01846',
#   'RENT_NM': '롯데캐슬골드파크1차 동문',
#   'RENT_ID_NM': '1846. 롯데캐슬골드파크1차 동문',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 금천구 독산동 441-19 ',
#   'STA_ADD2': '롯데캐슬골드파크1차 동문',
#   'STA_LAT': '37.46017075',
#   'STA_LONG': '126.89604187',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '143'},
#  {'STA_LOC': '금천구',
#   'RENT_ID': 'ST-1148',
#   'RENT_NO': '01847',
#   'RENT_NM': '독산주공 14단지 버스정류소',
#   'RENT_ID_NM': '1847. 독산주공 14단지 버스정류소',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 금천구 독산동 1091',
#   'STA_ADD2': '',
#   'STA_LAT': '37.46093369',
#   'STA_LONG': '126.88716888',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '144'},
#  {'STA_LOC': '금천구',
#   'RENT_ID': 'ST-1149',
#   'RENT_NO': '01848',
#   'RENT_NM': '벽산 디지털밸리 5차',
#   'RENT_ID_NM': '1848. 벽산 디지털밸리 5차',
#   'HOLD_NUM': '9',
#   'STA_ADD1': '서울특별시 금천구 가산동 60-73 ',
#   'STA_ADD2': '벽산 디지털밸리 5차',
#   'STA_LAT': '37.47627640',
#   'STA_LONG': '126.88539124',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '145'},
#  {'STA_LOC': '동작구',
#   'RENT_ID': 'ST-1150',
#   'RENT_NO': '02058',
#   'RENT_NM': '동작경찰서',
#   'RENT_ID_NM': '2058. 동작경찰서',
#   'HOLD_NUM': '14',
#   'STA_ADD1': '서울특별시 동작구 노량진동 113-7 ',
#   'STA_ADD2': '노량진동 맥도널드앞',
#   'STA_LAT': '37.51352310',
#   'STA_LONG': '126.94352722',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '146'},
#  {'STA_LOC': '동작구',
#   'RENT_ID': 'ST-1151',
#   'RENT_NO': '02059',
#   'RENT_NM': '보라매공원 정문',
#   'RENT_ID_NM': '2059. 보라매공원 정문',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 동작구 신대방동 395 ',
#   'STA_ADD2': '보라매공원 정문',
#   'STA_LAT': '37.49707794',
#   'STA_LONG': '126.91779327',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '147'},
#  {'STA_LOC': '동작구',
#   'RENT_ID': 'ST-1152',
#   'RENT_NO': '02060',
#   'RENT_NM': '남성역3번출구 뒤',
#   'RENT_ID_NM': '2060. 남성역3번출구 뒤',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 동작구 사당동 1131 ',
#   'STA_ADD2': '남성역3번출구 뒤',
#   'STA_LAT': '37.48463058',
#   'STA_LONG': '126.97154999',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '148'},
#  {'STA_LOC': '동작구',
#   'RENT_ID': 'ST-1153',
#   'RENT_NO': '02061',
#   'RENT_NM': '한강 현대아파트 건너편',
#   'RENT_ID_NM': '2061. 한강 현대아파트 건너편',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 동작구 흑석동 27-83 ',
#   'STA_ADD2': '한강 현대아파트 건너편',
#   'STA_LAT': '37.50592804',
# ...
#   'RENT_ID_NM': '2816.항동지구 8단지 803동옆(주차장입구)',
#   'HOLD_NUM': '5',
#   'STA_ADD1': '서울특별시 구로구 항동 220',
#   'STA_ADD2': '',
#   'STA_LAT': '37.47473145',
#   'STA_LONG': '126.81700897',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '951'},
#  {'STA_LOC': '구로구',
#   'RENT_ID': 'ST-1957',
#   'RENT_NO': '02817',
#   'RENT_NM': '천왕이펜하우스5단지 앞',
#   'RENT_ID_NM': '2817.천왕이펜하우스5단지 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 구로구 천왕동 277-4',
#   'STA_ADD2': '',
#   'STA_LAT': '37.47989655',
#   'STA_LONG': '126.84037018',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '952'},
#  {'STA_LOC': '구로구',
#   'RENT_ID': 'ST-1958',
#   'RENT_NO': '02818',
#   'RENT_NM': '천왕이펜하우스3단지 앞',
#   'RENT_ID_NM': '2818.천왕이펜하우스3단지 앞',
#   'HOLD_NUM': '14',
#   'STA_ADD1': '서울특별시 구로구 천왕로 56 천왕 이펜하우스 3단지',
#   'STA_ADD2': '',
#   'STA_LAT': '37.48223877',
#   'STA_LONG': '126.83853149',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '953'},
#  {'STA_LOC': '구로구',
#   'RENT_ID': 'ST-1959',
#   'RENT_NO': '02819',
#   'RENT_NM': '하늘숲초등학교 앞',
#   'RENT_ID_NM': '2819.하늘숲초등학교 앞',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 구로구 오리로 1100 천왕연지타워',
#   'STA_ADD2': '',
#   'STA_LAT': '37.48366547',
#   'STA_LONG': '126.84161377',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '954'},
#  {'STA_LOC': '중구',
#   'RENT_ID': 'ST-196',
#   'RENT_NO': '00381',
#   'RENT_NM': '장충체육관',
#   'RENT_ID_NM': '381. 장충체육관',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 중구 장충동2가 200-99',
#   'STA_ADD2': '장충체육관',
#   'STA_LAT': '37.55853271',
#   'STA_LONG': '127.00698853',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '955'},
#  {'STA_LOC': '구로구',
#   'RENT_ID': 'ST-1960',
#   'RENT_NO': '02820',
#   'RENT_NM': '신세기아파트 앞',
#   'RENT_ID_NM': '2820.신세기아파트 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 구로구 개봉로19길 87 로얄파크',
#   'STA_ADD2': '',
#   'STA_LAT': '37.49396515',
#   'STA_LONG': '126.85304260',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '956'},
#  {'STA_LOC': '구로구',
#   'RENT_ID': 'ST-1961',
#   'RENT_NO': '02821',
#   'RENT_NM': '청구아파트 앞',
#   'RENT_ID_NM': '2821.청구아파트 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 구로구 중앙로6길 5-15 청구아파트',
#   'STA_ADD2': '',
#   'STA_LAT': '37.50119019',
#   'STA_LONG': '126.86353302',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '957'},
#  {'STA_LOC': '구로구',
#   'RENT_ID': 'ST-1962',
#   'RENT_NO': '02822',
#   'RENT_NM': '제니스스포츠 앞',
#   'RENT_ID_NM': '2822.제니스스포츠 앞',
#   'HOLD_NUM': '14',
#   'STA_ADD1': '서울특별시 구로구 고척동 60-42',
#   'STA_ADD2': '',
#   'STA_LAT': '37.50452042',
#   'STA_LONG': '126.87055206',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '958'},
#  {'STA_LOC': '구로구',
#   'RENT_ID': 'ST-1963',
#   'RENT_NO': '02823',
#   'RENT_NM': '중앙유통단지 앞',
#   'RENT_ID_NM': '2823.중앙유통단지 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 구로구 구로동 635-32',
#   'STA_ADD2': '',
#   'STA_LAT': '37.49981308',
#   'STA_LONG': '126.87431335',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '959'},
#  {'STA_LOC': '구로구',
#   'RENT_ID': 'ST-1964',
#   'RENT_NO': '02824',
#   'RENT_NM': '미래사랑어린이공원 앞',
#   'RENT_ID_NM': '2824.미래사랑어린이공원 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 구로구 경인로 673-1 가로판매대',
#   'STA_ADD2': '',
#   'STA_LAT': '37.51006317',
#   'STA_LONG': '126.88956451',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '960'},
#  {'STA_LOC': '구로구',
#   'RENT_ID': 'ST-1965',
#   'RENT_NO': '02825',
#   'RENT_NM': '초롱타운 앞',
#   'RENT_ID_NM': '2825.초롱타운 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 구로구 구로동 467-62',
#   'STA_ADD2': '',
#   'STA_LAT': '37.49545288',
#   'STA_LONG': '126.88039398',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '961'},
#  {'STA_LOC': '구로구',
#   'RENT_ID': 'ST-1966',
#   'RENT_NO': '02826',
#   'RENT_NM': '가마산지하보도 옆',
#   'RENT_ID_NM': '2826.가마산지하보도 옆',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 구로구 가마산로 141',
#   'STA_ADD2': '',
#   'STA_LAT': '37.48864746',
#   'STA_LONG': '126.88047028',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '962'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1967',
#   'RENT_NO': '00295',
#   'RENT_NM': '영등포공원 분수대 앞',
#   'RENT_ID_NM': '295.영등포공원 분수대 앞',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 신길로 275 영등포문화원',
#   'STA_ADD2': '',
#   'STA_LAT': '37.51481247',
#   'STA_LONG': '126.91170502',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '963'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1968',
#   'RENT_NO': '00296',
#   'RENT_NM': 'KT플라자 영등포점',
#   'RENT_ID_NM': '296.KT플라자 영등포점',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 영등포구 영등포동8가 29-1',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52630234',
#   'STA_LONG': '126.90538025',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '964'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1969',
#   'RENT_NO': '00297',
#   'RENT_NM': '국회3문',
#   'RENT_ID_NM': '297.국회3문',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 여의도동 8-1',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52863693',
#   'STA_LONG': '126.91267395',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '965'},
#  {'STA_LOC': '중구',
#   'RENT_ID': 'ST-197',
#   'RENT_NO': '00382',
#   'RENT_NM': '약수역 10번출구 앞',
#   'RENT_ID_NM': '382. 약수역 10번출구 앞',
#   'HOLD_NUM': '7',
#   'STA_ADD1': '서울특별시 중구 신당동 357-1',
#   'STA_ADD2': '약수역 10번출구 앞',
#   'STA_LAT': '37.55519867',
#   'STA_LONG': '127.01004791',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '966'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1970',
#   'RENT_NO': '00298',
#   'RENT_NM': 'KBS 연구동 건너편',
#   'RENT_ID_NM': '298.KBS 연구동 건너편',
#   'HOLD_NUM': '25',
#   'STA_ADD1': '서울특별시 영등포구 여의도동 1-1',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52750778',
#   'STA_LONG': '126.91429901',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '967'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1971',
#   'RENT_NO': '00299',
#   'RENT_NM': '여의도 순복음교회',
#   'RENT_ID_NM': '299.여의도 순복음교회',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 여의서로 60-2 가로판매대22',
#   'STA_ADD2': '',
#   'STA_LAT': '37.53179169',
#   'STA_LONG': '126.92245483',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '968'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1972',
#   'RENT_NO': '03201',
#   'RENT_NM': '당산skv1센터',
#   'RENT_ID_NM': '3201.당산skv1센터',
#   'HOLD_NUM': '9',
#   'STA_ADD1': '서울특별시 영등포구 당산동4가 80-2',
#   'STA_ADD2': '',
#   'STA_LAT': '37.53073502',
#   'STA_LONG': '126.89916992',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '969'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1973',
#   'RENT_NO': '03202',
#   'RENT_NM': '당산롯데캐슬프레스티지',
#   'RENT_ID_NM': '3202.당산롯데캐슬프레스티지',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 영등포구 당산동4가 10-21',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52869034',
#   'STA_LONG': '126.90386200',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '970'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1974',
#   'RENT_NO': '03203',
#   'RENT_NM': '도림동배드민턴체육관',
#   'RENT_ID_NM': '3203.도림동배드민턴체육관',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 도신로15길 5 영등포 다목적 배드민턴 체육관',
#   'STA_ADD2': '',
#   'STA_LAT': '37.50611496',
#   'STA_LONG': '126.89859009',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '971'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1975',
#   'RENT_NO': '03204',
#   'RENT_NM': '도림고가도로 밑',
#   'RENT_ID_NM': '3204.도림고가도로 밑',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 도림동 187-87',
#   'STA_ADD2': '',
#   'STA_LAT': '37.51124191',
#   'STA_LONG': '126.89818573',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '972'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1976',
#   'RENT_NO': '03205',
#   'RENT_NM': '문래현대2차',
#   'RENT_ID_NM': '3205.문래현대2차',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 문래로4길 6 현대아파트',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52021790',
#   'STA_LONG': '126.88216400',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '973'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1977',
#   'RENT_NO': '03206',
#   'RENT_NM': '문래동 주민센터',
#   'RENT_ID_NM': '3206.문래동 주민센터',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 영등포구 문래동3가 55-13',
#   'STA_ADD2': '',
#   'STA_LAT': '37.51707077',
#   'STA_LONG': '126.89908600',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '974'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1978',
#   'RENT_NO': '03207',
#   'RENT_NM': '양남사거리1',
#   'RENT_ID_NM': '3207.양남사거리1',
#   'HOLD_NUM': '12',
#   'STA_ADD1': '서울특별시 영등포구 선유로 87',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52182770',
#   'STA_LONG': '126.88972473',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '975'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1979',
#   'RENT_NO': '03208',
#   'RENT_NM': '양평역 2번출구',
#   'RENT_ID_NM': '3208.양평역 2번출구',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 영등포구 양평동2가 33-80',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52555466',
#   'STA_LONG': '126.88587189',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '976'},
#  {'STA_LOC': '중구',
#   'RENT_ID': 'ST-198',
#   'RENT_NO': '00383',
#   'RENT_NM': '신당역 12번 출구 뒤',
#   'RENT_ID_NM': '383. 신당역 12번 출구 뒤',
#   'HOLD_NUM': '27',
#   'STA_ADD1': '서울특별시 중구 다산로 258 리마크빌 동대문',
#   'STA_ADD2': '',
#   'STA_LAT': '37.56591797',
#   'STA_LONG': '127.01642609',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '977'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1980',
#   'RENT_NO': '03209',
#   'RENT_NM': '롯데칠성음료신협양평분점(근린공원)',
#   'RENT_ID_NM': '3209.롯데칠성음료신협양평분점(근린공원)',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 양평동 1-1',
#   'STA_ADD2': '',
#   'STA_LAT': '37.54185104',
#   'STA_LONG': '126.89380646',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '978'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1981',
#   'RENT_NO': '03210',
#   'RENT_NM': '신길 꿈에그린아파트',
#   'RENT_ID_NM': '3210.신길 꿈에그린아파트',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 영등포구 신길로 119 신길뉴타운 한화 꿈에그린',
#   'STA_ADD2': '',
#   'STA_LAT': '37.50313568',
#   'STA_LONG': '126.91007996',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '979'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1982',
#   'RENT_NO': '03211',
#   'RENT_NM': '신길 래미안 프레비뉴',
#   'RENT_ID_NM': '3211.신길 래미안 프레비뉴',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 영등포구 가마산로 442 래미안프레비뉴',
#   'STA_ADD2': '',
#   'STA_LAT': '37.50438309',
#   'STA_LONG': '126.90808868',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '980'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1983',
#   'RENT_NO': '03212',
#   'RENT_NM': '신풍역 6번출구',
#   'RENT_ID_NM': '3212.신풍역 6번출구',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 신풍로 77 래미안에스티움',
#   'STA_ADD2': '',
#   'STA_LAT': '37.50025558',
#   'STA_LONG': '126.91215515',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '981'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1984',
#   'RENT_NO': '03213',
#   'RENT_NM': '썬프라자 웨딩홀뷔페',
#   'RENT_ID_NM': '3213.썬프라자 웨딩홀뷔페',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 신길로 39-3 가로판매대84',
#   'STA_ADD2': '',
#   'STA_LAT': '37.49636459',
#   'STA_LONG': '126.90824890',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '982'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1985',
#   'RENT_NO': '03214',
#   'RENT_NM': '영등포 푸르지오 아파트 A',
#   'RENT_ID_NM': '3214.영등포 푸르지오 아파트 A',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 도신로29길 28 영등포푸르지오',
#   'STA_ADD2': '',
#   'STA_LAT': '37.51202393',
#   'STA_LONG': '126.90105438',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '983'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1986',
#   'RENT_NO': '03215',
#   'RENT_NM': '강변삼성래미안',
#   'RENT_ID_NM': '3215.강변삼성래미안',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 영등포구 당산동 121-317',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52974319',
#   'STA_LONG': '126.90782928',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '984'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1987',
#   'RENT_NO': '03216',
#   'RENT_NM': '국회의사당',
#   'RENT_ID_NM': '3216.국회의사당',
#   'HOLD_NUM': '13',
#   'STA_ADD1': '서울특별시 영등포구 의사당대로 1 국회',
#   'STA_ADD2': '',
#   'STA_LAT': '37.53266525',
#   'STA_LONG': '126.91376495',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '985'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1988',
#   'RENT_NO': '03217',
#   'RENT_NM': '우리은행 여의도한화금융센터',
#   'RENT_ID_NM': '3217.우리은행 여의도한화금융센터',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 63로 40 라이프오피스텔',
#   'STA_ADD2': '',
#   'STA_LAT': '37.51987457',
#   'STA_LONG': '126.93881989',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '986'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1989',
#   'RENT_NO': '03218',
#   'RENT_NM': '여의도 미원빌딩',
#   'RENT_ID_NM': '3218.여의도 미원빌딩',
#   'HOLD_NUM': '25',
#   'STA_ADD1': '서울특별시 영등포구 여의도동 4-2',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52166367',
#   'STA_LONG': '126.93087769',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '987'},
#  {'STA_LOC': '중구',
#   'RENT_ID': 'ST-199',
#   'RENT_NO': '00384',
#   'RENT_NM': '중림동삼거리',
#   'RENT_ID_NM': '384. 중림동삼거리',
#   'HOLD_NUM': '5',
#   'STA_ADD1': '서울특별시 중구 청파로 456',
#   'STA_ADD2': '종로학원본원 앞',
#   'STA_LAT': '37.55978012',
#   'STA_LONG': '126.96850586',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '988'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1990',
#   'RENT_NO': '03219',
#   'RENT_NM': '영등포역 1번출구',
#   'RENT_ID_NM': '3219.영등포역 1번출구',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 영등포동 618-9',
#   'STA_ADD2': '',
#   'STA_LAT': '37.51484680',
#   'STA_LONG': '126.90773010',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '989'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1991',
#   'RENT_NO': '03220',
#   'RENT_NM': '래미안에스티움 앞 (신풍로)',
#   'RENT_ID_NM': '3220.래미안에스티움 앞 (신풍로)',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 영등포구 신길동 3859',
#   'STA_ADD2': '',
#   'STA_LAT': '37.50013733',
#   'STA_LONG': '126.91397858',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '990'},
#  {'STA_LOC': '영등포구',
#   'RENT_ID': 'ST-1992',
#   'RENT_NO': '03221',
#   'RENT_NM': '서울특별시 남부교육지원청',
#   'RENT_ID_NM': '3221.서울특별시 남부교육지원청',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 영등포구 문래로 121 서울특별시 남부교육지원청',
#   'STA_ADD2': '',
#   'STA_LAT': '37.51933289',
#   'STA_LONG': '126.89530182',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '991'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1993',
#   'RENT_NO': '00767',
#   'RENT_NM': '신정숲속마을아파트',
#   'RENT_ID_NM': '767.신정숲속마을아파트',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 신정로 110 신정숲속마을',
#   'STA_ADD2': '',
#   'STA_LAT': '37.50574493',
#   'STA_LONG': '126.83631134',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '992'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1994',
#   'RENT_NO': '00768',
#   'RENT_NM': '목동5단지아파트 501동',
#   'RENT_ID_NM': '768.목동5단지아파트 501동',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 양천구 목동동로 350 목동신시가지아파트5단지',
#   'STA_ADD2': '',
#   'STA_LAT': '37.53566742',
#   'STA_LONG': '126.88158417',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '993'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1995',
#   'RENT_NO': '00769',
#   'RENT_NM': 'CBS방송국 앞',
#   'RENT_ID_NM': '769.CBS방송국 앞',
#   'HOLD_NUM': '20',
#   'STA_ADD1': '서울특별시 양천구 목동서로 159-3 가로판매대2',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52785492',
#   'STA_LONG': '126.87467194',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '994'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1996',
#   'RENT_NO': '00770',
#   'RENT_NM': '목동역5번출구',
#   'RENT_ID_NM': '770.목동역5번출구',
#   'HOLD_NUM': '12',
#   'STA_ADD1': '서울특별시 양천구 목동 927-10',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52571487',
#   'STA_LONG': '126.86486816',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '995'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1997',
#   'RENT_NO': '00771',
#   'RENT_NM': '목동아파트 703동 앞',
#   'RENT_ID_NM': '771.목동아파트 703동 앞',
#   'HOLD_NUM': '8',
#   'STA_ADD1': '서울특별시 양천구 목동로 212 목동신시가지아파트7단지',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52820587',
#   'STA_LONG': '126.87016296',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '996'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1998',
#   'RENT_NO': '00772',
#   'RENT_NM': '대원칸타빌1차아파트',
#   'RENT_ID_NM': '772.대원칸타빌1차아파트',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 양천구 목동 812',
#   'STA_ADD2': '',
#   'STA_LAT': '37.52825928',
#   'STA_LONG': '126.86426544',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '997'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1999',
#   'RENT_NO': '00773',
#   'RENT_NM': '염창역 3, 4번 출구 사이',
#   'RENT_ID_NM': '773.염창역 3, 4번 출구 사이',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 공항대로 630 어바니엘',
#   'STA_ADD2': '',
#   'STA_LAT': '37.54670715',
#   'STA_LONG': '126.87457275',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '998'},
#  {'STA_LOC': '마포구',
#   'RENT_ID': 'ST-20',
#   'RENT_NO': '00114',
#   'RENT_NM': '홍대입구역 8번출구 앞',
#   'RENT_ID_NM': '114. 홍대입구역 8번출구 앞',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 마포구 양화로18길 3',
#   'STA_ADD2': '192-5',
#   'STA_LAT': '37.55706024',
#   'STA_LONG': '126.92442322',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '999'},
#  {'STA_LOC': '마포구',
#   'RENT_ID': 'ST-200',
#   'RENT_NO': '00142',
#   'RENT_NM': '아현역 4번출구 앞',
#   'RENT_ID_NM': '142. 아현역 4번출구 앞',
#   'HOLD_NUM': '11',
#   'STA_ADD1': '서울특별시 마포구 아현동 329-15',
#   'STA_ADD2': '아현역 4번출구 앞',
#   'STA_LAT': '37.55720139',
#   'STA_LONG': '126.95566559',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '1000'}]

# %% [markdown]
# ## 4) 데이터 프레임 만들기

# %%
data_list = response_json["stationInfo"]["row"]

import pandas as pd

data = pd.DataFrame(data_list)
data
# Out:
#     STA_LOC  RENT_ID RENT_NO          RENT_NM           RENT_ID_NM HOLD_NUM  \
# 0       마포구    ST-10   00108          서교동 사거리         108. 서교동 사거리       12
# 1       광진구   ST-100   00503      더샵스타시티 C동 앞     503. 더샵스타시티 C동 앞       15
# 2       양천구  ST-1000   00729      서부식자재마트 건너편     729. 서부식자재마트 건너편       10
# 3       양천구  ST-1002   00731     서울시 도로환경관리센터    731. 서울시 도로환경관리센터       10
# 4       양천구  ST-1003   00732            신월중학교           732. 신월중학교       10
# ..      ...      ...     ...              ...                  ...      ...
# 995     양천구  ST-1997   00771     목동아파트 703동 앞     771.목동아파트 703동 앞        8
# 996     양천구  ST-1998   00772       대원칸타빌1차아파트       772.대원칸타빌1차아파트       15
# 997     양천구  ST-1999   00773  염창역 3, 4번 출구 사이  773.염창역 3, 4번 출구 사이       10
# 998     마포구    ST-20   00114     홍대입구역 8번출구 앞    114. 홍대입구역 8번출구 앞       15
# 999     마포구   ST-200   00142       아현역 4번출구 앞      142. 아현역 4번출구 앞       11
#
#                            STA_ADD1      STA_ADD2      STA_LAT      STA_LONG  \
# 0                  서울특별시 마포구 양화로 93           427  37.55274582  126.91861725
# 1                서울특별시 광진구 아차산로 262   더샵스타시티 C동 앞  37.53666687  127.07359314
# 2                서울특별시 양천구 신정동 236    서부식자재마트 건너편  37.51037979  126.86679840
# 3              서울특별시 양천구 목동동로 316-6  서울시 도로환경관리센터  37.52989960  126.87654114
# 4                  서울특별시 양천구 화곡로 59       신월동 이마트  37.53955078  126.82830048
# ..                              ...           ...          ...           ...
# 995  서울특별시 양천구 목동로 212 목동신시가지아파트7단지                37.52820587  126.87016296
# 996                서울특별시 양천구 목동 812                37.52825928  126.86426544
# 997         서울특별시 양천구 공항대로 630 어바니엘                37.54670715  126.87457275
# 998              서울특별시 마포구 양화로18길 3         192-5  37.55706024  126.92442322
# 999            서울특별시 마포구 아현동 329-15    아현역 4번출구 앞  37.55720139  126.95566559
#
#      START_INDEX  END_INDEX  RNUM
# 0              0          0     1
# 1              0          0     2
# 2              0          0     3
# 3              0          0     4
# 4              0          0     5
# ..           ...        ...   ...
# 995            0          0   996
# 996            0          0   997
# 997            0          0   998
# 998            0          0   999
# 999            0          0  1000
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## 5) 데이터 많이 불러오기

# %%
# 샘플 URL: http://openapi.seoul.go.kr:8088/(인증키)/json/tbCycleStationInfo/1/5/

base_url = "http://openapi.seoul.go.kr:8088"

# 요청 파라미터
key = os.getenv("PUBLIC_BIKE_API_KEY")
type_n = "json"
service = "tbCycleStationInfo"
start_index = 1
end_index = 3171

# url 만들기
url = f"{base_url}/{key}/{type_n}/{service}/{start_index}/{end_index}"
print(url)
# Out:
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/1/3171

# %%
import requests

response = requests.get(url)
print(response.text)
# Out:
# <RESULT><CODE>ERROR-336</CODE><MESSAGE><![CDATA[데이터요청은 한번에 최대 1000건을 넘을 수 없습니다.
# 요청종료위치에서 요청시작위치를 뺀 값이 1000을 넘지 않도록 수정하세요.]]></MESSAGE></RESULT>

# %%
# 0 ~ 999
# 1000 ~ 1999
# 2000 ~ 2999
# 3000 ~ 3171


base_url = "http://openapi.seoul.go.kr:8088"

# 요청 파라미터
key = os.getenv("PUBLIC_BIKE_API_KEY")
type_n = "json"
service = "tbCycleStationInfo"

# 0. 빈 리스트를 만든다.(total_data)
# 1. start가 0, 1000, 2000, 3000
# 2. end를 만든다. end = start + 1000 - 1
# 3. url을 만든다.
# 4. 요청을 한다
# 5. 데이터 리스트를 파싱한다. data_list
# 6. total_data에 data_list를 합친다. ---- extend
# 7. total_data를 pd.DataFrame()을 이용해서 데이터프레임을 만든다.
total_data = []
for start in range(1, 3001, 1000):
    end = start + (1000 -1)

    url = f"{base_url}/{key}/{type_n}/{service}/{start}/{end}"
    print(url)
    response = requests.get(url)
    response_json = response.json()
    data_list = response_json["stationInfo"]["row"]
    print(len(data_list))
    total_data.extend(data_list)
# Out:
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/1/1000
# 1000
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/1001/2000
# 1000
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/2001/3000
# 1000

# %%
import pandas as pd

data = pd.DataFrame(total_data)
data
# Out:
#      STA_LOC  RENT_ID RENT_NO         RENT_NM            RENT_ID_NM HOLD_NUM  \
# 0        마포구    ST-10   00108         서교동 사거리          108. 서교동 사거리       12
# 1        광진구   ST-100   00503     더샵스타시티 C동 앞      503. 더샵스타시티 C동 앞       15
# 2        양천구  ST-1000   00729     서부식자재마트 건너편      729. 서부식자재마트 건너편       10
# 3        양천구  ST-1002   00731    서울시 도로환경관리센터     731. 서울시 도로환경관리센터       10
# 4        양천구  ST-1003   00732           신월중학교            732. 신월중학교       10
# ...      ...      ...     ...             ...                   ...      ...
# 2995     강남구   ST-822   02341  일원역 4~5번 출구 사이  2341. 일원역 4~5번 출구 사이       10
# 2996     강남구   ST-823   02342     대청역 1번출구  뒤     2342. 대청역 1번출구  뒤       15
# 2997     강서구   ST-824   01106          신방화사거리          1106. 신방화사거리       18
# 2998     성북구   ST-825   01302    한성대입구역6번출구 뒤    1302. 한성대입구역6번출구 뒤        5
# 2999     성북구   ST-826   01304            만해공원            1304. 만해공원       10
#
#                         STA_ADD1       STA_ADD2      STA_LAT      STA_LONG  \
# 0               서울특별시 마포구 양화로 93            427  37.55274582  126.91861725
# 1             서울특별시 광진구 아차산로 262    더샵스타시티 C동 앞  37.53666687  127.07359314
# 2             서울특별시 양천구 신정동 236     서부식자재마트 건너편  37.51037979  126.86679840
# 3           서울특별시 양천구 목동동로 316-6   서울시 도로환경관리센터  37.52989960  126.87654114
# 4               서울특별시 양천구 화곡로 59        신월동 이마트  37.53955078  126.82830048
# ...                          ...            ...          ...           ...
# 2995           서울특별시 강남구 일원로 127  일원역 4,5번 출구사이  37.48331070  127.08493805
# 2996          서울특별시 강남구 개포동 13-4                 37.49390793  127.07962036
# 2997  서울특별시 강서구 양천로24길 13 마곡센트레빌                 37.57256317  126.81642151
# 2998            서울특별시 성북구 동소문로 1   한성대입구역6번출구 뒤  37.58876419  127.00630951
# 2999         서울특별시 성북구 성북로 132-1           만해공원  37.59440231  126.99230957
#
#       START_INDEX  END_INDEX  RNUM
# 0               0          0     1
# 1               0          0     2
# 2               0          0     3
# 3               0          0     4
# 4               0          0     5
# ...           ...        ...   ...
# 2995            0          0  2996
# 2996            0          0  2997
# 2997            0          0  2998
# 2998            0          0  2999
# 2999            0          0  3000
#
# [3000 rows x 13 columns]

# %% [markdown]
# # 3. NAVER API

# %% [markdown]
# ## 1) 샘플 코드

# %% [markdown]
# ### 원본

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "thKpieLUTQ2B2Yp0dJV4"
client_secret = "WZ9F403bUp"
encText = urllib.parse.quote("인공지능")
url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 22 Jul 2025 18:09:42 +0900",
# 	"total":3085278,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"최호정 서울시의회 의장, &quot;AI 산업 선도할 것&quot;",
# 			"originallink":"http:\/\/www.newsroad.co.kr\/news\/articleView.html?idxno=42938",
# 			"link":"http:\/\/www.newsroad.co.kr\/news\/articleView.html?idxno=42938",
# 			"description":"이날 최 의장은 양재 일대 AI 인프라 조성 현황과 서울AI허브 운영성과 등을 보고받고 공군 AI신기술융합센터, <b>인공지능<\/b>산업협회, 카이스트 AI대학원 등 입주기업 및 기관들을 차례대로 둘러봤다. 또, 서울AI허브에... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:08:00 +0900"
# 		},
# 		{
# 			"title":"충남대–코리아크레딧뷰로, 업무협약 체결",
# 			"originallink":"https:\/\/daily.hankooki.com\/news\/articleView.html?idxno=1247035",
# 			"link":"https:\/\/daily.hankooki.com\/news\/articleView.html?idxno=1247035",
# 			"description":"사진=충남대 제공  충남대학교와 코리아크레딧뷰로(KCB)가 <b>인공지능<\/b>(AI) 기반 ESG 평가 플랫폼을 공동 구축하고 지역기업의 지속가능경영 역량 강화를 위한 본격적인 협력에 나선다. 충남대 ESG센터와 코리아크레딧뷰로... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:08:00 +0900"
# 		},
# 		{
# 			"title":"김민석 총리 &quot;새로운 한미관계, 한국과 미국을 다시 위대하게&quot;",
# 			"originallink":"https:\/\/news.mtn.co.kr\/news-detail\/2025072218051539688",
# 			"link":"https:\/\/news.mtn.co.kr\/news-detail\/2025072218051539688",
# 			"description":"김 총리는 한미 미래 협력 분야로 반도체, <b>인공지능<\/b>(AI), 바이오, 콘텐츠, 에너지를 꼽았다.김 총리는 &quot;새 정부는 ABCDE(AI·바이오·콘텐츠&amp;컬쳐·디펜스·에너지)를 전략 산업으로 육성하고 있으며, 이 과정에서 미국과 보완적... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:08:00 +0900"
# 		},
# 		{
# 			"title":"[단독] 222조 빨아들인 '1000개의 ETF'",
# 			"originallink":"https:\/\/www.mk.co.kr\/article\/11374853",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/009\/0005529438?sid=101",
# 			"description":"로보택시, 의료 <b>인공지능<\/b>(AI)부터 미국 국채까지 다양한 테마와 구조화된 상품을 선보였다. 이에 따라 국내 상장 ETF 수는 전날 995개에서 1002개로 늘었다. 이미 유가증권시장(코스피) 상장사(849개) 수를 크게... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:07:00 +0900"
# 		},
# 		{
# 			"title":"HD현대일렉 '질주', &quot;3년치 일감 쌓였다&quot;",
# 			"originallink":"https:\/\/www.hankyung.com\/article\/2025072252771",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/015\/0005161345?sid=101",
# 			"description":"미국 정부가 최근 에너지 인프라와 <b>인공지능<\/b>(AI)산업에 대규모 투자를 하겠다고 발표한 만큼 전력기기 호황은 당분간 계속될 전망이다. HD현대일렉트릭은 지난 2분기에만 9억9600만달러(약 1조3821억원)어치... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:07:00 +0900"
# 		},
# 		{
# 			"title":"여름방학 더 알차고 즐겁게",
# 			"originallink":"http:\/\/www.dynews.co.kr\/news\/articleView.html?idxno=812616",
# 			"link":"http:\/\/www.dynews.co.kr\/news\/articleView.html?idxno=812616",
# 			"description":"이번 여름방학에는 청소년들이 소프트웨어와 <b>인공지능<\/b>에 대한 관심과 흥미를 높일 수 있도록 교육부와 연계한 디지털 새싹캠프가 운영된다. 센터에 방문하기 어려운 청소년들을 위해 어진동 행복누림터에 센터 소속 전문... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:07:00 +0900"
# 		},
# 		{
# 			"title":"트럼프의 AI 야심작 반년째 제자리걸음",
# 			"originallink":"https:\/\/www.mk.co.kr\/article\/11374845",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/009\/0005529433?sid=104",
# 			"description":"WSJ &quot;스타게이트 사업 차질&quot; 소뱅·오픈AI·오라클 합작 700조원 AI 인프라 프로젝트 데이터센터 위치 놓고 잡음 연내 1개 건설로 목표 축소 도널드 트럼프 미국 행정부에서 자국 <b>인공지능<\/b>(AI) 역량 강화를 목표로 야심... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:07:00 +0900"
# 		},
# 		{
# 			"title":"취임식 생략하고 ‘수해현장’ 간 환경장관 “국민 지켜야”",
# 			"originallink":"http:\/\/www.edaily.co.kr\/news\/newspath.asp?newsid=04441126642237144",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/018\/0006071397?sid=102",
# 			"description":"또한 성능이 강화된 슈퍼컴퓨터를 도입해 <b>인공지능<\/b>(AI) 기술을 융합한 정밀한 예측 시스템을 구축하고, 기상청·지자체 등 유관 기관 간 관측망 확충 및 공동활용을 통해 감시 공백 최소화를 지시할 것으로 알려졌다. 김... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:07:00 +0900"
# 		},
# 		{
# 			"title":"과기정통부-행안부, 대전서 AI 기반 안전관리 시스템 검증",
# 			"originallink":"http:\/\/www.dynews.co.kr\/news\/articleView.html?idxno=812716",
# 			"link":"http:\/\/www.dynews.co.kr\/news\/articleView.html?idxno=812716",
# 			"description":"［동양일보 정래수 기자］ 과학기술정보통신부는 22일 대전 유성온천역에서 행정안전부와 현장 간담회를 열어 <b>인공지능<\/b>(AI)과 가상 융합 기술로 구축한 재난 안전 시스템을 점검했다고 밝혔다. 정부는 2023년부터 충청남... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:06:00 +0900"
# 		},
# 		{
# 			"title":"[은행가소식] 우리은행 반도체·AI 등 '성장산업 수출입 패키지' 출시",
# 			"originallink":"https:\/\/www.asiatime.co.kr\/article\/20250722500405",
# 			"link":"https:\/\/www.asiatime.co.kr\/article\/20250722500405",
# 			"description":"혁신성장 품목은 한국신용정보원의 혁신성장 인텔리전스 시스템(IGS)에서 확인 가능하며 △반도체 △<b>인공지능<\/b>(AI) △제조로봇 등 정부 정책과 산업 트렌드를 반영한 240개 품목으로 구성돼 있다. □ 농협은행 퇴직연금... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:06:00 +0900"
# 		}
# 	]
# }

# %% [markdown]
# ### 원본 변형

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

load_dotenv()
print(os.getenv("NAVER_CLIENT_ID"))
print(os.getenv("NAVER_CLIENT_SECRET"))
# 1. 정보 입력
client_id = os.getenv("NAVER_CLIENT_ID")
client_secret = os.getenv("NAVER_CLIENT_SECRET")

# 2. 키워드 입력
keyword = "인공지능"

# 3. 키워드 인코딩하기
encText = urllib.parse.quote(keyword)
# print(keyword)
# print(encText)

# 4. URL 만들기
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

# 5. 데이터 요청 준비
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

# 6. 데이터 요청
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# thKpieLUTQ2B2Yp0dJV4
# WZ9F403bUp
# {
# 	"lastBuildDate":"Tue, 22 Jul 2025 18:09:42 +0900",
# 	"total":3085278,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"김민석 총리 &quot;새로운 한미관계, 한국과 미국을 다시 위대하게&quot;",
# 			"originallink":"https:\/\/news.mtn.co.kr\/news-detail\/2025072218051539688",
# 			"link":"https:\/\/news.mtn.co.kr\/news-detail\/2025072218051539688",
# 			"description":"김 총리는 한미 미래 협력 분야로 반도체, <b>인공지능<\/b>(AI), 바이오, 콘텐츠, 에너지를 꼽았다.김 총리는 &quot;새 정부는 ABCDE(AI·바이오·콘텐츠&amp;컬쳐·디펜스·에너지)를 전략 산업으로 육성하고 있으며, 이 과정에서 미국과 보완적... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:08:00 +0900"
# 		},
# 		{
# 			"title":"최호정 서울시의회 의장, &quot;AI 산업 선도할 것&quot;",
# 			"originallink":"http:\/\/www.newsroad.co.kr\/news\/articleView.html?idxno=42938",
# 			"link":"http:\/\/www.newsroad.co.kr\/news\/articleView.html?idxno=42938",
# 			"description":"이날 최 의장은 양재 일대 AI 인프라 조성 현황과 서울AI허브 운영성과 등을 보고받고 공군 AI신기술융합센터, <b>인공지능<\/b>산업협회, 카이스트 AI대학원 등 입주기업 및 기관들을 차례대로 둘러봤다. 또, 서울AI허브에... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:08:00 +0900"
# 		},
# 		{
# 			"title":"충남대–코리아크레딧뷰로, 업무협약 체결",
# 			"originallink":"https:\/\/daily.hankooki.com\/news\/articleView.html?idxno=1247035",
# 			"link":"https:\/\/daily.hankooki.com\/news\/articleView.html?idxno=1247035",
# 			"description":"사진=충남대 제공  충남대학교와 코리아크레딧뷰로(KCB)가 <b>인공지능<\/b>(AI) 기반 ESG 평가 플랫폼을 공동 구축하고 지역기업의 지속가능경영 역량 강화를 위한 본격적인 협력에 나선다. 충남대 ESG센터와 코리아크레딧뷰로... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:08:00 +0900"
# 		},
# 		{
# 			"title":"트럼프의 AI 야심작 반년째 제자리걸음",
# 			"originallink":"https:\/\/www.mk.co.kr\/article\/11374845",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/009\/0005529433?sid=104",
# 			"description":"WSJ &quot;스타게이트 사업 차질&quot; 소뱅·오픈AI·오라클 합작 700조원 AI 인프라 프로젝트 데이터센터 위치 놓고 잡음 연내 1개 건설로 목표 축소 도널드 트럼프 미국 행정부에서 자국 <b>인공지능<\/b>(AI) 역량 강화를 목표로 야심... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:07:00 +0900"
# 		},
# 		{
# 			"title":"취임식 생략하고 ‘수해현장’ 간 환경장관 “국민 지켜야”",
# 			"originallink":"http:\/\/www.edaily.co.kr\/news\/newspath.asp?newsid=04441126642237144",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/018\/0006071397?sid=102",
# 			"description":"또한 성능이 강화된 슈퍼컴퓨터를 도입해 <b>인공지능<\/b>(AI) 기술을 융합한 정밀한 예측 시스템을 구축하고, 기상청·지자체 등 유관 기관 간 관측망 확충 및 공동활용을 통해 감시 공백 최소화를 지시할 것으로 알려졌다. 김... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:07:00 +0900"
# 		},
# 		{
# 			"title":"여름방학 더 알차고 즐겁게",
# 			"originallink":"http:\/\/www.dynews.co.kr\/news\/articleView.html?idxno=812616",
# 			"link":"http:\/\/www.dynews.co.kr\/news\/articleView.html?idxno=812616",
# 			"description":"이번 여름방학에는 청소년들이 소프트웨어와 <b>인공지능<\/b>에 대한 관심과 흥미를 높일 수 있도록 교육부와 연계한 디지털 새싹캠프가 운영된다. 센터에 방문하기 어려운 청소년들을 위해 어진동 행복누림터에 센터 소속 전문... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:07:00 +0900"
# 		},
# 		{
# 			"title":"[단독] 222조 빨아들인 '1000개의 ETF'",
# 			"originallink":"https:\/\/www.mk.co.kr\/article\/11374853",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/009\/0005529438?sid=101",
# 			"description":"로보택시, 의료 <b>인공지능<\/b>(AI)부터 미국 국채까지 다양한 테마와 구조화된 상품을 선보였다. 이에 따라 국내 상장 ETF 수는 전날 995개에서 1002개로 늘었다. 이미 유가증권시장(코스피) 상장사(849개) 수를 크게... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:07:00 +0900"
# 		},
# 		{
# 			"title":"HD현대일렉 '질주', &quot;3년치 일감 쌓였다&quot;",
# 			"originallink":"https:\/\/www.hankyung.com\/article\/2025072252771",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/015\/0005161345?sid=101",
# 			"description":"미국 정부가 최근 에너지 인프라와 <b>인공지능<\/b>(AI)산업에 대규모 투자를 하겠다고 발표한 만큼 전력기기 호황은 당분간 계속될 전망이다. HD현대일렉트릭은 지난 2분기에만 9억9600만달러(약 1조3821억원)어치... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:07:00 +0900"
# 		},
# 		{
# 			"title":"iM라이프, '청렴윤리경영 슬로건' 공모…&quot;임직원 청렴 가치 정립 기대&quot;",
# 			"originallink":"http:\/\/www.wikileaks-kr.org\/news\/articleView.html?idxno=171925",
# 			"link":"http:\/\/www.wikileaks-kr.org\/news\/articleView.html?idxno=171925",
# 			"description":"공모전에는 참가자 순수 창작물뿐 아니라 임직원의 <b>인공지능<\/b>(AI) 활용도 제고를 위해 챗GPT 등 AI 검색엔진을 활용한 제작물도 제출 가능하다. iM라이프는 내달 중 수상작을 발표하고 오는 9월 수상자 및 참여자 대상으로... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:06:00 +0900"
# 		},
# 		{
# 			"title":"[하재근의 족집게로 문화집기] <b>인공지능<\/b>의 음악계 위협 가시화",
# 			"originallink":"https:\/\/www.dt.co.kr\/article\/12005924?ref=naver",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/029\/0002970146?sid=110",
# 			"description":"그런데 그 노래가 <b>인공지능<\/b>(AI) 작품이라는 보도가 나와 파문이 인 것이다. 그 노래는 A씨가 <b>인공지능<\/b> 프로그램에 문자 명령을 수차례 입력해 간단히 만들었다고 한다. 당시 심사위원이었던 작곡가 김형석은 SNS에 “1위로... ",
# 			"pubDate":"Tue, 22 Jul 2025 18:06:00 +0900"
# 		}
# 	]
# }

# %% [markdown]
# ## 2) requests 활용

# %%
# 네이버 검색 API 예제 - 블로그 검색
import urllib.parse
import requests
import os
from dotenv import load_dotenv
load_dotenv()

# 1. 정보 입력
client_id = os.getenv("NAVER_CLIENT_ID")
client_secret = os.getenv("NAVER_CLIENT_SECRET")

# 2. 키워드 입력
keyword = "인공지능"

# 3. 키워드 인코딩하기
encText = urllib.parse.quote(keyword)
# print(keyword)
# print(encText)

# 4. URL 만들기
base_url = "https://openapi.naver.com/v1/search/news.json"
query = encText

url = f"{base_url}?query={query}"

# 5. 데이터 요청
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}
response = requests.get(url, headers=headers)
if response.status_code == 200:
    print(response.json())
else:
    print(response.status_code)
# Out:
# {'lastBuildDate': 'Tue, 22 Jul 2025 18:09:42 +0900', 'total': 3085278, 'start': 1, 'display': 10, 'items': [{'title': '최호정 서울시의회 의장, &quot;AI 산업 선도할 것&quot;', 'originallink': 'http://www.newsroad.co.kr/news/articleView.html?idxno=42938', 'link': 'http://www.newsroad.co.kr/news/articleView.html?idxno=42938', 'description': '이날 최 의장은 양재 일대 AI 인프라 조성 현황과 서울AI허브 운영성과 등을 보고받고 공군 AI신기술융합센터, <b>인공지능</b>산업협회, 카이스트 AI대학원 등 입주기업 및 기관들을 차례대로 둘러봤다. 또, 서울AI허브에... ', 'pubDate': 'Tue, 22 Jul 2025 18:08:00 +0900'}, {'title': '충남대–코리아크레딧뷰로, 업무협약 체결', 'originallink': 'https://daily.hankooki.com/news/articleView.html?idxno=1247035', 'link': 'https://daily.hankooki.com/news/articleView.html?idxno=1247035', 'description': '사진=충남대 제공  충남대학교와 코리아크레딧뷰로(KCB)가 <b>인공지능</b>(AI) 기반 ESG 평가 플랫폼을 공동 구축하고 지역기업의 지속가능경영 역량 강화를 위한 본격적인 협력에 나선다. 충남대 ESG센터와 코리아크레딧뷰로... ', 'pubDate': 'Tue, 22 Jul 2025 18:08:00 +0900'}, {'title': '김민석 총리 &quot;새로운 한미관계, 한국과 미국을 다시 위대하게&quot;', 'originallink': 'https://news.mtn.co.kr/news-detail/2025072218051539688', 'link': 'https://news.mtn.co.kr/news-detail/2025072218051539688', 'description': '김 총리는 한미 미래 협력 분야로 반도체, <b>인공지능</b>(AI), 바이오, 콘텐츠, 에너지를 꼽았다.김 총리는 &quot;새 정부는 ABCDE(AI·바이오·콘텐츠&amp;컬쳐·디펜스·에너지)를 전략 산업으로 육성하고 있으며, 이 과정에서 미국과 보완적... ', 'pubDate': 'Tue, 22 Jul 2025 18:08:00 +0900'}, {'title': "[단독] 222조 빨아들인 '1000개의 ETF'", 'originallink': 'https://www.mk.co.kr/article/11374853', 'link': 'https://n.news.naver.com/mnews/article/009/0005529438?sid=101', 'description': '로보택시, 의료 <b>인공지능</b>(AI)부터 미국 국채까지 다양한 테마와 구조화된 상품을 선보였다. 이에 따라 국내 상장 ETF 수는 전날 995개에서 1002개로 늘었다. 이미 유가증권시장(코스피) 상장사(849개) 수를 크게... ', 'pubDate': 'Tue, 22 Jul 2025 18:07:00 +0900'}, {'title': "HD현대일렉 '질주', &quot;3년치 일감 쌓였다&quot;", 'originallink': 'https://www.hankyung.com/article/2025072252771', 'link': 'https://n.news.naver.com/mnews/article/015/0005161345?sid=101', 'description': '미국 정부가 최근 에너지 인프라와 <b>인공지능</b>(AI)산업에 대규모 투자를 하겠다고 발표한 만큼 전력기기 호황은 당분간 계속될 전망이다. HD현대일렉트릭은 지난 2분기에만 9억9600만달러(약 1조3821억원)어치... ', 'pubDate': 'Tue, 22 Jul 2025 18:07:00 +0900'}, {'title': '트럼프의 AI 야심작 반년째 제자리걸음', 'originallink': 'https://www.mk.co.kr/article/11374845', 'link': 'https://n.news.naver.com/mnews/article/009/0005529433?sid=104', 'description': 'WSJ &quot;스타게이트 사업 차질&quot; 소뱅·오픈AI·오라클 합작 700조원 AI 인프라 프로젝트 데이터센터 위치 놓고 잡음 연내 1개 건설로 목표 축소 도널드 트럼프 미국 행정부에서 자국 <b>인공지능</b>(AI) 역량 강화를 목표로 야심... ', 'pubDate': 'Tue, 22 Jul 2025 18:07:00 +0900'}, {'title': '취임식 생략하고 ‘수해현장’ 간 환경장관 “국민 지켜야”', 'originallink': 'http://www.edaily.co.kr/news/newspath.asp?newsid=04441126642237144', 'link': 'https://n.news.naver.com/mnews/article/018/0006071397?sid=102', 'description': '또한 성능이 강화된 슈퍼컴퓨터를 도입해 <b>인공지능</b>(AI) 기술을 융합한 정밀한 예측 시스템을 구축하고, 기상청·지자체 등 유관 기관 간 관측망 확충 및 공동활용을 통해 감시 공백 최소화를 지시할 것으로 알려졌다. 김... ', 'pubDate': 'Tue, 22 Jul 2025 18:07:00 +0900'}, {'title': '여름방학 더 알차고 즐겁게', 'originallink': 'http://www.dynews.co.kr/news/articleView.html?idxno=812616', 'link': 'http://www.dynews.co.kr/news/articleView.html?idxno=812616', 'description': '이번 여름방학에는 청소년들이 소프트웨어와 <b>인공지능</b>에 대한 관심과 흥미를 높일 수 있도록 교육부와 연계한 디지털 새싹캠프가 운영된다. 센터에 방문하기 어려운 청소년들을 위해 어진동 행복누림터에 센터 소속 전문... ', 'pubDate': 'Tue, 22 Jul 2025 18:07:00 +0900'}, {'title': "[은행가소식] 우리은행 반도체·AI 등 '성장산업 수출입 패키지' 출시", 'originallink': 'https://www.asiatime.co.kr/article/20250722500405', 'link': 'https://www.asiatime.co.kr/article/20250722500405', 'description': '혁신성장 품목은 한국신용정보원의 혁신성장 인텔리전스 시스템(IGS)에서 확인 가능하며 △반도체 △<b>인공지능</b>(AI) △제조로봇 등 정부 정책과 산업 트렌드를 반영한 240개 품목으로 구성돼 있다. □ 농협은행 퇴직연금... ', 'pubDate': 'Tue, 22 Jul 2025 18:06:00 +0900'}, {'title': '엑사원으로 AI 혁신하는 LG그룹…국가 단위로 넓힐지 주목', 'originallink': 'http://www.g-enews.com/ko-kr/news/article/news_all/202507221538039000290c42db76_1/article.html', 'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202507221538039000290c42db76_1/article.html', 'description': 'LG그룹이 전사 차원에서 <b>인공지능</b>(AI) 기술에 승부수를 걸었다. 주력 계열사인 LG전자를 비롯해 싱크탱크인 AI연구원이 자체 AI 모델 엑사원의 새 버전과 함께 방대하고 다양한 데이터 해석과 강력한 보안에 필요한 특화... ', 'p ...

# %% [markdown]
# ## 3) requests 활용2

# %%
# 네이버 검색 API 예제 - 블로그 검색
import requests 
import os
from dotenv import load_dotenv 
load_dotenv()

# 1. 정보 입력
client_id = os.getenv("NAVER_CLIENT_ID")
client_secret = os.getenv("NAVER_CLIENT_SECRET")

# 2. 키워드 입력
keyword = "인공지능"

# 3. 파라미터 만들기
params = {
    "query": keyword,
    "display": 100
}

# 4. URL 만들기
base_url = "https://openapi.naver.com/v1/search/news.json"

# 5. 데이터 요청
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}
response = requests.get(url, headers=headers, params=params)
if response.status_code == 200:
    response_json = response.json()
    print(response.json())
else:
    print("Error")
# Out:
# {'lastBuildDate': 'Tue, 22 Jul 2025 18:09:42 +0900', 'total': 3085278, 'start': 1, 'display': 100, 'items': [{'title': '최호정 서울시의회 의장, &quot;AI 산업 선도할 것&quot;', 'originallink': 'http://www.newsroad.co.kr/news/articleView.html?idxno=42938', 'link': 'http://www.newsroad.co.kr/news/articleView.html?idxno=42938', 'description': '이날 최 의장은 양재 일대 AI 인프라 조성 현황과 서울AI허브 운영성과 등을 보고받고 공군 AI신기술융합센터, <b>인공지능</b>산업협회, 카이스트 AI대학원 등 입주기업 및 기관들을 차례대로 둘러봤다. 또, 서울AI허브에... ', 'pubDate': 'Tue, 22 Jul 2025 18:08:00 +0900'}, {'title': '충남대–코리아크레딧뷰로, 업무협약 체결', 'originallink': 'https://daily.hankooki.com/news/articleView.html?idxno=1247035', 'link': 'https://daily.hankooki.com/news/articleView.html?idxno=1247035', 'description': '사진=충남대 제공  충남대학교와 코리아크레딧뷰로(KCB)가 <b>인공지능</b>(AI) 기반 ESG 평가 플랫폼을 공동 구축하고 지역기업의 지속가능경영 역량 강화를 위한 본격적인 협력에 나선다. 충남대 ESG센터와 코리아크레딧뷰로... ', 'pubDate': 'Tue, 22 Jul 2025 18:08:00 +0900'}, {'title': '김민석 총리 &quot;새로운 한미관계, 한국과 미국을 다시 위대하게&quot;', 'originallink': 'https://news.mtn.co.kr/news-detail/2025072218051539688', 'link': 'https://news.mtn.co.kr/news-detail/2025072218051539688', 'description': '김 총리는 한미 미래 협력 분야로 반도체, <b>인공지능</b>(AI), 바이오, 콘텐츠, 에너지를 꼽았다.김 총리는 &quot;새 정부는 ABCDE(AI·바이오·콘텐츠&amp;컬쳐·디펜스·에너지)를 전략 산업으로 육성하고 있으며, 이 과정에서 미국과 보완적... ', 'pubDate': 'Tue, 22 Jul 2025 18:08:00 +0900'}, {'title': "[단독] 222조 빨아들인 '1000개의 ETF'", 'originallink': 'https://www.mk.co.kr/article/11374853', 'link': 'https://n.news.naver.com/mnews/article/009/0005529438?sid=101', 'description': '로보택시, 의료 <b>인공지능</b>(AI)부터 미국 국채까지 다양한 테마와 구조화된 상품을 선보였다. 이에 따라 국내 상장 ETF 수는 전날 995개에서 1002개로 늘었다. 이미 유가증권시장(코스피) 상장사(849개) 수를 크게... ', 'pubDate': 'Tue, 22 Jul 2025 18:07:00 +0900'}, {'title': "HD현대일렉 '질주', &quot;3년치 일감 쌓였다&quot;", 'originallink': 'https://www.hankyung.com/article/2025072252771', 'link': 'https://n.news.naver.com/mnews/article/015/0005161345?sid=101', 'description': '미국 정부가 최근 에너지 인프라와 <b>인공지능</b>(AI)산업에 대규모 투자를 하겠다고 발표한 만큼 전력기기 호황은 당분간 계속될 전망이다. HD현대일렉트릭은 지난 2분기에만 9억9600만달러(약 1조3821억원)어치... ', 'pubDate': 'Tue, 22 Jul 2025 18:07:00 +0900'}, {'title': '여름방학 더 알차고 즐겁게', 'originallink': 'http://www.dynews.co.kr/news/articleView.html?idxno=812616', 'link': 'http://www.dynews.co.kr/news/articleView.html?idxno=812616', 'description': '이번 여름방학에는 청소년들이 소프트웨어와 <b>인공지능</b>에 대한 관심과 흥미를 높일 수 있도록 교육부와 연계한 디지털 새싹캠프가 운영된다. 센터에 방문하기 어려운 청소년들을 위해 어진동 행복누림터에 센터 소속 전문... ', 'pubDate': 'Tue, 22 Jul 2025 18:07:00 +0900'}, {'title': '취임식 생략하고 ‘수해현장’ 간 환경장관 “국민 지켜야”', 'originallink': 'http://www.edaily.co.kr/news/newspath.asp?newsid=04441126642237144', 'link': 'https://n.news.naver.com/mnews/article/018/0006071397?sid=102', 'description': '또한 성능이 강화된 슈퍼컴퓨터를 도입해 <b>인공지능</b>(AI) 기술을 융합한 정밀한 예측 시스템을 구축하고, 기상청·지자체 등 유관 기관 간 관측망 확충 및 공동활용을 통해 감시 공백 최소화를 지시할 것으로 알려졌다. 김... ', 'pubDate': 'Tue, 22 Jul 2025 18:07:00 +0900'}, {'title': '트럼프의 AI 야심작 반년째 제자리걸음', 'originallink': 'https://www.mk.co.kr/article/11374845', 'link': 'https://n.news.naver.com/mnews/article/009/0005529433?sid=104', 'description': 'WSJ &quot;스타게이트 사업 차질&quot; 소뱅·오픈AI·오라클 합작 700조원 AI 인프라 프로젝트 데이터센터 위치 놓고 잡음 연내 1개 건설로 목표 축소 도널드 트럼프 미국 행정부에서 자국 <b>인공지능</b>(AI) 역량 강화를 목표로 야심... ', 'pubDate': 'Tue, 22 Jul 2025 18:07:00 +0900'}, {'title': '과기정통부-행안부, 대전서 AI 기반 안전관리 시스템 검증', 'originallink': 'http://www.dynews.co.kr/news/articleView.html?idxno=812716', 'link': 'http://www.dynews.co.kr/news/articleView.html?idxno=812716', 'description': '［동양일보 정래수 기자］ 과학기술정보통신부는 22일 대전 유성온천역에서 행정안전부와 현장 간담회를 열어 <b>인공지능</b>(AI)과 가상 융합 기술로 구축한 재난 안전 시스템을 점검했다고 밝혔다. 정부는 2023년부터 충청남... ', 'pubDate': 'Tue, 22 Jul 2025 18:06:00 +0900'}, {'title': '엑사원으로 AI 혁신하는 LG그룹…국가 단위로 넓힐지 주목', 'originallink': 'http://www.g-enews.com/ko-kr/news/article/news_all/202507221538039000290c42db76_1/article.html', 'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202507221538039000290c42db76_1/article.html', 'description': 'LG그룹이 전사 차원에서 <b>인공지능</b>(AI) 기술에 승부수를 걸었다. 주력 계열사인 LG전자를 비롯해 싱크탱크인 AI연구원이 자체 AI 모델 엑사원의 새 버전과 함께 방대하고 다양한 데이터 해석과 강력한 보안에 필요한 ...

# %%
for a in response_json["items"]:
    print(a["title"])
# Out:
# 최호정 서울시의회 의장, &quot;AI 산업 선도할 것&quot;
# 충남대–코리아크레딧뷰로, 업무협약 체결
# 김민석 총리 &quot;새로운 한미관계, 한국과 미국을 다시 위대하게&quot;
# [단독] 222조 빨아들인 '1000개의 ETF'
# HD현대일렉 '질주', &quot;3년치 일감 쌓였다&quot;
# 여름방학 더 알차고 즐겁게
# 취임식 생략하고 ‘수해현장’ 간 환경장관 “국민 지켜야”
# 트럼프의 AI 야심작 반년째 제자리걸음
# 과기정통부-행안부, 대전서 AI 기반 안전관리 시스템 검증
# 엑사원으로 AI 혁신하는 LG그룹…국가 단위로 넓힐지 주목
# [은행가소식] 우리은행 반도체·AI 등 '성장산업 수출입 패키지' 출시
# 강준현 의원 대표발의 , 첨단전략산업기금 설치법 법안 소위 통과
# [K방산 고도화] 미래 전장 승패 가를 'AI 무기체계' 개발 속도
# [하재근의 족집게로 문화집기] <b>인공지능</b>의 음악계 위협 가시화
# iM라이프, '청렴윤리경영 슬로건' 공모…&quot;임직원 청렴 가치 정립 기대&quot;
# 저렴한 그린피에 AI 캐디까지…영랑호CC가 입소문 타는 이유
# AI 거품 키우는 트럼프 정책, 기술주만 오르는 듯…버블은 언제 터질까...
# &quot;노란봉투법, 신속 통과해야&quot;…양대노총, 국무총리에게 요구(종합)
# 얇아진 갤럭시폴드·플립7, 사전판매 104만대 신기록
# NIA·국립국악원 맞손, ‘국악 AI’ 시대 연다
# 인핸스, 웹 AI 리더보드서 글로벌 3위…커머스 자동화 시장 노린다
# 의원 출신 장관 군기잡은 李 &quot;국회와 상황 달라,긴장하라&quot;
# 내년 7월 인천서 '로보컵 2026' 개최
# 구광모의 AI 특명, LG ‘엑사원’ 생태계로 윤곽
# 국내 첫 대규모 과학기술문화축제 '엠씨티페스티벌 조직위 발대식 개최
# 대전TP·KCL·KETI·한밭대, '적층제조 공유 팩토리 구축 협약'
# APEC 정상회의 D-100일…경주, 손님맞이 준비 '착착'
# LG, 기업용 AI모델 엑사원 공개 &quot;챗GPT 10분의 1 가격&quot;
# 코레일, 철도 디지털 전환 위한 'AI가속화추진단TF' 출범
# 관전 포인트는 '트럼프·시진핑' 참석…APEC 준비도 '올코트 프레싱'
# “직장인의 퇴사 충동, 결국 관계에서 온다”...소통의 힘을 말하다, CC...
# SPC, '변화와 혁신 추진단' 출범…&quot;새 공장 조속히 건립 권고&quot;
# LG전자·퀄컴 CEO간 브로맨스 강해진다...&quot;땡큐, 조주완&quot;
# “미디어아트 체험할 수 있는 공간 12월 오픈”
# [부고]류태준(팀쿠키 대표이사)씨 외조부상
# 코레일 'AI가속화추진단TF' 출범…AI 정책 '스마트 철도' 박차
# 피지컬AI 시대 리딩 'PLUS 미국 로보택시 ETF' 상장
# 코레일, ‘AX 경영’ 전담 조직 출범…‘스마트 철도’ 박차
# [월드스마트시티엑스포]스칼라웍스-AI 기반 도시안전 솔루션
# [월드스마트시티엑스포]인사말-김종민 의원
# [월드스마트시티엑스포]에이테크-AI 비전 기반 객체 인식
# 여름휴가 7말8초 몰린다…자동차로 동해안行 '최다'
# 하남시, 미사숲공원에 불법 오토바이 단속시스템 구축
# [월드스마트시티엑스포]가우스랩-'AI 기반 디지털 전환 솔루션' BOGO
# 李대통령 &quot;재난상황에 음주가무…정신 나간 공직자 엄단&quot;
# [월드스마트시티엑스포]인사말-이성권 의원
# [월드스마트시티엑스포]콘퍼런스 및 우수기업 개요
# [월드스마트시티엑스포]베스텔라랩-스마트시티 보안
# 오픈AI &quot;챗GPT 에이전트 도입으로 역대 최강 보안 체계 구축&quot;
# LG &quot;AI 3대 강국 위한 韓 산업 대전환…엑사원으로 주도&quot;
# 잠재 성장률 3%·세계 5강 한국, 공약(空約)이 될까(?)
# SPC, '변화와 혁신 추진단' 출범…의장에는 허진수 파리크라상 사장
# [직장 돋보기 분석] SK이노베이션, 평균연봉 1억4900만원인 국내 대표 에...
# 하나증권, 퇴직연금 DB형 수익률 4%…증권업계 1위
# 게임, K콘텐츠 주역인데…질병코드 도입땐 일자리 8만개 사라진다
# 인간사고력 넘은 AI … 국제수학대회 첫 金
# KB자산운용, 신정부 정책 수혜 기업 선별 'KB새로운 대한민국 펀드' 출시
# KB자산운용, 'KB 새로운 대한민국 펀드' 출시
# 2주 걸리던 암 변이 검사, AI가 1분만에 확인…LG, ‘엑사원 생태계’ 공...
# LG AI연구원, '엑사원 생태계' 공개...B2B 확장 청사진 제시
# 위밋모빌리티, WSCE 2025서 '<b>인공지능</b>·데이터 어워즈' 수상
# 새정부 전략 산업 골고루 투자 KB운용'새로운 대한민국 펀드'
# '2025년 APEC 정상회의' D-100일…행사·손님맞이 채비 순조
# LH, 국가정보원 '사이버보안 실태 평가'서 최고 등급 '우수' 획득
# LG, AI로 돈번다…&quot;기업분석 리포트 써주고 신약개발도&quot;
# 무적의 '신공<b>지능</b>'… 대회 최다승 기록 썼다
# [GS칼텍스배 프로기전] 백발백중 승자
# 미사숲공원 안전 지킨다…하남시, 오토바이 불법 통행 AI 실시간 단속
# [서정렬 칼럼] AI 발전이  미래 '1인 가구'에 미칠 영향
# &quot;‘스마트 철도’ 박차&quot;...코레일 ‘AX 경영’ 전담 조직 떴다
# 남부발전, 공정경제 생태계 조성 나섰다
# 북미향 수주 확대·고부가 제품 업고 K-전력기기 훨훨
# 중국 &quot;지난해 AI 산업규모 135조 원‥연간 20% 이상 성장세&quot;
# 산업현장 무인자율주행차 개발 공급 활발
# ‘AI 시대’ 보조금 늪에 또 빠진 통신3사
# 하나자산운용, '1Q 미국메디컬 AI ETF' 상장…상품 라인업 확충 박차
# 농협은행, 퇴직연금 로보어드바이저 가입 이벤트
# [비즈톡톡] 690조 AI 프로젝트 ‘스타게이트’, 오픈AI·소프트뱅크 갈등...
# ETF도 배당이 대세…美 아닌 국내 주식형에 뭉칫돈
# AI, 인간 수학능력 곧 넘는다…구글·오픈AI, 수학대회 '금메달' 성적
# “군대서 비극 경험”…장교 출신 최태원 차녀, 美서 창업한 이유
# 대구시, '2025년 기술융합형 문화콘텐츠 제작·지원사업' 공모 선정 완료
# [새로 나온 책] 편리함에 가려진 검은 그림자
# 미 공군 F-15, 발키리 무인전투기와 공중 협공
# &quot;AI 없는 나라에 주권 없다&quot;…LG, 새로운 한국형 AI 공개
# &quot;AI부터 SW, 항공·우주까지&quot;… 대학생 등의 뜨거운 탐구 정신 '눈길'
# APEC 'D-100'…경주시 &quot;정상숙소 등 차질 없이 준비&quot;
# [인사] 광주과학기술원(GIST)
# 대구교통공사, AI 활용해 '아이조아카드 부정 사용' 적발 프로그램 개발
# [만파식적] 그리스 ‘브레인 리게인’
# 법사위, '윤 거부권' 농어업 재해대책법 등 의결
# B2B 생태계 조성…‘LG AI 모델 청사진’
# 제주도, 아마존과 AI·디지털 대전환 가속한다
# 제주도, 글로벌 기업과 AI·디지털 대전환 협력 강화
# SK하이닉스·한화에어로·네오위즈…'깜짝 실적' 기대주 담아볼까
# 국회, 내일 본회의…농어업재해대책·보험법등 비쟁점법안 위주 처리
# 솔트룩스, KT와 '독자 AI 모델' 사업 참전
# 취업 포기자 학력 살펴보니…대졸자 &gt;중졸자 첫 추월
# [경북테크노파크 소식] AI 기반 자율제조 혁신 세미나 가져···스마트 ...
# 코레일, ‘AX 경영’ 전담 조직 출범…‘스마트 철도’ 박차

# %% [markdown]
# # 4. YouTube API

# %% [markdown]
# uv add google-api-python-client

# %%
from googleapiclient.discovery import build
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()

api_key = os.getenv("YOUTUBE_API_KEY")
video_id = "7qXFLRRMbKw"

youtube = build("youtube", "v3", developerKey=api_key)

comments = []
next_page_token = None

while True:
    response = youtube.commentThreads().list(
        part= "snippet",
        videoId=video_id,
        maxResults=100,
        pageToken= next_page_token,
        textFormat="plainText"
    ).execute()

    for item in response["items"]:
        comment = item["snippet"]["topLevelComment"]["snippet"]
        comments.append(
            {
            "author": comment["authorDisplayName"],
            "text": comment["textDisplay"],
            "likeCount": comment["likeCount"],
            "publishedAt": comment["publishedAt"]
            }
        )
    next_page_token = response.get("nextPageToken")
    if not next_page_token:
        break

data = pd.DataFrame(comments)
data.head()
# Out:
#       author                                               text  likeCount  \
# 0   @소그미-k2s  지구 온난화가 심해지고 있다는 게 체감되네요 더운 날씨에 모두들 건강 조심하시길 바...          0
# 1  @Hyuk-t7u                                            존나 시원한데          0
# 2    @kwersh                하나도 못 맞추노 ㅋㅋㅋㅋ 장마 또 시작했구먼 세금낭비다,,,,          0
# 3   @노홍철-m1b                                               아츠이나          0
# 4   @보리수-b1h                       다른나라 더. 더워. 우리나라 양호한거여. 기상청아          0
#
#             publishedAt
# 0  2025-07-21T06:04:55Z
# 1  2025-07-20T04:00:39Z
# 2  2025-07-18T11:39:46Z
# 3  2025-07-18T11:38:58Z
# 4  2025-07-15T01:30:33Z

# %% [markdown]
# ## 5) 데이터 저장하기
