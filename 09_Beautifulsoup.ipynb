# %% [markdown]
# # 정적 크롤링 : BeautifulSoup

# %% [markdown]
# uv add beautifulsoup4

# %% [markdown]
# * [참고자료, TCP School](https://tcpschool.com/html/html_intro_elementStructure)

# %% [markdown]
# # 1. 미니 실습

# %% [markdown]
# ## 1) HTML 파싱 준비

# %%
html = """
<html>
  <body>
    <div id="main" class="content">
      <h1>첫 번째 헤더</h1>
      <h1 class="header">두 번째 헤더</h1>
      <p class="description">설명입니다.</p>
      <a href="https://example1.com" class="link">링크 1</a>
      <a href="https://example2.com" class="link">링크 2</a>
      <a href="https://example3.com" class="external">링크 3</a>
    </div>
    <div id="main2" class="content">
      <div class="items">
        <div>
            <img class="thumbnail" src="/data/picture1.png" />
            <div class="title">타이틀1</div>
            <div class="description">설명1</div>
        </div>
        <div>
            <img class="thumbnail" src="/data/picture2.png" />
            <div class="title">타이틀2</div>
            <div class="description">설명2</div>
        </div>
        <div>
            <img class="thumbnail" src="/data/picture3.png" />
            <div class="title test">타이틀3</div>
            <div class="description">설명3</div>
        </div>
      </div>
    </div>
  </body>
</html>
"""

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, "html.parser")
print(soup)
# Out:
# <html>
# <body>
# <div class="content" id="main">
# <h1>첫 번째 헤더</h1>
# <h1 class="header">두 번째 헤더</h1>
# <p class="description">설명입니다.</p>
# <a class="link" href="https://example1.com">링크 1</a>
# <a class="link" href="https://example2.com">링크 2</a>
# <a class="external" href="https://example3.com">링크 3</a>
# </div>
# <div class="content" id="main2">
# <div class="items">
# <div>
# <img class="thumbnail" src="/data/picture1.png"/>
# <div class="title">타이틀1</div>
# <div class="description">설명1</div>
# </div>
# <div>
# <img class="thumbnail" src="/data/picture2.png"/>
# <div class="title">타이틀2</div>
# <div class="description">설명2</div>
# </div>
# <div>
# <img class="thumbnail" src="/data/picture3.png"/>
# <div class="title test">타이틀3</div>
# <div class="description">설명3</div>
# </div>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# ## 2) 파싱

# %% [markdown]
# ### soup.find("태그명", class_, id)

# %%
# 맨 처음 나오는 class 이름이 title 인 div를 추출해주세요.
soup.find("div", class_= "title")
# Out:
# <div class="title">타이틀1</div>

# %%
soup.find("div", class_="title").text
# Out:
# '타이틀1'

# %% [markdown]
# ### soup.find_all("태그명", class_, id)

# %%
# 맨 처음 나오는 class 이름이 title인 div를 추출해주세요.
output = soup.find_all("div", class_="title")
output
# Out:
# [<div class="title">타이틀1</div>,
#  <div class="title">타이틀2</div>,
#  <div class="title test">타이틀3</div>]

# %%
for out in output:
    print(out.text)
# Out:
# 타이틀1
# 타이틀2
# 타이틀3

# %%
# (미션)
# "두 번째 헤더"를 출력해주세요
# 목표: <h1 class="header">두 번째 헤더</h1>
output = soup.find("h1", class_="header")
print(output.text)
# Out:
# 두 번째 헤더

# %%
# "설명3"을 출력해주세요
# 목표: <div class="description">설명3</div>
outputs = soup.find_all("div", class_="description")
print(outputs[-1].text)
# Out:
# 설명3

# %%
# 태그 a를 모두 출력해주세요
outputs = soup.find_all("a")
outputs
# Out:
# [<a class="link" href="https://example1.com">링크 1</a>,
#  <a class="link" href="https://example2.com">링크 2</a>,
#  <a class="external" href="https://example3.com">링크 3</a>]

# %% [markdown]
# ### 속성 추출

# %%
output = outputs[0]
print(output)
print(output.attrs)
print(output["href"])
print(output.attrs["href"])
print(output.attrs.get("href"))
# Out:
# <a class="link" href="https://example1.com">링크 1</a>
# {'href': 'https://example1.com', 'class': ['link']}
# https://example1.com
# https://example1.com
# https://example1.com

# %% [markdown]
# soup.select_one("경로")

# %%
# 링크 1을 출력하고 싶어요
soup.select_one("div > a")
# Out:
# <a class="link" href="https://example1.com">링크 1</a>

# %%
# 링크 2를 출력하고 싶어요
soup.select_one("div > a:nth-child(5)")
# Out:
# <a class="link" href="https://example2.com">링크 2</a>

# %% [markdown]
# ### soup.select("경로")

# %% [markdown]
# * 클래스 이름 : "태그명, 클래스이름"
# * id : #id이름

# %%
# id가 main2를 출력해주세요
soup.select("div.items")
# Out:
# [<div class="items">
#  <div>
#  <img class="thumbnail" src="/data/picture1.png"/>
#  <div class="title">타이틀1</div>
#  <div class="description">설명1</div>
#  </div>
#  <div>
#  <img class="thumbnail" src="/data/picture2.png"/>
#  <div class="title">타이틀2</div>
#  <div class="description">설명2</div>
#  </div>
#  <div>
#  <img class="thumbnail" src="/data/picture3.png"/>
#  <div class="title test">타이틀3</div>
#  <div class="description">설명3</div>
#  </div>
#  </div>]

# %%
# id가 main2를 출력해주세요
soup.select('#main2')
# Out:
# [<div class="content" id="main2">
#  <div class="items">
#  <div>
#  <img class="thumbnail" src="/data/picture1.png"/>
#  <div class="title">타이틀1</div>
#  <div class="description">설명1</div>
#  </div>
#  <div>
#  <img class="thumbnail" src="/data/picture2.png"/>
#  <div class="title">타이틀2</div>
#  <div class="description">설명2</div>
#  </div>
#  <div>
#  <img class="thumbnail" src="/data/picture3.png"/>
#  <div class="title test">타이틀3</div>
#  <div class="description">설명3</div>
#  </div>
#  </div>
#  </div>]

# %%
# <div>
#     <img class="thumbnail" src="/data/picture3.png" />
#     <div class="title test">타이틀3</div>
#     <div class="description">설명3</div>
# </div>
# 이 요소만 출력해주세요
soup.select("div.items > div:nth-child(3)")
# Out:
# [<div>
#  <img class="thumbnail" src="/data/picture3.png"/>
#  <div class="title test">타이틀3</div>
#  <div class="description">설명3</div>
#  </div>]

# %% [markdown]
# ## 3) 데이터 프레임 만들기

# %%
# (미션)
# html에서 class 이름이 items 안에 있는 요소들로 데이터프레임을 만들고 싶다.
# 열 이름은 image, title, description로 설정할 것이다.
# image열에는 image의 src 속성을, 
# title열에는 class이름이 title인 요소의 텍스트,
# description열에는 class이름이 description인 요소의 텍스트이다.

## 1. 태그가 div이고 class이름이 items인 데이터를 추출해주세요
items_html = soup.find("div", class_="items") # 여기서 find_all을 쓰면 리스트로 묶여서 출력된다. 만약 다음 과정에 find_all을 다시 쓰게되면 오류발생. 그러나 0번째를 인덱스를 통해서 값을 추출하면 가능함
print(items_html)
# Out:
# <div class="items">
# <div>
# <img class="thumbnail" src="/data/picture1.png"/>
# <div class="title">타이틀1</div>
# <div class="description">설명1</div>
# </div>
# <div>
# <img class="thumbnail" src="/data/picture2.png"/>
# <div class="title">타이틀2</div>
# <div class="description">설명2</div>
# </div>
# <div>
# <img class="thumbnail" src="/data/picture3.png"/>
# <div class="title test">타이틀3</div>
# <div class="description">설명3</div>
# </div>
# </div>

# %%
## 2. items_html에서 div인 것을 추출해주세요
### recursive = True 일때
div_outputs = items_html.find_all("div")
for output in div_outputs:
    print(output)
    print("-"*50)
# Out:
# <div>
# <img class="thumbnail" src="/data/picture1.png"/>
# <div class="title">타이틀1</div>
# <div class="description">설명1</div>
# </div>
# --------------------------------------------------
# <div class="title">타이틀1</div>
# --------------------------------------------------
# <div class="description">설명1</div>
# --------------------------------------------------
# <div>
# <img class="thumbnail" src="/data/picture2.png"/>
# <div class="title">타이틀2</div>
# <div class="description">설명2</div>
# </div>
# --------------------------------------------------
# <div class="title">타이틀2</div>
# --------------------------------------------------
# <div class="description">설명2</div>
# --------------------------------------------------
# <div>
# <img class="thumbnail" src="/data/picture3.png"/>
# <div class="title test">타이틀3</div>
# <div class="description">설명3</div>
# </div>
# --------------------------------------------------
# <div class="title test">타이틀3</div>
# --------------------------------------------------
# <div class="description">설명3</div>
# --------------------------------------------------

# %%
### recursive = False 일때
div_outputs = items_html.find_all("div", recursive=False)
data_list = []
for output in div_outputs:
    temp_dict = {}
    temp_dict["image"] = output.find("img", class_="thumbnail").attrs.get("src")
    temp_dict["title"] = output.find("div", class_="title").text
    temp_dict["description"] = output.find("div", class_="description").text
    data_list.append(temp_dict)
    print(temp_dict)
    print("-"*50)
# Out:
# {'image': '/data/picture1.png', 'title': '타이틀1', 'description': '설명1'}
# --------------------------------------------------
# {'image': '/data/picture2.png', 'title': '타이틀2', 'description': '설명2'}
# --------------------------------------------------
# {'image': '/data/picture3.png', 'title': '타이틀3', 'description': '설명3'}
# --------------------------------------------------

# %%
data_list
# Out:
# [{'image': '/data/picture1.png', 'title': '타이틀1', 'description': '설명1'},
#  {'image': '/data/picture2.png', 'title': '타이틀2', 'description': '설명2'},
#  {'image': '/data/picture3.png', 'title': '타이틀3', 'description': '설명3'}]

# %%
import pandas as pd

data = pd.DataFrame(data_list)
data
# Out:
#                 image title description
# 0  /data/picture1.png  타이틀1         설명1
# 1  /data/picture2.png  타이틀2         설명2
# 2  /data/picture3.png  타이틀3         설명3

# %% [markdown]
# # 2. 교보문고 크롤링

# %% [markdown]
# ## 1) HTML 요청하기

# %%
# import urllib 사용할때
base_url = "https://search.kyobobook.co.kr/search"

keyword = "인공지능" # keyword를 인코딩하는 과정이 필요하다
target = "kyobo"
gbCode = "TOT"
page = 1

# url = f"{base_url}?keyword={keyword}&target={target}&gbCode={gbCode}&page={page}"

# %%
base_url = "https://search.kyobobook.co.kr/search"

keyword = "인공지능"
target = "kyobo"
gbCode="TOT"
page = 1

params = {
    "keyword" : keyword,
    "target" : target,
    "gbCode" : gbCode,
    "page" : page
}

headers = {"User-Agent" : "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Mobile Safari/537.36"}
# keyword = "%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5"
# target = "kyob"
# gbCode="TOT"
# page = 1

# url = f"{base_url}?keyword={keyword}&target={target}&gbcode={gbCode}&page={page}"

import requests
response = requests.get(base_url, params=params, headers=headers)
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko"
#     data-view="mok"
#     data-service="search"
# >
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#
#
#
#             <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1">
#
#
#
#
#
#         <meta name="title" content="인공지능 검색결과 | 교보문고">
#         <meta property="og:title" content="인공지능 검색결과 | 교보문고">
#
#
#
#         <meta name="description" content="꿈을 키우는 세상 교보문고는 온오프라인을 통틀어 대한민국 최고의 도서쇼핑몰이며 전자책, 음반, 기프트, 문화서비스까지 제공하는 종합문화기업입니다.">
#         <meta property="og:description" content="꿈을 키우는 세상 교보문고는 온오프라인을 통틀어 대한민국 최고의 도서쇼핑몰이며 전자책, 음반, 기프트, 문화서비스까지 제공하는 종합문화기업입니다.">
#
#
#     <meta property="og:type" content="website">
#     <meta property="og:image" content="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo@2x.png">
#     <meta property="og:url" content="http://mobile.kyobobook.co.kr">
#
#
#
#
#
# <meta name="format-detection" content="date=no">
#
#
#
#
#
#
#
# <meta name="google-site-verification" content="2dlgBOp3K0s6wHjZo_Hkas6yaYPKZIVsmres9vC3F34">
#
# <meta name="google-site-verification" content="vN9Zag6odZ4sMyJfDMMSZTqbD-nbmnh0ituV4pk4FV4">
#
# <meta name="google-site-verification" content="AHqpy7PvqPoZwSySpolatuTj8M3B9F10Pi6UCldP5hE">
#
#
#
# <meta name="facebook-domain-verification" content="ezckujv1qppxlglsp8fsry2bs2cw0n">
#
#
#
# <meta name="naver-site-verification" content="bef3d190b10f8cada477f5531d206cc1a799c498">
#
#
#
#
#
#
#
#
#     <link rel="icon" type="image/png"
#           sizes="256x256"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_256x256.png">
#
#
#     <link rel="icon" type="image/png"
#           sizes="196x196"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_196x196.png">
#
#
#     <link rel="icon" type="image/png"
#           sizes="128x128"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_128x128.png">
#
#
#     <link rel="icon" type="image/png"
#           sizes="48x48"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_48x48.png">
#
#
#     <link rel="icon" type="image/png"
#           sizes="32x32"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_32x32.png">
#
#
#     <link rel="icon" type="image/png"
#           sizes="16x16"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_16x16.png">
#
#
#
#
#     <meta name="msapplication-TileImage" content="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-144x144-precomposed.png">
#     <meta name="msapplication-TileColor" content="#222222">
#
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="700x700"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-700x700-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="180x180"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-180x180-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="167x167"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-167x167-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="152x152"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-152x152-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="144x144"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-144x144-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="120x120"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-120x120-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="114x114"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-114x114-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="80x80"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-80x80-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="72x72"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-72x72-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="60x60"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-60x60-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-57x57-precomposed.png">
#
#
#
#
#
#
#
# <title>인공지능 검색결과 | 교보문고</title>
#
#
#
#
#
#
#
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Noto+Sans+KR:wght@400;500;700&family=Roboto:wght@400;500;700&display=swap" />
#
#
#
#
#
#
#     <link rel="stylesheet" href="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery-ui.min.css" />
#
#
#
#
#
#
#
#
#
#
#     <link rel="stylesheet" href="https://contents.kyobobook.co.kr/resources/vendors/swiper/v7/swiper-bundle.min.css" />
#
#
#
#
#
#
#
#
#
#
#     <link rel="stylesheet" href="https://contents.kyobobook.co.kr/resources/fo/css/loading.css" />
#
#
#
#
#
#     <link rel="stylesheet" type="text/css" href="https://contents.kyobobook.co.kr/resources/fo/css/style_mok.css?t=202507231211" data-name="kbb-cm-style" />
#
#
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/essential-vendors.min.js"></script>
#
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery-ui.min.js" data-name="jquery-ui"></script>
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery.ui.spinner.js"></script>
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/lottie-5.9.4/lottie.min.js"></script>
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-loading.js?t=202507231211"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/kbbjs-loader-v2.js?t=202507231211"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.js?t=202507231211" data-name="kbb.js"></script>
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.shared.js?t=202507231211" data-name="kbb.shared.js"></script>
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="/mobile/js/mok_kyobo_search_auto.js?t=202507231211"></script>
#
#
#
#
#
#
# <script>
#     // IIFE
#     ;(function () {
#         // --------------------- [KbbJS/SSR] 서버 환경변수 전달
#         const CDN_URL = "https:\/\/contents.kyobobook.co.kr\/resources\/fo"
#
#         const tmpArr = CDN_URL.match(/((https?:)?\/\/[^/]+)(\/.*)/)
#         const cdnHost = tmpArr[1]
#         const cdnBaseURL = tmpArr[3]
#
#         KbbJS.setOption('service.cdn.host', cdnHost)
#         KbbJS.setOption('service.cdn.baseURL', cdnBaseURL)
#
#         /**
#          * KbbJS 라이브러리 경로 설정
#          */
#         let KbbjsURL = "\/lib\/kbb-js"
#         if (!/^(https?:|\/\/)/.test(KbbjsURL)) {
#             KbbjsURL = CDN_URL + KbbjsURL
#         }
#
#         const KBBJS_VER = "v2.0\/latest"
#         if (KBBJS_VER != null) {
#             KbbjsURL += '/' + KBBJS_VER
#         } else {
#             KbbjsURL = "https:\/\/search.kyobobook.co.kr\/lib\/kbb-js"
#         }
#
#         // KbbJS 배포 개선 작업 1차 - 속성 추가
#         KbbJS.setOption('loader.bootstamp', "202507231211")
#         KbbJS.setOption('loader.baseURL', KbbjsURL)
#
#         // 인증여부 속성 추가
#         KbbJS.setOption('loader.authorized', false)
#         KbbJS.setOption('loader.user.nickname', null)
#         KbbJS.setOption('loader.user.picture', null)
#
#         // 디바이스 정보 설정
#         KbbJS.setOption('ua.device', {
#             isMobile: true,
#             isMobileApp: false,
#             isIOS: false,
#             isAndroid: true,
#             isMSIE: false,
#             isMac: false
#         })
#
#         /**
#          * 서비스 호스트 설정
#          */
#         const oServiceData = {"hosts":{"ebook-product":"https:\/\/ebook-product.kyobobook.co.kr","semo":"https:\/\/semo.kyobobook.co.kr","product":"https:\/\/product.kyobobook.co.kr","ecash":"https:\/\/ecash.kyobobook.co.kr","elibrary":"https:\/\/elibrary.kyobobook.co.kr","best":"https:\/\/best.kyobobook.co.kr","bookcast":"https:\/\/casting.kyobobook.co.kr","store":null,"undefined":null,"search":"https:\/\/search.kyobobook.co.kr","ebook":"https:\/\/ebook.kyobobook.co.kr","member":"https:\/\/mmbr.kyobobook.co.kr","myroom":"https:\/\/my.kyobobook.co.kr","event":"https:\/\/event.kyobobook.co.kr","welcome":"https:\/\/www.kyobobook.co.kr","hottracks":"https:\/\/hottracks.kyobobook.co.kr\/","sam":"https:\/\/sam.kyobobook.co.kr","order":"https:\/\/order.kyobobook.co.kr"}}
#         const oServiceHosts = _.get(oServiceData, 'hosts', {})
#         _.forEach(_.keys(oServiceHosts), function (key) {
#             let prop = key
#             switch (key.toLowerCase()) {
#                 case 'ebookproduct':
#                 case 'ebook-product':
#                     prop = 'ebookProduct';
#                     break
#                 case 'elibrary':
#                     prop = 'eLibrary'
#                     break
#             }
#             let value = _.get(oServiceHosts, key)
#             if (value == null) {
#                 // 기본 호스트 설정
#                 switch (key.toLowerCase()) {
#                     case 'welcome': value = 'www'; break
#                     case 'myroom': value = 'my'; break
#                     case 'bookcast': value = 'casting'; break
#                     case 'member': value = 'mmbr'; break
#                     case 'ebookproduct':
#                     case 'ebook-product':
#                         value = 'ebook-product'
#                         break
#                     case 'elibrary':
#                         value = 'elibrary'
#                         break
#                     case 'product':
#                     case 'event':
#                     case 'order':
#                     case 'search':
#                     case 'best':
#                     case 'ebook':
#                     case 'sam':
#                     case 'store':
#                     case 'ecash':
#                         value = prop
#                         break
#                 }
#                 if (value == null) return
#                 value = 'https://' + value + '.kyobobook.co.kr'
#             }
#             KbbJS.setOption('service.' + prop + '.host', value)
#         })
#     }())
# </script>
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-netfunnel.js?t=202507231211"></script>
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/common-vars.js?t=202507231211"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/vars/common.js?t=202507231211" data-name="vars.common"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/vars/paper.js?t=202507231211" data-name="vars.service"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.stats.js?t=202507231211" data-name="kbb.stats.js"></script>
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.gautil.js?t=202507231211" data-name="kbb.gautil.js"></script>
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/ga360/common-vars.js?t=202507231211"></script>
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/ga360/util.js?t=202507231211"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="/mobile/js/mok_kyobo_search_common.js?t=202507231211"></script>
#
#
#
#
#         <!-- /* 큐봇(cubot) 초기화 */-->
#         <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-cubot-loader.js?t=1753328043245" defer></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/vendors.min.js?t=202507231211" data-name="kbb-vendors.min.js"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/shared.min.js?t=202507231211" data-name="kbb-shared.min.js"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/components.min.js?t=202507231211" data-name="kbb-components.min.js"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/core.min.js?t=202507231211" data-name="kbb-core.min.js"></script>
#
#
#
#
#
#
#
#
#
#
# </head>
# <body>
#
#         <div id="KbbLoading"
#     class="loading_box show"
# >
#     <div class="loading_box_inner">
#         <div class="loading_target"></div>
#     </div>
#     <div class="loading_dimmed"></div>
# </div>
#
#
#
#
#
#
#
#
#
#             <div class="skip_nav_wrap">
#                 <a href="#contents">본문 바로가기</a>
#             </div>
#             <div class="wrapper contents_search_result" id="mainDiv">
#
#
#
#
#             <!--
#             - 2024.02.05 PC인 경우 통합 GNB로 변경
#             - #TODO 모바일 통합 GNB 적용
#             -->
#
#             <!-- 헤더 -->
# <header class="header_wrapper header_main">
# <!--  앱 전환 유도 배너 임시 주석처리  -->
# <!--    <th:block th:insert="~{view/mok/include/mok_searchAppBanner}"></th:block>-->
#     <div class="header_top_wrap">
#         <div class="logo_box">
#             <!--<a th:href="${@utils.parseStageURL('/ONK/')}" class="logo_link" th:insert="~{:: ${@utils.getStr(logoPosition, 'header')}(alt='KYOBO 교보문고')}"></a>-->
#             <a href="https://www.kyobobook.co.kr/" class="logo_link">
#                 <img src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_logo_kyobo_mok@2x.png" alt="KYOBO 교보문고">
#             </a>
#         </div>
#
# <div class="service_mall_wrap">
#     <div class="service_mall_inner">
#         <ul class="service_mall_list">
#
#
#
#     <li class="service_mall_item tab ebook">
#         <a href="https://ebook.kyobobook.co.kr/" class="service_mall_link" onclick="ga360.GA_Event(&#39;click_공통_MO&#39;, &#39;헤더&#39;, &#39;&#39;, &#39;eBook&#39;, &#39;&#39;);">eBook</a>
#     </li>
#
#
#     <li class="service_mall_item tab sam">
#         <a href="https://sam.kyobobook.co.kr/" class="service_mall_link" onclick="ga360.GA_Event(&#39;click_공통_MO&#39;, &#39;헤더&#39;, &#39;&#39;, &#39;sam&#39;, &#39;&#39;);">sam</a>
#     </li>
#
#
#
#
#
#     <li class="service_mall_item tab hottracks">
#         <a href="https://mhottracks.kyobobook.co.kr/" class="service_mall_link" onclick="ga360.GA_Event(&#39;click_공통_MO&#39;, &#39;헤더&#39;, &#39;&#39;, &#39;핫트랙스&#39;, &#39;&#39;);">핫트랙스</a>
#     </li>
#     <li class="service_mall_item tab link">
#         <a href="https://storynew.kyobobook.co.kr/story/main/initMain.ink" class="service_mall_link" id="service_mal_story" onclick="ga360.GA_Event(&#39;click_공통_MO&#39;, &#39;헤더&#39;, &#39;&#39;, &#39;스토리&#39;, &#39;&#39;);">스토리</a>
#     </li>
# </ul>
#     </div>
#
#
#     <button type="button" class="btn_brand_more">
#     <span class="hidden">브랜드 더보기</span>
# </button>
#     <div class="brand_more_list_box">
#         <div class="custom_scroll_wrap">
#             <ul class="brand_more_list">
#                 <li class="brand_more_item">
#     <a class="brand_more_link"
#        href="https://www.kyobobook.co.kr/"
#     >
#         <span class="img_box">
#             <img loading="lazy"
#                  alt="교보문고 BI"
#                  src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_kyobo_mok.png"
#             >
#         </span>
#         <span class="brand_name">교보문고</span>
#     </a>
# </li><li class="brand_more_item">
#     <a class="brand_more_link"
#        href="https://ebook.kyobobook.co.kr/"
#     >
#         <span class="img_box">
#             <img loading="lazy"
#                  alt="교보문고 eBook BI"
#                  src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_ebook_mok.png"
#             >
#         </span>
#         <span class="brand_name">eBook</span>
#     </a>
# </li><li class="brand_more_item">
#     <a class="brand_more_link"
#        href="https://sam.kyobobook.co.kr/"
#     >
#         <span class="img_box">
#             <img loading="lazy"
#                  alt="교보문고 sam BI"
#                  src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_sam_mok.png"
#             >
#         </span>
#         <span class="brand_name">sam</span>
#     </a>
# </li><li class="brand_more_item">
#     <a class="brand_more_link"
#        href="https://mhottracks.kyobobook.co.kr/m/welcomeMain"
#     >
#         <span class="img_box">
#             <img loading="lazy"
#                  alt="핫트랙스 BI"
#                  src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_hot_tracks_mok.png"
#             >
#         </span>
#         <span class="brand_name">핫트랙스</span>
#     </a>
# </li><li class="brand_more_item">
#     <a class="brand_more_link"
#        href="https://www.kyobobook.co.kr/store"
#     >
#         <span class="img_box">
#             <img loading="lazy"
#                  alt="매장안내 BI"
#                  src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_store_mok.png"
#             >
#         </span>
#         <span class="brand_name">매장안내</span>
#     </a>
# </li><li class="brand_more_item">
#     <a class="brand_more_link"
#        href="https://storynew.kyobobook.co.kr/story/main/initMain.ink"
#        target="_blank"
#     >
#         <span class="img_box">
#             <img loading="lazy"
#                  alt="스토리 BI"
#                  src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_story_mok@2x.png"
#             >
#         </span>
#         <span class="brand_name">스토리</span>
#     </a>
# </li><li class="brand_more_item">
#     <a class="brand_more_link"
#        href="https://product.kyobobook.co.kr/pod/main"
#     >
#         <span class="img_box">
#             <img loading="lazy"
#                  alt="바로출판 BI"
#                  src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_pod_mok@2x.png"
#             >
#         </span>
#         <span class="brand_name">바로출판</span>
#     </a>
# </li><li class="brand_more_item">
#     <a class="brand_more_link"
#        href="https://wv4wthajb0i8pj89j0pigw.adtouch.adbrix.io/api/v1/click/LmEQQEQbqUeTaf0gSEpSJw?adv_campaign=2312_web_traffic&amp;adv_ad=kyobo_brand_list&amp;adv_adgroup=none&amp;adv_creative=brand_name"
#        target="_blank"
#     >
#         <span class="img_box">
#             <img loading="lazy"
#                  alt="리드로그 BI"
#                  src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_readlog_mok@2x.png"
#             >
#         </span>
#         <span class="brand_name">리드로그</span>
#     </a>
# </li>
#             </ul>
#         </div>
#     </div>
#
# </div>
#
#     </div>
#     <div class="gnb_search_wrap">
#         <div class="gnb_search_box">
#             <div class="search_input_wrap">
#
#                     <input type="search" class="ip_gnb_search" id="searchMainKeyword" title="통합검색어 입력" placeholder="" value="인공지능"/>
#
#                 <input type="hidden" name="searchBoxEventurl" id="searchBoxEventurl" value=""/>
#
#                     <script>
#                         jQuery(function () {
#                             jQuery.getJSON('/api/adv?url=/mobile/mok_wel_new/mobile_welcome@mo_3?callback=', function (data) {
#                                 var search_placeholder_txt = document.createElement('textarea');
#                                 search_placeholder_txt.innerHTML = data[0].text;
#                                 $(".ip_gnb_search").attr("placeholder", search_placeholder_txt.value);
#                                 $('#searchBoxEventurl').val(data[0].linkUrl);
#
#                                 setGtmForPlaceholder(data);
#                             });
#                         });
#                     </script>
#
#
#
#                 <button type="button" class="btn_ip_clear"><span class="hidden">초기화</span></button>
#             </div>
#             <a href="#" class="btn_gnb_search"><span class="hidden"></span></a>
#         </div>
#
#         <a href="https://order.kyobobook.co.kr/cart"
#    class="btn_header_cart"
# >
#     <span class="hidden">장바구니</span>
#
#     <span data-kbbfn="cart-size" style="display:none;" class="count"></span>
# </a>
#
#     </div>
#
#
#
#     <!-- 연관검색어 영역 -->
#         <!-- 연관검색어 -->
#
#     <div class="related_keyword_wrap">
#         <span class="text">연관</span>
#         <div class="tag_wrap size_sm scroll">
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;\uBA38\uC2E0\uB7EC\uB2DD&quot;);" class="tag">머신러닝</a>
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;\uAC00\uC0C1\uD654\uD3D0&quot;);" class="tag">가상화폐</a>
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;\uBE44\uD2B8\uCF54\uC778&quot;);" class="tag">비트코인</a>
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;\uC774\uB354\uB9AC\uC6C0&quot;);" class="tag">이더리움</a>
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;\uBE14\uB85D\uCCB4\uC778&quot;);" class="tag">블록체인</a>
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;\uB525\uB7EC\uB2DD&quot;);" class="tag">딥러닝</a>
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;\uD150\uC11C\uD50C\uB85C&quot;);" class="tag">텐서플로</a>
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;\uD074\uB77C\uC6B0\uC2A4 \uC288\uBC25&quot;);" class="tag">클라우스 슈밥</a>
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;4\uCC28 \uC0B0\uC5C5\uD601\uBA85&quot;);" class="tag">4차 산업혁명</a>
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;\uD50C\uB7AB\uD3FC&quot;);" class="tag">플랫폼</a>
#
#                 <a href="javascript:void(0);" onclick="goSearchKeywordPage(&quot;\uC778\uACF5\uC9C0\uB2A5&quot;);" class="tag">인공지능</a>
#
#         </div>
#         <button type="button" class="btn_tag_more"><span class="hidden">더보기</span></button>
#     </div>
#
# <!-- // 연관검색어 -->
#
#     <!-- // 연관검색어 영역 -->
# </header>
# <!-- // 헤더 -->
#
#
#
#
#
#         <main class="container_wrapper">
#         <input type="hidden" id="targetHidden" value="kyobo"/>
#         <input type="hidden" id="upperTargetHidden" value=""/>
#         <input type="hidden" id="categoryIdHidden" value=""/>
#         <input type="hidden" id="categoryDepthHidden" value=""/>
#         <input type="hidden" id="suggestKeywordHidden"  value=""/>
#         <input type="hidden" id="pageNo" value="1"/>
#         <input type="hidden" id="loginAgeHidden"  value="0"/>
#         <input type="hidden" id="loginGenderHidden"  value="0"/>
#         <input type="hidden" id="loginMmbrNumHidden" value=""/>
#
#         <section id="contents" class="contents_wrap">
#
#
#
#     <!-- combinedBannerData 리스트를 순회 -->
#
#         <!-- 광고 배너 영역 -->
#
#
#             <div class="search_event">
#                 <div class="swiper-container paging_right">
#                     <ul class="swiper-wrapper">
#                         <li class="swiper-slide" data-type="모바일 키워드 배너"
#                             data-title="비즈그리다주식회사_ad"
#                             data-device-type="모바일"
#                             data-ad-id="72983"
#                             data-publisher-id="9866825"
#                             id="mobile-banner-5765-003">
#                             <a href="https://event.kyobobook.co.kr/today-mission?missionId=1756">
#                                 <img
#                                     fetchpriority="high"
#                                     loading="eager"
#                                     src="https://contents.kyobobook.co.kr/advrcntr/IMAC/creatives/2025/07/14/72983/6.png"
#                                     alt="비즈그리다주식회사_ad"
#                                     onclick="GA_ChangeTartgetNmMO(&#39;click_검색_MO&#39;, &#39;kyobo&#39;, &#39;&#39;, &#39;클릭_상단배너&#39;, &#39;비즈그리다주식회사_ad&#39;, &#39;인공지능&#39;);"/>
#                             </a>
#                         </li>
#                     </ul>
#                     <div class="swiper-pagination"></div>
#                 </div>
#             </div>
#
#         <!-- // 광고 배너 영역 -->
#
#
#
#
#             <!-- tab_wrap -->
#             <div class="tab_wrap" id="tab_wrap_div">
#                 <!-- tab_list_wrap -->
#                 <div class="tab_list_wrap">
#                     <ul class="tabs">
#                         <!-- DESC : 탭 비활성화 시, .tab_link 영역 tab_disabled class 추가 -->
#                         <li class="tab_item  has_data"><a href="#tabSearch" onclick="searchTabFilter(&#39;total&#39;,&#39;8103&#39;);" class="tab_link"><span class="tab_text">통합검색</span></a></li>
#                         <li class="tab_item ui-tabs-active has_data"><a href="#tabSearch" onclick="searchTabFilter(&#39;kyobo&#39;,&#39;4440&#39;);" class="tab_link"><span class="tab_text">교보문고</span></a></li>
#                         <li class="tab_item  has_data"><a href="#tabSearch" onclick="searchTabFilter(&#39;ebook&#39;,&#39;3635&#39;);" class="tab_link"><span class="tab_text">eBook</span></a></li>
#                         <li class="tab_item  has_data"><a href="#tabSearch" onclick="searchTabFilter(&#39;sam&#39;,&#39;2525&#39;);" class="tab_link"><span class="tab_text">sam</span></a></li>
#                         <li class="tab_item  has_data"><a href="#tabSearch" onclick="searchTabFilter(&#39;hottracks&#39;,&#39;28&#39;);" class="tab_link"><span class="tab_text">핫트랙스</span></a></li>
#                         <!-- 20230517 중고장터 종료
#                         <li class="tab_item" th:classappend="|${target == 'used' || upperTarget == 'used' ? 'ui-tabs-active' : ''} ${allTotalCount.used > 0 ? 'has_data' : ''}|"><a href="#tabSearch" th:onclick="|searchTabFilter('used','${allTotalCount.used}');|" class="tab_link" th:classappend="${allTotalCount.used == 0} ? 'tab_disabled'"><span class="tab_text">중고장터</span></a></li>
#                         -->
#                     </ul>
#                 </div>
#                 <!-- //tab_list_wrap -->
#
#                 <!-- tab_content -->
#                 <div id="tabSearch" class="tab_content">
#
#     <div class="list_result_wrap">
#         <div class="sps sps_scroll_fixed">
#             <div class="sps_inner">
#                 <p class="result_count"><b class="fc_green">4,440</b>건</p>
#                 <div class="right_area" id="shop_item_group">
#
#                         <div class="form_sel type_no_line">
#                             <select title="정렬 방식 선택" id="orderList">
#                                 <option value="" selected="selected" >인기순</option>
#                                 <option value="qntt">판매량순</option>
#                                 <option value="date">최신순</option>
#                                 <option value="name">상품명순</option>
#                                 <option value="dc">할인율순</option>
#                                 <option value="prasc">낮은가격순</option>
#                                 <option value="prdesc">높은가격순</option>
#                                 <option value="kcont">클로버리뷰순</option>
#                                 <option value="krvgr">클로버평점순</option>
#                             </select>
#                         </div>
#
#
#
#
#
#
#
#                         <!-- DESC : data-target 리스트형/썸네일형 제어되는 해당 상품 리스트 타겟지정 필요(#{tabid} .switch_prod_wrap) -->
#                         <div class="switch_list_btn_wrap type_toggle" data-target="#tabSearch .switch_prod_wrap">
#                             <button type="button" id="view_type_list_btn" class="btn_sm ico_list" data-type="img"><span class="hidden">리스트형 으로 보기</span></button><!-- 수정 220221 상품 토글버튼 기본 active 상태 변경, date-type 값 변경 -->
#                             <button type="button" id="view_type_img_btn" class="btn_sm ico_img active" data-type="list"><span class="hidden">이미지형 으로 보기</span></button> <!-- 수정 220221 상품 토글버튼 기본 active 상태 변경, date-type 값 변경 -->
#                         </div>
#
#                     <!-- DESC : 필터 활성화 시, active class 추가 -->
#                     <button type="button" class="btn_filter" id="mokSearchFilter" data-role="btn-dialog" data-target="#popSearchFilter">
#                         <span class="text">필터</span>
#                         <span class="count hidden" id="mokSearchFilterCount"></span>
#                     </button>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#
#     <!-- 추천 필터 -->
#
#     <div class="recommend_filter_wrap type_popular">
#         <div class="sps sps_scroll_fixed sps_add" data-add-offset="30">
#             <div class="sps_inner">
#                 <div class="selected_filter_box" id="recommend_category_filter_box">
#                     <span class="heading">추천</span>
#                     <ul class="selected_filter_list" id="recommend_category_filter_list">
#                         <li class="selected_filter" id="recommend_category_filter">
#                             <button type="button" class="btn_select_category" id="recommendCategory_0" value="KOR|국내도서@KORBOOK@@컴퓨터/IT@33|국내도서&gt;컴퓨터/IT">
#                                 <span class="category_name" >국내도서</span><span class="category_name" >컴퓨터/IT</span>
#                             </button>
#                         </li>
#                         <li class="selected_filter" id="recommend_category_filter">
#                             <button type="button" class="btn_select_category" id="recommendCategory_1" value="KOR|국내도서@KORBOOK@@인문@05|국내도서&gt;인문">
#                                 <span class="category_name" >국내도서</span><span class="category_name" >인문</span>
#                             </button>
#                         </li>
#                         <li class="selected_filter" id="recommend_category_filter">
#                             <button type="button" class="btn_select_category" id="recommendCategory_2" value="KOR|국내도서@KORBOOK@@경제/경영@13|국내도서&gt;경제/경영">
#                                 <span class="category_name" >국내도서</span><span class="category_name" >경제/경영</span>
#                             </button>
#                         </li>
#                     </ul>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- 추천 필터 -->
#
#
#
#             <!-- 상품 리스트형 / 썸네일형 -->
#
#
#                 <div class="switch_prod_wrap view_type_list view_spec_compare" id="shopData_list">
#     <!-- 수정 220406 통합검색 상품 현행화 페이지 적용. 전체 상품군은 SCR-BIZ03-04-P001 페이지 확인필요 -->
#     <ul class="prod_list prod_view_list">
#         <!-- 교보 리스트 영역 -->
#
#              <!--결합, 오픈마켓, POD 상품이 아닐때-->
#
#                 <!-- 교보 리스트 영역 -->
#
#     <li class="prod_item">
#
#             <!-- 체크박스 영역 -->
#             <span class="form_chk no_label spec_checkbox_span" style="display:none;">
#                 <input class="spec_checkbox" id="chkSearch_S000217120455" type="checkbox" data-pid="S000217120455" data-bid="9788955685329" data-name="인공지능입문" data-code="KOR"/>
#                 <label for="chkSearch_S000217120455"><span class="hidden">상품선택</span></label>
#             </span>
#             <!-- // 체크박스 영역 -->
#
#
#         <div class="prod_area horizontal">
#             <div class="prod_thumb_box">
#                 <a href="https://product.kyobobook.co.kr/detail/S000217120455" class="prod_link" onclick="searchResultItemClickEvent(&#39;상품 썸네일&#39;, &quot;S000217120455&quot;);">
#                     <span class="img_box">
#                         <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-pid="S000217120455" data-kbbfn-bid="9788955685329" data-kbbfn-type="KOR" data-kbbfn-attr="src" data-kbbfn-size="200x0" data-kbbfn-title="인공지능입문" data-kbbfn-adult="0"/>
#                     </span>
#                 </a>
#             </div>
#             <div class="prod_info_box">
#
#                     <!-- 라벨 -->
#                     <!-- 라벨 페이지 -->
# <div class="prod_badge">
#     <!--교보일때-->
#     <!--종이책, 컬쳐(유료), GIFT일때-->
#
#
#         <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <!--ebook/sam 일때-->
#
#
#
#
#
#
#     <!--핫트랙스일때-->
#
# </div>
#
#
#
#                 <!-- 상품명 -->
#                 <span class="prod_name_group">
#                     <a href="https://product.kyobobook.co.kr/detail/S000217120455" class="prod_info" onclick="searchResultItemClickEvent(&#39;상품 제목&#39;, &quot;S000217120455&quot;);">
#
#                             <span class="prod_category">[국내도서]</span>
#
#
#
#
#                         <span>인공지능입문</span>
#                     </a>
#                 </span>
#                 <!-- // 상품명 -->
#
#
#                     <!-- 상품 부제명 -->
#                     <div class="prod_desc_info">
#
#
#                     </div>
#                     <!-- // 상품 부제명 -->
#
#
#
#
#                 <!-- 저자, 출판사 정보 -->
#                 <div class="prod_author_group">
#
#                         <!--인물 페이지-->
#                         <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
#
#
#
#
#
#
#
#                         <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#
#                             <a href="javascript:void(0);" onclick="goClickSearchPage(&#39;chrc&#39;,&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);" class="author rep">손창호</a>
#
#
#
#
#
#                     <!--인물역할코드 페이지-->
#                     <span class="type">저자(글)</span>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <span class="gap"> | </span>
#
#
#
#
#
#
#
#
#
#
#                         <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#
#
#                             <a href="javascript:void(0);" onclick="goClickSearchPage(&#39;chrc&#39;,&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);" class="author">이은애</a>
#
#
#
#
#                     <!--인물역할코드 페이지-->
#                     <span class="type">저자(글)</span>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <span class="count">외</span>
#
#
#
#
#                             <span class="gap">|</span>
#
#                         <span class="publish" onclick="goClickSearchPage(&#39;pbcm&#39;,&quot;PB04390&quot;,&quot;\uC591\uC11C\uAC01&quot;);">양서각</span>
#
#                 </div>
#                 <!-- //저자/출판사정보  -->
#
#                 <!-- 금액, 리스트 타입 버튼영역 -->
#                 <div class="prod_price_control">
#                     <!--가격정보 페이지-->
#                     <!-- 가격정보 페이지 -->
#
#     <!--판매/예약중일떄-->
#
#         <!--교보일때-->
#         <!--종이책, 컬쳐(유료), GIFT일때-->
#
#
#                 <div class="prod_price">
#                     <span class="price">
#                         <span class="val">12,600</span>
#                         <span class="unit">원&nbsp;</span>
#                     </span>
#
#
#                             <span class="percent">10%</span>
#
#                         <span class="point">(700p)</span>
#
#                 </div>
#
#
#
#
#
#
#
#
#
#         <!--ebook/sam 일때-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <!--핫트랙스일때-->
#
#
#
#
#     <!--판매/예약중이 아닐떄-->
#
#
#
#
#
#
#
#
# <!--중고 장터일때-->
#
#
#
#                 </div>
#                 <!-- // 금액, 리스트 타입 버튼영역 -->
#
#                 <!-- 리뷰영역 -->
#                 <!-- 클로버 리뷰 페이지 -->
#
#
#
#     <a href="javascript:void(0);" class="review_summary_wrap"
#        onclick="goKloverReviewPage(
#        &quot;KOR&quot;,
#        &quot;S000217120455&quot;
#         );">
#         <span class="review_klover_box">
#             <span class="review_klover_text">0.0</span>
#         </span>
#
#
#
#     </a>
#
#
#                 <!-- //리뷰영역-->
#
#                 <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
#                     <!--바로드림 전용상품이 아닐경우-->
#
#                         <!-- 배송정보 영역 -->
#
#     <div class="prod_order_state">
#
#
#                 <div class="order_state_desc">
#
#
#
#                     <!--<span>지금 주문하면</span> -->
#                     <span class="fw_bold">7/31(목)</span>
#
#                         <span>출고예정</span>
#
#                     <button type="button" class="btn_tooltip_sm" id="btnTooltipDelivery">
#                         <span class="ico_info"></span>
#                         <span class="hidden">팝업 열기</span>
#                     </button>
#                 </div>
#
#
#     </div>
#
#
#                     <!-- // 배송정보 영역 -->
#                 <!--</th:block>-->
#
#                     <!-- 이벤트 정보 -->
#
#                     <!-- // 이벤트 정보 -->
#
#
#                 <div class="prod_price_control">
#                     <div class="right_box">
#                         <!--좋아요 버튼 정책 레이아웃-->
#                          <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#
#     <!--교보일때-->
#
#         <input id="searchWishItemInfo_S000217120455" type="hidden" name="001_001_S000217120455_searchWishItemNm" data-pid="S000217120455" data-bid="9788955685329" />
#         <button type="button" class="btn_wish_circle has_val" id="S000217120455_CMDTCODE_ICON" onclick="searchResultWishClickEvent(this, false, &quot;S000217120455&quot;);" data-cmdtcode="9788955685329"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#             <span class="val" id="S000217120455_CMDTCODE_VAL">0</span>
#         </button>
#
#
#
#
#
#
#
#
#
#
#
#     <!--ebook/sam일때-->
#
#
#
#
#
#
#     <!--핫트랙스일때-->
#
#
#
#
#
# <!--중고 장터일때-->
#
#
# <!--캐스팅일때-->
#
#
#                         <!--결제기능 버튼 정책 레이아웃-->
#                          <!--결제기능 버튼 정책 레이아웃-->
#
#     <!--교보일때-->
#
#         <!--판매중/예약중 일떄-->
#         <!--or-->
#         <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
#
#
#                 <button type="button" class="btn_cart_circle" onclick="searchResultCartClickEvent(false, &quot;S000217120455&quot;);"><span class="ico_cart"></span><span class="hidden">장바구니 담기</span></button>
#
#
#
#
#
#
#     <!--ebook/sam일때-->
#
#
#
#
#
#     <!--핫트랙스일때-->
#     <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
#
#
#
#
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </li>
#
#
#                 <!-- // 교보 리스트 영역 -->
#
#
#             <!--결합, 오픈마켓, POD, FUD 상품일때-->
#
#
#              <!--결합, 오픈마켓, POD 상품이 아닐때-->
#
#                 <!-- 교보 리스트 영역 -->
#
#     <li class="prod_item">
#
#             <!-- 체크박스 영역 -->
#             <span class="form_chk no_label spec_checkbox_span" style="display:none;">
#                 <input class="spec_checkbox" id="chkSearch_S000217098239" type="checkbox" data-pid="S000217098239" data-bid="9791143007131" data-name="인공지능과 죽음" data-code="KOR"/>
#                 <label for="chkSearch_S000217098239"><span class="hidden">상품선택</span></label>
#             </span>
#             <!-- // 체크박스 영역 -->
#
#
#         <div class="prod_area horizontal">
#             <div class="prod_thumb_box">
#                 <a href="https://product.kyobobook.co.kr/detail/S000217098239" class="prod_link" onclick="searchResultItemClickEvent(&#39;상품 썸네일&#39;, &quot;S000217098239&quot;);">
#                     <span class="img_box">
#                         <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-pid="S000217098239" data-kbbfn-bid="9791143007131" data-kbbfn-type="KOR" data-kbbfn-attr="src" data-kbbfn-size="200x0" data-kbbfn-title="인공지능과 죽음" data-kbbfn-adult="0"/>
#                     </span>
#                 </a>
#             </div>
#             <div class="prod_info_box">
#
#                     <!-- 라벨 -->
#                     <!-- 라벨 페이지 -->
# <div class="prod_badge">
#     <!--교보일때-->
#     <!--종이책, 컬쳐(유료), GIFT일때-->
#
#
#         <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <!--ebook/sam 일때-->
#
#
#
#
#
#
#     <!--핫트랙스일때-->
#
# </div>
#
#
#
#                 <!-- 상품명 -->
#                 <span class="prod_name_group">
#                     <a href="https://product.kyobobook.co.kr/detail/S000217098239" class="prod_info" onclick="searchResultItemClickEvent(&#39;상품 제목&#39;, &quot;S000217098239&quot;);">
#
#                             <span class="prod_category">[국내도서]</span>
#
#
#
#
#                         <span>인공지능과 죽음</span>
#                     </a>
#                 </span>
#                 <!-- // 상품명 -->
#
#
#                     <!-- 상품 부제명 -->
#                     <div class="prod_desc_info">
#
# 	                		<span class="prod_desc">(인공지능총서)</span>
#
#
#                     </div>
#                     <!-- // 상품 부제명 -->
#
#
#
#
#                 <!-- 저자, 출판사 정보 -->
#                 <div class="prod_author_group">
#
#                         <!--인물 페이지-->
#                         <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
#
#
#
#
#
#
#                         <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#
#                             <a href="javascript:void(0);" onclick="goClickSearchPage(&#39;chrc&#39;,&quot;1001367001&quot;,&quot;\uC2EC\uD601\uC8FC&quot;);" class="author rep">심혁주</a>
#
#
#
#
#
#
#                     <!--인물역할코드 페이지-->
#                     <span class="type">저자(글)</span>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             <span class="gap">|</span>
#
#                         <span class="publish" onclick="goClickSearchPage(&#39;pbcm&#39;,&quot;PB09525&quot;,&quot;\uCEE4\uBBA4\uB2C8\uCF00\uC774\uC158\uBD81\uC2A4&quot;);">커뮤니케이션북스</span>
#
#                 </div>
#                 <!-- //저자/출판사정보  -->
#
#                 <!-- 금액, 리스트 타입 버튼영역 -->
#                 <div class="prod_price_control">
#                     <!--가격정보 페이지-->
#                     <!-- 가격정보 페이지 -->
#
#     <!--판매/예약중일떄-->
#
#         <!--교보일때-->
#         <!--종이책, 컬쳐(유료), GIFT일때-->
#
#
#                 <div class="prod_price">
#                     <span class="price">
#                         <span class="val">10,800</span>
#                         <span class="unit">원&nbsp;</span>
#                     </span>
#
#
#                             <span class="percent">10%</span>
#
#                         <span class="point">(600p)</span>
#
#                 </div>
#
#
#
#
#
#
#
#
#
#         <!--ebook/sam 일때-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <!--핫트랙스일때-->
#
#
#
#
#     <!--판매/예약중이 아닐떄-->
#
#
#
#
#
#
#
#
# <!--중고 장터일때-->
#
#
#
#                 </div>
#                 <!-- // 금액, 리스트 타입 버튼영역 -->
#
#                 <!-- 리뷰영역 -->
#                 <!-- 클로버 리뷰 페이지 -->
#
#
#
#     <a href="javascript:void(0);" class="review_summary_wrap"
#        onclick="goKloverReviewPage(
#        &quot;KOR&quot;,
#        &quot;S000217098239&quot;
#         );">
#         <span class="review_klover_box">
#             <span class="review_klover_text">0.0</span>
#         </span>
#
#
#
#     </a>
#
#
#                 <!-- //리뷰영역-->
#
#                 <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
#                     <!--바로드림 전용상품이 아닐경우-->
#
#                         <!-- 배송정보 영역 -->
#
#     <div class="prod_order_state">
#
#
#                 <div class="order_state_desc">
#
#
#
#                     <!--<span>지금 주문하면</span> -->
#                     <span class="fw_bold">7/29(화)</span>
#
#                         <span>출고예정</span>
#
#                     <button type="button" class="btn_tooltip_sm" id="btnTooltipDelivery">
# ...
#          <li class="main_menu_item"><a target="_blank" href="https://sam.kyobobook.co.kr/dig/sam/bkmrintro">북모닝소개</a></li>
#          <li class="main_menu_item"><a target="_blank" href="https://sam.kyobobook.co.kr/dig/sam/pssbuy">이용권 구매</a></li>
#         </ul>
#        </div>
#       </div>
#       <div class="title_wrap title_size_def">
#        <a target="_blank" class="btn_arw_link" href="https://storynew.kyobobook.co.kr/"><p class="title_heading">스토리</p></a>
#       </div>
#       <div class="main_menu_box">
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="_blank" href="https://storynew.kyobobook.co.kr/story/pof/initStoryIpBookList.ink">포트폴리오</a></li>
#          <li class="main_menu_item"><a target="_blank" href="https://storynew.kyobobook.co.kr/story/cont/initStoryContStoryPros.ink">스토리공모전</a></li>
#          <li class="main_menu_item"><a target="_blank" href="https://storynew.kyobobook.co.kr/story/up/initStoryUpProsView.ink">테마공모전</a></li>
#          <li class="main_menu_item"><a target="_blank" href="https://storynew.kyobobook.co.kr/story/smkt/initStorySmktBookList.ink">스토리마켓</a></li>
#         </ul>
#        </div>
#       </div>
#       <div class="title_wrap title_size_def">
#        <a target="" class="btn_arw_link" href="https://mmbr.kyobobook.co.kr/benefit"><p class="title_heading">회원혜택</p></a>
#       </div>
#       <div class="main_menu_box">
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="" href="https://mmbr.kyobobook.co.kr/benefit">교보북클럽</a></li>
#          <li class="main_menu_item"><a target="" href="https://mmbr.kyobobook.co.kr/benefit/grade">등급 혜택</a></li>
#          <li class="main_menu_item"><a target="" href="https://mmbr.kyobobook.co.kr/benefit/new">신규회원 혜택</a></li>
#          <li class="main_menu_item"><a target="" href="https://mmbr.kyobobook.co.kr/benefit/prestige">Prestige Lounge</a></li>
#         </ul>
#        </div>
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="" href="https://mmbr.kyobobook.co.kr/benefit/discount">제휴 혜택</a></li>
#         </ul>
#        </div>
#       </div>
#       <div class="title_wrap title_size_def">
#        <a target="" class="btn_arw_link" href="https://www.kyobobook.co.kr/cscenter"><p class="title_heading">고객센터</p></a>
#       </div>
#       <div class="main_menu_box">
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="" href="https://www.kyobobook.co.kr/cscenter/faq">자주묻는질문</a></li>
#          <li class="main_menu_item"><a target="" href="https://www.kyobobook.co.kr/cscenter/qna-form">1:1문의</a></li>
#          <li class="main_menu_item"><a target="" href="https://www.kyobobook.co.kr/cscenter/notice">공지사항</a></li>
#          <li class="main_menu_item"><a target="" href="https://www.kyobobook.co.kr/cscenter/contact">전화상담 안내도</a></li>
#         </ul>
#        </div>
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="" href="https://big.kyobobook.co.kr/">법인회원 대량주문</a></li>
#         </ul>
#        </div>
#       </div>
#       <div class="title_wrap title_size_def">
#        <a target="" class="btn_arw_link" href="https://my.kyobobook.co.kr/"><p class="title_heading">마이</p></a>
#       </div>
#       <div class="main_menu_box">
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="" href="https://order.kyobobook.co.kr/myroom/member/order-list">주문/배송목록</a></li>
#          <li class="main_menu_item"><a target="" href="https://order.kyobobook.co.kr/myroom/member/gift-detail">선물함</a></li>
#          <li class="main_menu_item"><a target="" href="https://my.kyobobook.co.kr/activity/community">활동내역</a></li>
#          <li class="main_menu_item"><a target="" href="https://order.kyobobook.co.kr/myroom/member/offline-list">매장 구매 내역</a></li>
#         </ul>
#        </div>
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="" href="https://order.kyobobook.co.kr/myroom/member/receipt">영수증 조회/후 적립</a></li>
#          <li class="main_menu_item"><a target="" href="https://mmbr.kyobobook.co.kr/member-info">회원정보</a></li>
#          <li class="main_menu_item"><a target="" href="https://my.kyobobook.co.kr/notice">알림센터</a></li>
#          <li class="main_menu_item"><a target="" href="https://order.kyobobook.co.kr/myroom/benefit/point">나의 통장</a></li>
#         </ul>
#        </div>
#       </div>
#       <div class="title_wrap title_size_def">
#        <a target="" class="btn_arw_link" href="https://my.kyobobook.co.kr/library"><p class="title_heading">라이브러리</p></a>
#       </div>
#       <div class="main_menu_box">
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="" href="https://my.kyobobook.co.kr/library/list">리스트</a></li>
#          <li class="main_menu_item"><a target="" href="https://my.kyobobook.co.kr/library/comment">코멘트</a></li>
#          <li class="main_menu_item"><a target="" href="https://my.kyobobook.co.kr/library/review">Klover리뷰</a></li>
#          <li class="main_menu_item"><a target="" href="https://my.kyobobook.co.kr/library/sentences">문장수집</a></li>
#         </ul>
#        </div>
#       </div>
#       <div class="title_wrap title_size_def">
#        <a target="" class="btn_arw_link" href="https://store.kyobobook.co.kr/store-info/001"><p class="title_heading">매장안내</p></a>
#       </div>
#       <div class="main_menu_box">
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="_blank" href="https://moonbojang.hottracks.co.kr/frContentCon/brandIntro.do"><em>문보장</em></a></li>
#         </ul>
#        </div>
#       </div>
#       <div class="title_wrap title_size_def">
#        <a target="_blank" class="btn_arw_link" href="https://company.kyobobook.co.kr/ims/user/Intro/r/go?param=intro"><p class="title_heading">회사소개</p></a>
#       </div>
#       <div class="main_menu_box">
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="_blank" href="https://company.kyobobook.co.kr/ims/user/Intro/r/go?param=intro">교보문고 소개</a></li>
#          <li class="main_menu_item"><a target="_blank" href="https://company.kyobobook.co.kr/ims/user/Intro/r/go?param=nowkyobo">사업현황</a></li>
#          <li class="main_menu_item"><a target="_blank" href="https://company.kyobobook.co.kr/ims/user/Intro/r/go?param=son">사회공헌</a></li>
#          <li class="main_menu_item"><a target="_blank" href="https://ehr.kyobobook.co.kr/recr/recruit_info_1.jsp">채용정보</a></li>
#         </ul>
#        </div>
#       </div>
#       <div class="title_wrap title_size_def">
#        <p class="title_heading">협력사여러분</p>
#       </div>
#       <div class="main_menu_box">
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="" href="https://www.kyobobook.co.kr/partners/chargeperson">협력사여러분</a></li>
#          <li class="main_menu_item"><a target="" href="https://www.kyobobook.co.kr/partners/suggest">제휴/제안</a></li>
#          <li class="main_menu_item"><a target="_blank" href="https://ad.kyobobook.co.kr">애드북</a></li>
#          <li class="main_menu_item"><a target="_blank" href="https://scm.kyobobook.co.kr/scm/login.action">협력사네트워크</a></li>
#         </ul>
#        </div>
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="_blank" href="https://partner.kyobobook.co.kr">CP관리시스템</a></li>
#         </ul>
#        </div>
#       </div>
#       <div class="title_wrap title_size_def">
#        <p class="title_heading">기타</p>
#       </div>
#       <div class="main_menu_box">
#        <div class="main_menu_col">
#         <ul class="main_menu_list">
#          <li class="main_menu_item"><a target="" href="https://www.kyobobook.co.kr/policy">이용약관</a></li>
#          <li class="main_menu_item"><a target="" href="https://www.kyobobook.co.kr/policy/privacy">개인정보처리방침</a></li>
#          <li class="main_menu_item"><a target="" href="https://www.kyobobook.co.kr/policy/youthpolicy">청소년보호정책</a></li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div id="tabMainMenuFavorite" class="tab_content">
#       <div class="contents_inner">
#        <div class="tab_wrap type_tag">
#         <div class="tab_list_wrap">
#          <ul class="tabs">
#           <li class="tab_item"><a href="#tabFavoriteCategory" class="tab_link"><span class="tab_text">즐겨찾는 카테고리</span></a></li>
#           <li class="tab_item"><a href="#tabFavoriteService" class="tab_link"><span class="tab_text">즐겨찾는 서비스</span></a></li>
#          </ul>
#         </div>
#         <div id="tabFavoriteCategory" class="tab_content tab_favorite"></div>
#         <div id="tabFavoriteService" class="tab_content tab_favorite"></div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="title_wrap title_size_lg">
#     <p class="title_heading">주요 서비스</p>
#    </div>
#    <div class="service_swiper_wrap">
#     <div class="swiper-container">
#      <ul class="service_list swiper-wrapper">
#       <li class="service_item swiper-slide"><a target="_self" class="service_link" href="https://www.kyobobook.co.kr/barodrim"><img loading="lazy" src="https://contents.kyobobook.co.kr/display/pc_icon_8d7a3306ef6045cdb406881a63b4d6a9.png" alt="바로드림"><p class="service_name">바로드림</p></a></li>
#       <li class="service_item swiper-slide"><a target="_self" class="service_link" href="https://product.kyobobook.co.kr/today-book"><img loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 1_017c321f59504c6f995c5c4c90bcd382.jpg" alt="오늘의 선택"><p class="service_name">오늘의 선택</p></a></li>
#       <li class="service_item swiper-slide"><a target="_self" class="service_link" href="https://store.kyobobook.co.kr/person"><img loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 4_dea56a082097433c80a6491aca4fcad6.jpg" alt="인물&amp;작품"><p class="service_name">인물&amp;작품</p></a></li>
#       <li class="service_item swiper-slide"><a target="_self" class="service_link" href="https://www.kyobobook.co.kr/gift"><img loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 5_6f76bd72614f4a24a89d905386b32c84.jpg" alt="선물하기"><p class="service_name">선물하기</p></a></li>
#       <li class="service_item swiper-slide"><a target="_self" class="service_link" href="https://www.kyobobook.co.kr/best-review"><img loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 6_a0981652bec94c7094de142a9440c909.jpg" alt="베스트리뷰"><p class="service_name">베스트리뷰</p></a></li>
#       <li class="service_item swiper-slide"><a target="_self" class="service_link" href="https://store.kyobobook.co.kr/handwriting/contest"><img loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 7_bd7dd305777e46b0b914490a234ec720.jpg" alt="손글씨캠페인"><p class="service_name">손글씨캠페인</p></a></li>
#       <li class="service_item swiper-slide"><a target="_self" class="service_link" href="https://store.kyobobook.co.kr/culture"><img loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 8_ead7c54f641e45fca4bf7bb27330f4c3.jpg" alt="문화공간"><p class="service_name">문화공간</p></a></li>
#       <li class="service_item swiper-slide"><a target="_self" class="service_link" href="https://product.kyobobook.co.kr/pod/main"><img loading="lazy" src="https://contents.kyobobook.co.kr/display/바로출판_POD_1bd71e6c18bd47e0b23bc2e4da998cd4.png" alt="바로출판"><p class="service_name">바로출판</p></a></li>
#      </ul>
#     </div>
#    </div>
#    <div class="contents_gap_area gab_menu_util">
#     <div class="contents_inner">
#      <ul class="main_util_menu_list">
#       <li class="util_menu_item"><a class="util_menu_link" href="https://www.kyobobook.co.kr/cscenter">고객센터</a></li>
#       <li class="util_menu_item"><a class="util_menu_link" href="https://store.kyobobook.co.kr/store-info">매장안내</a></li>
#       <li class="util_menu_item"><a class="util_menu_link" href="https://my.kyobobook.co.kr/app/config">설정</a></li>
#      </ul>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/react-bundle.min.js" data-name="react-bundle"></script>
#
#
#
# <!-- NetFUNNEL 스크립트 -->
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/netfunnel/custom-netfunnel.js" data-name="netfunnel"></script>
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/css-element-queries/ResizeSensor.js" data-name="ResizeSensor"></script>
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/awesomplete/awesomplete.min.js" data-name="awesomplete"></script>
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.recent.js?t=202507231211" data-name="kbb.recent.js"></script>
#
#
#
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/scrollpos-styler/scrollPosStyler.min.js" data-name="scrollPosStyler"></script>
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/blurify-master/blurify.min.js" data-name="blurify"></script>
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/masonry/masonry.pkgd.min.js" data-name="masonry"></script>
#
#
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-touch-punch/jquery.ui.touch-punch.min.js"></script>
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/swiper/v7/swiper-bundle.min.js" data-name="swiper"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/ui_mok.js?t=202507231211" data-name="kbb-cm-script"></script>
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="/assets/js/vars.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/common/js/kyobo_search_review.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/mobile/js/mok_kyobo_search_filter.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/mobile/js/mok_kyobo_search_spec.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/common/js/kyobo_search_gtm.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/common/js/kyobo_search_click_event.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/common/js/kyobo_search_lazy.js?t=202507231211"></script>
#
#
#
#
#
#
#         <!-- /* 큐봇(cubot) 스크립트 삽입 */-->
#
#     <script>
#         const maxAttempts = 12;
#         const attemptInterval = 5000; // 5초
#
#         function initializeCuBotWidgetAsync(page) {
#             return new Promise((resolve, reject) => {
#                 let attempts = 0;
#
#                 function tryInitialize() {
#                     if (window.initializeCubotWidget) {
#                         window.initializeCubotWidget({page: page});
#                         resolve();
#                     } else if (attempts < maxAttempts) {
#                         setTimeout(tryInitialize, attemptInterval);
#                         attempts++;
#                     } else {
#                         reject();
#                     }
#                 }
#
#                 tryInitialize();
#             });
#         }
#
#         document.addEventListener('DOMContentLoaded', () => {
#             initializeCuBotWidgetAsync("search")
#                 .then(() => console.log('CuBot Widget initialized successfully'));
#         });
#     </script>
#
#
#
#
#
# </body>
# </html>

# %% [markdown]
# ## 2) HTML 파싱 준비하기

# %%
from bs4 import BeautifulSoup

html = response.text
soup = BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html>
# <html data-service="search" data-view="mok" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="인공지능 검색결과 | 교보문고" name="title"/>
# <meta content="인공지능 검색결과 | 교보문고" property="og:title"/>
# <meta content="꿈을 키우는 세상 교보문고는 온오프라인을 통틀어 대한민국 최고의 도서쇼핑몰이며 전자책, 음반, 기프트, 문화서비스까지 제공하는 종합문화기업입니다." name="description"/>
# <meta content="꿈을 키우는 세상 교보문고는 온오프라인을 통틀어 대한민국 최고의 도서쇼핑몰이며 전자책, 음반, 기프트, 문화서비스까지 제공하는 종합문화기업입니다." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo@2x.png" property="og:image"/>
# <meta content="http://mobile.kyobobook.co.kr" property="og:url"/>
# <meta content="date=no" name="format-detection"/>
# <meta content="2dlgBOp3K0s6wHjZo_Hkas6yaYPKZIVsmres9vC3F34" name="google-site-verification"/>
# <meta content="vN9Zag6odZ4sMyJfDMMSZTqbD-nbmnh0ituV4pk4FV4" name="google-site-verification"/>
# <meta content="AHqpy7PvqPoZwSySpolatuTj8M3B9F10Pi6UCldP5hE" name="google-site-verification"/>
# <meta content="ezckujv1qppxlglsp8fsry2bs2cw0n" name="facebook-domain-verification"/>
# <meta content="bef3d190b10f8cada477f5531d206cc1a799c498" name="naver-site-verification"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_256x256.png" rel="icon" sizes="256x256" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_196x196.png" rel="icon" sizes="196x196" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_128x128.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_48x48.png" rel="icon" sizes="48x48" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/favicon_16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <meta content="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-144x144-precomposed.png" name="msapplication-TileImage"/>
# <meta content="#222222" name="msapplication-TileColor"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-700x700-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="700x700"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-180x180-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="180x180"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-167x167-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="167x167"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="152x152"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="144x144"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="120x120"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="114x114"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-80x80-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="80x80"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="72x72"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="60x60"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/favicon/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon-precomposed"/>
# <title>인공지능 검색결과 | 교보문고</title>
# <link href="https://fonts.googleapis.com/css2?family=Noto+Sans+KR:wght@400;500;700&amp;family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery-ui.min.css" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/vendors/swiper/v7/swiper-bundle.min.css" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/css/loading.css" rel="stylesheet"/>
# <link data-name="kbb-cm-style" href="https://contents.kyobobook.co.kr/resources/fo/css/style_mok.css?t=202507231211" rel="stylesheet" type="text/css"/>
# <script src="https://contents.kyobobook.co.kr/resources/vendors/essential-vendors.min.js"></script>
# <script data-name="jquery-ui" src="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery-ui.min.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery.ui.spinner.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/vendors/lottie-5.9.4/lottie.min.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-loading.js?t=202507231211" type="text/javascript"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/kbbjs-loader-v2.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb.js" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb.shared.js" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.shared.js?t=202507231211" type="text/javascript"></script>
# <script src="/mobile/js/mok_kyobo_search_auto.js?t=202507231211" type="text/javascript"></script>
# <script>
#     // IIFE
#     ;(function () {
#         // --------------------- [KbbJS/SSR] 서버 환경변수 전달
#         const CDN_URL = "https:\/\/contents.kyobobook.co.kr\/resources\/fo"
#
#         const tmpArr = CDN_URL.match(/((https?:)?\/\/[^/]+)(\/.*)/)
#         const cdnHost = tmpArr[1]
#         const cdnBaseURL = tmpArr[3]
#
#         KbbJS.setOption('service.cdn.host', cdnHost)
#         KbbJS.setOption('service.cdn.baseURL', cdnBaseURL)
#
#         /**
#          * KbbJS 라이브러리 경로 설정
#          */
#         let KbbjsURL = "\/lib\/kbb-js"
#         if (!/^(https?:|\/\/)/.test(KbbjsURL)) {
#             KbbjsURL = CDN_URL + KbbjsURL
#         }
#
#         const KBBJS_VER = "v2.0\/latest"
#         if (KBBJS_VER != null) {
#             KbbjsURL += '/' + KBBJS_VER
#         } else {
#             KbbjsURL = "https:\/\/search.kyobobook.co.kr\/lib\/kbb-js"
#         }
#
#         // KbbJS 배포 개선 작업 1차 - 속성 추가
#         KbbJS.setOption('loader.bootstamp', "202507231211")
#         KbbJS.setOption('loader.baseURL', KbbjsURL)
#
#         // 인증여부 속성 추가
#         KbbJS.setOption('loader.authorized', false)
#         KbbJS.setOption('loader.user.nickname', null)
#         KbbJS.setOption('loader.user.picture', null)
#
#         // 디바이스 정보 설정
#         KbbJS.setOption('ua.device', {
#             isMobile: true,
#             isMobileApp: false,
#             isIOS: false,
#             isAndroid: true,
#             isMSIE: false,
#             isMac: false
#         })
#
#         /**
#          * 서비스 호스트 설정
#          */
#         const oServiceData = {"hosts":{"ebook-product":"https:\/\/ebook-product.kyobobook.co.kr","semo":"https:\/\/semo.kyobobook.co.kr","product":"https:\/\/product.kyobobook.co.kr","ecash":"https:\/\/ecash.kyobobook.co.kr","elibrary":"https:\/\/elibrary.kyobobook.co.kr","best":"https:\/\/best.kyobobook.co.kr","bookcast":"https:\/\/casting.kyobobook.co.kr","store":null,"undefined":null,"search":"https:\/\/search.kyobobook.co.kr","ebook":"https:\/\/ebook.kyobobook.co.kr","member":"https:\/\/mmbr.kyobobook.co.kr","myroom":"https:\/\/my.kyobobook.co.kr","event":"https:\/\/event.kyobobook.co.kr","welcome":"https:\/\/www.kyobobook.co.kr","hottracks":"https:\/\/hottracks.kyobobook.co.kr\/","sam":"https:\/\/sam.kyobobook.co.kr","order":"https:\/\/order.kyobobook.co.kr"}}
#         const oServiceHosts = _.get(oServiceData, 'hosts', {})
#         _.forEach(_.keys(oServiceHosts), function (key) {
#             let prop = key
#             switch (key.toLowerCase()) {
#                 case 'ebookproduct':
#                 case 'ebook-product':
#                     prop = 'ebookProduct';
#                     break
#                 case 'elibrary':
#                     prop = 'eLibrary'
#                     break
#             }
#             let value = _.get(oServiceHosts, key)
#             if (value == null) {
#                 // 기본 호스트 설정
#                 switch (key.toLowerCase()) {
#                     case 'welcome': value = 'www'; break
#                     case 'myroom': value = 'my'; break
#                     case 'bookcast': value = 'casting'; break
#                     case 'member': value = 'mmbr'; break
#                     case 'ebookproduct':
#                     case 'ebook-product':
#                         value = 'ebook-product'
#                         break
#                     case 'elibrary':
#                         value = 'elibrary'
#                         break
#                     case 'product':
#                     case 'event':
#                     case 'order':
#                     case 'search':
#                     case 'best':
#                     case 'ebook':
#                     case 'sam':
#                     case 'store':
#                     case 'ecash':
#                         value = prop
#                         break
#                 }
#                 if (value == null) return
#                 value = 'https://' + value + '.kyobobook.co.kr'
#             }
#             KbbJS.setOption('service.' + prop + '.host', value)
#         })
#     }())
# </script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-netfunnel.js?t=202507231211" type="text/javascript"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/common-vars.js?t=202507231211" type="text/javascript"></script>
# <script data-name="vars.common" src="https://contents.kyobobook.co.kr/resources/fo/js/vars/common.js?t=202507231211" type="text/javascript"></script>
# <script data-name="vars.service" src="https://contents.kyobobook.co.kr/resources/fo/js/vars/paper.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb.stats.js" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.stats.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb.gautil.js" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.gautil.js?t=202507231211" type="text/javascript"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/ga360/common-vars.js?t=202507231211" type="text/javascript"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/ga360/util.js?t=202507231211" type="text/javascript"></script>
# <script src="/mobile/js/mok_kyobo_search_common.js?t=202507231211" type="text/javascript"></script>
# <!-- /* 큐봇(cubot) 초기화 */-->
# <script defer="" src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-cubot-loader.js?t=1753328043245" type="text/javascript"></script>
# <script data-name="kbb-vendors.min.js" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/vendors.min.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb-shared.min.js" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/shared.min.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb-components.min.js" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/components.min.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb-core.min.js" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/core.min.js?t=202507231211" type="text/javascript"></script>
# </head>
# <body>
# <div class="loading_box show" id="KbbLoading">
# <div class="loading_box_inner">
# <div class="loading_target"></div>
# </div>
# <div class="loading_dimmed"></div>
# </div>
# <div class="skip_nav_wrap">
# <a href="#contents">본문 바로가기</a>
# </div>
# <div class="wrapper contents_search_result" id="mainDiv">
# <!--
#             - 2024.02.05 PC인 경우 통합 GNB로 변경
#             - #TODO 모바일 통합 GNB 적용
#             -->
# <!-- 헤더 -->
# <header class="header_wrapper header_main">
# <!--  앱 전환 유도 배너 임시 주석처리  -->
# <!--    <th:block th:insert="~{view/mok/include/mok_searchAppBanner}"></th:block>-->
# <div class="header_top_wrap">
# <div class="logo_box">
# <!--<a th:href="${@utils.parseStageURL('/ONK/')}" class="logo_link" th:insert="~{:: ${@utils.getStr(logoPosition, 'header')}(alt='KYOBO 교보문고')}"></a>-->
# <a class="logo_link" href="https://www.kyobobook.co.kr/">
# <img alt="KYOBO 교보문고" src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_logo_kyobo_mok@2x.png"/>
# </a>
# </div>
# <div class="service_mall_wrap">
# <div class="service_mall_inner">
# <ul class="service_mall_list">
# <li class="service_mall_item tab ebook">
# <a class="service_mall_link" href="https://ebook.kyobobook.co.kr/" onclick="ga360.GA_Event('click_공통_MO', '헤더', '', 'eBook', '');">eBook</a>
# </li>
# <li class="service_mall_item tab sam">
# <a class="service_mall_link" href="https://sam.kyobobook.co.kr/" onclick="ga360.GA_Event('click_공통_MO', '헤더', '', 'sam', '');">sam</a>
# </li>
# <li class="service_mall_item tab hottracks">
# <a class="service_mall_link" href="https://mhottracks.kyobobook.co.kr/" onclick="ga360.GA_Event('click_공통_MO', '헤더', '', '핫트랙스', '');">핫트랙스</a>
# </li>
# <li class="service_mall_item tab link">
# <a class="service_mall_link" href="https://storynew.kyobobook.co.kr/story/main/initMain.ink" id="service_mal_story" onclick="ga360.GA_Event('click_공통_MO', '헤더', '', '스토리', '');">스토리</a>
# </li>
# </ul>
# </div>
# <button class="btn_brand_more" type="button">
# <span class="hidden">브랜드 더보기</span>
# </button>
# <div class="brand_more_list_box">
# <div class="custom_scroll_wrap">
# <ul class="brand_more_list">
# <li class="brand_more_item">
# <a class="brand_more_link" href="https://www.kyobobook.co.kr/">
# <span class="img_box">
# <img alt="교보문고 BI" loading="lazy" src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_kyobo_mok.png"/>
# </span>
# <span class="brand_name">교보문고</span>
# </a>
# </li><li class="brand_more_item">
# <a class="brand_more_link" href="https://ebook.kyobobook.co.kr/">
# <span class="img_box">
# <img alt="교보문고 eBook BI" loading="lazy" src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_ebook_mok.png"/>
# </span>
# <span class="brand_name">eBook</span>
# </a>
# </li><li class="brand_more_item">
# <a class="brand_more_link" href="https://sam.kyobobook.co.kr/">
# <span class="img_box">
# <img alt="교보문고 sam BI" loading="lazy" src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_sam_mok.png"/>
# </span>
# <span class="brand_name">sam</span>
# </a>
# </li><li class="brand_more_item">
# <a class="brand_more_link" href="https://mhottracks.kyobobook.co.kr/m/welcomeMain">
# <span class="img_box">
# <img alt="핫트랙스 BI" loading="lazy" src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_hot_tracks_mok.png"/>
# </span>
# <span class="brand_name">핫트랙스</span>
# </a>
# </li><li class="brand_more_item">
# <a class="brand_more_link" href="https://www.kyobobook.co.kr/store">
# <span class="img_box">
# <img alt="매장안내 BI" loading="lazy" src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_store_mok.png"/>
# </span>
# <span class="brand_name">매장안내</span>
# </a>
# </li><li class="brand_more_item">
# <a class="brand_more_link" href="https://storynew.kyobobook.co.kr/story/main/initMain.ink" target="_blank">
# <span class="img_box">
# <img alt="스토리 BI" loading="lazy" src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_story_mok@2x.png"/>
# </span>
# <span class="brand_name">스토리</span>
# </a>
# </li><li class="brand_more_item">
# <a class="brand_more_link" href="https://product.kyobobook.co.kr/pod/main">
# <span class="img_box">
# <img alt="바로출판 BI" loading="lazy" src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_pod_mok@2x.png"/>
# </span>
# <span class="brand_name">바로출판</span>
# </a>
# </li><li class="brand_more_item">
# <a class="brand_more_link" href="https://wv4wthajb0i8pj89j0pigw.adtouch.adbrix.io/api/v1/click/LmEQQEQbqUeTaf0gSEpSJw?adv_campaign=2312_web_traffic&amp;adv_ad=kyobo_brand_list&amp;adv_adgroup=none&amp;adv_creative=brand_name" target="_blank">
# <span class="img_box">
# <img alt="리드로그 BI" loading="lazy" src="https://contents.kyobobook.co.kr/resources/fo/images/common/mok/img_brand_more_readlog_mok@2x.png"/>
# </span>
# <span class="brand_name">리드로그</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="gnb_search_wrap">
# <div class="gnb_search_box">
# <div class="search_input_wrap">
# <input class="ip_gnb_search" id="searchMainKeyword" placeholder="" title="통합검색어 입력" type="search" value="인공지능"/>
# <input id="searchBoxEventurl" name="searchBoxEventurl" type="hidden" value=""/>
# <script>
#                         jQuery(function () {
#                             jQuery.getJSON('/api/adv?url=/mobile/mok_wel_new/mobile_welcome@mo_3?callback=', function (data) {
#                                 var search_placeholder_txt = document.createElement('textarea');
#                                 search_placeholder_txt.innerHTML = data[0].text;
#                                 $(".ip_gnb_search").attr("placeholder", search_placeholder_txt.value);
#                                 $('#searchBoxEventurl').val(data[0].linkUrl);
#
#                                 setGtmForPlaceholder(data);
#                             });
#                         });
#                     </script>
# <button class="btn_ip_clear" type="button"><span class="hidden">초기화</span></button>
# </div>
# <a class="btn_gnb_search" href="#"><span class="hidden"></span></a>
# </div>
# <a class="btn_header_cart" href="https://order.kyobobook.co.kr/cart">
# <span class="hidden">장바구니</span>
# <span class="count" data-kbbfn="cart-size" style="display:none;"></span>
# </a>
# </div>
# <!-- 연관검색어 영역 -->
# <!-- 연관검색어 -->
# <div class="related_keyword_wrap">
# <span class="text">연관</span>
# <div class="tag_wrap size_sm scroll">
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("\uBA38\uC2E0\uB7EC\uB2DD");'>머신러닝</a>
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("\uAC00\uC0C1\uD654\uD3D0");'>가상화폐</a>
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("\uBE44\uD2B8\uCF54\uC778");'>비트코인</a>
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("\uC774\uB354\uB9AC\uC6C0");'>이더리움</a>
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("\uBE14\uB85D\uCCB4\uC778");'>블록체인</a>
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("\uB525\uB7EC\uB2DD");'>딥러닝</a>
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("\uD150\uC11C\uD50C\uB85C");'>텐서플로</a>
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("\uD074\uB77C\uC6B0\uC2A4 \uC288\uBC25");'>클라우스 슈밥</a>
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("4\uCC28 \uC0B0\uC5C5\uD601\uBA85");'>4차 산업혁명</a>
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("\uD50C\uB7AB\uD3FC");'>플랫폼</a>
# <a class="tag" href="javascript:void(0);" onclick='goSearchKeywordPage("\uC778\uACF5\uC9C0\uB2A5");'>인공지능</a>
# </div>
# <button class="btn_tag_more" type="button"><span class="hidden">더보기</span></button>
# </div>
# <!-- // 연관검색어 -->
# <!-- // 연관검색어 영역 -->
# </header>
# <!-- // 헤더 -->
# <main class="container_wrapper">
# <input id="targetHidden" type="hidden" value="kyobo"/>
# <input id="upperTargetHidden" type="hidden" value=""/>
# <input id="categoryIdHidden" type="hidden" value=""/>
# <input id="categoryDepthHidden" type="hidden" value=""/>
# <input id="suggestKeywordHidden" type="hidden" value=""/>
# <input id="pageNo" type="hidden" value="1"/>
# <input id="loginAgeHidden" type="hidden" value="0"/>
# <input id="loginGenderHidden" type="hidden" value="0"/>
# <input id="loginMmbrNumHidden" type="hidden" value=""/>
# <section class="contents_wrap" id="contents">
# <!-- combinedBannerData 리스트를 순회 -->
# <!-- 광고 배너 영역 -->
# <div class="search_event">
# <div class="swiper-container paging_right">
# <ul class="swiper-wrapper">
# <li class="swiper-slide" data-ad-id="72983" data-device-type="모바일" data-publisher-id="9866825" data-title="비즈그리다주식회사_ad" data-type="모바일 키워드 배너" id="mobile-banner-5765-003">
# <a href="https://event.kyobobook.co.kr/today-mission?missionId=1756">
# <img alt="비즈그리다주식회사_ad" fetchpriority="high" loading="eager" onclick="GA_ChangeTartgetNmMO('click_검색_MO', 'kyobo', '', '클릭_상단배너', '비즈그리다주식회사_ad', '인공지능');" src="https://contents.kyobobook.co.kr/advrcntr/IMAC/creatives/2025/07/14/72983/6.png"/>
# </a>
# </li>
# </ul>
# <div class="swiper-pagination"></div>
# </div>
# </div>
# <!-- // 광고 배너 영역 -->
# <!-- tab_wrap -->
# <div class="tab_wrap" id="tab_wrap_div">
# <!-- tab_list_wrap -->
# <div class="tab_list_wrap">
# <ul class="tabs">
# <!-- DESC : 탭 비활성화 시, .tab_link 영역 tab_disabled class 추가 -->
# <li class="tab_item has_data"><a class="tab_link" href="#tabSearch" onclick="searchTabFilter('total','8103');"><span class="tab_text">통합검색</span></a></li>
# <li class="tab_item ui-tabs-active has_data"><a class="tab_link" href="#tabSearch" onclick="searchTabFilter('kyobo','4440');"><span class="tab_text">교보문고</span></a></li>
# <li class="tab_item has_data"><a class="tab_link" href="#tabSearch" onclick="searchTabFilter('ebook','3635');"><span class="tab_text">eBook</span></a></li>
# <li class="tab_item has_data"><a class="tab_link" href="#tabSearch" onclick="searchTabFilter('sam','2525');"><span class="tab_text">sam</span></a></li>
# <li class="tab_item has_data"><a class="tab_link" href="#tabSearch" onclick="searchTabFilter('hottracks','28');"><span class="tab_text">핫트랙스</span></a></li>
# <!-- 20230517 중고장터 종료
#                         <li class="tab_item" th:classappend="|${target == 'used' || upperTarget == 'used' ? 'ui-tabs-active' : ''} ${allTotalCount.used > 0 ? 'has_data' : ''}|"><a href="#tabSearch" th:onclick="|searchTabFilter('used','${allTotalCount.used}');|" class="tab_link" th:classappend="${allTotalCount.used == 0} ? 'tab_disabled'"><span class="tab_text">중고장터</span></a></li>
#                         -->
# </ul>
# </div>
# <!-- //tab_list_wrap -->
# <!-- tab_content -->
# <div class="tab_content" id="tabSearch">
# <div class="list_result_wrap">
# <div class="sps sps_scroll_fixed">
# <div class="sps_inner">
# <p class="result_count"><b class="fc_green">4,440</b>건</p>
# <div class="right_area" id="shop_item_group">
# <div class="form_sel type_no_line">
# <select id="orderList" title="정렬 방식 선택">
# <option selected="selected" value="">인기순</option>
# <option value="qntt">판매량순</option>
# <option value="date">최신순</option>
# <option value="name">상품명순</option>
# <option value="dc">할인율순</option>
# <option value="prasc">낮은가격순</option>
# <option value="prdesc">높은가격순</option>
# <option value="kcont">클로버리뷰순</option>
# <option value="krvgr">클로버평점순</option>
# </select>
# </div>
# <!-- DESC : data-target 리스트형/썸네일형 제어되는 해당 상품 리스트 타겟지정 필요(#{tabid} .switch_prod_wrap) -->
# <div class="switch_list_btn_wrap type_toggle" data-target="#tabSearch .switch_prod_wrap">
# <button class="btn_sm ico_list" data-type="img" id="view_type_list_btn" type="button"><span class="hidden">리스트형 으로 보기</span></button><!-- 수정 220221 상품 토글버튼 기본 active 상태 변경, date-type 값 변경 -->
# <button class="btn_sm ico_img active" data-type="list" id="view_type_img_btn" type="button"><span class="hidden">이미지형 으로 보기</span></button> <!-- 수정 220221 상품 토글버튼 기본 active 상태 변경, date-type 값 변경 -->
# </div>
# <!-- DESC : 필터 활성화 시, active class 추가 -->
# <button class="btn_filter" data-role="btn-dialog" data-target="#popSearchFilter" id="mokSearchFilter" type="button">
# <span class="text">필터</span>
# <span class="count hidden" id="mokSearchFilterCount"></span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <!-- 추천 필터 -->
# <div class="recommend_filter_wrap type_popular">
# <div class="sps sps_scroll_fixed sps_add" data-add-offset="30">
# <div class="sps_inner">
# <div class="selected_filter_box" id="recommend_category_filter_box">
# <span class="heading">추천</span>
# <ul class="selected_filter_list" id="recommend_category_filter_list">
# <li class="selected_filter" id="recommend_category_filter">
# <button class="btn_select_category" id="recommendCategory_0" type="button" value="KOR|국내도서@KORBOOK@@컴퓨터/IT@33|국내도서&gt;컴퓨터/IT">
# <span class="category_name">국내도서</span><span class="category_name">컴퓨터/IT</span>
# </button>
# </li>
# <li class="selected_filter" id="recommend_category_filter">
# <button class="btn_select_category" id="recommendCategory_1" type="button" value="KOR|국내도서@KORBOOK@@인문@05|국내도서&gt;인문">
# <span class="category_name">국내도서</span><span class="category_name">인문</span>
# </button>
# </li>
# <li class="selected_filter" id="recommend_category_filter">
# <button class="btn_select_category" id="recommendCategory_2" type="button" value="KOR|국내도서@KORBOOK@@경제/경영@13|국내도서&gt;경제/경영">
# <span class="category_name">국내도서</span><span class="category_name">경제/경영</span>
# </button>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- 추천 필터 -->
# <!-- 상품 리스트형 / 썸네일형 -->
# <div class="switch_prod_wrap view_type_list view_spec_compare" id="shopData_list">
# <!-- 수정 220406 통합검색 상품 현행화 페이지 적용. 전체 상품군은 SCR-BIZ03-04-P001 페이지 확인필요 -->
# <ul class="prod_list prod_view_list">
# <!-- 교보 리스트 영역 -->
# <!--결합, 오픈마켓, POD 상품이 아닐때-->
# <!-- 교보 리스트 영역 -->
# <li class="prod_item">
# <!-- 체크박스 영역 -->
# <span class="form_chk no_label spec_checkbox_span" style="display:none;">
# <input class="spec_checkbox" data-bid="9788955685329" data-code="KOR" data-name="인공지능입문" data-pid="S000217120455" id="chkSearch_S000217120455" type="checkbox"/>
# <label for="chkSearch_S000217120455"><span class="hidden">상품선택</span></label>
# </span>
# <!-- // 체크박스 영역 -->
# <div class="prod_area horizontal">
# <div class="prod_thumb_box">
# <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000217120455&quot;);">
# <span class="img_box">
# <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9788955685329" data-kbbfn-pid="S000217120455" data-kbbfn-size="200x0" data-kbbfn-title="인공지능입문" data-kbbfn-type="KOR"/>
# </span>
# </a>
# </div>
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- 상품명 -->
# <span class="prod_name_group">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 제목', &quot;S000217120455&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span>인공지능입문</span>
# </a>
# </span>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);">손창호</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="gap"> | </span>
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);">이은애</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="count">외</span>
# <span class="gap">|</span>
# <span class="publish" onclick="goClickSearchPage('pbcm',&quot;PB04390&quot;,&quot;\uC591\uC11C\uAC01&quot;);">양서각</span>
# </div>
# <!-- //저자/출판사정보  -->
# <!-- 금액, 리스트 타입 버튼영역 -->
# <div class="prod_price_control">
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매/예약중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="price">
# <span class="val">12,600</span>
# <span class="unit">원 </span>
# </span>
# <span class="percent">10%</span>
# <span class="point">(700p)</span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매/예약중이 아닐떄-->
# <!--중고 장터일때-->
# </div>
# <!-- // 금액, 리스트 타입 버튼영역 -->
# <!-- 리뷰영역 -->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000217120455"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text">0.0</span>
# </span>
# </a>
# <!-- //리뷰영역-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!--바로드림 전용상품이 아닐경우-->
# <!-- 배송정보 영역 -->
# <div class="prod_order_state">
# <div class="order_state_desc">
# <!--<span>지금 주문하면</span> -->
# <span class="fw_bold">7/31(목)</span>
# <span>출고예정</span>
# <button class="btn_tooltip_sm" id="btnTooltipDelivery" type="button">
# <span class="ico_info"></span>
# <span class="hidden">팝업 열기</span>
# </button>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 이벤트 정보 -->
# <!-- // 이벤트 정보 -->
# <div class="prod_price_control">
# <div class="right_box">
# <!--좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9788955685329" data-pid="S000217120455" id="searchWishItemInfo_S000217120455" name="001_001_S000217120455_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_circle has_val" data-cmdtcode="9788955685329" id="S000217120455_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000217120455");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217120455_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <button class="btn_cart_circle" onclick='searchResultCartClickEvent(false, "S000217120455");' type="button"><span class="ico_cart"></span><span class="hidden">장바구니 담기</span></button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# </div>
# </div>
# </div>
# </div>
# </li>
# <!-- // 교보 리스트 영역 -->
# <!--결합, 오픈마켓, POD, FUD 상품일때-->
# <!--결합, 오픈마켓, POD 상품이 아닐때-->
# <!-- 교보 리스트 영역 -->
# <li class="prod_item">
# <!-- 체크박스 영역 -->
# <span class="form_chk no_label spec_checkbox_span" style="display:none;">
# <input class="spec_checkbox" data-bid="9791143007131" data-code="KOR" data-name="인공지능과 죽음" data-pid="S000217098239" id="chkSearch_S000217098239" type="checkbox"/>
# <label for="chkSearch_S000217098239"><span class="hidden">상품선택</span></label>
# </span>
# <!-- // 체크박스 영역 -->
# <div class="prod_area horizontal">
# <div class="prod_thumb_box">
# <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000217098239" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000217098239&quot;);">
# <span class="img_box">
# <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791143007131" data-kbbfn-pid="S000217098239" data-kbbfn-size="200x0" data-kbbfn-title="인공지능과 죽음" data-kbbfn-type="KOR"/>
# </span>
# </a>
# </div>
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- 상품명 -->
# <span class="prod_name_group">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000217098239" onclick="searchResultItemClickEvent('상품 제목', &quot;S000217098239&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span>인공지능과 죽음</span>
# </a>
# </span>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# <span class="prod_desc">(인공지능총서)</span>
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1001367001&quot;,&quot;\uC2EC\uD601\uC8FC&quot;);">심혁주</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="gap">|</span>
# <span class="publish" onclick="goClickSearchPage('pbcm',&quot;PB09525&quot;,&quot;\uCEE4\uBBA4\uB2C8\uCF00\uC774\uC158\uBD81\uC2A4&quot;);">커뮤니케이션북스</span>
# </div>
# <!-- //저자/출판사정보  -->
# <!-- 금액, 리스트 타입 버튼영역 -->
# <div class="prod_price_control">
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매/예약중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="price">
# <span class="val">10,800</span>
# <span class="unit">원 </span>
# </span>
# <span class="percent">10%</span>
# <span class="point">(600p)</span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매/예약중이 아닐떄-->
# <!--중고 장터일때-->
# </div>
# <!-- // 금액, 리스트 타입 버튼영역 -->
# <!-- 리뷰영역 -->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000217098239"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text">0.0</span>
# </span>
# </a>
# <!-- //리뷰영역-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!--바로드림 전용상품이 아닐경우-->
# <!-- 배송정보 영역 -->
# <div class="prod_order_state">
# <div class="order_state_desc">
# <!--<span>지금 주문하면</span> -->
# <span class="fw_bold">7/29(화)</span>
# <span>출고예정</span>
# <button class="btn_tooltip_sm" id="btnTooltipDelivery" type="button">
# <span class="ico_info"></span>
# <span class="hidden">팝업 열기</span>
# </button>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 이벤트 정보 -->
# <!-- // 이벤트 정보 -->
# <div class="prod_price_control">
# <div class="right_box">
# <!--좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9791143007131" data-pid="S000217098239" id="searchWishItemInfo_S000217098239" name="001_001_S000217098239_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_circle has_val" data-cmdtcode="9791143007131" id="S000217098239_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000217098239");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217098239_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <button class="btn_cart_circle" onclick='searchResultCartClickEvent(false, "S000217098239");' type="button"><span class="ico_cart"></span><span class="hidden">장바구니 담기</span></button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# </div>
# </div>
# </div>
# </div>
# </li>
# <!-- // 교보 리스트 영역 -->
# <!--결합, 오픈마켓, POD, FUD 상품일때-->
# <!--결합, 오픈마켓, POD 상품이 아닐때-->
# <!-- 교보 리스트 영역 -->
# <li class="prod_item">
# <!-- 체크박스 영역 -->
# <span class="form_chk no_label spec_checkbox_span" style="display:none;">
# <input class="spec_checkbox" data-bid="9791163037231" data-code="KOR" data-name="된다! 하루 만에 끝내는 챗GPT 활용법" data-pid="S000216645088" id="chkSearch_S000216645088" type="checkbox"/>
# <label for="chkSearch_S000216645088"><span class="hidden">상품선택</span></label>
# </span>
# <!-- // 체크박스 영역 -->
# <div class="prod_area horizontal">
# <div class="prod_thumb_box">
# <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000216645088" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000216645088&quot;);">
# <span class="img_box">
# <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791163037231" data-kbbfn-pid="S000216645088" data-kbbfn-size="200x0" data-kbbfn-title="된다! 하루 만에 끝내는 챗GPT 활용법" data-kbbfn-type="KOR"/>
# </span>
# </a>
# </div>
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <span class="badge_md badge_line_gray"><span class="text">이벤트</span></span>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- 상품명 -->
# <span class="prod_name_group">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000216645088" onclick="searchResultItemClickEvent('상품 제목', &quot;S000216645088&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span>된다! 하루 만에 끝내는 챗GPT 활용법</span>
# </a>
# </span>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# <span class="prod_desc">인공지능에게 일 시키고 시간 버는 법 최신 버전 GPT 4.1 반영! (된다! 시리즈)<span class="gap"> | </span></span>
# <span class="prod_desc normal">전면개정판 3판</span>
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1117520301&quot;,&quot;\uD504\uB86C\uD504\uD2B8 \uD06C\uB9AC\uC5D0\uC774\uD130&quot;);">프롬프트 크리에이터</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="gap">|</span>
# <span class="publish" onclick="goClickSearchPage('pbcm',&quot;PB26874&quot;,&quot;\uC774\uC9C0\uC2A4\uD37C\uBE14\uB9AC\uC2F1&quot;);">이지스퍼블리싱</span>
# </div>
# <!-- //저자/출판사정보  -->
# <!-- 금액, 리스트 타입 버튼영역 -->
# <div class="prod_price_control">
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매/예약중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="price">
# <span class="val">18,000</span>
# <span class="unit">원 </span>
# </span>
# <span class="percent">10%</span>
# <span class="point">(1,000p)</span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매/예약중이 아닐떄-->
# <!--중고 장터일때-->
# </div>
# <!-- // 금액, 리스트 타입 버튼영역 -->
# <!-- 리뷰영역 -->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000216645088"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text">9.89</span>
# </span>
# <span class="gap">/</span>
# <span class="review_quotes_text">도움돼요</span>
# </a>
# <!-- //리뷰영역-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!--바로드림 전용상품이 아닐경우-->
# <!-- 배송정보 영역 -->
# <div class="prod_order_state">
# <div class="order_state_desc">
# <span class="badge_sm badge_pill badge_primary"><span class="text">새벽배송</span></span>
# <!--<span>지금 주문하면</span> -->
# <span class="fw_bold">내일(7/25, 금 오전 7시 전) </span>
# <span>도착</span>
# <button class="btn_tooltip_sm" id="btnTooltipDelivery" type="button">
# <span class="ico_info"></span>
# <span class="hidden">팝업 열기</span>
# </button>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 이벤트 정보 -->
# <div class="prod_gift_info"><a class="prod_gift_text" href="javascript:void(0);" onclick="goEventDetailPage(232030)">7월의 바로 이 책</a> 외 2건<div class="tooltip_wrap type_sm">
# <button class="btn_tooltip" type="button"><span class="ico_info"></span><span class="hidden">툴팁열기</span></button>
# <div class="tooltip_inner">
# <div class="tooltip_header">
# <div class="tooltip_head_title">이벤트 안내</div>
# </div>
# <div class="tooltip_contents"><div class="tooltip_sub_title">이벤트</div><ul class="bul_list"><li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(237043)">2025 하반기 기대 신간 캘린더</a></li>
# </ul><div class="tooltip_sub_title">사은품</div><ul class="bul_list"><li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(232030)">7월의 바로 이 책</a></li>
# </ul><div class="tooltip_sub_title">경품</div><ul class="bul_list"><li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(236845)">🔐 읽는 친구끼리 비밀 교환 독서기록장 : 세 번째 기록, 방학 🏖️</a></li>
# </ul></div>
# <button class="btn_tooltip_close" type="button"><span class="hidden">툴팁닫기</span></button>
# </div>
# </div></div>
# <!-- // 이벤트 정보 -->
# <div class="prod_price_control">
# <div class="right_box">
# <!--좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9791163037231" data-pid="S000216645088" id="searchWishItemInfo_S000216645088" name="001_001_S000216645088_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_circle has_val" data-cmdtcode="9791163037231" id="S000216645088_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000216645088");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000216645088_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <button class="btn_cart_circle" onclick='searchResultCartClickEvent(false, "S000216645088");' type="button"><span class="ico_cart"></span><span class="hidden">장바구니 담기</span></button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# </div>
# </div>
# </div>
# </div>
# </li>
# <!-- // 교보 리스트 영역 -->
# <!--결합, 오픈마켓, POD, FUD 상품일때-->
# <!--결합, 오픈마켓, POD 상품이 아닐때-->
# <!-- 교보 리스트 영역 -->
# <li class="prod_item">
# <!-- 체크박스 영역 -->
# <span class="form_chk no_label spec_checkbox_span" style="display:none;">
# <input class="spec_checkbox" data-bid="9788965404026" data-code="KOR" data-name="AI 리터러시: 인공지능 필수 지식부터 완벽 활용까지" data-pid="S000214845678" id="chkSearch_S000214845678" type="checkbox"/>
# <label for="chkSearch_S000214845678"><span class="hidden">상품선택</span></label>
# </span>
# <!-- // 체크박스 영역 -->
# <div class="prod_area horizontal">
# <div class="prod_thumb_box">
# <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000214845678" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000214845678&quot;);">
# <span class="img_box">
# <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9788965404026" data-kbbfn-pid="S000214845678" data-kbbfn-size="200x0" data-kbbfn-title="AI 리터러시: 인공지능 필수 지식부터 완벽 활용까지" data-kbbfn-type="KOR"/>
# </span>
# </a>
# </div>
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <span class="badge_md badge_line_gray"><span class="text">이벤트</span></span>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- 상품명 -->
# <span class="prod_name_group">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000214845678" onclick="searchResultItemClickEvent('상품 제목', &quot;S000214845678&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span>AI 리터러시: 인공지능 필수 지식부터 완벽 활용까지</span>
# </a>
# </span>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# <span class="prod_desc">여전히 챗GPT만 붙들고 있는 당신에게</span>
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1000093814&quot;,&quot;\uAE40\uC6A9\uC131&quot;);">김용성</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="gap">|</span>
# <span class="publish" onclick="goClickSearchPage('pbcm',&quot;PB14984&quot;,&quot;\uD504\uB9AC\uB809&quot;);">프리렉</span>
# </div>
# <!-- //저자/출판사정보  -->
# <!-- 금액, 리스트 타입 버튼영역 -->
# <div class="prod_price_control">
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매/예약중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="price">
# <span class="val">22,500</span>
# <span class="unit">원 </span>
# </span>
# <span class="percent">10%</span>
# <span class="point">(1,250p)</span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매/예약중이 아닐떄-->
# <!--중고 장터일때-->
# </div>
# <!-- // 금액, 리스트 타입 버튼영역 -->
# <!-- 리뷰영역 -->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000214845678"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text">9.68</span>
# </span>
# <span class="gap">/</span>
# <span class="review_quotes_text">도움돼요</span>
# </a>
# <!-- //리뷰영역-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!--바로드림 전용상품이 아닐경우-->
# <!-- 배송정보 영역 -->
# <div class="prod_order_state">
# <div class="order_state_desc">
# <span class="badge_sm badge_pill badge_primary"><span class="text">새벽배송</span></span>
# <!--<span>지금 주문하면</span> -->
# <span class="fw_bold">내일(7/25, 금 오전 7시 전) </span>
# <span>도착</span>
# <button class="btn_tooltip_sm" id="btnTooltipDelivery" type="button">
# <span class="ico_info"></span>
# <span class="hidden">팝업 열기</span>
# </button>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 이벤트 정보 -->
# <div class="prod_gift_info"><a class="prod_gift_text" href="javascript:void(0);" onclick="goEventDetailPage(235484)">OttOn 어떤 3호: 모험</a> 외 3건<div class="tooltip_wrap type_sm">
# <button class="btn_tooltip" type="button"><span class="ico_info"></span><span class="hidden">툴팁열기</span></button>
# <div class="tooltip_inner">
# <div class="tooltip_header">
# <div class="tooltip_head_title">이벤트 안내</div>
# </div>
# <div class="tooltip_contents"><div class="tooltip_sub_title">사은품</div><ul class="bul_list"><li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(235484)">OttOn 어떤 3호: 모험</a></li>
# <li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(236494)">2025 상반기 북로그</a></li>
# <li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(232810)">2025년 기대 신간 캘린더</a></li>
# <li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(231930)">2025 무료배송/정가인하 이벤트</a></li>
# </ul></div>
# <button class="btn_tooltip_close" type="button"><span class="hidden">툴팁닫기</span></button>
# </div>
# </div></div>
# <!-- // 이벤트 정보 -->
# <div class="prod_price_control">
# <div class="right_box">
# <!--좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9788965404026" data-pid="S000214845678" id="searchWishItemInfo_S000214845678" name="001_001_S000214845678_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_circle has_val" data-cmdtcode="9788965404026" id="S000214845678_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000214845678");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000214845678_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# ...
# <a class="btn_arw_link" href="https://mhottracks.kyobobook.co.kr/" target=""><p class="title_heading">핫트랙스</p></a>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="http://mhottracks.kyobobook.co.kr/m/hot/hotdealMain" target="">오늘만특가</a></li>
# <li class="main_menu_item"><a href="http://mhottracks.kyobobook.co.kr/m/hot/best" target="">베스트</a></li>
# <li class="main_menu_item"><a href="http://mhottracks.kyobobook.co.kr/m/coupon/cpnIncnt" target="">쿠폰/혜택</a></li>
# <li class="main_menu_item"><a href="https://mhottracks.kyobobook.co.kr/m/pod/podMain" target="">COVER WELL (POD)</a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <a class="btn_arw_link" href="https://casting.kyobobook.co.kr/" target=""><p class="title_heading">CASTing</p></a>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://casting.kyobobook.co.kr/" target="">홈</a></li>
# <li class="main_menu_item"><a href="https://casting.kyobobook.co.kr/live" target="">라이브</a></li>
# <li class="main_menu_item"><a href="https://casting.kyobobook.co.kr/video" target="">영상</a></li>
# <li class="main_menu_item"><a href="https://casting.kyobobook.co.kr/post" target="">포스트</a></li>
# </ul>
# </div>
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://casting.kyobobook.co.kr/event" target="">이벤트</a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <a class="btn_arw_link" href="https://sam.kyobobook.co.kr/dig/pnd/showcase?pageNo=3115" target="_blank"><p class="title_heading">북모닝</p></a>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://sam.kyobobook.co.kr/dig/sam/sambkmr" target="_blank">이달의 북모닝도서</a></li>
# <li class="main_menu_item"><a href="https://sam.kyobobook.co.kr/dig/pnd/showcase?pageNo=3115" target="_blank">이주의 북모닝도서</a></li>
# <li class="main_menu_item"><a href="https://sam.kyobobook.co.kr/dig/sam/bkmrintro" target="_blank">북모닝소개</a></li>
# <li class="main_menu_item"><a href="https://sam.kyobobook.co.kr/dig/sam/pssbuy" target="_blank">이용권 구매</a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <a class="btn_arw_link" href="https://storynew.kyobobook.co.kr/" target="_blank"><p class="title_heading">스토리</p></a>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://storynew.kyobobook.co.kr/story/pof/initStoryIpBookList.ink" target="_blank">포트폴리오</a></li>
# <li class="main_menu_item"><a href="https://storynew.kyobobook.co.kr/story/cont/initStoryContStoryPros.ink" target="_blank">스토리공모전</a></li>
# <li class="main_menu_item"><a href="https://storynew.kyobobook.co.kr/story/up/initStoryUpProsView.ink" target="_blank">테마공모전</a></li>
# <li class="main_menu_item"><a href="https://storynew.kyobobook.co.kr/story/smkt/initStorySmktBookList.ink" target="_blank">스토리마켓</a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <a class="btn_arw_link" href="https://mmbr.kyobobook.co.kr/benefit" target=""><p class="title_heading">회원혜택</p></a>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://mmbr.kyobobook.co.kr/benefit" target="">교보북클럽</a></li>
# <li class="main_menu_item"><a href="https://mmbr.kyobobook.co.kr/benefit/grade" target="">등급 혜택</a></li>
# <li class="main_menu_item"><a href="https://mmbr.kyobobook.co.kr/benefit/new" target="">신규회원 혜택</a></li>
# <li class="main_menu_item"><a href="https://mmbr.kyobobook.co.kr/benefit/prestige" target="">Prestige Lounge</a></li>
# </ul>
# </div>
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://mmbr.kyobobook.co.kr/benefit/discount" target="">제휴 혜택</a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <a class="btn_arw_link" href="https://www.kyobobook.co.kr/cscenter" target=""><p class="title_heading">고객센터</p></a>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://www.kyobobook.co.kr/cscenter/faq" target="">자주묻는질문</a></li>
# <li class="main_menu_item"><a href="https://www.kyobobook.co.kr/cscenter/qna-form" target="">1:1문의</a></li>
# <li class="main_menu_item"><a href="https://www.kyobobook.co.kr/cscenter/notice" target="">공지사항</a></li>
# <li class="main_menu_item"><a href="https://www.kyobobook.co.kr/cscenter/contact" target="">전화상담 안내도</a></li>
# </ul>
# </div>
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://big.kyobobook.co.kr/" target="">법인회원 대량주문</a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <a class="btn_arw_link" href="https://my.kyobobook.co.kr/" target=""><p class="title_heading">마이</p></a>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://order.kyobobook.co.kr/myroom/member/order-list" target="">주문/배송목록</a></li>
# <li class="main_menu_item"><a href="https://order.kyobobook.co.kr/myroom/member/gift-detail" target="">선물함</a></li>
# <li class="main_menu_item"><a href="https://my.kyobobook.co.kr/activity/community" target="">활동내역</a></li>
# <li class="main_menu_item"><a href="https://order.kyobobook.co.kr/myroom/member/offline-list" target="">매장 구매 내역</a></li>
# </ul>
# </div>
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://order.kyobobook.co.kr/myroom/member/receipt" target="">영수증 조회/후 적립</a></li>
# <li class="main_menu_item"><a href="https://mmbr.kyobobook.co.kr/member-info" target="">회원정보</a></li>
# <li class="main_menu_item"><a href="https://my.kyobobook.co.kr/notice" target="">알림센터</a></li>
# <li class="main_menu_item"><a href="https://order.kyobobook.co.kr/myroom/benefit/point" target="">나의 통장</a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <a class="btn_arw_link" href="https://my.kyobobook.co.kr/library" target=""><p class="title_heading">라이브러리</p></a>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://my.kyobobook.co.kr/library/list" target="">리스트</a></li>
# <li class="main_menu_item"><a href="https://my.kyobobook.co.kr/library/comment" target="">코멘트</a></li>
# <li class="main_menu_item"><a href="https://my.kyobobook.co.kr/library/review" target="">Klover리뷰</a></li>
# <li class="main_menu_item"><a href="https://my.kyobobook.co.kr/library/sentences" target="">문장수집</a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <a class="btn_arw_link" href="https://store.kyobobook.co.kr/store-info/001" target=""><p class="title_heading">매장안내</p></a>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://moonbojang.hottracks.co.kr/frContentCon/brandIntro.do" target="_blank"><em>문보장</em></a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <a class="btn_arw_link" href="https://company.kyobobook.co.kr/ims/user/Intro/r/go?param=intro" target="_blank"><p class="title_heading">회사소개</p></a>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://company.kyobobook.co.kr/ims/user/Intro/r/go?param=intro" target="_blank">교보문고 소개</a></li>
# <li class="main_menu_item"><a href="https://company.kyobobook.co.kr/ims/user/Intro/r/go?param=nowkyobo" target="_blank">사업현황</a></li>
# <li class="main_menu_item"><a href="https://company.kyobobook.co.kr/ims/user/Intro/r/go?param=son" target="_blank">사회공헌</a></li>
# <li class="main_menu_item"><a href="https://ehr.kyobobook.co.kr/recr/recruit_info_1.jsp" target="_blank">채용정보</a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <p class="title_heading">협력사여러분</p>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://www.kyobobook.co.kr/partners/chargeperson" target="">협력사여러분</a></li>
# <li class="main_menu_item"><a href="https://www.kyobobook.co.kr/partners/suggest" target="">제휴/제안</a></li>
# <li class="main_menu_item"><a href="https://ad.kyobobook.co.kr" target="_blank">애드북</a></li>
# <li class="main_menu_item"><a href="https://scm.kyobobook.co.kr/scm/login.action" target="_blank">협력사네트워크</a></li>
# </ul>
# </div>
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://partner.kyobobook.co.kr" target="_blank">CP관리시스템</a></li>
# </ul>
# </div>
# </div>
# <div class="title_wrap title_size_def">
# <p class="title_heading">기타</p>
# </div>
# <div class="main_menu_box">
# <div class="main_menu_col">
# <ul class="main_menu_list">
# <li class="main_menu_item"><a href="https://www.kyobobook.co.kr/policy" target="">이용약관</a></li>
# <li class="main_menu_item"><a href="https://www.kyobobook.co.kr/policy/privacy" target="">개인정보처리방침</a></li>
# <li class="main_menu_item"><a href="https://www.kyobobook.co.kr/policy/youthpolicy" target="">청소년보호정책</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="tab_content" id="tabMainMenuFavorite">
# <div class="contents_inner">
# <div class="tab_wrap type_tag">
# <div class="tab_list_wrap">
# <ul class="tabs">
# <li class="tab_item"><a class="tab_link" href="#tabFavoriteCategory"><span class="tab_text">즐겨찾는 카테고리</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabFavoriteService"><span class="tab_text">즐겨찾는 서비스</span></a></li>
# </ul>
# </div>
# <div class="tab_content tab_favorite" id="tabFavoriteCategory"></div>
# <div class="tab_content tab_favorite" id="tabFavoriteService"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="title_wrap title_size_lg">
# <p class="title_heading">주요 서비스</p>
# </div>
# <div class="service_swiper_wrap">
# <div class="swiper-container">
# <ul class="service_list swiper-wrapper">
# <li class="service_item swiper-slide"><a class="service_link" href="https://www.kyobobook.co.kr/barodrim" target="_self"><img alt="바로드림" loading="lazy" src="https://contents.kyobobook.co.kr/display/pc_icon_8d7a3306ef6045cdb406881a63b4d6a9.png"/><p class="service_name">바로드림</p></a></li>
# <li class="service_item swiper-slide"><a class="service_link" href="https://product.kyobobook.co.kr/today-book" target="_self"><img alt="오늘의 선택" loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 1_017c321f59504c6f995c5c4c90bcd382.jpg"/><p class="service_name">오늘의 선택</p></a></li>
# <li class="service_item swiper-slide"><a class="service_link" href="https://store.kyobobook.co.kr/person" target="_self"><img alt="인물&amp;작품" loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 4_dea56a082097433c80a6491aca4fcad6.jpg"/><p class="service_name">인물&amp;작품</p></a></li>
# <li class="service_item swiper-slide"><a class="service_link" href="https://www.kyobobook.co.kr/gift" target="_self"><img alt="선물하기" loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 5_6f76bd72614f4a24a89d905386b32c84.jpg"/><p class="service_name">선물하기</p></a></li>
# <li class="service_item swiper-slide"><a class="service_link" href="https://www.kyobobook.co.kr/best-review" target="_self"><img alt="베스트리뷰" loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 6_a0981652bec94c7094de142a9440c909.jpg"/><p class="service_name">베스트리뷰</p></a></li>
# <li class="service_item swiper-slide"><a class="service_link" href="https://store.kyobobook.co.kr/handwriting/contest" target="_self"><img alt="손글씨캠페인" loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 7_bd7dd305777e46b0b914490a234ec720.jpg"/><p class="service_name">손글씨캠페인</p></a></li>
# <li class="service_item swiper-slide"><a class="service_link" href="https://store.kyobobook.co.kr/culture" target="_self"><img alt="문화공간" loading="lazy" src="https://contents.kyobobook.co.kr/display/bn – 8_ead7c54f641e45fca4bf7bb27330f4c3.jpg"/><p class="service_name">문화공간</p></a></li>
# <li class="service_item swiper-slide"><a class="service_link" href="https://product.kyobobook.co.kr/pod/main" target="_self"><img alt="바로출판" loading="lazy" src="https://contents.kyobobook.co.kr/display/바로출판_POD_1bd71e6c18bd47e0b23bc2e4da998cd4.png"/><p class="service_name">바로출판</p></a></li>
# </ul>
# </div>
# </div>
# <div class="contents_gap_area gab_menu_util">
# <div class="contents_inner">
# <ul class="main_util_menu_list">
# <li class="util_menu_item"><a class="util_menu_link" href="https://www.kyobobook.co.kr/cscenter">고객센터</a></li>
# <li class="util_menu_item"><a class="util_menu_link" href="https://store.kyobobook.co.kr/store-info">매장안내</a></li>
# <li class="util_menu_item"><a class="util_menu_link" href="https://my.kyobobook.co.kr/app/config">설정</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script data-name="react-bundle" src="https://contents.kyobobook.co.kr/resources/vendors/react-bundle.min.js"></script>
# <!-- NetFUNNEL 스크립트 -->
# <script data-name="netfunnel" src="https://contents.kyobobook.co.kr/resources/vendors/netfunnel/custom-netfunnel.js"></script>
# <script data-name="ResizeSensor" src="https://contents.kyobobook.co.kr/resources/vendors/css-element-queries/ResizeSensor.js"></script>
# <script data-name="awesomplete" src="https://contents.kyobobook.co.kr/resources/vendors/awesomplete/awesomplete.min.js"></script>
# <script data-name="kbb.recent.js" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.recent.js?t=202507231211" type="text/javascript"></script>
# <script data-name="scrollPosStyler" src="https://contents.kyobobook.co.kr/resources/vendors/scrollpos-styler/scrollPosStyler.min.js"></script>
# <script data-name="blurify" src="https://contents.kyobobook.co.kr/resources/vendors/blurify-master/blurify.min.js"></script>
# <script data-name="masonry" src="https://contents.kyobobook.co.kr/resources/vendors/masonry/masonry.pkgd.min.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-touch-punch/jquery.ui.touch-punch.min.js"></script>
# <script data-name="swiper" src="https://contents.kyobobook.co.kr/resources/vendors/swiper/v7/swiper-bundle.min.js"></script>
# <script data-name="kbb-cm-script" src="https://contents.kyobobook.co.kr/resources/fo/js/ui_mok.js?t=202507231211" type="text/javascript"></script>
# <script src="/assets/js/vars.js?t=202507231211" type="text/javascript"></script>
# <script src="/common/js/kyobo_search_review.js?t=202507231211" type="text/javascript"></script>
# <script src="/mobile/js/mok_kyobo_search_filter.js?t=202507231211" type="text/javascript"></script>
# <script src="/mobile/js/mok_kyobo_search_spec.js?t=202507231211" type="text/javascript"></script>
# <script src="/common/js/kyobo_search_gtm.js?t=202507231211" type="text/javascript"></script>
# <script src="/common/js/kyobo_search_click_event.js?t=202507231211" type="text/javascript"></script>
# <script src="/common/js/kyobo_search_lazy.js?t=202507231211" type="text/javascript"></script>
# <!-- /* 큐봇(cubot) 스크립트 삽입 */-->
# <script>
#         const maxAttempts = 12;
#         const attemptInterval = 5000; // 5초
#
#         function initializeCuBotWidgetAsync(page) {
#             return new Promise((resolve, reject) => {
#                 let attempts = 0;
#
#                 function tryInitialize() {
#                     if (window.initializeCubotWidget) {
#                         window.initializeCubotWidget({page: page});
#                         resolve();
#                     } else if (attempts < maxAttempts) {
#                         setTimeout(tryInitialize, attemptInterval);
#                         attempts++;
#                     } else {
#                         reject();
#                     }
#                 }
#
#                 tryInitialize();
#             });
#         }
#
#         document.addEventListener('DOMContentLoaded', () => {
#             initializeCuBotWidgetAsync("search")
#                 .then(() => console.log('CuBot Widget initialized successfully'));
#         });
#     </script>
# </body>
# </html>

# %% [markdown]
# ## 3) 파싱

# %%
# ul 태그 : class가 prod_list
prod_list = soup.find("ul", class_="prod_list")
# print(prod_list)

# %%
# prod_list에서 li태그 : class가 prod_item
prod_item = soup.find_all("li", class_="prod_item")
print(len(prod_item))
# Out:
# 20

# %% [markdown]
# ### 하나의 책만 파싱해보기(find로만 찾기)

# %%
book = prod_item[0]

# %%
info_box = book.find("div", class_= "prod_info_box")
info_box
# Out:
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- 상품명 -->
# <span class="prod_name_group">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 제목', &quot;S000217120455&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span>인공지능입문</span>
# </a>
# </span>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);">손창호</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="gap"> | </span>
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);">이은애</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="count">외</span>
# <span class="gap">|</span>
# <span class="publish" onclick="goClickSearchPage('pbcm',&quot;PB04390&quot;,&quot;\uC591\uC11C\uAC01&quot;);">양서각</span>
# </div>
# <!-- //저자/출판사정보  -->
# <!-- 금액, 리스트 타입 버튼영역 -->
# <div class="prod_price_control">
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매/예약중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="price">
# <span class="val">12,600</span>
# <span class="unit">원 </span>
# </span>
# <span class="percent">10%</span>
# <span class="point">(700p)</span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매/예약중이 아닐떄-->
# <!--중고 장터일때-->
# </div>
# <!-- // 금액, 리스트 타입 버튼영역 -->
# <!-- 리뷰영역 -->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000217120455"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text">0.0</span>
# </span>
# </a>
# <!-- //리뷰영역-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!--바로드림 전용상품이 아닐경우-->
# <!-- 배송정보 영역 -->
# <div class="prod_order_state">
# <div class="order_state_desc">
# <!--<span>지금 주문하면</span> -->
# <span class="fw_bold">7/31(목)</span>
# <span>출고예정</span>
# <button class="btn_tooltip_sm" id="btnTooltipDelivery" type="button">
# <span class="ico_info"></span>
# <span class="hidden">팝업 열기</span>
# </button>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 이벤트 정보 -->
# <!-- // 이벤트 정보 -->
# <div class="prod_price_control">
# <div class="right_box">
# <!--좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9788955685329" data-pid="S000217120455" id="searchWishItemInfo_S000217120455" name="001_001_S000217120455_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_circle has_val" data-cmdtcode="9788955685329" id="S000217120455_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000217120455");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217120455_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <button class="btn_cart_circle" onclick='searchResultCartClickEvent(false, "S000217120455");' type="button"><span class="ico_cart"></span><span class="hidden">장바구니 담기</span></button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# </div>
# </div>
# </div>

# %% [markdown]
# ### 책 이름

# %%
# 방법 1
title = info_box.find("a", class_= "prod_info").text
print(title)
# Out:
# [국내도서]
# 인공지능입문

# %%
print(info_box.find("a", class_= "prod_info"))
print("-"*100)
print(info_box.find("a", class_= "prod_info").attrs["href"])
print("-"*100)
print(info_box.find("a", class_= "prod_info").text)

#나는 예약판매가 필요없다면? (어떤 책은 예약 판매가 있고, 어떤 책은 없다)
print(info_box.find("a", class_= "prod_info").find_all("span"))
print(len(info_box.find("a", class_= "prod_info").find_all("span")))
span_list = info_box.find("a", class_= "prod_info").find_all("span")
print("-"*100)
catagory = span_list[0].text
title = span_list[-1].text
print(catagory, title)
# Out:
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 제목', &quot;S000217120455&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span>인공지능입문</span>
# </a>
# ----------------------------------------------------------------------------------------------------
# https://product.kyobobook.co.kr/detail/S000217120455
# ----------------------------------------------------------------------------------------------------
#
# [국내도서]
# 인공지능입문
#
# [<span class="prod_category">[국내도서]</span>, <span>인공지능입문</span>]
# 2
# ----------------------------------------------------------------------------------------------------
# [국내도서] 인공지능입문

# %% [markdown]
# ### 저자 정보

# %%
# 방법 1
author_line = info_box.find("div", class_="prod_author_group").text
# print(author_line)
# print("="*100)
author_line = author_line.replace("\n", " ").strip()
print(author_line)
# Out:
# 손창호  저자(글)  |   이은애  저자(글) 외 | 양서각
# 손창호  저자(글)  |   이은애  저자(글) 외 | 양서각

# %%
# 방법 2
print(info_box.find("div", class_= "prod_author_group"))
print("-"*100)
author_list = info_box.find("div", class_="prod_author_group")
print(author_list.find_all("a", class_="author"))
print(author_list.find_all("span", class_="type"))
print("-"*100)
authors = author_list.find_all("a", class_="author")
types = author_list.find_all("span", class_="type")
# Out:
# <div class="prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);">손창호</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="gap"> | </span>
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);">이은애</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="count">외</span>
# <span class="gap">|</span>
# <span class="publish" onclick="goClickSearchPage('pbcm',&quot;PB04390&quot;,&quot;\uC591\uC11C\uAC01&quot;);">양서각</span>
# </div>
# ----------------------------------------------------------------------------------------------------
# [<a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);">손창호</a>, <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);">이은애</a>]
# [<span class="type">저자(글)</span>, <span class="type">저자(글)</span>]
# ----------------------------------------------------------------------------------------------------

# %%
print(info_box.find("div", class_="prod_author_group"))
# Out:
# <div class="prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);">손창호</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="gap"> | </span>
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);">이은애</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="count">외</span>
# <span class="gap">|</span>
# <span class="publish" onclick="goClickSearchPage('pbcm',&quot;PB04390&quot;,&quot;\uC591\uC11C\uAC01&quot;);">양서각</span>
# </div>

# %%
#shopData_list > ul > li:nth-child(1) > div > div.prod_info_box
info_box = one.select_one("#shopData_list > ul > li:nth-child(1) > div.prod_area.horizontal > div.prod_info_box")
info_box
# Out:
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- 상품명 -->
# <span class="prod_name_group">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 제목', &quot;S000217120455&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span>인공지능입문</span>
# </a>
# </span>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);">손창호</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="gap"> | </span>
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);">이은애</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="count">외</span>
# <span class="gap">|</span>
# <span class="publish" onclick="goClickSearchPage('pbcm',&quot;PB04390&quot;,&quot;\uC591\uC11C\uAC01&quot;);">양서각</span>
# </div>
# <!-- //저자/출판사정보  -->
# <!-- 금액, 리스트 타입 버튼영역 -->
# <div class="prod_price_control">
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매/예약중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="price">
# <span class="val">12,600</span>
# <span class="unit">원 </span>
# </span>
# <span class="percent">10%</span>
# <span class="point">(700p)</span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매/예약중이 아닐떄-->
# <!--중고 장터일때-->
# </div>
# <!-- // 금액, 리스트 타입 버튼영역 -->
# <!-- 리뷰영역 -->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000217120455"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text">0.0</span>
# </span>
# </a>
# <!-- //리뷰영역-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!--바로드림 전용상품이 아닐경우-->
# <!-- 배송정보 영역 -->
# <div class="prod_order_state">
# <div class="order_state_desc">
# <!--<span>지금 주문하면</span> -->
# <span class="fw_bold">7/31(목)</span>
# <span>출고예정</span>
# <button class="btn_tooltip_sm" id="btnTooltipDelivery" type="button">
# <span class="ico_info"></span>
# <span class="hidden">팝업 열기</span>
# </button>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 이벤트 정보 -->
# <!-- // 이벤트 정보 -->
# <div class="prod_price_control">
# <div class="right_box">
# <!--좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9788955685329" data-pid="S000217120455" id="searchWishItemInfo_S000217120455" name="001_001_S000217120455_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_circle has_val" data-cmdtcode="9788955685329" id="S000217120455_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000217120455");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217120455_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <button class="btn_cart_circle" onclick='searchResultCartClickEvent(false, "S000217120455");' type="button"><span class="ico_cart"></span><span class="hidden">장바구니 담기</span></button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# </div>
# </div>
# </div>

# %%
title = info_box.select_one("#shopData_list > ul > li:nth-child(1) > div > div.prod_info_box > span").text
print(title)
print("-"*100)
title.replace("\n", " ").strip()
print(title)
# Out:
# [국내도서]
# 인공지능입문
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# [국내도서]
# 인공지능입문

# %%
info_box.text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n[국내도서]\n인공지능입문\n\n\n\n\n\n\n\n\n\n\n\n\n손창호\n\n저자(글)\n | \n\n이은애\n\n저자(글)\n외\n|\n양서각\n\n\n\n\n\n\n\n\n\n\n\n12,600\n원\xa0\n\n10%\n(700p)\n\n\n\n\n\n\n\n\n\n\n\n0.0\n\n\n\n\n\n\n\n\n\n7/31(목)\n출고예정\n\n\n팝업 열기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n관심 등록\n0\n\n\n\n\n\n\n\n\n\n\n\n장바구니 담기\n\n\n\n\n\n'

# %%
info_box = book.find("div", class_= "prod_info_box")
info_box
# Out:
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- 상품명 -->
# <span class="prod_name_group">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 제목', &quot;S000217120455&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span>인공지능입문</span>
# </a>
# </span>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);">손창호</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="gap"> | </span>
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);">이은애</a>
# <!--인물역할코드 페이지-->
# <span class="type">저자(글)</span>
# <span class="count">외</span>
# <span class="gap">|</span>
# <span class="publish" onclick="goClickSearchPage('pbcm',&quot;PB04390&quot;,&quot;\uC591\uC11C\uAC01&quot;);">양서각</span>
# </div>
# <!-- //저자/출판사정보  -->
# <!-- 금액, 리스트 타입 버튼영역 -->
# <div class="prod_price_control">
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매/예약중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="price">
# <span class="val">12,600</span>
# <span class="unit">원 </span>
# </span>
# <span class="percent">10%</span>
# <span class="point">(700p)</span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매/예약중이 아닐떄-->
# <!--중고 장터일때-->
# </div>
# <!-- // 금액, 리스트 타입 버튼영역 -->
# <!-- 리뷰영역 -->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000217120455"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text">0.0</span>
# </span>
# </a>
# <!-- //리뷰영역-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!--바로드림 전용상품이 아닐경우-->
# <!-- 배송정보 영역 -->
# <div class="prod_order_state">
# <div class="order_state_desc">
# <!--<span>지금 주문하면</span> -->
# <span class="fw_bold">7/31(목)</span>
# <span>출고예정</span>
# <button class="btn_tooltip_sm" id="btnTooltipDelivery" type="button">
# <span class="ico_info"></span>
# <span class="hidden">팝업 열기</span>
# </button>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 이벤트 정보 -->
# <!-- // 이벤트 정보 -->
# <div class="prod_price_control">
# <div class="right_box">
# <!--좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9788955685329" data-pid="S000217120455" id="searchWishItemInfo_S000217120455" name="001_001_S000217120455_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_circle has_val" data-cmdtcode="9788955685329" id="S000217120455_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000217120455");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217120455_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--결제기능 버튼 정책 레이아웃-->
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <button class="btn_cart_circle" onclick='searchResultCartClickEvent(false, "S000217120455");' type="button"><span class="ico_cart"></span><span class="hidden">장바구니 담기</span></button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# </div>
# </div>
# </div>
